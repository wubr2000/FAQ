# %%
import pandas as pd
import numpy as np
import sys
import logging
import seaborn 
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
from time import time

from sklearn import metrics
from sklearn.metrics.pairwise import linear_kernel,pairwise_distances
from sklearn.feature_extraction import text as txt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer, HashingVectorizer
from sklearn import decomposition

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation

from optparse import OptionParser

import bs4 as bs4
import re, sys

from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from nltk.tokenize.regexp import WordPunctTokenizer
import nltk

import gensim
from gensim import corpora, similarities, models
from gensim import matutils

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
forum = pd.read_csv("statsLearningForum.csv", quoting = 2, header = None, 
                    escapechar = "\\", encoding = "ISO-8859-1")

# %%
forum.columns = ["anon_screen_name", "type", "anonymous", "anonymous_to_peers", 
                 "at_position_list", "user_int_id", "body", "course_display_name", 
                 "created_at", "votes", "count", "down_count", "up_count", "up", "down",
                 "comment_thread_id", "parent_id",  "parent_ids", "sk","extra"]

# %%
pd.options.display.max_colwidth=110
#forum.head()

# %%
del forum["anon_screen_name"]
del forum["at_position_list"]
del forum["extra"]
del forum["course_display_name"]

# %%
forum.body.head()
# Out:
# 0    Welcome to the discussion forum! We are hoping this will be a useful place for us to discuss anything rela...
# 1                                           Thank you , Sir!\nIts great to have this Stat learning class from you.
# 2                                                Great to have online free textbook - here's to some "R" learning.
# 3                                                  Will we be able to download the videos as in other edX courses?
# 4                                                     FYI this is not an edX course but a Stanford OpenEdX course.
# Name: body, dtype: object

# %% [markdown]
# ##Text Cleaning Functions

# %%
#Text Cleaning Functions
def mrclean(text):
    '''
    NAME
            mrclean
    SYNOPSIS
            Cleans incoming text
    DESCRIPTION
            Removes all untranslatable unicode
    '''
    c = ['\xe2','\x80','\x93','\xc2','\xa0','\n', '\r', '\u2019', '\n\n', '\x96', 
         'zipredac', 'phoneredac', 'nameRedac_anon_screen_name_redacted']  
    return re.sub('[%s]' % ''.join(c), '', text)

def soupText(eText):
    '''
    NAME
            soupText

    SYNOPSIS
            Removes all the HTML tags using BeautifulSoup

    DESCRIPTION
            Explicitly calls utf-8, replaces all double quotes with single and calls on helper function mrclean
    '''
    eText = str(eText.encode("utf-8").replace("'",'"') )
    soup = bs4.BeautifulSoup(eText)
    cleanText = soup.findAll(text=True)  #.get_text()
    return mrclean(''.join(cleanText))

# %% [markdown]
# ##Group all comments together first by `comment_thread_id` and

# %%
#Need to figure out how comments and questions are grouped together
#forum[forum.type == "CommentThread"].head()

#Concatenate all comments together that has the same "comment_thread_id" 
#- i.e. jam all the comments on one question together - this should be better for analysis
concat_comments = forum[forum.type=="Comment"].sort("comment_thread_id").groupby("comment_thread_id").body.sum()

grouped_comments=[]
for c in concat_comments:
    unicode(c)
    soupText(c)
    grouped_comments.append(c)

# %% [markdown]
# ##Stopwords, Lemmatizer, and TfidfVectorizer

# %%
#Discussion forums specific stopwords
additional_stop_words = [
                         "zipredac","phoneredac","nameRedac_anon_screen_name_redacted", 
                         "explanation", "helpful", "yes",
                         "agree","excellent","dear", "thanks",
                         "ok", "cool", "idea", "guys",
                         "hello", "student", "sorry", "makes",
                         "sense", "nice", "meet", "yeah", "wow",
                         "hint", "post", "understand", "helped",
                         "www","http","https","org","web","en","wiki","wikipedia","youtube","edu","com","://"
                         ]

# %% [markdown]
# >Token-level analysis such as stemming, lemmatizing, compound splitting, filtering based on part-of-speech, etc. are not included in the scikit-learn codebase, but can be added by customizing either the tokenizer or the analyzer. Here’s a TfidfVectorizer with a tokenizer and lemmatizer using NLTK:

# %%
class LemmaTokenizer(object):
    '''Scikit learn requires the tokenizer to be a callable class if custom made'''
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]

# %% [markdown]
# > Adjusting for "outliers"
# - Adjusting `min_df` and `max_df` affects the results ALOT!!! They will essentially get rid of "OUTLIERS". Tell function to ignore these words because they occurred in either too many (`max_df`) or in too few (`min_df`) documents.
#
# - Setting `min_df`= X means that calculation will include only words that appear in at least X documents. This will throw out many really weird, idiosyncratic, or made-up words that appear rarely and that are not germane to the comment.
#
# - Setting `max_df` = Y means that calculation will exclude words that appear over and over again in every documents. For example, in these forum discussions, there are alot of "thanks", "good", "agree","helpful","helps", "thanks alot" type of words that will throw off calculation. Again, they are not germane to the discussion but will throw off the calcuation. `max_df` is not that relevant if `sublinear_tf` is also turned on since they both do similar things.
#
# - The `sublinear_tf` parameter, when True, transforms the term frequency calculation to: tf = 1 + log(tf).
#
# - This transformation, as the name implies, is sublinear, which in practice lessens the effect of frequently occurring words. Since this calculation is only for the term frequency—and thus only affects the numerator of the tf-idf calculation—having a sublinear transform is a good way to reduce the effect of very common words.
#
# - Bigrams and higher tend to make the results worse.
#
# - NLTK WordNetLemmatizer really screwed things up...

# %% [markdown]
# >Need to throw away URLs in bag of words

# %%
n_samples = len(grouped_comments)
n_features = 10000

tfidf = TfidfVectorizer(min_df = 10, 
                         #max_df =.99,
                         max_features = n_features, 
                         stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words),
                         #tokenizer = LemmaTokenizer(),
                         sublinear_tf=True,
                         ngram_range=(1,2),
                         )

counts = tfidf.fit_transform(grouped_comments[:n_samples])
X = TfidfTransformer().fit_transform(counts)

print X.shape
print len(grouped_comments)
type(X)
# Out:
# (1071, 1584)
# 1071
# scipy.sparse.csr.csr_matrix

# %% [markdown]
# ##K Means Clustering

# %%
#K-means clustering analysis

km = KMeans(n_clusters=30, init='k-means++', max_iter=100, n_init=1,
                verbose=True)
km_fit = km.fit_transform(X)
km_fit.shape
# Out:
# Initialization complete
# Iteration  0, inertia 1007.182
# Iteration  1, inertia 957.696
# Iteration  2, inertia 947.606
# Iteration  3, inertia 941.538
# Iteration  4, inertia 939.290
# Iteration  5, inertia 938.914
# Iteration  6, inertia 938.788
# Converged at iteration 6
# (1071, 30)

# %% [markdown]
# Below is from a [Stackoverflow article](http://stackoverflow.com/questions/12497252/how-can-i-cluster-document-using-kmean-flann-with-python):
#
# There is one big problem here: K-means is designed for Euclidean distance.
#
# The key problem is the mean function. The mean will reduce variance for Euclidean distance, but it might not do so for a different distance function. So in the worst case, k-means will no longer converge, but run in an infinite loop (although most implementations support stopping at a maximum number of iterations).
#
# Furthermore, the mean is not very sensible for sparse data, and text vectors tend to be very sparse. Roughly speaking the problem is that the mean of a large number of documents will no longer look like a real document, and this way become dissimilar to any real document, and more similar to other mean vectors. So the results to some extend degenerate.
#
# For text vectors, you probably will want to use a different distance function such as cosine similarity.
#
# And of course you first need to compute number vectors. For example by using relative term frequencies, normalizing them via TF-IDF.
#
# There is a variation of the k-means idea known as k-medoids. It can work with arbitrary distance functions, and it avoids the whole "mean" thing by using the real document that is most central to the cluster (the "medoid"). But the known algorithms for this are much slower than k-means.

# %% [markdown]
# ##K-Medoids Clustering
# > Good for very sparse matrix and also can use other distance measures
#
# > Rather than using the mean (which is usually not a real datapoint), K-medoids uses a particular datapoint as the centroid. This makes K-medoids less sensitive to outliers. And in case of text, can give an actual "representative" document of a topic.
#
# Valid values for metric are:
# from scikit-learn: [‘euclidean’, ‘l2’, ‘l1’, ‘manhattan’, ‘cityblock’]
# from scipy.spatial.distance: [‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘correlation’, ‘cosine’, ‘dice’, ‘hamming’, ‘jaccard’, ‘kulsinski’, ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’] See the documentation for scipy.spatial.distance for details on these metrics.

# %%
#K-Medoid
#Can pass in other distances for K-Medoids
import Pycluster
from Pycluster import kmedoids

distances = pairwise_distances(X, metric='euclidean', n_jobs=1)
nb_clusters = 40
clusterid, error, nfound = Pycluster.kmedoids(distances, nclusters= nb_clusters, npass=100)

# %%
#Look at the actual comments that are central to each cluster:
medoids = list(set(clusterid))

for m in medoids:
    print "------------------------"
    print "medoid ", m, ":", grouped_comments[m]
# Out:
# ------------------------
# medoid  514 : See [here][1].  Dividing by n-1 gives an unbiased estimate of the sample variance, but NOT of the sample standard deviation.  Taking the square root introduces some bias.
#
#
#   [1]: http://en.wikipedia.org/wiki/Standard_deviation#Corrected_sample_standard_deviationThanks, MikeML, I am mostly ok with the difference.
#
# What confuses me is why somebody would want a biased estimator? I.e. why not always dividing by n-1 and getting an unbiased estimator?
#
# Greeting from a fellow bio-stats trooper !!! In the slide 18 in the linked pdf, I think the n-1 is assumed in calculating $SD(	heta)$, otherwise the procedure would use a biased estimator of the sample standard deviation. See slides 18-20 in lecture 4 of biostats course [1].
#
# [1] http://github.com/bcaffo/Caffo-Coursera/raw/master/lecture4.pdf"*It has always been quite confusing to me when to use n-1 and when to use n. I would also appreciate some guidance about this point.*"
#
# Divide by n-1 to get an **unbiased** estimator: *low bias, high variance*
#
# Divide by n to get a biased estimator: *high bias, low variance*
#
# This course covers it well: https://www.coursera.org/course/biostats
#
#
# The formula on slide 16 is for estimating the **sample standard deviation** of **validation errors in each fold**. We need to divide the **sample standard deviation** by sqrt(K) to obtain the **standard error of cross-validation estimate**. It's explained really well here: http://www.stat.cmu.edu/~ryantibs/datamining/lectures/18-val1-marked.pdf. Someone please correct me if I am wrong.This has something about using n-1 instead of n to try to correct some of the bias in the estimate of the population SD. [1]
#
# It has always been quite confusing to me when to use n-1 and when to use n. I would also appreciate some guidance about this point.
#
# [1] I have just found that this is called Bessel's correction
# https://en.wikipedia.org/wiki/Bessel%27s_correctionThanks all for the comments.@alhf appreciate the post, but seemed to me to hinge on a semantic issue of "zero deviation" vs "no deviation" combined with the concept of degrees of freedom which wasn't totally clear. so couldn't really put me over the top in terms of understanding. However I found the "source of the bias" in the [Bessel correction][1] page to contain a really good example.
#
#
#   [1]: http://en.wikipedia.org/wiki/Bessel%27s_correction@DanBowman:
#
# Good point (about Jensen's inequality). Thanks for posting
# about that. (I've added some "edits" to the original post)
#
# @boethian:
#
# Thanks for the feedback.  I guess the "degrees of freedom"
# idea did was not sufficiently clear in my post.  The degrees
# of freedom has a nice geometrical interpretation [*] in an
# n-dimensional space (where n is the sample size).  I guess I
# was trying to "translate" this into simpler language and the
# idea didn't come across so clearly.
#
# Anyway thanks for reading and giving feedback. (and also
# for the suggested reference.)
#
# ----
#
# [*] The dimension of the space of deviations from the sample
# mean.@pochete:
#
# > This has something about using n-1 instead of n to try to
# > correct some of the bias in the estimate of the population
# > SD.
# >
# > It has always been quite confusing to me when to use n-1 and
# > when to use n. I would also appreciate some guidance about
# > this point.
#
# On the subject of the unbiased estimator of sample standard
# deviation.
#
# The following formula for sample standard deviation, with
# the division by $(n-1)$, and not $n$, gives an unbiased
# estimate of the standard deviation.
# [Edit: Well, not quite. See DanBowman's post]
#
# $
# ar x)^2over n - 1}
# $
#
# The $i$ in the $Sigma$ goes from $1$ to $n$, where $n$ is
# the number of observations in the sample.
#
# If we square it, to get the sample variance, we have
#
# $
# ar x)^2over n - 1}
# $
#
# [Edit: It is this variance which is unbiased. See DanBowman's post]
#
#
# In words, we're getting an estimate of the variance of $X$
# by adding up all the squared deviations of all the $n$
# observations, then dividing by $n-1$ to get an "average
# squared deviation".
#
# At first it may seem surprising that the "average" is
# calculated by dividing by $n-1$ instead of the total number
# of observations, $n$.
#
# Because we're measuring deviations of the sample values
# *about their own sample mean*, we don't really have $n$
# points worth or variability, only $n-1$. (That is, we have
# only $n-1$ "degrees of freedom".)
#
# If we *were* to divide by $n$, we would systematically
# underestimate the true variability of $X$.  (we would get a
# *biased* estimate).
#
# Consider the extreme case where the sample size is 1 ($n=1$).
# Suppose the single observation is $x_1=4$.
# Well, we can start by calculating the sample mean:
#
# ar x = {Sigma x_i over n} = { 4 over 1 } $
#
# So far, so good.
# Now let's try to estimate the variability, by getting the sum
# of squared deviations from the sample mean.
#
# ar x)^2 } = { (4 - 4)^2 } = 0 $
#
# That's NO deviation from the mean.  Is a sign that there is
# no variability in the $X$ variable?  Of course not.  With
# only one observation, we put the sample mean at that
# observation.  And when we measured the deviation from that
# point, of course it was zero.
#
# If we treat that zero squared deviation as being the total
# deviation for one observation then take the average by
# dividing by one, we'll get an "average" squared deviation of zero
#
# ar x)^2 over n } = { (4 - 4)^2  over 1} = 0 $
#
# But we can't really treat this as an estimate of the
# varianc
# ------------------------
# medoid  902 : ![enter image description here][1]
#
# Hope this helps ~
#
#
#   [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>08.png
# ------------------------
# medoid  9 : ???????????????????????????????????????????I am happpy to meet you here.
# ????????????
# ------------------------
# medoid  139 : I've been tearing my hair over these questions. I thought I knew something about linear regression, but I have scored so low that it is obvious I don't know anything at all. Commiserations to anyone else in the same category. Probably if I had checked off the inverse of what I thought to be true I might have succeeded. Hoping the rest of the course will be enlightening.The confidence interval applies to the range encompassing the value, not the value falling within the range. The second option speaks of the probability that the true parameter lies between 0.4 and 0.5, which is not correct.What's wrong with the second option? Because it says "linear regression", which is too restrictive?
#
# By the way, I also thought the 3rd option is not right because no 95% is specified.I agree with both DougLearner and KirillV. See also my explanation here:
#
# https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2014-course-material-feedback/threads/52e55be09b16c7d<phoneRedac>4dFailing to explicitly specify 95% confidence for each interval in that question was a mistake by the teaching staff. For that question, you may assume all confidence intervals are 95%. For why the second and third options are incorrect, see my explanation here:
#
# https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2014-course-material-feedback/threads/52e55be09b16c7d<phoneRedac>4dThe confusion comes from the slide 7 of the lecture, where it is stated that "with 95% probability, the range will contain the true unknown value of the parameter". This can be understood as the value belongs to the range with that probability since the range is computed by the specific formula. I think it is not stressed enough during the lecture the real meaning of the confidence interval. Moreover, professor Tibshirani said: "if you want a confidence interval of 95%, we take the estimate of our slope plus or minus twice the estimate of the standard error. And this, ..., this will contain the true value, the true slope, with probability 0.95.", which most people would understand as the probability that the true parameter lies in this interval is 95%.I had multiple goes on this, which I believe I chose the right two options on one of the 5 submissions, yet still got it marked wrong!? Is there anyway of you checking this by looking at my account? I see there were some confusion as you have mentioned above.I agree.
# <nameRedac_anon_screen_name_redacted>The last option doesn't include a confidence level, so I just assumed 95% as the previous two options specified the 95%.
# ------------------------
# medoid  910 : I think so: seems to me that's data snooping!Actually PCA is only used for transformation. Then use 1:300 for fitting & 301:1300 for prediction.
# CheersGreat point. I feel the same too. Using the x's from the test data will not allow us to to validate the performance of our factor loadings on say a new set of x'sIt has an influence and actually computing the PCA on the training set only yields to more variance explained and to a lower mean squared error in test!This could be an easy one to answer Imguess. You should run the analysis twice once with the test set and once without and see whether thos has an influence. If it does it is data snooping, clearly.
#
# cheers
# <nameRedac_anon_screen_name_redacted>I think PCA is a data transform like converting from Cartesian to polar coordinates. The transform does not change the data, but it makes it easier to work with. The difference with PCA is that variation in the data defines the new reference frame.It is true that PCA is a feature extraction method but similarly, converting your coordinates from Cartesian to polar because you know the test set can be linearly separated in this new space would be data snooping.But extracting the principal components is part of building the model. I think it's data snooping!
#
# I'm expecting profs. answering this important question...Yes, I wondered the same thing. How can the test set error be valid when the test set is used to build the model? It's pretty similar to doing feature selection before cross-validation, which we were warned against.
# ------------------------
# medoid  344 : Sorry about the formatting. It appears to be automatic.
# ------------------------
# medoid  147 : [This answer][1] explains it really well. Especially the geometric explanation.
#
#
#   [1]: https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2014-course-material-feedback/threads/52e819e84c0c9bd8f<phoneRedac>It's not discussed anywhere in the book period.  It's mentioned *briefly* in a question ('conceptual example') under section 4.7 question #4.
#
# I'm probably the exception to the rule here, not coming in with a math-heavy background, but that (2.2 R2) seemed like a pretty off-the-wall thing to throw in at this point in the course.
#
# YMMV.Hypercube is just a n-dimensional equivalent of 3D cube, as for example is square in 2D. The total volume of the n dimensional cube is $V_n = a^n$, where $a$ is a side length. In this problem, the side length is 1, so the volume in any dimension stays 1.In the lecture on slide 8, there is a graph showing "Fraction of volume" on the x-axis and "Radius" on the y-axis. Then the plot shows how increasing dimensionality of the feature vector increases the radius of the boundary region. I'm unsure how the plot was calculated, but the Quiz question pertains to determining the fraction of volume for p=50.Memilanuk
# Thanks for the reply.@Ed53
# I was also baffled by this question, as it appears to be un  related to the topics covered by the lecture. I would gladly try to solve it if you could explain the "intuitive dimension" approach in more detail. ThanksI agree.  I thought the course was going to be more about how to select and use appropriate statistical models to explore various data sets.  I do not know what a hypercube is, let alone have any idea how to solve for 2.2 R2.  Furthermore, it is impossible to get an explanation of the answer without getting the answer correct.Then, could you please provide your example here? The lecture does not make it very explicit and the wording is convoluted.Try solving this problem in "intuitive dimensions" (1D, 2D, 3D) first, draw the boundaries on a 1D line, than on 2D square, you should understand it from there, and you could check it on 3D, the generalization on n dimensions applies easily (it really does, don't get discouraged).
# ------------------------
# medoid  1049 : I laughed!
# ------------------------
# medoid  26 : Hi Gaurav,
#
# Same here. I am somewhat familiar with Python and do not know R. I am going to try and use Pythona and skip the R sessions. I don't see the point of learning R.  Maybe we can share exoeriences here.
#
# Regards, <nameRedac_anon_screen_name_redacted>.Hi MarcD,
#
# Thanks. I have working knowledge of R and used it for last 3 years. I moved to python because of the limitations I felt with R. I feel python = perl + R... its a good decision to move forward with python but knowing R is always useful because of community support. I would be doing assignments with python too ... I would be happy share any experiences with you.Hi all,
#
# my colleagues at DataRobot and I were pretty excited when we first heard about the course. Since we are using both Python and R to build statistical learning software, we decided to create a series of blog posts that follow along with the course and show how many of the statistical learning techniques presented in the course can be applied using tools from the Python ecosystem such as [scikit-learn][1] and [statsmodels][2]. You can find the first posting here: http://www.datarobot.com/category/stat-learning/
#
# We hope that we can give some insight to people who are new to Python but familiar with statistical learning packages in R. For my part, I've co-authored some of the algorithms in scikit-learn that are covered in this course and there are often some subtle differences between implementations in scikit-learn vs. their reference implementations in R (e.g. gbm, randomForest) that are worth knowing.
#
# best,
#  <nameRedac_anon_screen_name_redacted>
#
#
#   [1]: http://scitkit-learn.org
#   [2]: http://statsmodels.sourceforge.netHi GJain,
#
# There are questions about R the programming language.  Those might be hard to answer with Python...
#
# The course/book is centered around R and has sessions that exist specifically to teach R.  You should feel free to use any language, but might not get the full benefit of those sections if you are using Python.  Also, will only be providing support for R.I will say that if you want to do data analysis,  then learning R is likely a good investment in your effort. I am sure many of the things we will do can be done with Python, but it may also be that some can't be done as easy (for example say there is an existing routine to do something in R and nont in python, of course you can write your own but that may be time consuming)
#  If I was taking the class and if it was in Python, I would do Pyuthon as opposed to try to force R - when I took the ML class from stamford that used Octave I used it as an opportunity to learn octave, - just my 5 centsPeter... this is a great resource.... thanks for sharing with us ...This is awesome and greatly appreciated. I'm mainly a pythonista, but for consistency with the course I'll try to do the assignments in R. I'll be sure to check out your blog to learn how to do this stuff in Python, though, and learn about any differences in approach. I've used a bit of scikit-learn/numpy/scipy in the past, but I've never used pandas or statsmodels.I was also planning on attempting to do the exercises in both languages concurrently. I have a strong python background and have been coding it as my primary language for my own research, but my work does not require the use of libraries like scikit-learn and pandas, etc. I'm definitely curious about R, and I thought it would be a good opportunity to learn it as well as teach myself about a part of the scipy stack that I haven't played with too much. I'm looking forward to following the blog.So far, pretty much all the exercises have been doable in either Python (w/ pandas and statsmodels) or pencil and paper. I only fired up R to answer the "what does R say when you type this" kind of question.
#
# (Nice to see you here too, Peter :)I´m starting both languages at the same time... The blog sounds interesting. I will be reading it frequentlyHi Rito,
# I agree its good to know but I still feel python provides more power.
#
# Thanks@Gaurav
#
# I am also a bit more comfy with Python than with R. Still R is unparalleled in some areas, as I have seen around. I would try to learn as much as possible about R & Stat.
#
# Cheers.Cool! that sure sounds interesting!
#
# Btw, thanks for the effort you're putting in it for us to benefit!We've published the first posting http://www.datarobot.com/blog/introduction-to-python-for-statistical-learning/ -- if you have questions or remarks please leave a comment.Thanks Smgross for the insights. I understand... they have to choose one language and R is very popular.
# ------------------------
# medoid  283 : Thanks for telling us!
# ------------------------
# medoid  34 : Very inspiring interview indeed. Thanks!
# ------------------------
# medoid  940 : yes
# ------------------------
# medoid  816 : The '~" sign used in the expressions confused me, especially because it is used in Review questions in segment on R ("models" sign!)Thanks for your help. One of the subtleties that would have taken me a while to pick up.  I really appreciate it.The data.frame testdat has not the same colnames as dat, so the svmfit doesn't recognize it when making predictions.
#
# Check colnames(testdat), colnames(dat). You can simply use
#
#     testdat=data.frame(xtest, y = as.factor(ytest))
#
# or directly
#
#     colnames(testdat) <- colnames(dat)I've tried using the code in lecture and the book and here is what I have come up with:
#
#        x=matrix(rnorm(1000),100,10)
#        y=rep(c(0,1),c(50,50))
#        x[y==1,1:5]=x[y==1,1:5]+1
#
#        library(e1071)
#        dat=data.frame(x,y=as.factor(y))
#        svmfit=svm(y~.,data=dat,kernel="radial",scale=FALSE)
#
#        xtest=matrix(rnorm(1000), 100,10)
#        ytest=sample(c(0,1), 100, rep=TRUE)
#        xtest[ytest==1,1:5]=xtest[ytest==1,1:5] + 1
#        testdat=data.frame(x=xtest, y=as.factor(ytest))
#        ypred=predict(svmfit, testdat)
#        table(predict=ypred, truth=testdat$y)
#
# it seems to work until I get to the next to last line, the ypred statement.  R will spit out "Error in eval(expr, envir, enclos) : object 'X1' not found"  Is there any idea what might be wrong?
#
# Also, once I get this idea down, I will need to find the error and run it in a loop say 1000 times?
#
# Thanks for any help!Yes, that is exactly what I have done.
# 1000 cases for the test set should be sufficient, however I would repeat more than 2-3 times. I used 1000 iterations, however you probably don't need that much.Thank you for explaining the expression.  I am still having problem with this problem.
#
# I have generated a data frame with 100 points as described in the problem.
# I use the svm R function as explained in class without specifying any cost parameter.
#
# I am not quite sure what the next step is.  Am I supposed to generate a lot more test data with the same characteristics, use svmfit to predict and find the number of wrong predictions relative to the number of points and repeat the test 2-3 times.  How large is a large data set ?  Would generating 1000 points be considered "large data set" ?  I am not sure how other way could I find the expected error ?
#
# Would appreciate very much if someone could point me to the right direction. I already made 2 mistakes out of 5 trials.  ThanksThe co-variance matrix (Sigma) is a 10 dimensional matrix. In both cases it is identity matrix. We have two distributions with different means and are being asked to classify the data. Hope that helpsThanks for decoding the (previously unintroduced) terminology in the question.Thanks, that has clarified it. I shall try 9.R.1, 9.R.2 and 9.R.3 accordingly.I interpreted it as follows
#
# $%
# ightarrow
# %$
# we are using 10 dimensions:
# $%
# x_i^{(1)},x_i^{(2)},x_i^{(3)},...,x_i^{(10)}
# %$
#
# If
# $%
# y=0
# %$
# then all of those have a normal distribution with
# $%
# mu=0
# %$
# and
# $%
# sigma=1
# %$
# $%
# (N{(0,1)})
# %$
# .
#
# If
# $%
# y=1
# %$
# then
# $%
# x_i^{(1)},...,x_i^{(5)}
# %$
# have a normal distribution with $%
# mu=1
# %$
# and
# $%
# sigma=1
# %$
# $%
# (N{(1,1)})
# %$
# and
# $%
# x_i^{(6)},...,x_i^{(10)}
# %$
# have a normal distribution with $%
# mu=0
# %$
# and
# $%
# sigma=1
# %$
# $%
# (N{(0,1)})
# %$
# .Thanks.
# ------------------------
# medoid  433 : Ch1 Introduction
#
# 1.1 Opening Remarks
# (https://www.youtube.com/watch?v=2wLfFB_6SKI)
# 1.2 Examples and Framework
# (https://www.youtube.com/watch?v=LvaTokhYnDw)
#
# Ch 02 Overview of Statistical Learning
#
# Introduction to Regression Model
# (https://www.youtube.com/watch?v=WjyuiK5taS8)
# 2.2 Dimensionality and Structured Models
# (https://www.youtube.com/watch?v=UvxHOkYQl8g)
# 2.3 Model Selection and Bias-Variance Tradeoff
# (https://www.youtube.com/watch?v=VusKAosxxyk)
# 2.4 Classification
# (https://www.youtube.com/watch?v=vVj2itVNku4)
# 2.R Introduction to R
# (https://www.youtube.com/watch?v=jwBgGS_4RQA)
# Interview with John Chambers
# (https://www.youtube.com/watch?v=jk9S3RTAl38)
#
# Ch 03 Linear Regression
#
# 3.1 Simple Linear Regression
# (https://www.youtube.com/watch?v=PsE9UqoWtS4)
# 3.2 Hypothesis Testing and Interval Confidence
# (https://www.youtube.com/watch?v=J6AdoiNUyWI)
# 3.3 Multiple Linear Regression
# (https://www.youtube.com/watch?v=1hbCJyM9ccs)
# 3.4 Some Important Questions
# (https://www.youtube.com/watch?v=3T6RXmIHbJ4)
# 3.5 Extensions of the linear models
# (https://www.youtube.com/watch?v=IFzVxLv0TKQ)
# 3.R Linear Regression in R
# (https://www.youtube.com/watch?v=5ONFqIk3RFg)
#
# Ch4 Classification
#
# 4.1 Introduction to Classification Problems
# (https://www.youtube.com/watch?v=sqq21-VIa1c)
# 4.2 Logistic Regression
# (https://www.youtube.com/watch?v=31Q5FGRnxt4)
# 4.3 Multivariate Logistic Regression
# (https://www.youtube.com/watch?v=MpX8rVv_u4E)
# 4.4 Logistic Regression - Case Control Sampling and Multiclass
# (https://www.youtube.com/watch?v=GavRXXEHGqU)
# 4.5 Discriminant Analysis
# (https://www.youtube.com/watch?v=RfrGiG1Hm3M)
# 4.6 Gaussian Discriminant Analysis - One Variable
# (https://www.youtube.com/watch?v=QG0pVJXT6EU)
# 4.7 Gaussian Discriminant Analysis - Many Variable
# (https://www.youtube.com/watch?v=X4VDZDp2vqw)
# 4.8 Quadratic Discriminant Analysis and Naive Bayes
# (https://www.youtube.com/watch?v=6FiNGTYAOAA)
# 4.R Classification in R
# (https://www.youtube.com/watch?v=TxvEVc8YNlU)
#
# Ch05 Resampling Methods
#
# Interview with Bradley Efron
# (https://www.youtube.com/watch?v=6l9V1sINzhE)
# 5.1 Cross-Validation
# (https://www.youtube.com/watch?v=_2ij6eaaSl0)
# 5.2 K-fold Cross-Validation
# (https://www.youtube.com/watch?v=nZAM5OXrktY)
# 5.3 Cross-Validation: the wong and right way
# (https://www.youtube.com/watch?v=S06JpVoNaA0)
# 5.4 The Bootstrap
# (https://www.youtube.com/watch?v=p4BYWX7PTBM)
# 5.5 More on the Bootstrap
# (https://www.youtube.com/watch?v=BzHz0J9a6k0)
# 5.R Resampling in R
# (https://www.youtube.com/watch?v=6dSXlqYou can download the videos now and watch them whenever you want later.Thanks for the answer and does it include the videos ?I'm afraid I do not think so.Yes, I believe so.
# ------------------------
# medoid  820 : Thanks
# ------------------------
# medoid  310 : It would be great if the lecture videos are available anytime on YouTube.
# ------------------------
# medoid  568 : https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2<zipRedac>14/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2<zipRedac>14-course-material-feedback/threads/52fbd<zipRedac>17<zipRedac><zipRedac>bdb62c<zipRedac>1<zipRedac><zipRedac><zipRedac><zipRedac>3<zipRedac>
# ------------------------
# medoid  186 : Hi alhf,
#
# first of all, thanks a lot for the detailed, and very interesting, answer! However, I'm not convinced. Of course, if we define linear as "linear in the  **parameters** to be estimated", then for sure not only polynomial models, but even much more general models such as
#
# eta_2 Gamma^3(X_2)+epsilon$
#
# are linear.
#
# However, slide 1 of Chap. 3 clearly states that "Linear regression is a simple approach to supervised learning. It assumes that the dependence of $Y$ on $X_1,X_2,ldots X_p$ is linear". According to this definition, linear regression is linear not only in the **parameters**, but also in the **variables**, as also evident from its expression on slide 14:
#
# eta_p X_p + epsilon $
#
#  Since the question wasn't on **linear models** in general, but on **linear regression**, I don't see how the answer "Linear regression is very extensible and can be used to capture nonlinear effects" can be correct.
#
# ps on a side note, I didn't think it would be necessary to read the textbook in order to answer the quizzes. If this is the case, the instructors should state it more clearly -- don't get me wrong, it's wonderful that they let us read it for free, and I really appreciate it. But if I need to study it before answering the quizzes, I should be informed of that, if only to correctly allocate time for my study!just to say that I had exactly the same problem. We are talking about linear regression, and this multiple choice test should have been phrased more carefully. But I see there is a lot of nitpicking in the questions, e.g. R3.2.2.@AndreaPanizza The courses uses "linear regression" and "linear model" interchangeably. Also, re your point about not reading the course text, it *is* the course text and the video material can't possibly cover all of the things relevant to the course. It is entirely natural to expect students on any university course to read around the subject.> However, there was no hint to linear regression being able
# > to capture nonlinear effects. Was that in book? How can a
# > linear model capture nonlinear effects?
#
#
#
#
# The book mentions a couple of ways that linear regression
# can be used to model nonlinear effects --- polynomial
# regression and interaction terms.  Some references and
# extracts are below.
#
#
#
#
# page 90
#
#
#
#
# > **Non-linear Relationships**
# >
# > As discussed previously, the linear regression model (3.19)
# > assumes a linear relationship between the response and
# > predictors. But in some cases, the true relationship between
# > the response and the predictors may be non- linear. Here we
# > present a very simple way to directly extend the linear
# > model to accommodate non-linear relationships, using
# > polynomial regression.
#
#
#
#
# page 87
#
#
#
#
# > **Removing the Additive Assumption**
# >
# > ... One way of extending this model to allow for
# > interaction effects is to include a third predictor,
# > called an interaction term, which is constructed by
# > computing the product of X1 and X2.
#
#
#
#
# Note that the "linear" in "linear regression" means that the
# function is linear with respect to the **parameters** to be
# eta,$s, if you like.)
#
#
#
#
# That is, all the partial derivatives of the function with
# eta,$s) are constant.
# (This makes it easy to minimize the sum of squared residuals.
# Writing all the partial derivatives of the sum of
# squared residuals and setting them to zero gives a set of linear
# equations which are easy to solve.)
#
#
#
#
# The examples mentioned above are examples of linear
# regression in that sense.
#
#
#
#
# However they are non-linear with respect to the
# **variables** (the $x,$s).  This means that the response
# does not change by a constant amount for each unit change in
# one of the $x$ variables.  (The partial derivatives with
# respect to the **variables** are not all constant)@alhf,
#
# Brilliant! That's what I was looking for. The "trick" of defining new predictor variables (hinted to at the end of Chap. 3.3.2 in the book) indeed allows us to transform any linear model to
#
# eta_iX_i + epsilon$
#
# This is not necessarily a good idea: for example, if the model has interaction terms, such as
#
# eta_3X_1X_2 + epsilon$
#
# then introducing $X_3=X_1X_2$ leave us with a model which is indeed linear in the **parameters** AND in the **variables**, BUT with correlated predictors. And this causes all kinds of problems (slide 15 of Chap.3 and expecially Chap.3.3.3, paragraph 2, of the book).
#
# I understand now why linear regression has a lot of extensibility, as well as the ability to capture nonlinear effects. Still, I think the teachers should have hinted to all this stuff in the lectures, or at least pointed to the relevant section of the book, as they did on Slide 47 for other subjects. It was otherwise impossible to answer the question without previous knowledge of the topic. Thanks again, @alhf!Nitpicking and moocs go hand-in-hand. Comes from the range of abilities of participants.
#
# Most fun are courses where there is no assumed knowledge. You end up with  highly qualified people getting really upset because they can't put themselves back in the "beginner" frame of mind. And the beginners get upset because suddenly the forums are full of incredibly tecnical stuff.@AndreaPanizza
#
# > Of course, if we define linear as "linear in the parameters
# > to be estimated", then for sure not only polynomial models,
# > but even much more general models such as
# >
# eta_2 Gamma^3(X_2) + epsilon $
# >
# > are linear.
#
# You're right.  That's linear in the parameters, so you could
# definitely estimate it with linear regression.
#
# I might be careful about calling it a "linear model" in every context.
# For example, if you said "we modelled $Y$ in terms of $X_1$ and $X_2$ using
# a linear model", then that would suggest:
#
# eta_2 X_2 + epsilon $
#
# rather than the sort of non-linear form (in the variables $X_1$,
# $X_2$) above.
#
# > However, slide 1 of Chap. 3 clearly states that "Linear
# > regression is a simple approach to supervised learning. It
# > assumes that the dependence of Y on X1,X2,Xp is
# > linear". According to this definition, linear regression is
# > linear not only in the parameters, but also in the
# > variables, as also evident from its expression on slide 14:
# >
# eta_p X_p + epsilon $
#
# Yes, if you have a model of that form you can use the linear
# regression technique to fit it.
#
# As far as the linear regression technique goes, it doesn't
# matter where the $X_i,$s come from,  as long as you have
# numbers for them.
#
# So when it says,
#
# > "... assumes that the dependence of Y on X1, X2, ..., Xp
# > is linear".
#
# that's true, *but* the $X,$s can be whatever you want.
# This is where there is a lot of extensibility and the ability to
# capture nonlinear effects.
#
# From a regression point-of-view, the complex model above is just
#
# eta_2 X_2^prime + epsilon $
#
# in terms of two variables $X_1^prime$, $X_2^prime$, where
#
# $X_1^prime = e^{X_1} sin^2(X_1)$
#
# $X_2^prime = Gamma^3(X_2) $
#
# So, applying linear regression to the $Y$ and $X_i^prime$
# values will fit the model and give estimates for the
# eta,$s) of the model.  (Note that there are no primes,
# eta,$s --- they're the same as in the
# original model.)
#
# > Since the question wasn't on linear models in general, but
# > on linear regression, I don't see how the answer "Linear
# > regression is very extensible and can be used to capture
# > nonlinear effects" can be correct.
#
# This model has nonlinear effects:
#
# eta_2 Gamma^3(X_2) + epsilon $
#
# and linear regression can capture them.
#
# Of course,
# ------------------------
# medoid  315 : The terms are related to the log-likelihood of the null model (incercept only)and the fittel model, respectively. You can rewrite D(y) as follows:
#
# D(y) = -2log(null_likelihood/fitted_likelihood)
#
# You take logs because the likelyhood are very small numbers, so computational issues may arise. One multiplies by -2 to get a positive value with an approximate Xi-squared distribution.
#
# Finally, the bigger D(y), the better because the difference between model deviances is more likely to be significant.If you are using logistic regression for classification, then you can just choose the logit model with the lowest test set misclassification rate. Or if some errors are more costly than others (for example, in my industry, false positives are really costly), then I might choose the model with the lowest test set *weighted* misclassification rate. You could also look at the ROC curve and choose the model with the highest Area Under The Curve (AUC). However, when you use logistic regression for point estimates for probabilities or odds, things get really hairy.One can use measure called the Gini coefficient to compare logistic regression models. Gini is a summary of ROC curve which says how your model separates "good" and "bad" cases. Some statisticians use also the K-S statistics (maximal difference between CDF's of "good" and "bad" cases).
# If you want to test weather a model is valid I recommend the Hosmer-Lemeshow test.This is a really good question, and I hope someone from the staff will answer Mauricio's question. I would like to add a layer of complexity to the question. Logistic regression was introduced primarily as a tool to classify an observation based on $X$. If we are using logistic regression as a classifier, then rank-order will be very important. However, there are situations where I actually care about the point estimate (the odds or probability). Please tell us good metrics to measure rank-order and to measure goodness-of-fit (accuracy of the point estimates).Thank you for the hints.
#
# The confusion I'm having is that we've been hearing about how colinearity can cause some predictors to appear as very "not significant" as evidenced by large p-values ... yet receiving no formal guidance on how to address that model selection.  R output for logistic regression via glm() shows null and residual deviance ... but no mention is made of that in book/lecture.
#
# I take your comments to mean that the chapter on resampling will address the model selections concerns ... thus making deviance measures a less relevant concern.I think that the criteria for selecting between models is how the model performs on out of sample data. The insignificant terms are likely to overfit the training data. So that will render the model less valuable against the out of sample.Ch. 5 will cover techniques to overcome "test data is not available". Specifically, cross-validation. However, this still does not answer the question "how do I judge which of two logistic regression models is better"? In linear regression, you just calculate the test set MSE and choose the model with the lowest test set MSE. There is no equivalent concept to MSE in logistic regression.Can D(y) be calculated on a test data set knowing only the model parameters from the training data set?Performance against test data is always a great option.  Since it applies to any model, why bother with $R^2$ or $F$ in linear regression?  Why not go straight to testing?
#
# When I have many models to choose from, it would be nice to have a set of diagnostic criteria to identify which may be the best candidates to evaluate against test data.
#
# Also, if one model performs slightly better on one set of test data than another, how do I know how much of that difference is due to chance? If test data was plentiful, I could do multiple evaluations and see which model has the best long-run test performance.
#
# Since test data is sometimes difficult to obtain ... hence my motivation selection criteria of fitted models.Great questions (and conversation)!
#
# First, the deviance of a logistic regression model is very similar to RSS for many purposes.  The are analogues of the F-test using Chi-Sq distributions on deviance.
#
# The only sense in which an entire model can be tested for significance is by the Chi-Sq test for dropping all of the predictors.  Also, be careful about how you label those "insignificant" (I would say not significant) coefficients!  Just because a t-test says p<.05 does NOT mean that a variable is hurting your predictions.
#
# CV and resampling techniques to address model selection/hypothesis testing are popular because they require very few assumptions.  Logistic regression already has some peculiarities under misspecification (see our very own Will Fithian's research), so it is probably best to avoid doubling down too hard on assumptions that you don't need.Could you explain a little bit more on how deviance is calculated? I'm looking at the Wiki page, and I have no idea what's going on.
#
# ![deviance][1]
#
# ar y$).
#   [1]: http://upload.wikimedia.org/math/d/5/7/d57c4a2ed5584d2fdd80e2ead2b7d07d.png
# ------------------------
# medoid  188 : RE: ", I suggest that you pretend the question said "what is the effect of an additional 1000 dollars of radio ads if TV = <zipRedac>0000 dollars" and calculate it that way" ... your B2 term would be underestimated by a factor of 1000, right? since it does not have TV termThe question should have been self-contained. the reference to the 1000 units is as obscure as it possibly could have been.See slide 39 (Interpretation- continued), the last formula.Thank you, Kevin, for taking the time to explain it so thoroughly for us. It helped me tremendously. Thank you.nabramson, no. The 1000 is for the lecture example.
#
# For the quiz TV is 50 and then 250, while radio is 1.I was concerned about this one too. I don't agree with the "correct" answer as I don't think that the fact that TV budget is measured in thousands of dollars has been taken into consideration. Anyone else wonder about this?Are we to assume to take the difference from the $1000 budget? I still am confused.I really thought I understood what is going on but I am still puzzled. I thought the effect would be the gain of the slope from the fixed TV and radio values. This must not be the case as my answer is marked wrong for the effect of 1.0389 .50,250 and 1 WHAT? unit? $1's ? $1000's?.. I think a "unit" should mean $1000's which results in a red X (wrong answer".. so can the course instructors please clarify. thank you@feelosophy13 and @nabramson: you're very welcome! I'm glad to help.Thank you Kevin - best explanation - helped me a lot  :)Thanks Kevin. Your explanation really helped me understand too.The first step in understanding this question is to make sure you have a crystal clear understanding of what the coefficients indiciate.
#
# For example, let's take B2, which is 0.0289. That means that for every increase of 1 radio advertising "unit", there will be a 0.0289 increase in sales "units" (when in the presence of TV and the TV*radio interaction). As you can see in the book on page 16, 1 radio advertising "unit" is equal to 1000 dollars in spending, and 1 sales "units" is equal to selling 1000 of whatever they are selling (let's call them "widgets").
#
# Thus, a B2 of 0.0289 means that if you increasing your spending on radio by 1000 dollars, your sales will go up by 28.9 widgets. (Note that I'm ignoring the interaction effect for the moment, and also note that 28.9 is incorrect for a model that does not include the interaction effect.)
#
# Now let's get to the sales formula, which can be rewritten as follows:
#
#     sales = B0 + (B2 + B3*TV)*radio + B1*TV + e
#
# We have rewritten it so that the coefficient of radio is modified to be a function of TV spending. In other words, the radio coefficient takes into account the interaction effect. Let's now focus on the radio coefficient:
#
#     B2 + B3*TV
#
# That means that if you increase your spending on radio by 1000 dollars, your sales will go up by 28.9 widgets, plus an additional 1.1 widgets for every unit spent on TV ads. And again, remember that 1 TV unit equals 1000 dollars in spending.
#
# Now let's get to the actual question: "According to the model for sales vs TV interacted with radio, what is the effect of an additional 1 dollar of radio advertising if TV = <zipRedac>0 dollars?"
#
# If you understand what I have written above, this is a simple calculation. If you get confused about the units, I suggest that you pretend the question said "what is the effect of an additional 1000 dollars of radio ads if TV = <zipRedac>0000 dollars" and calculate it that way, and then divide your answer by 1000.
#
# I'm sure there is a simpler way of explaining this, but this is how I walked through the problem in my head.
#
# <nameRedac_anon_screen_name_redacted>Are we supposed to give the exact figure, round to 2 decimal points or the nearest whole number?
# ------------------------
# medoid  395 : I'm not getting the data to appear either.
#
# > load("F:/Statistical Learning (Stanford University)/Datasets/5.R.RData")
# > summary("F:/Statistical Learning (Stanford University)/Datasets/5.R.RData")
#    Length     Class      Mode
#         1 character character
# > names("F:/Statistical Learning (Stanford University)/Datasets/5.R.RData")
# NULL
#
# You get the same result using single quotes too:
#
# > load('F:/Statistical Learning (Stanford University)/Datasets/5.R.RData')
# > summary('F:/Statistical Learning (Stanford University)/Datasets/5.R.RData')
#    Length     Class      Mode
#         1 character character
# > names('F:/Statistical Learning (Stanford University)/Datasets/5.R.RData')
# NULL
#
# How am I supposed to do this quiz when I can't get to the data???You can download it at:
#
# https://class.stanford.edu/c4x/HumanitiesScience/StatLearning/asset/5.R.RDataRight, `load` is unlike `read.table` or `read.csv` in that loads whole variables automatically into your workspace, so you don't need assignment at all, e.g.
#
#     load('5.R.Rdata')
#
# and then the variables show up.Okey.
# After loading data with command in exercise description, one can access dataframe typing Xy.`ls()` is a simple option.After you load "5.R.RData", type ls().<br />
# This will list variables available.<br />
# It will output Xy<br />
# Then you can type dim(Xy):<br />
# 1000 3<br />
# Then you can type str(Xy):<br />
# 'data.frame':   1000 obs. of  3 variables:<br />
#  $ X1: num  1.3 1.27 1.24 1.21 1.18 ...<br />
#  $ X2: num  0.806 0.799 0.792 0.785 0.778 ...<br />
#  $ y : num  0.299 0.318 0.337 0.356 0.375 ...<br />You have to replace / with \\. Probably moving data to path without brackets, spaces and so on might be useful. After calling load, all you need is typing Xy.I can't load the data too. Besides, how can we check whether loading is successful or not?
# ------------------------
# medoid  198 : nevermind found it under the bashboard
# ------------------------
# medoid  712 : Hi Matt,
#
# I'm not sure I correctly understand your question, but here goes:
#
# If I wanted to model the type of scenario you seem to be describing I would consider using a vector ARIMA (VARIMA) model. In such a case, you can account for correlated errors and multiple predictors.
#
# Although completely out of left field, another approach you might consider is that of multidimensional wavelets. If I recall correctly, wavelets have some nice properties that help one circumvent correlated error terms. Perhaps someone with more exposure to this topic could step in here and advise?
#
# Best of luck,
#
# <nameRedac_anon_screen_name_redacted>Hi Jonathan,
#
# Thanks. I've done a bit of reading and a bit of work in R. The Cochrane/Orcutt method works quite well in this context to deal with the correlated error terms. I believe the nlme package in R also deals with correlated error terms, however, I've yet to experiment with this package.
#
# I've done a bit of work auto-regressive models in the past, although I was using them for spectral estimation. Here I want a predictive model. I will read up on the VARIMA models.
#
# The wavelet approach sounds interesting. My use of wavelets has also been in the area of spectral estimation. So it would be interesting to see the extension of wavelets in this context.
#
# Thanks Again.
# ------------------------
# medoid  73 : except that probability is tougher than simple geometry.Very elegant. I appreciate your explanation.A very nice quiz to realize that the higher the dimensionality, the more points in the boundaries, if i understand it correctly.Hi!
#
# Try to start with a simple hypercube of 3 dimensions and calculate the volume. I found it useful!Yup! I understood that if you wanted to capture 10% of the neighbors of a given data point in a 50 dimension space, you would need to include almost the entire space!I have no idea either. I'm getting a 0.Great Explanation!
#
# Second Try! Thanks a lot !First try.Rather than think about the question geometrically, I thought about it probabilistically. I pick a random point in my hypercube. What is the chance that random point is outside the boundaries for at least one of its coordinates?Simple and beautifully explained. Thanks. Got it right on the first try because of you.Thank you! I thought I would never get thisThanks for this great explanation. Also first try!Start with a 1 dimension line. If it is 1 unit long and you're capturing .05 of its length on both sides with .9 left in the middle, what is the equation to calculate the amount of the boundary you capture (as a function of what's left in the middle).
#
# Now move to a 2 dimension square. Again if you're capturing .05 of its length and width in two dimensions, so that the part that isn't in the boundary area is itself a square inset in the 1x1 square by 0.05 on all sides, what is the equation to calculate the amount of the boundary area you capture?
#
# Try the same thing with a 3 dimension cube. You'll end up with a cube inset into the 1x1x1 cube by 0.05 on all sides. You'll have two volumes. What is the equation for the difference between these two volumes, which is the volume of the boundary area?
#
# The equation is the same for all three dimensions and can be generalized to 50 dimensions.Thank you so much for the explanation. What really help me was the hint of *"calculate the amount of the boundary you capture (as a function of what's left in the middle)"*.I had a very har time with this question, and hat to go at it step by step. Hope it helps...
#
# 	In geometry, a hypercube is an n-dimensional analogue of a square (n = 2) and a cube (n = 3) (Wikipedia).
#
# 	See image of a hypercube with n=4 (a tesseract): http://www.math.union.edu/~dpvc/talks/2002-02-26.shpe/GIF/4-cube.gif
#
# 	If an n-cube has an edge length of s, its n-volume is s^n (http://gregegan.customer.netspace.net.au/APPLETS/29/HypercubeNotes.html)
#
# 	So, for a hypercube of edge lenght = 1, its volume is 1^50, or 1.
#
# 	The boundary region, as defined for the exercise, is the set of all points such that there exists a j for which 0?xj?.05 or .95?xj?1, i.e., the 10% most extreme values.
#
# 	Remember that you want what is inside the boundary region, and not what is outside...That's a good way to think about it, Anne!So...I got the right answer here, but still am not sure I understand it.  Even after reading Phildow's explanation below.  Is the "boundary area" everything that is outside of the hyperspace described by p=50?Thank you! Excellent explanation.This makes sense and follows the logic of the lecture, but I was thrown by the fact that the problem says "there exists a j" (implying at least one) rather than "for all j".  It seems to me that your explanation models the case of "for all j".  Can anyone help point out where I might be confused?Think about what it would mean if the point was in the boundary "for all j."  This is not the boundary being described by the problem, but would rather correspond to something like the corners of the hypercube.I see now.  Thanks.Thanks for your great explanation.Amazing explanation! Thank you so much for clarifying the question. I think the question is not clearly worded. Anyway, thanks again!Anne, is there any way you can explain this without giving away the answer? (Wish there was an ability to PM users!)Let me try. Say for the singe dimension, straight line, what's the probability a point is in the boundary?
# ...
# to some finite degree (depending on $gamma$), but in
# principle, they go up to infinity.  (And I guess that
# "effectively" having too high a degree would lead to
# over-fitting.)
#
# With two variables, $p=2$, there would be similar terms for
# each variable, plus interaction terms.
#
# ----
#
# By contrast, with one variable $p=1$, the polynomial kernel
# (eq 9.22) with degree $d=2$ would be:
#
# $
# egin{array}{lll}
#   K(x_i, x_{i^prime}) &
#   = &
#   left(
#   1 +
#   x_{i} x_{i^prime}
# ight)^2
#   \ & = &
#   1 + 2 x_{i} x_{i^prime} +  x_{i}^2 x_{i^prime}^2
# end{array}
# $
#
# which only goes up to the second power of the original feature.
#
# ----
#
# And, with $p=1$ the support vector classifier kernel (eq
# 9.21) would just be:
#
# $
# egin{array}{lll}
#   K(x_i, x_{i^prime}) &
#   = &
#   x_{i} x_{i^prime}
# end{array}
# $
#
# So that's no higher powers of the original feature.
#
# But we could add the second power (square) of the original feature as a
# second feature. (Note that $j=1$ is the original feature,
# and $j=2$ is the second power of the original feature.)
# Then we'd have:
#
# $
# egin{array}{lll}
#   K(x_i, x_{i^prime}) &
#   = &
#   sum_{j=1}^{2}
#   x_{ij} x_{i^prime j}
#   \ & = &
#   x_{i} x_{i^prime}
#   + x_{i}^2 x_{i^prime}^2
# end{array}
# $
#
# which obviously has up to the second power of the original
# feature, because we explicitly put it in.
#
# But the polynomial kernel of degree 2 implicitly has the
# second power, and the radial kernel implicitly has unlimited
# powers.> The bottom of Pg. 353 of the book makes the above claim. Might anyone
# > be able to explain how this is so?
#
# If we take the radial kernel, equation (9.24)
#
# $
# K(x_i, x_{i^prime})
# =
# expleft(
# -gamma
# sum_{j=1}^{p}
# (x_{ij}  - x_{i^prime j})^2
# ight)
# $
#
# and do a Taylor series expansion of the exponential function, we'll
# end up with terms involving higher powers of the original features all
# the way to infinity.  So this would be like an infinite dimensional
# feature space.
#
# (Compared  with the polynomial kernel in equation (9.22), or the
# plain support vector classifier in equation (9.21) which only have
# finite powers of the features)The Taylor series expansion for $exp(x)$ is readily available, you would just need to expand the summation in place of $x$ but I think this suffices to see the infinite dimensionality. See $e^x$ here: http://en.wikipedia.org/wiki/Exponential_function
# ------------------------
# medoid  614 : I took it as well.  Enjoyed it very much!!Do you know of any online courses you could please recommend to everyone, for those of us that have enjoyed it? Personally I want Bayesian analysis, but others probably will want other things.
# Also I love your teaching for it's unexpected but exceptionally welcome emphasis on usefulness and guided preference choice. Two presenters is good as well.
# Thanks again, <nameRedac_anon_screen_name_redacted>.Thank you for the information!I am starting to work through some of "Applied Predictive Modeling" by Max Kuhn as an extension to this course - see http://appliedpredictivemodeling.com/blog/. It is another nice applied book to follow this one, but that uses caret (of which Kuhn is the author) to make parameter tuning and a wide variety of algorithms & pre-processing very quickly available.I plan to take "Machine Learning" by Andrew Ng of Stanford.  It is offered on the Coursera platform (www.coursera.org/course/ml) beginning March 3.  It appears to include substantial programming assignments.  [Lectures and course slides & notes from either that course or the original Stanford class CS229 on Youtube and the professor's Web site (respectively).
#
# [But I agree that a longer, more advanced course based on ESL would be great.]
#
# <nameRedac_anon_screen_name_redacted>An advanced course would be excellent, but if that isn't possible, could we get a suggested self-study guide for the more advanced ESL text?  It's a huge book and probably too much to work through all of it in a realistic timeframe. It would be really helpful to know, for example, what sections the authors would cover when using it in a typical Stanford course.Thanks a lot for these references, Evgeniy.Wow! Thank you for posting this. The caret package looks excellent. I just watched a webinar by Max Kuhn about caret.
#
# Based on your experience so far, would you say that it delivers on its promise to standardize the interface for functions and the selection of tuning parameters?I took that course and it was great, there're programming assignment every week, but as long as you know how to do matrix manipulation in octave or matlab, you should be ok.For a lot of stuff yes. BUT sometimes you can't just do whatever you want.Just found this topic!
#
# The ones who want more R practice with real-life data sets, I would recommend "The Analytics Edge" by MIT at edx:
# http://www.edx.org/course/mitx/mitx-<zipRedac>5-07<zipRedac>x-analytics-edge-<zipRedac>4<zipRedac>6
# It is currently running. If you join now, you've missed only one week, but it is small % of the grade -> you can still get you certificate.
#
# For more rigor theory on machine learning (VC dimension, etc.) and language-agnostic practice exercises, The Learning from data by Caltech was great!
# http://www.edx.org/course/caltechx/caltechx-cs<zipRedac><zipRedac>56x-learning-data-<zipRedac><zipRedac>20
# You can wait for the next session, or take it at you own pace at iTunes-U.
#
# For the Bayesian methods, I heard that Probabilistic Graphical Models by Coursera is quite advanced: http://www.coursera.org/course/pgm
#
# For those that want to learn more R, consider the Data Science specialization at Coursera: http://www.coursera.org/specialization/jhudatascience/<zipRedac>/courses
#
# For Python/iPython community, you can go through videos from a Harvard Data Science course
# http://cm.dce.harvard.edu/20<zipRedac>4/0<zipRedac>/<zipRedac>4328/publicationListing.shtml
# http://www.cs<zipRedac>09.org/If we could *replace "Introduction"* with *"Applied"*, and get more points for R sessions it would be a dream come true!
#
# P.S. *Official* solutions to the ISLR book could do the trick, as well... :-)I took professor Ng's course too. EXCELLENT ALL THE WAY!!!Andrew Ng's class in Coursera is really fantastic. The assignments are enough to learn the material better but not substantial. In my opinion they are just right, taking 2-5 hours per week, and I found about 90% of your time is spent on the crux material rather than doing set up or fiddling around with things. Dr. Ng really did a phenomenal job of narrowing down the content to a core set of material. Assignments are done with Matlab or Octave.If you have a spare $1450 laying around you could take this course:
#
# http://www.stanford.edu/~hastie/SLDM/sldmpaIII.htmlI did take that one and it is a very good course. It does have a significant programming homework which will serve as future reference when you want to use some of these algorithms on you own projects. Highly recommended.I think in an advanced course I would really like to see some more theory -not exclusively theory- but some more depth. For example, I have no idea why repeating examples in a training set when using Bootstrap is beneficial at all.. I would have liked some more discussion of that.I felt it was a bit like driving a car without looking under the hood - the profs did suggest some "exercises for the reader" and I think I'll go through the notes again with different datasets to see what works and what doesn't and try and bash through some of the math proofs where applicable (and not too hard!).
# ------------------------
# medoid  785 : If I have time, I first read the book(s), then watch the lectures, and then do the quizzes.
# I found this the most productive and time efficient. If I watch the lectures first, it is much harder for me to answer quizzes and I still need to go back and forth to the books and to the lectures; I tried to avoid just guessing the answers, as this does not increase long-term learning/memorizing. The second way is more time consuming and more frustrating.
# I do R-programming at the very end.I've added my attempt for Ch 7, Ex 1, a and b. But if anyone knows a better solution, please feel free to edit.Under the link above for "Wiki", I think they want us to post our solutions. One link went to one student's attempts on github, but he only did up to Ch 6. I'll try to post some on the wiki page, hopefully get some discussion going.Not having the Applied exercises solutions are greatly hindering my learning. To me, it's key to get the mechanics down in the code. Actual learning is 100 fold iteration between coding mechanics and theory. After a long search on Google, I couldn't find the applied solutions anywhere after Chapter 6.Undergrad Psych 20+ years ago, a decade before students having their own computer really caught on. There was lots of stats in the research papers, and "Statistics for Psychology" which I didn't understand great. Since then, after learning how to code, I study math and statistics (like this course) as a hobby. When I see the math formula, I write the code to do it. It is so funny, after writing the code, I regularly find myself thinking, "So that's what they meant, why didn't they just say ..., that would have been so much clearer" when running into the same topic from 20+ years ago. Math notation is very vague and abstract, but coding helps to understand, forces you to note all the details and visualize the steps and what the formula is doing.I am somewhat behind on linear discriminant analysis and logistic regression.  That stuff is rather hard, it's not intuitive why, of all functions you would use a sigmoid function.
#
# I understand the sigmoid function outputs [0,1].  How are we supposed to think?  Unlike regression, with slope, rise, and run, but sigmoid function becomes hard.  I guess I will have to trust the probability outcome.David_L,
# btw, what is your background, if you don't mind?  I study statistics in grad school, I am still struggling with a lot of these stuff.
#
# Maybe it's due to weak math background.I used to the quiz right after watching the lecture, however, I don't remember anything a week later.  So, I'm in doubt about the validity of that technique.
#
# As for the book questions, I hope it is fine to post and discuss.
#
# Yes, you have to find data and use it, that's the only way to understand.  Doing the right problems is the key to understand these material IMO.I find reading the book, the most helpful.  The lecture videos, sometimes I don't get it---esp. chap 4 on discriminative analysis, the book did not go into it.  Also, how logistic regression tie to DA.
#
# By pdfs, you mean lecture slides?
#
# I am saving the book work in the end, I plan do the ones with R especially.
#
# Bishop is comprehensive, but the notation gets to fancy for me.  Not much examples like here.I watch the lectures until the lab lecture and do the quizzes; then read the book until the lab section; watch the lab video and type it in R as he goes (if I have time, it's better then running directly from the .rmd); then do the chapter quiz. I did some of the conceptual exercises in the book, but there's no answer key, it would be better if there were answers. If I have time, I try to do the lab exercises because that helps the most. It's easy to understand the description of what to do, but actually doing it is a different experience that works out all the details.
#
# Ultimately, when the course is over, if I want to learn anything, I'll have to find a project of my own and try to apply the course work to my own project. That's always the best way to learn anything, you get all the details right, understand in depth what you are doing, and the experience and intuition of how this stuff works and how to interpret your findings.Personally I watch the videos, read the book and only then do the quizzes. In a couple occasions I noticed that lectures weren't sufficient to answer quizzes, so I decided to read the book before attempting answers. Also, reading the book is great to fix the key points in my mind. I never read the pdfs, since I watched the videos already. If I have any spare time, I prefer to study the book or navigate the forum. Doing the book exercises would be a great idea, but I've got a full-time job and I I'd never find time for that.
#
# <nameRedac_anon_screen_name_redacted>
#
# ps I'm very curious, so I like to read extra references, such as ESL, and the book by Bishop I cited some time ago. The few times I do that, I regularly fall behind schedule (but I feel satisfied :)
# ------------------------
# medoid  372 : Thanks! Helped me!
# ------------------------
# medoid  759 : Yes.
# ------------------------
# medoid  379 : I think this is a good explanation, and I also found this question rather tricky.
#
# My way to describe what the effect is would be:
#
# The more complex the models are, the higher the likelihood of overfitting.
#
# How do we recognize overfitting? By seeing that the test-data has an error rate a lot worse than the training data.
#
# But by using all data (that is, the training data as well) you "prepare" your model for the test data that will come.
#
# This preparation will lower the error rate on the test-data, and you will not recognize overfitting.@Gavin: I think what you are asking (second part of your question) is:
#
# *does the answer of 5.3.R1 somehow suggest that **more data is worse?***
#
# No, it does not! Here is what I think it says:
#
# We want to choose the model size, call it "n". Put some limits to this, suppose it ranges between 1 and "n_max".
#
# - the right way to do Cross-Validation is to set up K pairs of training and validation datasets. For each one of the K pairs:
# 1. Take the training data, and apply forward selection to get one model for each n (i.e. you have a total of n_max models).
# 2. Fit each one of these models to the training data (i.e. n_max fits).
# 3. For each one of the models fitted, take the validation data and apply the model to get a test error (i.e. n_max test errors).
# 4. Plot a curve of test error versus n (n ranges from 1 to n_max, a curve like Fig. 5.2 of the book).
#
# (Notice that each one of the K pairs may give rise to different models in step 1. This is the subject of question 5.2.R1.) This leaves you with K curves of test error versus model-size. These estimates of test error are reasonable.
#
# - the wrong way to do Cross-Validation is to begin with ***all*** the data, and apply the forward selection process to arrive at one model for each n (i.e. n_max models). Then, set up K pairs of training and validation datasets. For each one of the K pairs:
# 1. Fit each one of the models to the training data (i.e. n_max fits).
# 2. For each one of the models fitted, take the validation data and apply the model to get a test error (i.e. n_max test errors).
# 3. Plot a curve of test error versus n (n ranges from 1 to n_max).
#
# (Notice that, now, the model selected for each value of n is the same across all the K pairs.) Again, this leaves you with K curves of test error versus model-size. These estimates of test error are ***NOT*** reasonable.
#
# The reason is that the model selection process was performed on ***all*** the data, therefore the models selected for each value of n *have been fit on the data you **subsequently** split into training and validation sets*. The data that was supposed to penalise overfitting have been "massaged into the models".
#
# The result is that models that would normally be rejected (because of high test error), are instead accepted (because they appear to have lower test error). In conclusion, we will tend to arrive at more complex models than is optimal.
#
#
# Like I said, this is my opinion/ understanding, I would like to have some comments/ feedback....That really helps!Thank you, dimitrioschr and Neronus.Forward stepwise regression was covered in the chapter on linear regression (starting at the bottom of page 78 of the book).
#
# The "sequence of models" is, I'm presuming, simply the various models you'd try out during the process of stepwise regression.Thank you, Jeff.

# %% [markdown]
# ##Non-Negative Matrix Factorization

# %%
#NMF for grouped comments
n_topics = 30
n_top_words = 15

print("size of corpus: {}".format(len(grouped_comments)))

t0 = time()

# Fit the NMF model
print("Fitting the NMF model on with n_samples=%d and n_features=%d..."
      % (n_samples, X.shape[1]))
nmf = decomposition.NMF(n_components=n_topics).fit(X)
print("done in %0.3fs." % (time() - t0))

# Inverse the vectorizer vocabulary to be able
feature_names = tfidf.get_feature_names()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join( [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]] ))
    print
# Out:
# size of corpus: 1071
# Fitting the NMF model on with n_samples=1071 and n_features=1584...
# done in 29.246s.
# Topic #0:
# trees tree number caret split adding long forest unfortunately random classification red approach kernel population
#
# Topic #1:
# humanitiesscience winter2 winter2 14 forum courses humanitiesscience stanford courses discussion forum threads humanitiesscience statlearning class stanford statlearning 14 i4x forum i4x i4x humanitiesscience
#
# Topic #2:
# videos download watch video download videos firefox download video mp4 url hd copy downloading format access downloaded
#
# Topic #3:
# rdata load load rdata xy ls file workspace loaded x1 x2 command x1 x2 list r1 output
#
# Topic #4:
# image image description enter image edx amazonaws s3 amazonaws edx west west uploads west uploads s3 uploads s3 enter description description edx
#
# Topic #5:
# great great course course learning thank tibshirani hastie prof enjoyed books statistical learning statistical prof hastie book machine learning
#
# Topic #6:
# cv validation cross validation cross fold test cv error estimate test fold cv best best model training estimate test set set
#
# Topic #7:
# bcf usc bcf usc gareth usc gareth gareth isl isl isl data csv islr textbook html credit pdf website
#
# Topic #8:
# tsboot boot index xy function coef sim fixed sim block function data lm x1 blocks lm bootstrap x1
#
# Topic #9:
# glmnet lambda lasso alpha ridge plot ridge regression family regularization cv package net coefficients increases glm
#
# Topic #10:
# install packages install packages package packages islr islr library cran library islr cran project project packages project version islr library islr package
#
# Topic #11:
# data frame 50 frame rnorm dat rep pred matrix predict matrix rnorm svm 10 data train 100
#
# Topic #12:
# automatic appears ols logit lda past posting grading ch resampling allow getting answers finish things
#
# Topic #13:
# base log natural formula correct answer consistent used correct answer stats 10 instructors wrong notes accepted
#
# Topic #14:
# lecture slides slides pdf lecture 30 page link chapter hd downloaded numbers slide class stanford humanitiesscience statlearning statlearning
#
# Topic #15:
# variable predictors variables interaction dummy x2 x1 predictor correlated effect model levels relationship interactions x3
#
# Topic #16:
# solutions github manual nameredac_anon_screen_name_redacted stat learning official stat cheers community learning aware exercises hi working based
#
# Topic #17:
# chrome browser fine mac screen firefox clicking video tried works button using windows worked volume
#
# Topic #18:
# volume cube dimensions dimension boundary hypercube square region length unit area distance dimensional 50 line
#
# Topic #19:
# elemstatlearn tibs stanford tibs tibs elemstatlearn statweb stanford statweb stanford esl elements statistical elements statistical learning 2nd statistical pdf learning
#
# Topic #20:
# bias variance high bias variance flexible low high variance irreducible irreducible error error var tradeoff variance tradeoff rate model
#
# Topic #21:
# file rstudio directory open csv auto editor working directory files installed script desktop save read csv windows
#
# Topic #22:
# interval confidence confidence interval 95 intervals confidence intervals parameter null hypothesis null hypothesis true contain value probability distribution
#
# Topic #23:
# poly reg df lm splines spline polynomial polynomials fitted values fitted raw freedom degrees freedom degree summary
#
# Topic #24:
# sales tv advertising units typo interaction 39 37 impact 1000 increase wrong calculation figure round
#
# Topic #25:
# eta_1 eta_0 epsilon eta_0 eta_1 x_1 hat x_2 eta_2 log mathrm odds eta frac egin hat eta
#
# Topic #26:
# submit quiz progress button quizzes video click icon certificate accomplishment clicking bar questions march section
#
# Topic #27:
# logistic logistic regression regression linear regression linear discriminant classification models discriminant analysis regression model glm multivariate logit gaussian watch
#
# Topic #28:
# bootstrap samples sample size data points time series bootstrap sample block data point bootstrap samples series points standard block bootstrap sample size
#
# Topic #29:
# pca principal components principal components 200 component pc proportion explained pr var variance test sum rows

# %%
for topic_idx, topic in enumerate(nmf.components_):

    words = [feature_names[i] for i in topic.argsort()[:-(n_top_words):-1]]
    scores = [topic[i] for i in topic.argsort()[:-(n_top_words):-1]]

    dicta = {word: score for score, word in zip(scores, words)}

    s=pd.Series(dicta)
    plt.figure()
    plt.title("Topic #%d:" % topic_idx)
    s.plot(kind='bar');

# %%
#Word clouds
import vincent
vincent.core.initialize_notebook()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    tmpDic = {}
    for i in topic.argsort()[:-50 - 1:-1]:
        tmpDic[feature_names[i]] = topic[i]*100
    vincent.Word(tmpDic).display();
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# Topic #0:
# <div id="vis933b744bb4fc474d8769097b8cfae2e4"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "adding", "val": 26.802331765826331}, {"col": "data", "idx": "answer question", "val": 14.07600489604822}, {"col": "data", "idx": "appreciate", "val": 12.641727526428603}, {"col": "data", "idx": "approach", "val": 20.213263853335313}, {"col": "data", "idx": "assume", "val": 12.4594274639598}, {"col": "data", "idx": "average", "val": 15.074626076103254}, {"col": "data", "idx": "caret", "val": 30.911974296786244}, {"col": "data", "idx": "classification", "val": 20.855667852709104}, {"col": "data", "idx": "constant", "val": 16.567040511578327}, {"col": "data", "idx": "decision", "val": 13.972855421017766}, {"col": "data", "idx": "don know", "val": 14.81960600680077}, {"col": "data", "idx": "efficient", "val": 12.583852993493522}, {"col": "data", "idx": "expect", "val": 11.934422235894488}, {"col": "data", "idx": "forest", "val": 24.295952811655241}, {"col": "data", "idx": "good", "val": 12.373798782286487}, {"col": "data", "idx": "good point", "val": 14.124432676618817}, {"col": "data", "idx": "html", "val": 15.500579092520434}, {"col": "data", "idx": "instead", "val": 14.210475588509627}, {"col": "data", "idx": "job", "val": 13.018920523456162}, {"col": "data", "idx": "kernel", "val": 19.998992024459199}, {"col": "data", "idx": "level", "val": 13.251092559070399}, {"col": "data", "idx": "loading", "val": 11.9881046492004}, {"col": "data", "idx": "long", "val": 24.839802938420068}, {"col": "data", "idx": "maybe", "val": 12.13102835181826}, {"col": "data", "idx": "min", "val": 13.765691272182789}, {"col": "data", "idx": "number", "val": 39.160977891344793}, {"col": "data", "idx": "observations", "val": 17.735847022389738}, {"col": "data", "idx": "package", "val": 13.680530300550107}, {"col": "data", "idx": "population", "val": 19.409600273025898}, {"col": "data", "idx": "probability", "val": 17.868762816906873}, {"col": "data", "idx": "project packages", "val": 13.027311598702981}, {"col": "data", "idx": "quite", "val": 15.83305242409026}, {"col": "data", "idx": "random", "val": 22.472560902395102}, {"col": "data", "idx": "random variable", "val": 13.56392359941948}, {"col": "data", "idx": "red", "val": 20.288469671588032}, {"col": "data", "idx": "reply", "val": 19.283797435802576}, {"col": "data", "idx": "residuals", "val": 12.295679352855922}, {"col": "data", "idx": "response", "val": 14.636602451243389}, {"col": "data", "idx": "said", "val": 13.060776803016722}, {"col": "data", "idx": "single", "val": 15.421836493636047}, {"col": "data", "idx": "smgross", "val": 15.991417376367137}, {"col": "data", "idx": "sort", "val": 13.937976599158475}, {"col": "data", "idx": "split", "val": 28.676234739322275}, {"col": "data", "idx": "staff", "val": 13.597767963506765}, {"col": "data", "idx": "suggest", "val": 15.973621811275004}, {"col": "data", "idx": "total", "val": 15.61506005616333}, {"col": "data", "idx": "tree", "val": 180.82251808692092}, {"col": "data", "idx": "trees", "val": 183.23730469040237}, {"col": "data", "idx": "unfortunately", "val": 23.075257912205778}, {"col": "data", "idx": "years", "val": 12.421002043471729}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis933b744bb4fc474d8769097b8cfae2e4"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #1:
# <div id="visdcb197af10644db99f7a27e6505dfba3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "14", "val": 31.005060835524546}, {"col": "data", "idx": "14 course", "val": 18.893931057037918}, {"col": "data", "idx": "14 discussion", "val": 25.460931571411738}, {"col": "data", "idx": "16", "val": 3.5490220811060347}, {"col": "data", "idx": "class", "val": 20.898458785059688}, {"col": "data", "idx": "class stanford", "val": 32.021743637423747}, {"col": "data", "idx": "course", "val": 18.612902170118108}, {"col": "data", "idx": "course material", "val": 26.833537056546387}, {"col": "data", "idx": "course winter2", "val": 23.078533530269041}, {"col": "data", "idx": "course winter2014", "val": 17.181314297148489}, {"col": "data", "idx": "courses", "val": 28.690203009152583}, {"col": "data", "idx": "courses humanitiesscience", "val": 33.554496774695082}, {"col": "data", "idx": "discussed", "val": 5.3883684759565993}, {"col": "data", "idx": "discussion", "val": 27.395375674270412}, {"col": "data", "idx": "discussion forum", "val": 32.980409690025567}, {"col": "data", "idx": "especially", "val": 3.4261605194002431}, {"col": "data", "idx": "feedback", "val": 24.057418209350381}, {"col": "data", "idx": "feedback threads", "val": 27.756331875297157}, {"col": "data", "idx": "following", "val": 2.9255812747794154}, {"col": "data", "idx": "forum", "val": 33.645204858629143}, {"col": "data", "idx": "forum i4x", "val": 30.782378866877579}, {"col": "data", "idx": "humanitiesscience", "val": 49.104550153457673}, {"col": "data", "idx": "humanitiesscience statlearning", "val": 32.094472742944561}, {"col": "data", "idx": "humanitiesscience stats216", "val": 28.232319747953248}, {"col": "data", "idx": "i4x", "val": 30.782378866877579}, {"col": "data", "idx": "i4x humanitiesscience", "val": 30.782378866877579}, {"col": "data", "idx": "includes", "val": 3.0215639548067537}, {"col": "data", "idx": "info", "val": 2.8284141311454918}, {"col": "data", "idx": "material", "val": 19.476780084771384}, {"col": "data", "idx": "material feedback", "val": 27.756331875297157}, {"col": "data", "idx": "mistake", "val": 2.9505631976977038}, {"col": "data", "idx": "question", "val": 3.8324451487069275}, {"col": "data", "idx": "quiz", "val": 3.5447842200613615}, {"col": "data", "idx": "review", "val": 5.9331361737579087}, {"col": "data", "idx": "staff", "val": 3.244393800343774}, {"col": "data", "idx": "stanford", "val": 26.037768660421872}, {"col": "data", "idx": "stanford courses", "val": 33.554496774695082}, {"col": "data", "idx": "statlearning", "val": 31.252661195145897}, {"col": "data", "idx": "statlearning winter2", "val": 27.572961282007231}, {"col": "data", "idx": "statlearning winter2014", "val": 18.032188503977601}, {"col": "data", "idx": "stats216", "val": 28.232319747953248}, {"col": "data", "idx": "stats216 course", "val": 27.471816826269745}, {"col": "data", "idx": "thread", "val": 16.463783285880321}, {"col": "data", "idx": "thread class", "val": 14.492874183235516}, {"col": "data", "idx": "threads", "val": 32.491413021108059}, {"col": "data", "idx": "winter2", "val": 41.860005678973664}, {"col": "data", "idx": "winter2 14", "val": 38.440925979413954}, {"col": "data", "idx": "winter2014", "val": 28.498182819496144}, {"col": "data", "idx": "winter2014 course", "val": 14.119664155534876}, {"col": "data", "idx": "winter2014 discussion", "val": 17.262918862681158}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "t ...
#          chart({el: "#visdcb197af10644db99f7a27e6505dfba3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #2:
# <div id="visb2e87d4b8bf94a62b005d3fa29104271"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "able", "val": 9.8491201872942256}, {"col": "data", "idx": "access", "val": 17.771688170257196}, {"col": "data", "idx": "add", "val": 14.721540865190185}, {"col": "data", "idx": "advance", "val": 7.3228387690179932}, {"col": "data", "idx": "available", "val": 16.724856405574272}, {"col": "data", "idx": "better", "val": 7.9518312653708332}, {"col": "data", "idx": "click", "val": 16.666447403174782}, {"col": "data", "idx": "connection", "val": 11.087833597809892}, {"col": "data", "idx": "content", "val": 7.3483577015538257}, {"col": "data", "idx": "copy", "val": 22.899428228576081}, {"col": "data", "idx": "course", "val": 7.454924959261235}, {"col": "data", "idx": "coursera", "val": 7.0508515286451541}, {"col": "data", "idx": "currently", "val": 10.457353505317554}, {"col": "data", "idx": "discussions", "val": 6.786248594778459}, {"col": "data", "idx": "dl", "val": 16.242004117031847}, {"col": "data", "idx": "download", "val": 84.392796123148358}, {"col": "data", "idx": "download video", "val": 36.911033872417789}, {"col": "data", "idx": "download videos", "val": 47.762367381722996}, {"col": "data", "idx": "downloaded", "val": 17.477089680108122}, {"col": "data", "idx": "downloading", "val": 21.48162823362312}, {"col": "data", "idx": "firefox", "val": 44.356645820882655}, {"col": "data", "idx": "format", "val": 18.310189830911241}, {"col": "data", "idx": "free", "val": 7.8834895526720086}, {"col": "data", "idx": "hd", "val": 23.25665190494378}, {"col": "data", "idx": "internet", "val": 15.616367727354245}, {"col": "data", "idx": "lecture", "val": 7.8105981088407885}, {"col": "data", "idx": "lectures", "val": 16.109353430264196}, {"col": "data", "idx": "link", "val": 17.190827981922315}, {"col": "data", "idx": "links", "val": 16.543740076704495}, {"col": "data", "idx": "list", "val": 10.414016627975462}, {"col": "data", "idx": "low", "val": 9.0182722751721389}, {"col": "data", "idx": "materials", "val": 7.4385692645881507}, {"col": "data", "idx": "mp4", "val": 31.298815017028858}, {"col": "data", "idx": "online", "val": 15.282647504650388}, {"col": "data", "idx": "paste", "val": 14.423203496193713}, {"col": "data", "idx": "play", "val": 16.565209802201235}, {"col": "data", "idx": "quality", "val": 11.887678026376747}, {"col": "data", "idx": "right", "val": 9.6225201671105829}, {"col": "data", "idx": "select", "val": 7.7297115065770887}, {"col": "data", "idx": "site", "val": 7.5628526875684985}, {"col": "data", "idx": "unable", "val": 7.2351009031759519}, {"col": "data", "idx": "url", "val": 30.309935377313234}, {"col": "data", "idx": "use", "val": 7.0492722450590364}, {"col": "data", "idx": "versions", "val": 9.2393395596179673}, {"col": "data", "idx": "video", "val": 50.86621098563807}, {"col": "data", "idx": "videos", "val": 92.182948198908207}, {"col": "data", "idx": "watch", "val": 53.343536807895731}, {"col": "data", "idx": "website", "val": 10.216860365885355}, {"col": "data", "idx": "windows", "val": 7.2170461224966846}, {"col": "data", "idx": "work", "val": 7.8682440384903183}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visb2e87d4b8bf94a62b005d3fa29104271"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #3:
# <div id="vis91203ae1e20b447586221b7dabf84986"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "10", "val": 7.1688756251768515}, {"col": "data", "idx": "assignment", "val": 9.8629817806413449}, {"col": "data", "idx": "attach", "val": 6.3053317419234869}, {"col": "data", "idx": "called", "val": 7.5593532891993167}, {"col": "data", "idx": "class", "val": 7.3321736003840234}, {"col": "data", "idx": "class stanford", "val": 9.5436492692971768}, {"col": "data", "idx": "click", "val": 7.0909091228182648}, {"col": "data", "idx": "command", "val": 13.68171551762666}, {"col": "data", "idx": "couldn", "val": 7.915765520886012}, {"col": "data", "idx": "data", "val": 9.5658310282874819}, {"col": "data", "idx": "data frame", "val": 8.8962284498743003}, {"col": "data", "idx": "dataframe", "val": 8.9403324888333398}, {"col": "data", "idx": "datasets", "val": 6.7875712041815843}, {"col": "data", "idx": "didn", "val": 6.1341905287278857}, {"col": "data", "idx": "directly", "val": 8.1652108830750443}, {"col": "data", "idx": "directory", "val": 7.9658070925361883}, {"col": "data", "idx": "download", "val": 7.6089265554895622}, {"col": "data", "idx": "figure", "val": 7.8851865611682195}, {"col": "data", "idx": "file", "val": 29.224354766347389}, {"col": "data", "idx": "frame", "val": 8.2824456946205274}, {"col": "data", "idx": "head", "val": 9.9223669710843794}, {"col": "data", "idx": "humanitiesscience", "val": 8.2008271012345091}, {"col": "data", "idx": "humanitiesscience statlearning", "val": 9.2402513081202393}, {"col": "data", "idx": "link", "val": 9.8959067195060921}, {"col": "data", "idx": "list", "val": 12.881405090752818}, {"col": "data", "idx": "load", "val": 53.737998908034058}, {"col": "data", "idx": "load rdata", "val": 47.405772486412303}, {"col": "data", "idx": "loaded", "val": 21.272212686522312}, {"col": "data", "idx": "loading", "val": 10.854357518766649}, {"col": "data", "idx": "ls", "val": 33.177815806097037}, {"col": "data", "idx": "names", "val": 8.985752736360638}, {"col": "data", "idx": "numeric", "val": 6.8262871844556265}, {"col": "data", "idx": "object", "val": 6.1009138639652161}, {"col": "data", "idx": "objects", "val": 7.5031360600247758}, {"col": "data", "idx": "output", "val": 10.946791767022656}, {"col": "data", "idx": "r1", "val": 11.983933153486602}, {"col": "data", "idx": "rdata", "val": 88.384830100561231}, {"col": "data", "idx": "shown", "val": 7.5886016008460278}, {"col": "data", "idx": "stanford", "val": 8.8313675947502919}, {"col": "data", "idx": "statlearning", "val": 8.925962372572501}, {"col": "data", "idx": "stuck", "val": 8.7063413678572363}, {"col": "data", "idx": "studio", "val": 7.7426999150896165}, {"col": "data", "idx": "summary", "val": 9.1306306097515666}, {"col": "data", "idx": "type", "val": 9.4259773207419482}, {"col": "data", "idx": "using", "val": 6.0565823754530461}, {"col": "data", "idx": "workspace", "val": 26.825436695001898}, {"col": "data", "idx": "x1", "val": 20.532958112253784}, {"col": "data", "idx": "x1 x2", "val": 12.887100143928951}, {"col": "data", "idx": "x2", "val": 13.897584747738309}, {"col": "data", "idx": "xy", "val": 38.012907451268461}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis91203ae1e20b447586221b7dabf84986"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #4:
# <div id="vis05a7d7086dd6415c9d5e8dbf9a7172ef"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "amazonaws", "val": 43.400460472818466}, {"col": "data", "idx": "bar", "val": 9.8393582632643337}, {"col": "data", "idx": "blue", "val": 7.4749080948114708}, {"col": "data", "idx": "click", "val": 10.238079507220977}, {"col": "data", "idx": "code", "val": 4.6811402507621596}, {"col": "data", "idx": "col", "val": 8.8653799515012928}, {"col": "data", "idx": "curve", "val": 5.481894991726759}, {"col": "data", "idx": "description", "val": 37.682342239096648}, {"col": "data", "idx": "description edx", "val": 37.133538718828781}, {"col": "data", "idx": "design", "val": 6.7220536490175631}, {"col": "data", "idx": "distance", "val": 5.2930905590099364}, {"col": "data", "idx": "edx", "val": 43.583699591474677}, {"col": "data", "idx": "edx west", "val": 43.317092305221152}, {"col": "data", "idx": "enter", "val": 38.505120919410771}, {"col": "data", "idx": "enter image", "val": 44.889325261877964}, {"col": "data", "idx": "example", "val": 4.8848446435136621}, {"col": "data", "idx": "graph", "val": 4.6676825181790242}, {"col": "data", "idx": "helps", "val": 4.6581254268041032}, {"col": "data", "idx": "hope helps", "val": 5.6038079470093951}, {"col": "data", "idx": "icon", "val": 18.820661018933777}, {"col": "data", "idx": "image", "val": 45.364374186202468}, {"col": "data", "idx": "image description", "val": 44.889325261877964}, {"col": "data", "idx": "label", "val": 5.5538101549441068}, {"col": "data", "idx": "lecture", "val": 7.7651086897536983}, {"col": "data", "idx": "left", "val": 6.8337906300105038}, {"col": "data", "idx": "min", "val": 5.0526757624896588}, {"col": "data", "idx": "multiple", "val": 6.4783711462944762}, {"col": "data", "idx": "platform", "val": 5.9003076038454907}, {"col": "data", "idx": "plot", "val": 10.796524777095058}, {"col": "data", "idx": "png", "val": 29.37522087629339}, {"col": "data", "idx": "points", "val": 6.5615453313658296}, {"col": "data", "idx": "print", "val": 5.5547640558417672}, {"col": "data", "idx": "quizzes", "val": 6.346508780916106}, {"col": "data", "idx": "red", "val": 5.3419955047065644}, {"col": "data", "idx": "s3", "val": 42.987044038255299}, {"col": "data", "idx": "s3 amazonaws", "val": 43.400460472818466}, {"col": "data", "idx": "section", "val": 6.7828516686118734}, {"col": "data", "idx": "seed", "val": 4.9191873483140665}, {"col": "data", "idx": "seq", "val": 5.8735790416678988}, {"col": "data", "idx": "set seed", "val": 5.6644579199016967}, {"col": "data", "idx": "shows", "val": 6.9117481702861179}, {"col": "data", "idx": "small", "val": 5.0767993630571588}, {"col": "data", "idx": "sort", "val": 5.8875367392878433}, {"col": "data", "idx": "type", "val": 6.5484223197740015}, {"col": "data", "idx": "typically", "val": 4.7501087873614694}, {"col": "data", "idx": "uploads", "val": 43.25034900131854}, {"col": "data", "idx": "uploads s3", "val": 43.317092305221152}, {"col": "data", "idx": "video", "val": 10.910931739048046}, {"col": "data", "idx": "west", "val": 43.317092305221152}, {"col": "data", "idx": "west uploads", "val": 43.317092305221152}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis05a7d7086dd6415c9d5e8dbf9a7172ef"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #5:
# <div id="visb5863a36a5864f0f985f82be6e7c35a4"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "advanced", "val": 14.248611946306722}, {"col": "data", "idx": "applied", "val": 11.647338123047701}, {"col": "data", "idx": "book", "val": 18.079466738059153}, {"col": "data", "idx": "books", "val": 21.759089479142933}, {"col": "data", "idx": "class", "val": 11.266246228124535}, {"col": "data", "idx": "course", "val": 38.055134956075399}, {"col": "data", "idx": "course great", "val": 17.146352507427704}, {"col": "data", "idx": "coursera", "val": 11.999582113062353}, {"col": "data", "idx": "data analysis", "val": 11.448244261488091}, {"col": "data", "idx": "effort", "val": 15.347532994701568}, {"col": "data", "idx": "enjoyed", "val": 23.647361996832647}, {"col": "data", "idx": "esl", "val": 16.649143407255494}, {"col": "data", "idx": "experience", "val": 13.970506143764288}, {"col": "data", "idx": "feel", "val": 13.074194958437287}, {"col": "data", "idx": "forward", "val": 11.599216549851683}, {"col": "data", "idx": "free", "val": 14.604878705923706}, {"col": "data", "idx": "good", "val": 11.264921945043191}, {"col": "data", "idx": "great", "val": 48.781169218965914}, {"col": "data", "idx": "great course", "val": 40.621178704006866}, {"col": "data", "idx": "hastie", "val": 25.576324492916612}, {"col": "data", "idx": "hastie tibshirani", "val": 14.519873644468564}, {"col": "data", "idx": "learned", "val": 14.192839554421354}, {"col": "data", "idx": "learning", "val": 27.002539690082966}, {"col": "data", "idx": "looking forward", "val": 14.440280756859391}, {"col": "data", "idx": "lot", "val": 16.695878894947835}, {"col": "data", "idx": "love", "val": 11.79217393985151}, {"col": "data", "idx": "machine", "val": 17.136021348622865}, {"col": "data", "idx": "machine learning", "val": 17.856312457548992}, {"col": "data", "idx": "material", "val": 13.05328390000181}, {"col": "data", "idx": "people", "val": 13.207298588008989}, {"col": "data", "idx": "prof", "val": 24.221109876065629}, {"col": "data", "idx": "prof hastie", "val": 18.460329313697194}, {"col": "data", "idx": "prof tibshirani", "val": 15.740146168128533}, {"col": "data", "idx": "professors", "val": 17.573509168739516}, {"col": "data", "idx": "questions", "val": 11.990538816243664}, {"col": "data", "idx": "really", "val": 13.206766644556877}, {"col": "data", "idx": "rob", "val": 16.295186655760787}, {"col": "data", "idx": "statistical", "val": 20.232489445946424}, {"col": "data", "idx": "statistical learning", "val": 20.458568736658997}, {"col": "data", "idx": "statistics", "val": 12.486982462697762}, {"col": "data", "idx": "taught", "val": 12.336000936737674}, {"col": "data", "idx": "team", "val": 13.345892418890701}, {"col": "data", "idx": "techniques", "val": 11.758506866830833}, {"col": "data", "idx": "thank", "val": 26.992111734214873}, {"col": "data", "idx": "thank course", "val": 16.802169067232523}, {"col": "data", "idx": "tibshirani", "val": 26.09946867355108}, {"col": "data", "idx": "time", "val": 13.949804724920758}, {"col": "data", "idx": "trevor", "val": 15.816752930076236}, {"col": "data", "idx": "useful", "val": 11.329030739479203}, {"col": "data", "idx": "week", "val": 14.078120973749137}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visb5863a36a5864f0f985f82be6e7c35a4"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #6:
# <div id="visd940e481903d4367a468c01f2890958e"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "10 fold", "val": 23.789813222461444}, {"col": "data", "idx": "approach", "val": 11.881205778702366}, {"col": "data", "idx": "average", "val": 14.796829349584378}, {"col": "data", "idx": "best", "val": 30.189270491436361}, {"col": "data", "idx": "best model", "val": 30.123680345887628}, {"col": "data", "idx": "choose", "val": 20.343351467038058}, {"col": "data", "idx": "compute", "val": 11.407213277914929}, {"col": "data", "idx": "cross", "val": 47.427632909984411}, {"col": "data", "idx": "cross validation", "val": 50.70756571655334}, {"col": "data", "idx": "cv", "val": 74.340306247178233}, {"col": "data", "idx": "cv error", "val": 33.87717697553466}, {"col": "data", "idx": "data", "val": 13.872349182009527}, {"col": "data", "idx": "data set", "val": 18.610889196840247}, {"col": "data", "idx": "error", "val": 24.620277382827961}, {"col": "data", "idx": "estimate", "val": 27.835941690131062}, {"col": "data", "idx": "estimate test", "val": 32.422091782076201}, {"col": "data", "idx": "fold", "val": 46.905007165094645}, {"col": "data", "idx": "fold cross", "val": 15.641508013302236}, {"col": "data", "idx": "fold cv", "val": 31.194277862120064}, {"col": "data", "idx": "folds", "val": 26.626992098933361}, {"col": "data", "idx": "forward", "val": 18.620029682470037}, {"col": "data", "idx": "loocv", "val": 15.765506131907948}, {"col": "data", "idx": "lowest", "val": 12.375037138946006}, {"col": "data", "idx": "method", "val": 14.686506168488943}, {"col": "data", "idx": "model", "val": 25.606332948200851}, {"col": "data", "idx": "model selection", "val": 11.377093576477133}, {"col": "data", "idx": "models", "val": 23.70937366948279}, {"col": "data", "idx": "mse", "val": 13.74306428810498}, {"col": "data", "idx": "optimal", "val": 14.397499917340104}, {"col": "data", "idx": "parameters", "val": 15.301689363315161}, {"col": "data", "idx": "performance", "val": 12.456159845435581}, {"col": "data", "idx": "process", "val": 11.287278227065579}, {"col": "data", "idx": "select", "val": 13.142522988233301}, {"col": "data", "idx": "selection", "val": 24.983227378276055}, {"col": "data", "idx": "set", "val": 27.113519612968474}, {"col": "data", "idx": "set error", "val": 13.326063050511111}, {"col": "data", "idx": "sets", "val": 12.969585836519437}, {"col": "data", "idx": "split", "val": 12.512145206060362}, {"col": "data", "idx": "step", "val": 15.362856818449794}, {"col": "data", "idx": "stepwise", "val": 20.669841046736899}, {"col": "data", "idx": "subset", "val": 13.349072518572552}, {"col": "data", "idx": "test", "val": 39.280971226934511}, {"col": "data", "idx": "test data", "val": 14.796802355565386}, {"col": "data", "idx": "test error", "val": 26.73121078377309}, {"col": "data", "idx": "test set", "val": 27.508794014921627}, {"col": "data", "idx": "training", "val": 28.473026954799678}, {"col": "data", "idx": "training set", "val": 17.834801153260731}, {"col": "data", "idx": "using data", "val": 13.423030072822579}, {"col": "data", "idx": "validation", "val": 56.911609219423134}, {"col": "data", "idx": "validation set", "val": 13.676888378891732}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visd940e481903d4367a468c01f2890958e"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #7:
# <div id="vis9f735a71742b4c438a2ecc13e81efcc3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "address", "val": 4.1207667808347557}, {"col": "data", "idx": "auto", "val": 7.9344165793306072}, {"col": "data", "idx": "available", "val": 8.7138413558436767}, {"col": "data", "idx": "bcf", "val": 68.002421548076498}, {"col": "data", "idx": "bcf usc", "val": 68.002421548076498}, {"col": "data", "idx": "book", "val": 13.87615020737694}, {"col": "data", "idx": "codes", "val": 5.0377265576459624}, {"col": "data", "idx": "credit", "val": 17.826090066541163}, {"col": "data", "idx": "csv", "val": 28.562538030500939}, {"col": "data", "idx": "data", "val": 8.3821001909913218}, {"col": "data", "idx": "data set", "val": 6.7884022762366785}, {"col": "data", "idx": "data sets", "val": 5.5702085843854663}, {"col": "data", "idx": "datasets", "val": 10.852503498938724}, {"col": "data", "idx": "download", "val": 8.9741676516598989}, {"col": "data", "idx": "email", "val": 5.1954272325150699}, {"col": "data", "idx": "end", "val": 4.5590880493993087}, {"col": "data", "idx": "end chapter", "val": 4.2573236034725088}, {"col": "data", "idx": "exercises", "val": 7.0230557808617533}, {"col": "data", "idx": "file", "val": 4.7906557032203834}, {"col": "data", "idx": "following", "val": 4.126771927293662}, {"col": "data", "idx": "gareth", "val": 67.405523684624285}, {"col": "data", "idx": "gareth isl", "val": 66.972084467799192}, {"col": "data", "idx": "homework", "val": 4.9123495605187983}, {"col": "data", "idx": "html", "val": 18.839946697932682}, {"col": "data", "idx": "index", "val": 4.6090379433334734}, {"col": "data", "idx": "isl", "val": 57.237656650956993}, {"col": "data", "idx": "isl data", "val": 36.602164868563328}, {"col": "data", "idx": "islr", "val": 23.432979160742658}, {"col": "data", "idx": "islr library", "val": 8.0729424869929467}, {"col": "data", "idx": "labs", "val": 14.776391393032851}, {"col": "data", "idx": "library", "val": 4.6222929013880751}, {"col": "data", "idx": "library islr", "val": 5.7601953851933612}, {"col": "data", "idx": "packages islr", "val": 8.5660344743568491}, {"col": "data", "idx": "page", "val": 4.6451065121064987}, {"col": "data", "idx": "pdf", "val": 16.165426885391859}, {"col": "data", "idx": "plots", "val": 4.538521160838326}, {"col": "data", "idx": "provide", "val": 6.2240138869298276}, {"col": "data", "idx": "read", "val": 8.8453437244030724}, {"col": "data", "idx": "read csv", "val": 14.150722142744284}, {"col": "data", "idx": "set", "val": 4.2886948467196415}, {"col": "data", "idx": "sets", "val": 4.1752310776353649}, {"col": "data", "idx": "site", "val": 13.347375369218392}, {"col": "data", "idx": "str", "val": 7.4828275481321604}, {"col": "data", "idx": "text", "val": 5.5884704561446181}, {"col": "data", "idx": "text book", "val": 11.355162016395834}, {"col": "data", "idx": "textbook", "val": 21.073605396844471}, {"col": "data", "idx": "tutorial", "val": 4.307916927960691}, {"col": "data", "idx": "usc", "val": 68.002421548076498}, {"col": "data", "idx": "usc gareth", "val": 67.405523684624285}, {"col": "data", "idx": "website", "val": 16.162759423980695}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis9f735a71742b4c438a2ecc13e81efcc3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #8:
# <div id="vis1247fb24771c4629bb8912925102f98f"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "100", "val": 11.841980304247974}, {"col": "data", "idx": "1000", "val": 20.793624169140546}, {"col": "data", "idx": "1000 100", "val": 16.839212860038678}, {"col": "data", "idx": "alpha", "val": 10.922927907399648}, {"col": "data", "idx": "argument", "val": 12.40779675951732}, {"col": "data", "idx": "arguments", "val": 13.206434974992437}, {"col": "data", "idx": "beta1", "val": 12.81995985196644}, {"col": "data", "idx": "block", "val": 25.960313858596564}, {"col": "data", "idx": "block bootstrap", "val": 16.203339795297858}, {"col": "data", "idx": "blocks", "val": 23.428230755121433}, {"col": "data", "idx": "boot", "val": 84.044251118989152}, {"col": "data", "idx": "bootstrap", "val": 22.488074088609107}, {"col": "data", "idx": "coef", "val": 32.764859392845011}, {"col": "data", "idx": "data data", "val": 13.381547542448688}, {"col": "data", "idx": "dataset", "val": 6.8620802267033767}, {"col": "data", "idx": "fixed", "val": 19.031983003242132}, {"col": "data", "idx": "function", "val": 33.841019585103929}, {"col": "data", "idx": "function data", "val": 23.776884457418767}, {"col": "data", "idx": "functions", "val": 6.5771571737965342}, {"col": "data", "idx": "got", "val": 7.7624454895483055}, {"col": "data", "idx": "help", "val": 10.243851663569078}, {"col": "data", "idx": "index", "val": 43.012557425038779}, {"col": "data", "idx": "indices", "val": 16.489373617052163}, {"col": "data", "idx": "lm", "val": 22.673719630788103}, {"col": "data", "idx": "lm data", "val": 10.758554371440971}, {"col": "data", "idx": "lm x1", "val": 23.762050145645901}, {"col": "data", "idx": "look", "val": 8.8388269830370927}, {"col": "data", "idx": "original", "val": 8.5862992815439778}, {"col": "data", "idx": "package", "val": 19.397013766624511}, {"col": "data", "idx": "pass", "val": 15.297589881494561}, {"col": "data", "idx": "r3", "val": 19.313506690742752}, {"col": "data", "idx": "return", "val": 20.280646040661967}, {"col": "data", "idx": "returns", "val": 6.728831442780919}, {"col": "data", "idx": "se", "val": 10.064232793338309}, {"col": "data", "idx": "seed", "val": 8.9419256251810442}, {"col": "data", "idx": "series", "val": 13.279744751666408}, {"col": "data", "idx": "set seed", "val": 6.8375340395518736}, {"col": "data", "idx": "sim", "val": 28.754519783121964}, {"col": "data", "idx": "sim fixed", "val": 31.149104177582863}, {"col": "data", "idx": "statistic", "val": 20.793865137601173}, {"col": "data", "idx": "std", "val": 9.7689000289116201}, {"col": "data", "idx": "std error", "val": 9.6717081624891907}, {"col": "data", "idx": "subset", "val": 16.316391772290338}, {"col": "data", "idx": "time series", "val": 15.40825301163208}, {"col": "data", "idx": "tsboot", "val": 107.62375295789212}, {"col": "data", "idx": "x1", "val": 22.416386309289916}, {"col": "data", "idx": "x1 x2", "val": 20.558373731458172}, {"col": "data", "idx": "x2", "val": 19.862278325162059}, {"col": "data", "idx": "x2 data", "val": 18.78433460693109}, {"col": "data", "idx": "xy", "val": 36.888335802498396}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis1247fb24771c4629bb8912925102f98f"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #9:
# <div id="vis14d7938b322f4635a3b0717196c3d0b3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "10", "val": 6.6855978496272765}, {"col": "data", "idx": "100", "val": 8.6848199786939535}, {"col": "data", "idx": "20", "val": 10.248524189785964}, {"col": "data", "idx": "90", "val": 8.533787165579291}, {"col": "data", "idx": "alpha", "val": 54.641496410435352}, {"col": "data", "idx": "binomial", "val": 10.221613845551206}, {"col": "data", "idx": "called", "val": 8.1489180315806884}, {"col": "data", "idx": "coefficients", "val": 13.914482397018055}, {"col": "data", "idx": "cran", "val": 6.5107331671600042}, {"col": "data", "idx": "cv", "val": 14.961431377257064}, {"col": "data", "idx": "family", "val": 16.13737140084227}, {"col": "data", "idx": "features", "val": 8.5023455786364863}, {"col": "data", "idx": "glm", "val": 13.439836284738286}, {"col": "data", "idx": "glmnet", "val": 102.47592119853255}, {"col": "data", "idx": "hastie", "val": 7.1891851636490856}, {"col": "data", "idx": "help", "val": 6.8343610387058895}, {"col": "data", "idx": "html", "val": 6.6474722984082701}, {"col": "data", "idx": "important", "val": 9.017108513108294}, {"col": "data", "idx": "increases", "val": 13.545985651487497}, {"col": "data", "idx": "installed", "val": 13.389519010258539}, {"col": "data", "idx": "lambda", "val": 59.581433036048459}, {"col": "data", "idx": "lasso", "val": 56.246188005681596}, {"col": "data", "idx": "matrix", "val": 7.6572653551661567}, {"col": "data", "idx": "mse", "val": 6.6002613413095155}, {"col": "data", "idx": "net", "val": 14.183075314436937}, {"col": "data", "idx": "non", "val": 7.805822371767178}, {"col": "data", "idx": "ols", "val": 11.965742071437704}, {"col": "data", "idx": "option", "val": 8.9078561291337728}, {"col": "data", "idx": "package", "val": 14.341374034150203}, {"col": "data", "idx": "parameter", "val": 9.0572770185662339}, {"col": "data", "idx": "pick", "val": 8.412177068458309}, {"col": "data", "idx": "plot", "val": 16.293837331098558}, {"col": "data", "idx": "problem", "val": 7.4218310069950917}, {"col": "data", "idx": "purpose", "val": 7.2589276619140746}, {"col": "data", "idx": "regularization", "val": 15.811846821151732}, {"col": "data", "idx": "ridge", "val": 37.811553211731116}, {"col": "data", "idx": "ridge regression", "val": 16.262349800862058}, {"col": "data", "idx": "saying", "val": 8.5831058253843331}, {"col": "data", "idx": "seeing", "val": 9.1510401509995507}, {"col": "data", "idx": "shouldn", "val": 7.4095245943849264}, {"col": "data", "idx": "shrinkage", "val": 8.4581279470141695}, {"col": "data", "idx": "solved", "val": 13.438828398348299}, {"col": "data", "idx": "source", "val": 10.084973173326112}, {"col": "data", "idx": "std", "val": 7.0973097531438709}, {"col": "data", "idx": "true", "val": 9.0772641735857675}, {"col": "data", "idx": "tuning", "val": 8.5902876966150323}, {"col": "data", "idx": "uses", "val": 6.9756246184934367}, {"col": "data", "idx": "value", "val": 10.24252775456724}, {"col": "data", "idx": "william", "val": 9.8505465331964892}, {"col": "data", "idx": "zero", "val": 10.398631280372745}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis14d7938b322f4635a3b0717196c3d0b3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #10:
# <div id="vis242f46a44db249e6859656d68700274b"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
# ...
#          chart({el: "#vis362e034c3bf94f96b38b6ce46301844d"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #27:
# <div id="vis1041f0333ea34eeb84e5177251bbe622"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "analysis", "val": 10.80017105162945}, {"col": "data", "idx": "applicable", "val": 9.7128767484589318}, {"col": "data", "idx": "applies", "val": 8.8328695834702078}, {"col": "data", "idx": "assumptions", "val": 7.2332379765995869}, {"col": "data", "idx": "bayes", "val": 8.9458519512844035}, {"col": "data", "idx": "bayesian", "val": 7.7667030245421165}, {"col": "data", "idx": "binomial", "val": 12.01578313942481}, {"col": "data", "idx": "built", "val": 7.3513079666640762}, {"col": "data", "idx": "class", "val": 6.8831513965636262}, {"col": "data", "idx": "classes", "val": 7.7197675070946135}, {"col": "data", "idx": "classification", "val": 34.398118588780385}, {"col": "data", "idx": "discriminant", "val": 34.557240290546915}, {"col": "data", "idx": "discriminant analysis", "val": 22.732053542786105}, {"col": "data", "idx": "familiar", "val": 6.8966882497323816}, {"col": "data", "idx": "family", "val": 8.6856594779777208}, {"col": "data", "idx": "fit", "val": 7.1827432214343787}, {"col": "data", "idx": "function", "val": 7.3067777749247149}, {"col": "data", "idx": "gaussian", "val": 15.740434089340392}, {"col": "data", "idx": "glm", "val": 17.489955339853676}, {"col": "data", "idx": "guess", "val": 7.6185110714319135}, {"col": "data", "idx": "higher", "val": 9.2994860142381448}, {"col": "data", "idx": "hypothesis testing", "val": 7.0443956172635742}, {"col": "data", "idx": "introduction", "val": 9.0451751468520794}, {"col": "data", "idx": "lda", "val": 11.361746988069516}, {"col": "data", "idx": "linear", "val": 37.274075773076731}, {"col": "data", "idx": "linear models", "val": 8.3773127533477165}, {"col": "data", "idx": "linear regression", "val": 45.576441398053824}, {"col": "data", "idx": "logistic", "val": 76.692158921268401}, {"col": "data", "idx": "logistic regression", "val": 70.244324358507342}, {"col": "data", "idx": "logit", "val": 16.242867226828047}, {"col": "data", "idx": "loop", "val": 8.111215035190444}, {"col": "data", "idx": "lower", "val": 8.4248716408628539}, {"col": "data", "idx": "mass", "val": 8.6071988512248669}, {"col": "data", "idx": "methods", "val": 10.273701107087264}, {"col": "data", "idx": "model", "val": 8.9205440780591871}, {"col": "data", "idx": "models", "val": 32.116555805514899}, {"col": "data", "idx": "multivariate", "val": 16.425503558872432}, {"col": "data", "idx": "odds", "val": 7.7578424290546319}, {"col": "data", "idx": "predict", "val": 9.248026456944352}, {"col": "data", "idx": "probabilities", "val": 11.965535595043226}, {"col": "data", "idx": "probability", "val": 13.943534321196966}, {"col": "data", "idx": "regression", "val": 61.064797427103159}, {"col": "data", "idx": "regression model", "val": 18.18590622586543}, {"col": "data", "idx": "resampling", "val": 7.7120174450737125}, {"col": "data", "idx": "response", "val": 7.9677859230507924}, {"col": "data", "idx": "simple linear", "val": 10.851978419815431}, {"col": "data", "idx": "structured", "val": 7.6554850667281817}, {"col": "data", "idx": "svm", "val": 11.566252937505329}, {"col": "data", "idx": "vs", "val": 7.3666695203755932}, {"col": "data", "idx": "watch", "val": 14.833085485484542}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis1041f0333ea34eeb84e5177251bbe622"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #28:
# <div id="visa39d169159e44d9397169b1b75491d13"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "answer", "val": 14.678303693902167}, {"col": "data", "idx": "block", "val": 30.382117297401319}, {"col": "data", "idx": "block bootstrap", "val": 25.735400878305821}, {"col": "data", "idx": "bootstrap", "val": 57.071876071830232}, {"col": "data", "idx": "bootstrap sample", "val": 31.230311814784883}, {"col": "data", "idx": "bootstrap samples", "val": 29.417697961495836}, {"col": "data", "idx": "bootstrapping", "val": 20.738077080075847}, {"col": "data", "idx": "data", "val": 17.157737107265596}, {"col": "data", "idx": "data point", "val": 29.467354120150958}, {"col": "data", "idx": "data points", "val": 33.05346878480735}, {"col": "data", "idx": "data set", "val": 13.561776782308204}, {"col": "data", "idx": "data sets", "val": 13.280327371295009}, {"col": "data", "idx": "deviation", "val": 13.286197907533376}, {"col": "data", "idx": "distribution", "val": 14.155523643693355}, {"col": "data", "idx": "equal", "val": 10.945201375553209}, {"col": "data", "idx": "errors", "val": 13.488581944848052}, {"col": "data", "idx": "formula", "val": 11.017851463175138}, {"col": "data", "idx": "given", "val": 10.693174526938225}, {"col": "data", "idx": "helps", "val": 10.495887835681231}, {"col": "data", "idx": "independent", "val": 19.906560577764772}, {"col": "data", "idx": "non", "val": 10.269063521765966}, {"col": "data", "idx": "normal", "val": 10.852806745177478}, {"col": "data", "idx": "number", "val": 14.738846098276293}, {"col": "data", "idx": "observations", "val": 12.785874581519025}, {"col": "data", "idx": "order", "val": 12.198642706831718}, {"col": "data", "idx": "original", "val": 10.291775286594955}, {"col": "data", "idx": "point", "val": 15.63230170071953}, {"col": "data", "idx": "points", "val": 27.699605563726792}, {"col": "data", "idx": "population", "val": 10.54410296182062}, {"col": "data", "idx": "probability", "val": 14.769693989001109}, {"col": "data", "idx": "question", "val": 10.711786958363374}, {"col": "data", "idx": "randomly", "val": 19.369043554498951}, {"col": "data", "idx": "replacement", "val": 25.339065408278667}, {"col": "data", "idx": "resampling", "val": 11.313959814876412}, {"col": "data", "idx": "sample", "val": 38.58422365995834}, {"col": "data", "idx": "sample size", "val": 25.564391679061671}, {"col": "data", "idx": "sampled", "val": 12.322186213588603}, {"col": "data", "idx": "samples", "val": 45.416851584309157}, {"col": "data", "idx": "sampling", "val": 21.135171117069742}, {"col": "data", "idx": "series", "val": 28.908264917702041}, {"col": "data", "idx": "set", "val": 11.175555728815048}, {"col": "data", "idx": "sets", "val": 13.07766498914747}, {"col": "data", "idx": "size", "val": 33.733585511411377}, {"col": "data", "idx": "standard", "val": 25.847113778056059}, {"col": "data", "idx": "standard deviation", "val": 13.467608998425055}, {"col": "data", "idx": "standard error", "val": 16.292758679708143}, {"col": "data", "idx": "standard errors", "val": 13.246457224442063}, {"col": "data", "idx": "time", "val": 22.281250714291392}, {"col": "data", "idx": "time series", "val": 32.386690671390333}, {"col": "data", "idx": "uncorrelated", "val": 10.648513314071025}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visa39d169159e44d9397169b1b75491d13"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #29:
# <div id="vis03892b4aaf5d4472aa884e60bd83120a"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "200", "val": 35.299434740486817}, {"col": "data", "idx": "asks", "val": 8.3918971398625661}, {"col": "data", "idx": "bit", "val": 8.2432406428035705}, {"col": "data", "idx": "check", "val": 9.1938486060706719}, {"col": "data", "idx": "columns", "val": 12.285380607057096}, {"col": "data", "idx": "component", "val": 26.334730606101093}, {"col": "data", "idx": "components", "val": 61.414929723983157}, {"col": "data", "idx": "compute", "val": 8.1265382896773666}, {"col": "data", "idx": "concept", "val": 8.1331730454060462}, {"col": "data", "idx": "covariance", "val": 12.51882531857034}, {"col": "data", "idx": "create", "val": 11.042695851203337}, {"col": "data", "idx": "data frame", "val": 11.417499558003797}, {"col": "data", "idx": "data train", "val": 8.6765906990947315}, {"col": "data", "idx": "difference", "val": 8.4870175502860707}, {"col": "data", "idx": "egin", "val": 9.9023793503685447}, {"col": "data", "idx": "explain", "val": 8.582992958422917}, {"col": "data", "idx": "explained", "val": 19.721023284719156}, {"col": "data", "idx": "feature", "val": 13.810671576520638}, {"col": "data", "idx": "features", "val": 13.917991697190816}, {"col": "data", "idx": "frame", "val": 12.550662430990474}, {"col": "data", "idx": "lm data", "val": 8.7701280646384152}, {"col": "data", "idx": "matrix", "val": 14.30266372167627}, {"col": "data", "idx": "mean squared", "val": 9.7008442721575445}, {"col": "data", "idx": "note", "val": 9.3022316680949189}, {"col": "data", "idx": "obs", "val": 8.8233459750804268}, {"col": "data", "idx": "original", "val": 15.444516444506517}, {"col": "data", "idx": "orthogonal", "val": 14.70448312809963}, {"col": "data", "idx": "pc", "val": 24.339632489436124}, {"col": "data", "idx": "pca", "val": 87.508185045896411}, {"col": "data", "idx": "pr", "val": 19.708672558726146}, {"col": "data", "idx": "predict function", "val": 7.8768509897739172}, {"col": "data", "idx": "principal", "val": 67.544821795053778}, {"col": "data", "idx": "principal components", "val": 59.087368825680727}, {"col": "data", "idx": "product", "val": 9.0657640162983064}, {"col": "data", "idx": "proportion", "val": 20.741590858373367}, {"col": "data", "idx": "rbind", "val": 12.686789732564973}, {"col": "data", "idx": "rows", "val": 16.357748867746267}, {"col": "data", "idx": "scale", "val": 12.122067069750452}, {"col": "data", "idx": "squared", "val": 9.7240387318620094}, {"col": "data", "idx": "sum", "val": 16.544252936926906}, {"col": "data", "idx": "summary", "val": 8.320382916870372}, {"col": "data", "idx": "test", "val": 16.631705553937437}, {"col": "data", "idx": "test data", "val": 11.781922629784539}, {"col": "data", "idx": "test set", "val": 9.2240393398835323}, {"col": "data", "idx": "train", "val": 15.146186230335731}, {"col": "data", "idx": "train data", "val": 14.039149482621891}, {"col": "data", "idx": "var", "val": 18.364762830884153}, {"col": "data", "idx": "variance", "val": 17.352284666385824}, {"col": "data", "idx": "vector", "val": 11.008434294024093}, {"col": "data", "idx": "vectors", "val": 11.069253453410766}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis03892b4aaf5d4472aa884e60bd83120a"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
#Write file to EXCEL for labeling each comment by hand
# import csv
# reload(sys)
# sys.setdefaultencoding("utf-8")

# myfile = csv.writer(open("grouped_comments.csv", 'wb'))
# for g in grouped_comments:
#     myfile.writerow([g])

# %% [markdown]
# ##Latent Dirichlet Allocation (LDA) by using `gensim` library
#
# > Gensim unfortunately isn't sklearn friendly.
#
# > Take corpus again and run it through the mmcorpus. Then use it for LDA model in gensim.

# %%
#NLTK-generated corpus vector
stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words)

def cleanDoc(doc):
    stopset = stop_words
    stemmer = nltk.PorterStemmer()
    lemmatizer = nltk.WordNetLemmatizer()
    tokens = WordPunctTokenizer().tokenize(doc)
    clean = [token.lower() for token in tokens if token.lower() not in stopset and len(token) > 2]
    stemmed = [stemmer.stem(word) for word in clean]
    final = [lemmatizer.lemmatize(word) for word in stemmed]
    return final


cleaned = []
for line in grouped_comments:
    cleaned.append(' '.join(cleanDoc(line)))

class MyCorpus(object):
    def __iter__(self):
        for line in cleaned:
            yield dictionary.doc2bow(line.lower().split())

corpus = MyCorpus()

# %%
#corpus = gensim.matutils.Sparse2Corpus(X.T) #corpus vector directly from scipy sparse matrix

# collect statistics about all tokens
dictionary = corpora.Dictionary(line.lower().split() for line in cleaned)
# remove stop words and words that appear only once

stop_ids = [dictionary.token2id[stopword] for stopword in stop_words 
            if stopword in dictionary.token2id]
once_ids = [tokenid for tokenid, docfreq in dictionary.dfs.iteritems() 
            if docfreq == 1 or docfreq == 2 or docfreq == 3 or docfreq == 4]
dictionary.filter_tokens(stop_ids + once_ids) # remove stop words and words that appear only once
dictionary.compactify() # remove gaps in id sequence after words that were removed
dictionary.save('questions.dict')
print(dictionary)


corpora.MmCorpus.serialize('questions.mm', corpus)
corpora.SvmLightCorpus.serialize('questions.svmlight', corpus)
corpora.BleiCorpus.serialize('questions.lda-c', corpus)
#corpora.LowCorpus.serialize('questions.low', corpus)

# ##Then the dictionary and corpus can be used to train using LDA

mm = corpora.MmCorpus('questions.mm')
blei = corpora.BleiCorpus('questions.lda-c')
#low = corpora.LowCorpus('questions.low')
# Out:
# Dictionary(1738 unique tokens)

# %%
print(mm)
# Out:
# MmCorpus(1071 documents, 1738 features, 49088 non-zero entries)

# %%
#LDA model
import warnings
warnings.filterwarnings('ignore')

lda = gensim.models.ldamodel.LdaModel(corpus = blei, 
                                      id2word = dictionary, 
                                      num_topics = n_topics, 
                                      #update_every = 1, 
                                      #chunksize = 10000, 
                                      passes = 4,
                                      )
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes to improve accuracy

# %%
for i in range(0, lda.num_topics-1):
    print lda.print_topic(i)
# Out:
# 0.074*plot + 0.014*use + 0.014*line + 0.013*ight + 0.012*data + 0.012*point + 0.011*right + 0.010*valu + 0.010*advertis + 0.010*look
# 0.035*use + 0.025*regress + 0.022*data + 0.021*model + 0.018*balanc + 0.014*coeffici + 0.014*linear + 0.013*incom + 0.012*lasso + 0.010*default
# 0.021*error + 0.021*packag + 0.017*normal + 0.013*point + 0.010*think + 0.009*distribut + 0.008*hat + 0.008*estim + 0.008*deadlin + 0.007*elemstatlearn
# 0.033*dimens + 0.022*cube + 0.021*boundari + 0.020*volum + 0.019*point + 0.016*answer + 0.014*squar + 0.014*problem + 0.014*think + 0.012*question
# 0.033*cours + 0.019*learn + 0.016*statist + 0.011*question + 0.011*great + 0.010*book + 0.009*model + 0.009*like + 0.009*thank + 0.009*use
# 0.023*model + 0.019*interact + 0.018*data + 0.018*effect + 0.014*use + 0.014*correl + 0.012*radio + 0.011*coeffici + 0.010*think + 0.009*mean
# 0.036*data + 0.035*model + 0.034*error + 0.032*set + 0.030*test + 0.021*use + 0.021*train + 0.014*estim + 0.011*valid + 0.011*question
# 0.020*compon + 0.019*valu + 0.014*sum + 0.014*princip + 0.013*use + 0.013*like + 0.013*glmnet + 0.012*squar + 0.011*vector + 0.010*direct
# 0.070*function + 0.055*tsboot + 0.041*block + 0.030*boot + 0.020*pas + 0.016*estim + 0.015*1000 + 0.015*fix + 0.014*data + 0.013*use
# 0.057*interv + 0.039*confid + 0.037*valu + 0.028*true + 0.020*null + 0.018*sampl + 0.018*probabl + 0.013*paramet + 0.012*hypothesi + 0.012*error
# 0.038*video + 0.031*download + 0.023*use + 0.019*book + 0.017*pdf + 0.014*work + 0.014*tri + 0.013*link + 0.013*lectur + 0.012*page
# 0.076*fit + 0.049*age + 0.046*salari + 0.021*data + 0.021*valu + 0.016*spline + 0.016*reg + 0.015*line + 0.013*horsepow + 0.013*mpg
# 0.112*watch + 0.018*video + 0.017*sampl + 0.013*use + 0.012*download + 0.011*regress + 0.011*>.< + 0.010*cours + 0.009*data + 0.009*model
# 0.039*video + 0.039*quiz + 0.034*lectur + 0.020*question + 0.018*section + 0.016*cours + 0.014*quizz + 0.014*thank + 0.013*imag + 0.013*upload
# 0.062*cours + 0.045*nameredac_anon_screen_name_redact + 0.031*learn + 0.022*thank + 0.022*work + 0.018*statist + 0.011*use + 0.011*great + 0.010*data + 0.009*lot
# 0.031*mean + 0.020*matrix + 0.016*varianc + 0.016*standard + 0.015*covari + 0.014*just + 0.014*bayesian + 0.013*valu + 0.012*sampl + 0.012*use
# 0.054*model + 0.048*variabl + 0.019*predictor + 0.018*use + 0.014*fit + 0.013*regress + 0.012*set + 0.012*data + 0.011*test + 0.010*differ
# 0.038*probabl + 0.020*answer + 0.019*question + 0.017*data + 0.017*point + 0.016*class + 0.015*sampl + 0.013*function + 0.010*credit + 0.009*use
# 0.021*use + 0.017*test + 0.016*data + 0.015*estim + 0.013*model + 0.013*fit + 0.013*sampl + 0.012*mean + 0.012*predict + 0.011*valu
# 0.030*data + 0.027*hat + 0.024*fit + 0.022*model + 0.014*squar + 0.013*error + 0.012*linear + 0.012*coeffici + 0.011*sum + 0.011*valu
# 0.030*use + 0.024*mean + 0.023*matrix + 0.022*log + 0.018*base + 0.013*coursera + 0.012*col + 0.011*standard + 0.011*scale + 0.010*glmnet
# 0.045*linear + 0.031*model + 0.025*regress + 0.023*eta_0 + 0.022*predict + 0.020*epsilon + 0.016*eta_1 + 0.016*variabl + 0.014*use + 0.014*x_1
# 0.034*test + 0.029*column + 0.028*mathrm + 0.023*compon + 0.022*matrix + 0.021*pca + 0.020*200 + 0.019*use + 0.019*princip + 0.018*300
# 0.040*data + 0.022*sampl + 0.021*use + 0.019*bootstrap + 0.017*answer + 0.015*mean + 0.015*error + 0.014*function + 0.014*set + 0.013*differ
# 0.020*video + 0.016*file + 0.014*work + 0.014*use + 0.014*like + 0.013*data + 0.012*rdata + 0.012*>.< + 0.011*problem + 0.011*download
# 0.043*function + 0.030*100 + 0.022*knot + 0.022*reg + 0.021*spline + 0.020*thank + 0.015*lasso + 0.015*basi + 0.015*summari + 0.015*variabl
# 0.024*use + 0.022*varianc + 0.021*data + 0.016*bia + 0.014*learn + 0.013*tree + 0.011*cours + 0.010*model + 0.009*fit + 0.009*good
# 0.028*data + 0.028*file + 0.027*packag + 0.023*islr + 0.020*use + 0.018*instal + 0.016*work + 0.015*auto + 0.014*csv + 0.013*load
# 0.025*use + 0.024*variabl + 0.022*glm + 0.021*data + 0.018*function + 0.017*forward + 0.015*fit + 0.014*model + 0.013*formula + 0.012*error

# %%
#Matching NMF topics with LDA topics

nmf_lda=[]
for topic_idx, topic in enumerate(nmf.components_):

    words = [feature_names[i] for i in topic.argsort()[:-(n_top_words):-1]]
    nmf_lda.append(lda[dictionary.doc2bow(words)])

for k, v in enumerate(nmf_lda): print max(nmf_lda[k])
# Out:
# (26, 0.68386376664475768)
# (29, 0.75833333333332686)
# (10, 0.89259259258782031)
# (27, 0.83888888888873714)
# (13, 0.75833333333322794)
# (14, 0.83888888888884405)
# (6, 0.80666666666659348)
# (27, 0.47484136537521132)
# (8, 0.89259259259258417)
# (20, 0.86190476190469101)
# (27, 0.80666666666661802)
# (23, 0.9121212121209864)
# (19, 0.49287398618792549)
# (20, 0.39915323630615379)
# (10, 0.83888888888885882)
# (16, 0.80666666666658704)
# (11, 0.75833333333323327)
# (24, 0.3405340321194717)
# (3, 0.86190476190474763)
# (10, 0.19675021888692246)
# (26, 0.60061417643204973)
# (27, 0.90333333333332178)
# (9, 0.75833333333330943)
# (25, 0.36002084080208496)
# (5, 0.6086282636994198)
# (22, 0.14671307528780936)
# (29, 0.089503400945036379)
# (28, 0.21632399529086938)
# (23, 0.42660814204476344)
# (22, 0.36352087614598927)

# %% [markdown]
# > Try Pachinko Allocation Model
#
# > Anchor word algorithm

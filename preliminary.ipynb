# %%
import pandas as pd
import numpy as np
import sys
import logging
import seaborn 
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
from time import time

from sklearn import metrics
from sklearn.metrics.pairwise import linear_kernel,pairwise_distances
from sklearn.feature_extraction import text as txt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer, HashingVectorizer
from sklearn import decomposition

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation

from optparse import OptionParser

import bs4 as bs4
import re, sys

from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
forum = pd.read_csv("statsLearningForum.csv", quoting = 2, header = None, 
                    escapechar = "\\", encoding = "ISO-8859-1")

# %%
forum.columns = ["anon_screen_name", "type", "anonymous", "anonymous_to_peers", 
                 "at_position_list", "user_int_id", "body", "course_display_name", 
                 "created_at", "votes", "count", "down_count", "up_count", "up", "down",
                 "comment_thread_id", "parent_id",  "parent_ids", "sk","extra"]

# %%
pd.options.display.max_colwidth=110
#forum.head()

# %%
del forum["anon_screen_name"]
del forum["at_position_list"]
del forum["extra"]
del forum["course_display_name"]

# %%
forum.body.head()
# Out:
# 0    Welcome to the discussion forum! We are hoping this will be a useful place for us to discuss anything rela...
# 1                                           Thank you , Sir!\nIts great to have this Stat learning class from you.
# 2                                                Great to have online free textbook - here's to some "R" learning.
# 3                                                  Will we be able to download the videos as in other edX courses?
# 4                                                     FYI this is not an edX course but a Stanford OpenEdX course.
# Name: body, dtype: object

# %%
#Create "final_corpus", "all_questions", and "all_comments"

#"all_questions" are not only rows labeled "CommentThread" but also rows where there is a question mark - i.e.
#clearly a question and not just someone making a statement to initiate a chain.

corpus = []
for body in forum.body:
    corpus.append(''.join(body))    

#Clean junk in strings
final_corpus = []
for c in corpus:
    unicode(c)
    final_corpus.append(c.replace("\n"," ").replace("\n\n"," "))

print len(final_corpus)

questions = [ f for f in forum.body[forum.type=="CommentThread"] if "?" in f ]
#Clean junk in strings
all_questions = []
for q in questions:
    unicode(q)
    all_questions.append(q.replace("\n"," ").replace("\n\n"," "))

print len(all_questions)

all_comments = [ comment for comment in final_corpus if comment not in all_questions ]

print len(all_comments)
# Out:
# 5803
# 851
# 4952

# %%
#TF-IDF calculation on "all_questions"
#Prior to any topic modeling or clustering
#This doesn't work very well - take a look at the questions that are grouped together

tfidf = TfidfVectorizer(encoding='utf-8', lowercase = True, 
                        stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words))
tfid = tfidf.fit_transform(all_questions)

print tfid.shape
# Out:
# (851, 5046)

# %%
#Get the top 10 most similar questions using cosine similarity for each question

cosine_similarities = linear_kernel(tfid, tfid)

most_similar_index = []
for similar in cosine_similarities:
    most_similar_index.append(similar.argsort()[-10:][::-1])

print len(most_similar_index)
# Out:
# 851

# %%
for questions in most_similar_index[:10]:
    print "------------------------"
    for q in questions:
        print q, ":", all_questions[q]
# Out:
# ------------------------
# 0 : Does this course have an option to download video material? It will help for offline viewing and for locations with slow Internet access
# 89 : It would be nice if this course were offered thru Coursera.  Has anybody found the way to save video lectures for offline viewing onto their iPad ?
# 817 : Hello! I have a question:  The last notice about the course was: "The new course termination date is April 4, an extension by two weeks. This applies to all the quizzes, and access to course materials".  That last part **"access to course materials"**  is worrying me, **what does it mean as access?** Because what I used to do was download the videos from youtube and watch them in my ipad (for convinience because sometimes I didn't have access to internet), I did this for most of them so I'm worried that my record will not count in that matter. I've already watched every video, some online, some in my ipad.     Thank you.
# 246 : Anyone using an iPad mini for viewing the course material? Any limitations there?
# 140 : I'm a student at a high school that allows access to the internet. However, YouTube is blocked. In the Stanford online course, Environment Physiology, the individual video lectures could be downloaded. Can you offer to download the different lectures as well as embedded code to YouTube? I'm sure there are also other people who are taking this course that have limited access to YouTube as well.
# 640 : The video quality of .mov file available for download through download link is quite poor (slide text shown in the video are often blur).  Additionally since youtube in our country is blocked so it is not possible to view the course video directly.  It would be great help if someone can list down all the youtube video url for each lecture. For example the video url for lecture (Ch5-Resampling in R) is      https://www.youtube.com/watch?feature=player_embedded&v=YVSmsWoBKnA   Once this url is available, i can then download the video using www.clipconverter.cc
# 748 : I could not find the answer to this on the site.  I understand that the deadline for the course certificate is April 4, but what happens to the course material (slides, videos, R code) after April 4?  Will we retain access at that point?  Thank you.
# 5 : Dear colleagues,  Thank you for this course and its materials. my internet speed is low in Iran and i have exhausting problem to online learning. may I ask you to provide a possibility to download course materials include videos, please? Bests, H.M.V
# 821 : Hello everyone, I am a student learning statistic but English is not my native language. Therefore, I find it difficult to watch the lecture video without caption. Does anyone know how to download the subtitle file for the video(.swf)? In addition, the video which I downloaded is blur and hard to read words, I want to find the source for better quality of video. Thanks for reading!
# 139 : Does anyone know how to gain access to the R Sessions that are not HTML files? Thank you
# ------------------------
# 1 : Hi all,  Is it possible to download the subtitles as srt format?  Thanks!
# 763 : Is it possible to download all of the discussion threads (with responses)?
# 149 : I'd like to download it. Don't see it under "R Sessions".  Where might I find it? Thanks.
# 254 : Hi all. I'm very glad to participate this course. I saw that we can download de full video of each class. Is it possible to release also the captions? If is, how?  Thanks a lot!
# 287 : For categorical variables, do we always need to create dummy variables (0-1 format) for each class? why can't we simply use something like 1-yellow, 2-blue, 3-red...
# 39 : Hi,  Is it possible that we use Matlab instead of R in writing codes?
# 36 : Hi, Everyone,     I am in China where Youtube is blocked by the Great-Fire-Wall. So are there any other approaches or servers for me to visit or download the videos?        Thanks
# 262 : "If we have n data points, what is the probability that a given data point does not appear in a bootstrap sample?"  What is the format of the answer accepted? just a real number? I used fractionals and reals but it doesn't seems to get accepted... anyone got this question right? thanks
# 257 : Hello, I normally use Minitab for statistical analysis and I wanted to get the Lab files (such as Carseats in chapter 3) in CSV or text format so that I can do the exercises with Minitab.  I haven't been able to find them on the ISRL site. Could you help please ? Thanks, <nameRedac_anon_screen_name_redacted>
# 423 : Hi everyone,  I just would like to know, why do we get 2 coefficients in LDA for the R example in the lecture?  Thanks!
# ------------------------
# 2 : Seriously, have you looked at those questions in light of the material in the lecture? You either need to do a helluva lot better job of explaining the difference between supervised or unsupervised learning, or you need to write questions that are decidable based on the information available in the lecture.  The first question presents four learning problems.  1. Predict whether a website user will click on an ad     no training data mentioned.   2. Find clusters of genes that interact with each other     no training data mentioned,     clustering is mentioned explicitly in the lecture as an unsupervised training    problem.   3. Classify a handwritten digit as 0-9 from labeled examples     measurable outcome, and training data is available - supervised!   4. Find stocks that are likely to rise      No training data mentioned, so not supervised   And seriously, question 2?   What's up with that question?  The answer has one out of three goals for supervised learning, but because the other two are not mentioned it is incorrect?  This is like a game of simon says?   simon didn't say  "Understand which inputs affect the outcome, and how" so the answer is incorrect? No, the answer is correct, perhaps incomplete, but predicting IS a goal of supervised learning.  You guys are just playing games here.
# 48 : Why the #1 is a supervised learning and not #2, even though we can have sample of genes cluster?  1) Predict whether a website user will click on an ad  2) Find clusters of genes that interact with each other
# 60 : Hello there, I copy here the text of the question.   > Which of the following are supervised learning problems? More than one > box can be checked.    >-  Predict whether a website user will click on an ad  > - Find clusters of genes that interact with each other > - Classify  a handwritten digit as 0-9 from labeled examples >- Find stocks that  are likely to rise   As far as I have understood, only in the third answer the Y (response variable) is labelled, also known. Unlikely, in the first answer, it is clear the response variable would be clicking or not in the ad; in the fourth answer, rising or not would be the dependent variable Y, but in the way it is written, it is not clear to me that those response variables are given in the problem.  Thanks in advance for your answers
# 59 : Can Discriminant Analysis be considered an example of supervised learning ?
# 43 : Is is correct to say that ANY supervised learning problem involves prior labeling? As opposed to SOME?
# 152 : True or False: The goal of any supervised learning study is to be able to predict the response very accurately.  Why we don't want to predict the response very accurately? Or the main case of the question, that we can't always do it? Thank you.
# 575 : In the lecture, the professors comment on the selection of 500 genes, based on largest variance, from the thousands available (slide 38).  Professor Hastie explains that this does not bias the outcome because the genes were unsupervised by class.  Can somebody explain what *unsupervised by class* means and how one does it?  Thanks!
# 672 : Good day everyone,  I understand that sequential supervised learning is different from times series ["Machine Learning for Sequential Data: A Review" by Dietterich]. How can I apply bootstrap for these 2 different cases?  Thanks!
# 170 : Confidence interval derived in lecture 3 refers to statistical inference drawn out from the training data. That is, in the context of a given training data, the coefficients are estimated and a given confidence interval is calculated.  Which are the practical uses, in the context of learning, of confidence intervals drawn over training data sets?  Or in a different way: what does that confidence interval (calculated over the training set) tell us about how well the model will perform over other data set (real data, other test data)?.   I have similar question about p-values. For example, if the model is overfitted, the p-value will probably be very small but performance (prediction accuracy) over real data can be poor.
# 408 : I have seen these Bias and Variance graphs multiple times throughout the book. I never figured out how training or test data is used (or in other cases if the true model that generated the training data is even involved). How are the data for these graphs computed really?  Take Figure 6.5 as an example.  ![Figure 6.5 from ISL][1]    [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>77.png  For example, Wikipedia says Bias is E[f_i - E(f_hat_i)]^2  But if I am not mistaken, all these terms need to be estimated? But how?  I just need an equation that explicitly explains how test data or training data is used. I can handle x_ij or Sigma notation. I just don't know if it's right to obtain E(f_hat_i) by averaging over predicted values y_hat_i from all training data x_i (vector).
# ------------------------
# 3 : Hi,  I'm not sure whether it's an issue with Chrome but the slides are quite fuzzy and I'm unable to make out the text and graphics in some of the slides. Does anyone else have the same issues?  <nameRedac_anon_screen_name_redacted>
# 665 : Hi, I have found slides about "Pre-validation" and "Permutation tests" at the very end of Chapter #5 slides, however there are no such materials in video lectures. Am I missing something?
# 443 : Is it possible to remove the duplicate/transition slides from the lecture slides posted for download?  It's pretty unhelpful to have multiple copies (all but the last one incomplete) of many of the slides -- painful for reviewing.
# 24 : If the slides are being typeset with the Beamer package in LaTeX, may I suggest using the handout option, as in documentclass[handout]{beamer}, to reduce the number of pages for those of us who want to print them out? For example, the statistical learning slides are 37 pages, but fit on 30 slides. At 4-to-1, that's an extra two pages. Given the number of enrollees who might want to print them, that adds up quickly. I noticed the linear regression slides are 64 pages on 48 slides.   See section 20 of the Beamer manual for more details if necessary.
# 22 : Hi everyone,  I am unable to hear the audio properly. The voices sound like "chocky". I've tried mozilla and chrome and had the same problem.   Did anyone out there notice it as well?  Regards
# 220 : I understand that you downsize the video to make it fast to download. However, I cannot see the slides clearly, and it is troublesome to switch between video and slides. Can you upload a version of video that is high resolution? You can keep the one with low resolution too in case others need low resolution one.   Thanks.
# 25 : I tried to download and view the lecture slides (shortened url deleted) however, Adobe Reader claims the pdf's are corrupt. This occurs on 2 different machines.  Anyone else seeing this issue?  Staff edit: Download and view the lecture slides here: https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/ba1951b8f66c4cdca2fcaabcdc91b792/  Please don't use url shorteners.  Thanks!
# 594 : Hi - maybe it's just me, but I think there might be additional lecture notes/material that I'm not seeing on the website? I'm now up to Chapter 4 and I'm still having this issue that the lectures seem to leap to the quiz questions and there's nothing in between?   In some cases the quiz refers to a dataset I don't have, and in others it refers to "lecture notes".   I have the pdf of the lecture slides, but they don't seem to contain quite enough information to fill in the gaps.   Is anyone else having this problem?
# 167 : I think this is a important issue, but somewhat there are no details in the textbook, can someone explain it?  Thanks. <nameRedac_anon_screen_name_redacted>
# 45 : Hi there,  Is the solutions to the exercises in the text book available somewhere?
# ------------------------
# 4 : I'm really confused about this hypercube stuff, can anyone explain what this question is asking? Thanks..
# 116 : can anybody help me on this question? i did not understand what are they asking....
# 276 : I'm trying to understand how the hypercube question relates to the curse of dimensionality but can't find a clear connection. I know that most of the data at 50D will be at the 10% extreme of the hypercube, but what does that say about the distance between points?
# 153 : Can someone help me understand the question?  (A hypercube with side length 1 in d dimensions is defined to be the set of points (x1, x2, ..., xd) such that 0?xj?1 for all j = 1, 2, ..., d. Define the boundary region of the hypercube to be the set of all points such that there exists a j for which 0?xj?.05 or .95?xj?1 (i.e., it is the set of all points that have at least one dimension in the most extreme 10% of possible values). What proportion of the volume of a hypercube of dimension 50 is in the boundary region?  Please give your answer as a value between 0 and 1 with 3 significant digits. If you think the answer is 50.52%, you should say 0.505:)
# 406 : Could someone please explain to me how I get the model for question 3.5.R1 I have tried to answer the question but I can't wrap my head around it?  Thank you,
# 44 : I have no clue how to begin this question. I assumed that when p = 50, we would have captured the majority of the hypercube, but how would one begin to calculate something like this?
# 263 : The question states "Consider the linear regression model of y on X1 and X2. To within 10%, what is the standard error for ?1?"  Can someone explain explicitly what "within 10%" means here?  Thanks.
# 167 : I think this is a important issue, but somewhat there are no details in the textbook, can someone explain it?  Thanks. <nameRedac_anon_screen_name_redacted>
# 338 : I don´t understand the wording of this question: *Download the file 5.R.RData and load it into R using load("5.R.RData"). Consider the linear regression model of y on X1 and X2.  To within 10%, what is the standard error for ?1?*  What are they exactly asking by "To within 10%".  Any help welcome.
# 565 : Can anyone explain to me the "-1"?      x=model.matrix(Salary~.-1,data=Hitters)
# ------------------------
# 5 : Dear colleagues,  Thank you for this course and its materials. my internet speed is low in Iran and i have exhausting problem to online learning. may I ask you to provide a possibility to download course materials include videos, please? Bests, H.M.V
# 817 : Hello! I have a question:  The last notice about the course was: "The new course termination date is April 4, an extension by two weeks. This applies to all the quizzes, and access to course materials".  That last part **"access to course materials"**  is worrying me, **what does it mean as access?** Because what I used to do was download the videos from youtube and watch them in my ipad (for convinience because sometimes I didn't have access to internet), I did this for most of them so I'm worried that my record will not count in that matter. I've already watched every video, some online, some in my ipad.     Thank you.
# 793 : Is it possible to look through again materials after course finished?
# 678 : Will the course materials remain accessible to course participants flowing March 21st?  Or, should we download all pdfs and videos we might like to keep for future reference?  Thank you!
# 541 : Will the lecture materials, videos, notes etc. be available after the course is over?  Would be useful for those that want to review at a later point.
# 834 : First of all, Thank you so much to Trevor, Rob and the staffs to making this excellent online course. Well prepared materials and excellent video lectures. It was a wonderful learning experience.   I am interested to have further research and study on Statistical Learning area. Can you suggest any good postgraduate courses or research programs that fit well for students finish this course?  Regards
# 667 : Hello,  I find the videos far more viewable at 1.5x speed, but I am no longer able to get the videos to display at that speed.  Was that a deliberate change?  Thank you, Greg
# 209 : Hi-  I can't seem to get the video to play at any faster speed than 1.0x. When I download and play in VLC Player, it does not render well.  Any ideas on how to watch videos at higher playback speed?  thanks!
# 0 : Does this course have an option to download video material? It will help for offline viewing and for locations with slow Internet access
# 140 : I'm a student at a high school that allows access to the internet. However, YouTube is blocked. In the Stanford online course, Environment Physiology, the individual video lectures could be downloaded. Can you offer to download the different lectures as well as embedded code to YouTube? I'm sure there are also other people who are taking this course that have limited access to YouTube as well.
# ------------------------
# 6 : Hi, is there a possibility to see the videos with a 1.25x speedup? I'd like a quicker pace than 1x, but I can't follow 1.5x, and (at least in Firefox) there is no option in between.
# 667 : Hello,  I find the videos far more viewable at 1.5x speed, but I am no longer able to get the videos to display at that speed.  Was that a deliberate change?  Thank you, Greg
# 515 : I found that quiz formulas don't show appropriately. I didn't notice this problem until a recent firefox update (now I use firefox v20)   I tried IE, but it says it doesn't support the frame or something at all.  Can anyone help? Thanks  Attached: ![formulas don't work][1]     [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>12.png
# 19 : I am using Linux (Kubuntu 13.10).  Because of the course's "Progress" page, I assume there are embedded review questions in the videos.  I have tried watching the videos using both Firefox and Chrome but do not see the questions.  [My expectation is a yellow bar on the playback progress bar as appears with Coursera videos.]  Is my assumption correct about the review questions?  If so, how do I view them using Linux.  Thanks.
# 272 : Hello,  As some of you have noted before, I have found out that while the streaming videos have an optimal image quality, the downloads from the course site (which in my case I reproduce with either VCL on a Fedora <zipRedac>9 OS or with Quicktime on a Mac OS <zipRedac>0.5.8) are blurred.  In fact, one can't distinguish what is written on the screen at all.  Instead, the downloads from Youtube are all right (which I download with the aid of the Firefox add-on that you can find at http://www.downloadhelper.net/install.php).  However, by subscribing to the channel "Statistical learning" in Youtube, I only find the video "<zipRedac>0<zipRedac><zipRedac><zipRedac>3 Lab Meeting".  There are more videos at  https://www.youtube.com/channel/UC4OWDcPB<zipRedac>peiBXDfCSZ3h-w/videos?flow=grid&view=<zipRedac> but the order is not obvious and some lectures are missing.  Does anyone know where can I find all the videos in Youtube and whether the "blurredness" in the videos posted on the course site (once you download them) is going to be fixed at some point?  Thank you very much for this superb course.  Best wishes,  <nameRedac_anon_screen_name_redacted>
# 239 : ![slide 18 in Ch4 classification][1]     [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><zipRedac>38466.jpg  On slide 18 in Ch4 (as above), I don't quite follow why multiclass regression is formulated like this.  - what's k? is it the total number of classes in Y? - what's the expected result from multiclass regression? possibility for each class of Y?  - Do we need to determine which class the Y belongs to and how? what if possibilities are quite close?
# 5 : Dear colleagues,  Thank you for this course and its materials. my internet speed is low in Iran and i have exhausting problem to online learning. may I ask you to provide a possibility to download course materials include videos, please? Bests, H.M.V
# 582 : Is there a way to download high definition versions of the videos?  I don't have access to a particularly fast connection.  Mostly it is not a problem but I can't read the text of the videos of the Section 6 video.  I downloaded the videos and they are even less clear than the streamed versions.
# 775 : Since it comes to the end of the course, is there any possibility that we could have all the discussion section as a document and downloading in case we want to come back and revisit in future? Thanks.
# 423 : Hi everyone,  I just would like to know, why do we get 2 coefficients in LDA for the R example in the lecture?  Thanks!
# ------------------------
# 7 : Topic 2.2 is about Dimensionality and Structured models, while quiz 2.2 r1 asks about bias and variance, which are discussed in topic 2.3. What's the point of asking questions on topics which are not discussed yet?
# 92 : Hi Can somebody provide clues on solving this question ?  I am not sure if the topic is discussed in lect 2.2 ?  TIA
# 116 : can anybody help me on this question? i did not understand what are they asking....
# 194 : I viewed video 4.1 on Categories and then went to take the quiz associated with the video. The question was on Case/Control Samples. I don't recall that being discussed in the video. Am I missing something?
# 29 : The textbook and the lectures have a very specific definition of bias:  ![bias][1]  Does this definition capture the other forms of statistical bias (sample bias, omitted-variable bias, reporting bias, exclusion bias, analytical bias)?   http://en.wikipedia.org/wiki/Bias_(statistics)     [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>97.png
# 144 : Why we dont use different models for apples and oranges? I mean if we have interest in differences.   I dont understand questions 3.4.R1 and 3.4.R2.
# 28 : Test Set MSE can be decomposed into Bias, Variance, and Irreducible Error. "Bias" sounds worse than "Variance". Are they equally bad or is one more bad than the other?
# 8 : Is there any quiz from chapter 1?
# 112 : I think the question means two-sided alternative as one sided alternative were not discussed yet?
# 774 : Really like Introduction to Statistical Learning...plan on getting Elements of Statistical Learning next.   Does anyone else have any recommended books on the topic?
# ------------------------
# 8 : Is there any quiz from chapter 1?
# 37 : Very confused!  In the Courseware section I only see one link to a quiz.  It is for Chapter 2 (four binary-choice questions).  I've noticed some discussion posts about quizzes 1 and 2 ... where's quiz 1?  Or is the quiz for Chapter two 'quiz 1'?  Is there another open quiz?  Also, I've noticed some discussions about Quiz:2.2 R2  ... but I don't know what they're referring to.  Are there R quizzes as well?  Where?  I take it that the R quizzes are separate from the labs.  (The 'R Sessions' link doesn't indicate quizzes)  Can anyone point me in the right direction?  Thanks
# 380 : Is the quiz from section 6.9 missing?
# 459 : Dear all, So under Courseware, for every week there is a tab that says Chapter X quiz and when I click on that I can only see one MCQ question. There are the left and right buttons on top of the quiz but it doesn't seem to work on my laptop. So does that mean there is only one quiz question per week? Or there is something wrong with my web browser.... Thanks heaps for your help guys!!!
# 30 : Hi, what is the due date of quiz 1 and 2?
# 214 : Is there a help file of some sort explaining how the quiz software works?  Sorry to be dense, but I can't figure out what it's doing.  Can I go to the end of a chapter and do all the quiz questions?  If I get an answer wrong, what should I do?  What does the given number of "submits" mean?  Do I have to "Save"?  What if I don't?
# 839 : Can anyone help with this quiz? Are they looking for an numerical answer or in terms of n and k.
# 698 : As indicated by the slides will we get a Chapter 10 courseware package of videos, exercises and quiz ??, If so when, we have 7 days more till March 21st deadline.  regards
# 594 : Hi - maybe it's just me, but I think there might be additional lecture notes/material that I'm not seeing on the website? I'm now up to Chapter 4 and I'm still having this issue that the lectures seem to leap to the quiz questions and there's nothing in between?   In some cases the quiz refers to a dataset I don't have, and in others it refers to "lecture notes".   I have the pdf of the lecture slides, but they don't seem to contain quite enough information to fill in the gaps.   Is anyone else having this problem?
# 421 : Are there problems in each section, other than quiz? For example, I saw this in my progress: 2.4 Classification 0 of 1 possible points (0/1) Review & Quiz due Mar 21, 2014 at 16:30 PDT Problem Scores:    0/1  Where are problems? How could I see them? Thanks
# ------------------------
# 9 : Is there any spanish speaking people interested in creating a group for discussing, just in case, different topics of the course in our mother tongue?
# 813 : I know at least two other people who would be interested in seeing the videos and the book.  Can I direct them somewhere, or is this only available during the course?
# 805 : I understand having a deadline to finish the course helps motivation. However, the possibility of keeping the course open seems like a viable alternative given the format. It'd be nice for people to come back after applying the information to work and share some experiences. And, what will happen to all of this great discussion? Will it just disappear? Given the effort it took to create this course, I'm sure it will be offered again. However, why not just keep the course open?
# 568 : For the model y ~ 1+x+x^2, what is the coefficient of x ...  I got quite different result creating the following two models:  Fit1=lm(y~poly(x,2))  and  Fit2==lm(y~x+I(x^2))  Could someone explain what's the difference for this two models? I thought they should do the same thing, but apparently not.
# 13 : I realise that every student is different, but other MOOC platforms publish the expected volume of work for each course, say 10 hours per week, so that some degree of capacity planning is possible. This is particularly useful for people like me who have taken time off work to 're-purpose' their skills, in my case in data science.  Did the teaching team write anywhere what their expectation is for this course? I would be really grateful to know.  <nameRedac_anon_screen_name_redacted>
# 66 : Hi all,  I am developing a start-up which relies on statistical modelling. I would be interested to know what motivated others to join this course?  What kind of projects is everyone working on? I am quite curious...  M
# 787 : I took this course as an independent study for my degree. I just wonder after we finish this course, are we going to get the certificate? Thanks.
# 7 : Topic 2.2 is about Dimensionality and Structured models, while quiz 2.2 r1 asks about bias and variance, which are discussed in topic 2.3. What's the point of asking questions on topics which are not discussed yet?
# 140 : I'm a student at a high school that allows access to the internet. However, YouTube is blocked. In the Stanford online course, Environment Physiology, the individual video lectures could be downloaded. Can you offer to download the different lectures as well as embedded code to YouTube? I'm sure there are also other people who are taking this course that have limited access to YouTube as well.
# 42 : Hi all -- My statistical training was all in social sciences (sociology, demography) and biomed (public health, clinical trials). To me, this course is kind of like a language class so far. The concepts are familiar but they are called different things. Anyone else having this experience? Here are two examples:  1. "Bias." In this course, bias is a feature of a model. In my training, bias is a feature of the sample (called "training data" in this class), and can never be overcome by anything you do in the model. This class operates on an assumption of "big data," where the costs of drawing another sample are essentially zero, and you don't have to worry about how that sample was drawn. Very different from my "small data" background, where samples are expensive and time-consuming, and the way they are drawn is all important (was it random selection? were there inclusion/exclusion criteria?). In my world, there is no such thing as just "getting some more training datasets"!  2. "Qualitative." Here, the word qualitative is used to mean what I would call a categorical variable. So a "qualitative" model for Hastie is one where the dependent variable has classes rather than continuous numeric values. In my training, "qualitative" research is the kind anthropologists might do: conducting open or guided interviews with a small group of people, and then analyzing the text of those interviews for concepts. Nothing statistical about it. Thoughts, anyone? Other examples?

# %% [markdown]
# >Using pure cosine similarity between questions doesn't work too well.

# %% [markdown]
# ##Group all comments together first by `comment_thread_id` and Text Cleaning

# %%
#Text Cleaning Functions
def mrclean(text):
    '''
    NAME
            mrclean
    SYNOPSIS
            Cleans incoming text
    DESCRIPTION
            Removes all untranslatable unicode
    '''
    c = ['\xe2','\x80','\x93','\xc2','\xa0','\n', '\r', '\u2019', '\n\n', '\x96', 
         'zipredac', 'phoneredac', 'nameRedac_anon_screen_name_redacted']  
    return re.sub('[%s]' % ''.join(c), '', text)

def soupText(eText):
    '''
    NAME
            soupText

    SYNOPSIS
            Removes all the HTML tags using BeautifulSoup

    DESCRIPTION
            Explicitly calls utf-8, replaces all double quotes with single and calls on helper function mrclean
    '''
    eText = str(eText.encode("utf-8").replace("'",'"') )
    soup = bs4.BeautifulSoup(eText)
    cleanText = soup.findAll(text=True)  #.get_text()
    return mrclean(''.join(cleanText))

# %%
#Need to figure out how comments and questions are grouped together
#forum[forum.type == "CommentThread"].head()

#Concatenate all comments together that has the same "comment_thread_id" 
#- i.e. jam all the comments on one question together - this should be better for analysis
concat_comments = forum[forum.type=="Comment"].sort("comment_thread_id").groupby("comment_thread_id").body.sum()

grouped_comments=[]
for c in concat_comments:
    unicode(c)
    soupText(c)
    grouped_comments.append(c)

# %% [markdown]
# ##Stopwords, Lemmatizer, and TfidfVectorizer

# %%
#Discussion forums specific stopwords
additional_stop_words = [
                         "zipredac","phoneredac","nameRedac_anon_screen_name_redacted", 
                         "explanation", "helpful", "yes",
                         "agree","excellent","dear", "thanks",
                         "ok", "cool", "idea", "guys",
                         "hello", "student", "sorry", "makes",
                         "sense", "nice", "meet", "yeah", "wow",
                         "hint", "post", "understand", "helped",
                         ]

# %% [markdown]
# >Token-level analysis such as stemming, lemmatizing, compound splitting, filtering based on part-of-speech, etc. are not included in the scikit-learn codebase, but can be added by customizing either the tokenizer or the analyzer. Here’s a TfidfVectorizer with a tokenizer and lemmatizer using NLTK:

# %%
class LemmaTokenizer(object):
    '''Scikit learn requires the tokenizer to be a callable class if custom made'''
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]

# %% [markdown]
# > Adjusting for "outliers"
# - Adjusting `min_df` and `max_df` affects the results ALOT!!! They will essentially get rid of "OUTLIERS". Tell function to ignore these words because they occurred in either too many (`max_df`) or in too few (`min_df`) documents.
#
# - Setting `min_df`= X means that calculation will include only words that appear in at least X documents. This will throw out many really weird, idiosyncratic, or made-up words that appear rarely and that are not germane to the comment.
#
# - Setting `max_df` = Y means that calculation will exclude words that appear over and over again in every documents. For example, in these forum discussions, there are alot of "thanks", "good", "agree","helpful","helps", "thanks alot" type of words that will throw off calculation. Again, they are not germane to the discussion but will throw off the calcuation. `max_df` is not that relevant if `sublinear_tf` is also turned on since they both do similar things.
#
# - The `sublinear_tf` parameter, when True, transforms the term frequency calculation to: tf = 1 + log(tf).
#
# - This transformation, as the name implies, is sublinear, which in practice lessens the effect of frequently occurring words. Since this calculation is only for the term frequency—and thus only affects the numerator of the tf-idf calculation—having a sublinear transform is a good way to reduce the effect of very common words.
#
# - Bigrams and higher tend to make the results worse.
#
# - NLTK WordNetLemmatizer really screwed things up...

# %% [markdown]
# >Need to throw away URLs in bag of words

# %%
n_samples = len(grouped_comments)
n_features = 10000

tfidf = TfidfVectorizer(min_df = 10, 
                         #max_df =.99,
                         max_features = n_features, 
                         stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words),
                         #tokenizer = LemmaTokenizer(),
                         sublinear_tf=True,
                         ngram_range=(1,2),
                         )

counts = tfidf.fit_transform(grouped_comments[:n_samples])
X = TfidfTransformer().fit_transform(counts)

print X.shape
print len(grouped_comments)
# Out:
# (1071, 1627)
# 1071

# %% [markdown]
# ##K Means Clustering

# %%
#K-means clustering analysis

km = KMeans(n_clusters=30, init='k-means++', max_iter=100, n_init=1,
                verbose=True)
km_fit = km.fit_transform(X)
km_fit.shape
# Out:
# Initialization complete
# Iteration  0, inertia 1020.480
# Iteration  1, inertia 970.885
# Iteration  2, inertia 963.518
# Iteration  3, inertia 960.545
# Iteration  4, inertia 959.708
# Iteration  5, inertia 959.507
# Iteration  6, inertia 959.369
# Iteration  7, inertia 959.337
# Converged at iteration 7
# (1071, 30)

# %% [markdown]
# Below is from a [Stackoverflow article](http://stackoverflow.com/questions/12497252/how-can-i-cluster-document-using-kmean-flann-with-python):
#
# There is one big problem here: K-means is designed for Euclidean distance.
#
# The key problem is the mean function. The mean will reduce variance for Euclidean distance, but it might not do so for a different distance function. So in the worst case, k-means will no longer converge, but run in an infinite loop (although most implementations support stopping at a maximum number of iterations).
#
# Furthermore, the mean is not very sensible for sparse data, and text vectors tend to be very sparse. Roughly speaking the problem is that the mean of a large number of documents will no longer look like a real document, and this way become dissimilar to any real document, and more similar to other mean vectors. So the results to some extend degenerate.
#
# For text vectors, you probably will want to use a different distance function such as cosine similarity.
#
# And of course you first need to compute number vectors. For example by using relative term frequencies, normalizing them via TF-IDF.
#
# There is a variation of the k-means idea known as k-medoids. It can work with arbitrary distance functions, and it avoids the whole "mean" thing by using the real document that is most central to the cluster (the "medoid"). But the known algorithms for this are much slower than k-means.

# %% [markdown]
# ##K-Medoids Clustering
# > Good for very sparse matrix and also can use other distance measures
#
# > Rather than using the mean (which is usually not a real datapoint), K-medoids uses a particular datapoint as the centroid. This makes K-medoids less sensitive to outliers. And in case of text, can give an actual "representative" document of a topic.
#
# Valid values for metric are:
# from scikit-learn: [‘euclidean’, ‘l2’, ‘l1’, ‘manhattan’, ‘cityblock’]
# from scipy.spatial.distance: [‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘correlation’, ‘cosine’, ‘dice’, ‘hamming’, ‘jaccard’, ‘kulsinski’, ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’] See the documentation for scipy.spatial.distance for details on these metrics.

# %%
#K-Medoid
#Can pass in other distances for K-Medoids
import Pycluster
from Pycluster import kmedoids

distances = pairwise_distances(X, metric='euclidean', n_jobs=1)
nb_clusters = 40
clusterid, error, nfound = Pycluster.kmedoids(distances, nclusters= nb_clusters, npass=100)

# %%
#Look at the actual comments that are central to each cluster:
medoids = list(set(clusterid))

for m in medoids:
    print "------------------------"
    print "medoid ", m, ":", grouped_comments[m]
# Out:
# ------------------------
# medoid  0 : Hope to get full benefit of the course. Thanks.Sure! Count me in
# ???? ????It should be a great opportunity to pick up useful ideas on a hot subject from those who have made significant contributions to the field. I wish everyone has the most enjoyable learning experience the next eight weeks.vedio lecture is not opening in pakistanThanks so much for the comment DWaterson.  Glad you enjoyed the course!  I'd recommend taking a look at Elements of Statistical Learning if you want to get further into any of the material (available free online from the authors).  It is a little mathier than ISLR, but that allows one to get further into the models.Hi Enook,
#
# Thanks so much for the comment.  I forwarded your post to the stanford edx people.  One of the main goals of online education is to provide more accessibility, so it is nice to hear it is working!Master's student Medical Informatics at the University of Amsterdam / Academic Medical Center (The Netherlands) present! I look forward to finishing this course.
#
# -<nameRedac_anon_screen_name_redacted>This is an awesome class!
# I have 10yrs of job experience and now I wish to learn statistics as I see how it influences my regular life.yes this should be a real relaxed class that I will love to learn aboutOlá,
#
# I'm very happy with the course and contents and feeling guilty because I gave not the appropriate attention to this discipline before.
#
# Thanks for the opportunity!Thanks, lots of interesting code and method to learn from the course.yes it is because nowadays textbooks are expensiveThank you , Sir!
# Its great to have this Stat learning class from you.Thank you for this course, I hope to learn so much about this. I like the statitics.Thank you for the course. I'm taking it because it's interesting, and maybe I'll find ways to use it later. Last year, I downloaded and started reading ESL, but while I could conceptually understand the presentation, I could not do the exercises. Most of the math was too advanced for me as I've tried to learn math on my own as a hobby. With lectures and a forum and the new ISL, I hope it will be enough for me keep up with this class, and I look forward to the challenge.Hello!  I really appreciate your taking the time and effort to arrange this MOOC and allow a wide variety of folks to take it.  For many of us, making the pilgrimage to Stanford is physically impractical - time constraints and all - so this medium makes it a possibility.  This is my 3rd exposure to R so curious to see how you handle the tricks of the language from a practical basis.  I do appreciate you making the book pdf available for free - very generous on your part.Hello Professors and TA's,
# Thanks for all the hard work you've put into this class.  I'm probably a fairly typical attendee. I'm a middle age guy looking to grow some knowledge in an area that I am interested in but fairly unfamiliar with. The MOOC scene absolutely fascinates me and I find myself wanting to sign up for everything. I have lots of other things pulling at my time like my family and the need to put food on the table and wouldn't be able to risk my limited capital for a traditional bricks and mortars class with the rigidity of the benchmarking process. I just want to learn and I love the fact that this knowledge is available.  I'm grateful. Thank you.Hi, Mr. Hastie and Mr. Tibshirani:
#
# Thank You very much for this wonderful course. I was counting the days left for the beginning, finally here It is!.flattered to follow this online course. Am eager to know the R software as am using SPSS.It's  amazing lectures. I will enjoy it with my friends and classmates.Thanks for offering this course and all the free resources. And many thanks for your efforts.Yep, India in particulargreeting !! Very interested in learning the application part of these course. Especially i would excited to learn R in the level i can use for my graduate study.
#
# Please where can i find the schedule ??Hi, Mate! Came back here after a loooong time. Well, there are a lot of packages written by the Professors and hosted on CRAN (which you can think of as App Store of R); some of them are- gam, glmnet, lars, mda, covTest, glasso, PMA, glmpath, elasticnet, sparsenet, protoclust, SGL, softImputeThank you. Looking forward to fortifying old learning and learning anew.Hello from Zambia, I would like to thank the team behind this training. I personally will benefit a great deal from this class and hope it will improve my statistical interest.Thanks for putting the effort into this work.  The presentations and material show a well thought out plan and an effective use of the available media.  This should be a great experience.  Thank you.Thanks for taking this course, also the book ISLR is very good.Both the sir i am very very very excited to learn this course from both of you. And i am a regular student of this course. I am very thankful to you for offering this course. I know i am going to learn a lot of things in the course. ThanksThanks I'm so happy to be part of this course.are you from asiaI am really excited about the course.
# I am a great fan of ESL so taking a course based on its contents taught by its authors is just, uah!!!
# Thanks for the initiativeThank you for this course.hey thanks for posting the link tooThanks am so happy to be part of this course and I greet you all.I hope to take this course. thanks for offering it openlyProfessor, I really enjoyed watching the intro video. As a first time watching these regression models, words can't explain how beautiful I find the model done with thin-plate spline. Extremely excited to start this course!I am looking forward to this course, as I am a great fan of [The Elements of Statisical Learning][1]. Thanks in advance to Profs. Hastie and Tibshirani for making this possible!
#
#
#   [1]: http://statweb.stanford.edu/~tibs/ElemStatLearn/Yay!  The class is finally starting!  I've been looking forward to this for weeks.Many Thanks for Professors and TA, which spend they valuable time on this course.
# Looking forward for this exciting course.Hola, vivo en Perú, y el curso es muy interesante, espero que se publicite más a países latinoamericanos !A big warm greeting. I'm <nameRedac_anon_screen_name_redacted>, 32 yo programmer from Rome, Italy. I have completed several online courses offered by the Stanford University on Coursera and I love this course too. Both content and presentation are very compelling. I hope I will improve anything I've already learned in the field of applied statistics so far, and also to make it through these weeks the best way I can do. Good luck to everyone!Looking forward to this course. I am excited and intend to follow the entire course schedule.Very interested in learning the application part of these course. Especially that R will be in use. But reading the theoretical part of it is my problem. But i will tryIs the email sent to remind me of this course every week?
# I did not receive any email about the information of this course.I am also looking forward to this class. I am a Econ major at Cal state Fullerton so this class will come in handy later in my studies. I was especially attracted to the part about predicting market behaviors.I joined the course a week late, but was able to catch up fast thanks to the excellent material posted online.Thanks for putting together such a nice course for free. I am liking what i am seeing so far. All your efforts are greats appreciated!!!thank all of you  !
# the class give me a shortcut to understand R and statistical learning !Thanks for this great course and ISL book! It'll be useful to flourish our statistical learning knowledge with applications. Also I'm hoping that you will offer an advanced course based on ESL soon.Hi, Week 1: Introduction and Overview of Statistical Learning (Chapters 1-2, starts Jan 21)
# Week 2: Linear Regression (Chapter 3, starts Jan 25)
# Week 3: Classification (Chapter 4, starts Feb 1)
# Week 4: Resampling Methods (Chapter 5, starts Feb 8)
# Week 5: Linear Model Selection and Regularization (Chapter 6, starts Feb 15)
# Week 6: Moving Beyong Linearity (Chapter 7, starts Feb 22)
# Week 7: Tree-based Methods (Chapter 8, starts Mar 1)
# Week 8: Support Vector Machines (Chapter 9, starts Mar 8)
# Week 9: Unsupervised Learning (Chapter 10, starts Mar 15)Please where can I find the open source R codes
# <nameRedac_anon_screen_name_redacted> BeeThanks for offering this course.  I'm looking forward to this learning experience!Hi Professors! I´m very happy in participate and to be part in Stat Learning course. I´m from Brazil at Universidade do Vale do Itajaí - UNIVALI in Santa Catarina State.Thanks for the book apriori...!!All d best everyone for the learning sessions..!!Si... sobretodo en español...Thanks for bringing all these stuff together in a user-friendly course! It seems that we're gonna have fun with statistics all over the World :)Its a great course indeed. Please suggest something relating to the video problem mentioned in above comments, as we are unable to open any of your videos here in Pakistan.Thank you for providing this great lectures!!You guys all progressed so fast? I just finished lesson 2 and it looks like you finished lesson 3 already?!Hi! Does anyone know whether we receive something like a Certificate or Statement of Accomplishment after successfull completing the course?Thank you, and nice to meet you :-) Been looking forward to doing this course as the authors & ESL are so well known. Great choice of topics!Great to have online free textbook - here's to some "R" learning.Will we be able to download the videos as in other edX courses?Glad to be a course participant. I am enjoying the course already. Thank you for the book. I have some difficulty assessing the quiz. Am I the only one?Thank you , Sir! Its great to be here in Stat learning class. but the video lectures are not opening here in Pakistan. Can you please help?Thank you sir for opening the course. looking forward to the next lectures.I admit that I have a natural resistance to statistics. Whenever someone tells me some theories based on statistics, I would show disinterest right away. To me statistical conclusions are a bit metaphysical and lack of due reasoning. At the same time, I need to deal with it at work to prove my performance and to raise awareness of potential pitfalls so to gain attention from my boss and the office.I hope this course will give me a better understanding on the subject.Hello!
#
# It's great that I can participate in this course and be taught by the best! :)
#
# Best wishes,
# DDI am Medical Doctor working in Nigeria. Has a good grasp of Epidemiology and Biostatistics. Familiar with Stata, looking forward to learning R and other Statistical Modelling methods in this course.Thank for this coure! It's very valuable and instructive curses. I will try to learn everything in this course, because this is the core of machine learning.I love statistics and I study Statistics in Brazil in Universidade Federal de Goiás.What a great course. Thank you!Excited to learn from the bright professors and their invaluable knowledge of statistical techniques, modeling, and analysis.Looking forward to very exciting lectures. Thanks for putting this togetherHello Professor Hastie and Tibshirani,
#
# As a deaf student, I want to think you for the amazing access I experienced with this online course.  The reason I chose this one over others was the fact that it was captioned, which made a world of a difference to me.  Thanks again!I am so excited about this course!!!Professors - I have taken several MOOC via Coursera, edX. However, never seen such a comprehensive course in terms of delivery that includes free books, classes in videos and pdf format, lab sessions for hands on practice and ample time for each section with timeline till March. The content of the course is well thought through as per today's times. Both of you have set the bar pretty high for MOOC courses for other  professors. Kudos to you for such a brilliant job done for teaching and sharing knowledge across the globe. BIG thank you!!Looking forward to this course ;)Thank you , Sir! Its great to have this Stat learning class from you and providing valuable free resources. It'll be great pleasure for me to learn the subject which would be helpful in academic research.Thanks a lot... this was a great experience of learning statisticsThanks sir!  It's my pleasure to follow this course from you.Videos are still not working here, you still got the same problem?Now it is over :( I really would like to thank you both for the excellent material presented and knowledge shared, which resulted extremely valuable to my position - Marketing analytics,I am totally convinced statistics is leading Marketing into another whole Era, greetings from Guadalajara, Mexico!!!
#
# As simple as a day to day pleasure watching you both every morning. I already miss you!!
#
# Warm regards,
#
# Gina :)Thank you for the welcome!  I am really looking forward to learning about statistics and being able to apply what I learn in my job understanding what the people around me are talking about.FYI this is not an edX course but a Stanford OpenEdX course.Hi Sam,
# I will do that as I do have the book as both hard and soft copies. I will also look for this course to be offered for credit again so I may begin the certificate program.Cool!  Hope you enjoyed the class.Very interesting course and quite good for understanding! Also it is a nice way to learn new things and to improve English skills as well!Glad you enjoyed the class Elena!Dear Professor Hastie and Professor Tibshirani as well as Sam and Will, I truly enjoyed this course. It was as I expected it to be. The course title, "Statistical Learning", and the book title, "An Introduction to Statistical Learning with Applications in R", led me to believe this was more of a statistical learning course than a course for learning R. Others seems concerned not enough R was presented, but I felt the course lived up to it's title and I learned some R programming to boot. Though, as a matter of course, I am a statistician who programs and not a programmer who uses statistics. Although, I have been taught many of these statistical methods previous, many I have not. It was great to have a thorough exposition of the many supervised statistical learning methods providing practical compare and contrast between them. I also enjoyed learning about cross-validation and the bootstrap methods of choosing best fit models and parameter estimation when it is otherwise unavailable. These methods suggest a different answer other than the traditional, "we need more samples". Throughout the course and text is discussed high dimensionality which I find very useful and that of prediction accuracy versus interpretable models. I have spent my career in R&D and have never had the luxury of any other than having to interpret the statistical results. In my field people viewed predictive models as always wrong and sometimes useful. It was nice to see the genomic examples of predictive usefulness. I will keep a look out for follow on courses to this one for data science. Many thanks to the teaching team.Thank you, Sir, & Prof. Tibshirani
#
#  - for this course
#  - for the free text books (both ISL & ESL)
#  - for the open source codes in the *lingua franca* of Statistics
#  - and for your contributions to the Subject of Statistics
#
# (not necessarily in that order :-))
#
# <nameRedac_anon_screen_name_redacted>Thanks a lot sir!! Its a great opportunity to learn statistics from you.Is there anyone interested in a greek study group?Hi! I'm really in love with this course :) ! I never laughed so much before while learning statistics.
# I appreciate that you introduce the concepts first and put a bigger stress on understanding instead of inondating the audience with all the mathy notations right away. Also I find interesting all the historical and inter-subject references : they really put thing into perspective for me. The massive use of plots and illustrations is really helpful too.
# You really make studing statistics sexy :)  !
# Thank you for such a wonderful and exciting learning experience!Thanks for the free online textbook! :)Hello there, my name is <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted>, <nameRedac_anon_screen_name_redacted>, from Caracas, Venezuela. I want to thank  all people behind this mooc too. Thanks you very much for your time and for all those resources you have made available for all us of  for free.
# ------------------------
# medoid  129 : SallySue - Thank you so much for the quick response and guidance!ok I just went through all the steps you outlined and when I go to the Chapter 2 Introduction R sessions and click on it, it still tells me to download R. What does it keep doing this? Driving me crazy a little bit. Thanks for your prompt response.Posting down here so I can edit if need be.
#
# ![enter image description here][1]
#
# If you put you cursor on Line 2 of the code and run (circled in red), that line will be executed. In the console window the command is repeated. When you run Line 3, the contents of "x" are listed.
#
# There is no exercise to hand in. This is just a copy of the commands used during the lecture in case you want to try them yourself.
#
# If you want a dataset you have to load it. If you attach the library ISLR (type: library("ISLR") ) you just have to type data(dataset name) and that particular data is available.
#
#   [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>81.jpgThank you SallySue for your response! Looks like I got that to work. So I am trying to understand, as far as R assignments for Grading purposes for this course, is anything to be handed it or is the entire course grade based on these short quizzes?What happens when you open R the program? It should look like a command prompt, if you opened R.exe, or it should look like an old text editor if you opened Rgui.exe, like one of these:
# ![enter image description here][1]
#
#
#   [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>14.png
#
# For the R Sessions file download, rename it with '.txt' or open with Notepad to see the commands. Type them in one line at a time at the prompt > in R. You should see R start giving you some responses.See belowIf you are using the Rgui.exe, download it to your default directory and you can select the File | Open script and you should see a display of all the .R files. Select the one you want and it opens in a text editor within R. You can select one or more lines and execute them without typing. Retyping the commands may help you to learn R faster however and encourages you to try variations on each command.what type of os do you have? if windows, towards the end of the installation it will ask you for the short cut, if you chose no, you will have to find the rgui.exe to run the program. Just go to the R installation folder, then bin, then the bit version of your os, in there, you will see the rgui.exe.Try installing RStudio (http://www.rstudio.com/)I haven't looked at all these, but UCLA is a good resource for lots of statistical computing packages.
#
# http://www.ats.ucla.edu/stat/r/
#
# As said above, RStudio is good. So install it after you install R. The instructional R videos here use RStudio.OK, looks like I got it to work in RStudio, thank you for your responses! But now what I do not understand is this seems to be only a bunch of functions, what is the actual assignment that needs to be done?Where is the run button I don't see it? But what is the dataset, it seems like there is just a bunch of functions out there?
#
# Is there supposed to be some actual exercise that needs to be handed in?I could use some guidance on this, too. I opened Chapter 2's R Session and see the R script in the upper left window of R Studio, but I'm not certain what my task is. Any help will be appreciated.You can run the session and observe what happens.
#
# Put your cursor to the far left of a line of code in the top left window, click Run (top right of window). That command will be run, and the result will appear in the bottom left window.
#
# You can go step by step, or highlight several rows at a time and Run.
#
# You can type commands directly in the Console window, but if they are ones you will use repeatedly then you can put them in the top window and save as a .R file. Then you can open the file whenever you want and run the commands again.Sally, for the LIFE of my, i cannot find the ISLR package....I am completely LOST?
# ------------------------
# medoid  772 : @tjbec:
#
# > Very good points all, and thank you for correcting my
# > loose/sloppy language. I would add that it's true that when
# > in 2-d the the red area in your graph seems like a lot, but
# > in higher dimensions, it'll get swamped by the white
# > area. And so you're likely to wind up at a corner solution
# > where some variables are getting zero weight.
#
# Yes, that's a good point about higher dimensions.
#
# For the benefit of others reading:
#
# This might be visualized by noting that the the shaded red
# areas are only "large" in the radial direction, they are
# narrow in the "sideways" directions.  For example, in 3
# dimensions, they would be like "pencils" coming out from the
# centre  long in one direction, narrow in the two other
# directions.  In higher dimenstions, they would be long in
# one direction and narrow in all others, so they would take up a
# suprisingly small fraction of the total higher dimenstional
# volume.
#
# Even in only 2-dimensions, if the blue diamond is shrunk
# enough, the red shaded regions would be quite narrow and
# only occupy a small fraction of the ("relevant") space.
# And this effect would be greater in high dimenstions.
#
# So, once the penalty "starts to bite", some
# coefficients are likely to get shrunk to zero.@rakhlin:
#
# > So you confirm that hitting an edge is likely but not
# > necessary.
#
# That's right  it's certainly not *necessary*.
#
# How likely it is depends on the situation.
#
# Other things being equal, it will be more likely if the blue
# diamond is smaller.This response is just to add a little to the explantion in an earlier thread
# ([click here for earlier thread](https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2014-course-material-feedback/threads/5302bd339ad87c<phoneRedac>))
# and to the earlier response in this thread.
#
#
# Here's a rough diagram showing that the lasso will not have
# a corner solution (and one of the coefficients will be exactly zero) if the centre of the ellipses is in
# certain zones  shaded red. [*]
# If the centre is in the white area there will ba a corner solution.
# (And of course if the centre is in the blue diamond, there will
# be no shrikage at all.)
#
# ![lasso does not always have corner solution][1]
#
# As the constraint gets tighter (more shrinkage), the blue
# diamond gets smaller, and the zones where there's not a
# corner solution get smaller.  With enough shrinkage, one of
# the coefficients will go to zero.[**]
#
#
# ----
# [*] The ellipses are drawn with no correlation between the two
# estimated slope coefficients, so the axes of symmetry are
# exactly vertical and horizontal.  But the idea would be
# similar if there was correlation between the estimated slope
# coefficients, where the ellipses would be tilted.
#
#
# [**]
# Except, I guess, in circumstances which are so particular that
# they are quite unlikey.
#
#
#   [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac>0<phoneRedac>7.png@tjbecn:
#
# > Well, the RSS will be minimized subject to the restriction
# > at the point where the slope of the two curves is the same
# > (this is why Prof Witten was mentioning calculus). I.e.,
# > you're looking for the spot where the RSS ellipse is
# > tangential to the curve traced out by the restriction
# > (either the circle or the diamond in the picture).
#
# Yes.
#
# > In the case of ridge regression, since the restriction takes
# > the form of a circle it will certainly not be at zero.
#
# Well, at least *extremely* unlikely to be zero.
#
# > For the Lasso, the problem is going to be a "corner
# > solution,"
#
# Not necessarily.
#
# > and the only time you would be "off" the corner of the
# > restriction would be if the RSS ellipse happens to have
# > slope -1 tangential to the diamond in the picture. This is
# > a very special case.
#
# It's not necessarily that special
#  check out the first response in
# [this thread.](https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2014-course-material-feedback/threads/5302bd339ad87c<phoneRedac>)
#
# Edit: See also the response (with diagram) later in this thread.Check out the first response in
# [this post.](https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2014-course-material-feedback/threads/5302bd339ad87c<phoneRedac>)
#
# It explains why a zero coefficient would be a very special
# case in ridge regression, but is not such a special case
# with lasso.Well, the RSS will be minimized subject to the restriction at the point where the slope of the two curves is the same (this is why Prof Witten was mentioning calculus). I.e., you're looking for the spot where the RSS ellipse is tangential to the curve traced out by the restriction (either the circle or the diamond in the picture).
#
# In the case of ridge regression, since the restriction takes the form of a circle it will certainly not be at zero. For the Lasso, the problem is going to be a "corner solution," and the only time you would be "off" the corner of the restriction would be if the RSS ellipse happens to have slope -1 tangential to the diamond in the picture. This is a very special case.So you confirm that hitting an edge is likely but not necessary. The latter was not apparent from the lecture.Very good points all, and thank you for correcting my loose/sloppy language. I would add that it's true that when in 2-d the the red area in your graph seems like a lot, but in higher dimensions, it'll get swamped by the white area. And so you're likely to wind up at a corner solution where some variables are getting zero weight.
# ------------------------
# medoid  9 : ???????????????????????????????????????????I am happpy to meet you here.
# ????????????
# ------------------------
# medoid  910 : I think so: seems to me that's data snooping!Actually PCA is only used for transformation. Then use 1:300 for fitting & 301:1300 for prediction.
# CheersGreat point. I feel the same too. Using the x's from the test data will not allow us to to validate the performance of our factor loadings on say a new set of x'sIt has an influence and actually computing the PCA on the training set only yields to more variance explained and to a lower mean squared error in test!This could be an easy one to answer Imguess. You should run the analysis twice once with the test set and once without and see whether thos has an influence. If it does it is data snooping, clearly.
#
# cheers
# <nameRedac_anon_screen_name_redacted>I think PCA is a data transform like converting from Cartesian to polar coordinates. The transform does not change the data, but it makes it easier to work with. The difference with PCA is that variation in the data defines the new reference frame.It is true that PCA is a feature extraction method but similarly, converting your coordinates from Cartesian to polar because you know the test set can be linearly separated in this new space would be data snooping.But extracting the principal components is part of building the model. I think it's data snooping!
#
# I'm expecting profs. answering this important question...Yes, I wondered the same thing. How can the test set error be valid when the test set is used to build the model? It's pretty similar to doing feature selection before cross-validation, which we were warned against.
# ------------------------
# medoid  783 : Sorry, I am not being very clear.  The bs() function for the cubic spline with 3 knots in the homework example (wage~age) produces 6 terms like this:
#
# ![basis spline terms][1]
#
#
# And the 6 hand-coded terms look like this:
#
# ![hand-coded spline terms][2]
#
#
#   [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac>10<phoneRedac>.png
#   [2]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>3.png
#
# It seems pretty extraordinary that both sets of terms could give the identical results (R squared, standard error) with different coefficients, but they do, so there must be a straight-forward transformation from one set of terms to the other.  It seems that if I could figure that out, then I could use the coefficients from the bs() model in a memory-less implementation.Splines can be memory-less. You can write the basis expansion of x as the sum products of dummy variables and polynomials. For example:
#
#     y ~ bs(x, df=<zipRedac>, degree=1)
#
# Can be re-written as:
#
#     y ~ x + I((x > p2<zipRedac>)*(x - p2<zipRedac>)) + I((x > p<zipRedac>0)*(x - p<zipRedac>0)) + I((x > p7<zipRedac>)*(x - p7<zipRedac>))
#
# p2<zipRedac>, p<zipRedac>0, and p7<zipRedac> are the 2<zipRedac>th, <zipRedac>0th, and 7<zipRedac>th percentiles of x. The percentiles are estimated from the training set.
#
# Here's some code that you can plug into R:
#
#     set.seed(1)
#
#     x <- rnorm(1000, <zipRedac>0, <zipRedac>)
#     y <- <zipRedac>00000 + x - <zipRedac>0*x^2 + 0.003 * x^3 + rnorm(1000,0,<zipRedac>000)
#
#     plot(x,y)
#
#
#     # bs()
#
#     reg.bs <- lm(y~ bs(x, df=<zipRedac>, degree=1))
#
#     summary(reg.bs)
#
#     attr(bs(x, df=<zipRedac>, degree=1), "knots")
#
#     # hand-code splines
#
#     reg.lm <- lm(y~ x + I((x > <zipRedac>6.<zipRedac>1313)*(x-<zipRedac>6.<zipRedac>1313))
#                  +I((x > <zipRedac>9.<zipRedac>233<zipRedac>)*(x- <zipRedac>9.<zipRedac>233<zipRedac>))
#                    +I((x > <zipRedac>3.<zipRedac><zipRedac>21<zipRedac>)*(x- <zipRedac>3.<zipRedac><zipRedac>21<zipRedac>)))
#
#     summary(reg.lm)
#
#     # The coefficients are different, are the predictions the same?
#
#     plot(reg.lm$fitted.values, reg.bs$fitted.values) # You bet!!!attr(bs(x, df=4, degree=1), "knots")This is great, William - thanks.  I was trying to compare hand-coded cubic splines with results from the bs() function, and what was throwing me was that the coefficients were vastly different (and the linear terms for that matter).  I hadn't thought to compare the fitted values, and sure enough my predictions match too.
#
# Are the (k+d) vectors/terms created by the bs() function just a 'normalized' version of the dummied polynomial terms, or are they something completely different?  I know bs() creates some sort of design matrix, but I can't see how you get from the 4 terms above (x, I((x > 46.<zipRedac>1313)*(x-46.<zipRedac>1313)), etc.) to the design vectors.
# ------------------------
# medoid  344 : Sorry about the formatting. It appears to be automatic.
# ------------------------
# medoid  914 : Regarding R resources, there was a thread on that with some links you might find helpful
#
# https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2014-course-material-feedback/threads/<zipRedac>3211c61cadc90a<zipRedac>c<zipRedac>00001d
#
# For further courses, I found the Data Analysis on Coursera pretty good. They have since split their offerings up into their Data Science specialization scheme so it won't exist in one course anymore, but that kinda has the advantage that you can just focus on what you want. For example, Jeff, there is a short course just on Getting and Cleaning Data. They work in R, and are a bit more applied, at least from the Jeff Leek stuff I've seen.
#
# Their Specialization has this price tag, but I'm pretty sure the individual courses w/o a fancy schmancy specialization certificate remain free.
#
# https://www.coursera.org/specialization/jhudatascience/1/courses
#
# https://www.coursera.org/course/getdataI agree with the comment regarding Analytics Edge. I have taken many courses that use R, and that class has given me the most amount of practice than any other, simply because it has a high workload with 3-4 different problem sets with different data sets to work with each week. I am a polyglot programmer, so it was easy for me to pick up R, but all I needed was lots of hands-on R practice and that class provides a ton. You'd love it if that's what you are looking for. https://www.edx.org/course/mitx/mitx-15-071x-analytics-edge-1416
#
# I think you may be too late to get a certificate in that class but if learning is your aim, it should not matter.check this out yo
# https://www.edx.org/course/mitx/mitx-15-071x-analytics-edge-1416
# ------------------------
# medoid  934 : 9.R.*
# ------------------------
# medoid  1049 : I laughed!
# ------------------------
# medoid  410 : http://www-bcf.usc.edu/~gareth/ISL/ISLR%20First%20Printing.pdf
# ------------------------
# medoid  31 : Hello everyone! Very cool to see such a wide assortment of backgrounds. I am looking forward to learning from everyone. There are good discussions in the forum from which I am learning already. I am an applied statistician and six sigma master black belt keeping my skills current with this course. I reside in Longmont, Colorado. Cheers!Hi there!  <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted> here in sunny Boca Raton, FL.  I'm an MD - interventional radiologist - with a deep interest in complex systems and process analytics, particularly as they apply to healthcare.  Cut my teeth on a Heathkit programming BASIC and assembly language in 5th grade. Before I was a doc, I modeled trading systems at a large US I-bank, so I'm intimately familiar with data munging.  I have used biostatistics & six sigma throughout my career, but about a year ago I became intrigued by deep learning methods that lead me to R and MOOCs.
#
# I'm really excited about integrating statistical & machine learning methods with the rapidly changing US healthcare system to create the quadruple win - **Improved outcomes**, **Improved patient satisfaction**, **decreased cost** and **improved provider satisfaction**.Hi! My name is Edward, I'm from Moscow
# Is there anybody from Russia?:)Hi! I'm <nameRedac_anon_screen_name_redacted>, I work and live in Geneva, Switzerland (French part, too).Hello!
# My name is <nameRedac_anon_screen_name_redacted>. I'm from Moscow. Hold MSc in Innovation Management & International Marketing from Halmstad University (Sweden). Back to the master studies, there was a truly international collaboration for every project, would be really cool to have it here as well, although I'm not sure how it can work out for the distant learning.Hi! My name is Jordi. I'm from Madrid (Spain). My last work is Credit Risk Analyst in a Bank. Actually I'm unemployed since december of 2013. I'm studying "Computing for Data Analysis" with Coursera.Hi everybody I'm <nameRedac_anon_screen_name_redacted>, I live in Venezuela and I currently work for the Bolivarian Agency for Space Activities (ABAE) as an engineer. I'm very happy to take part in this course and want to thank everyone involved in making it possible.Hi. My name is <nameRedac_anon_screen_name_redacted>. I'm a PhD candidate in Anthropology at the University of Washington in Seattle, Washington, U.S.A. I have a lot of statistical training but not about "statistical learning" per se. So that's why I'm here.Hi Everyone
# I am <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted> working as a consultant with a company called IMT in Winnipeg, Canada. I would like to learn about Statistics and Probability and applications in real world such as Data analytics.
#
# Regards
# <nameRedac_anon_screen_name_redacted>Hello, I am <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted>, a PhD candidate in Agricultural Economics at Kwame Nkrumah University of Science and Technology, Ghana. I am also a Principal Research Assistant University of Cape Coast, Ghana. Its with great excitement that I was introduced to this online course since statistics play a major role in my daily life in terms of studies and work. I therefore hope to get a lot out of it for my studies and my work.Hello all, I'm <nameRedac_anon_screen_name_redacted> Gustafson, a finance analyst from Sweden, Stockholm. Thrilled to be attending this online! I headstarted with background of degree in statistics and IT, and this will be fun! Thanks for putting this course together, misters Trevor and Rob, I'm very thankful!Hello world! Me, I'm Joe <nameRedac_anon_screen_name_redacted>, a biostatistician working under contract for the National Institute of Child Health and Human Development in Rockville, MD. (But I live across the Potomac River, in northern Virginia.) Looking forward to this course!I'm <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted>. I live in Brussels, Belgium. I'm an analytics developer working for Oracle. Looking forward to this course too.Hi Sacha and Edward! I'm from Chile, but I'm actually living in Argentina. I have a background in social and physical anthropology, and now I'm studying philosophy and german. Hope you´re doing well guys!Hi I´m <nameRedac_anon_screen_name_redacted> from Colombia. I´m an economist and I´m interested in urban economics.<nameRedac_anon_screen_name_redacted>, based in Cambridge UK, Paris FR, and sometimes Stanford CA. Learning about functional programming, category theory, bayesian, convex optimisation.
#
# Thank you for the teachers to provide such good material.Hello, Everyone.
# It's nice to see such a wide variety of interesting people taking this course with me.  My name is <nameRedac_anon_screen_name_redacted> and I just finished my PhD in Neuroscience at the University of Pennsylvania (Philadelphia, USA).  I'm now a Post-Doctoral Researcher in my Thesis lab.Hello to everybody... My name's <nameRedac_anon_screen_name_redacted> I'm electrical engineer and actually i am finish my master on electrical engineering. My thesis research is oriented on data mining analysis.Hello all,
#
# My name is Steve, I'm a current Graduate Student of Public Health at Stony Brook University School of Medicine. I am employed at a stand alone hospital as a Clinical Decision Support Analyst. I am very interested in what we are about to take part in not only because the topic intrigues me but because I find that it will have tremendous applications for patient outcome modeling and treatment plan analysis.Hi everyone,
#
# I'm <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted> from San Antonio Texas. My areas of interest are Consumer/Marketing Research and "Voice of the Customer."from ex-USSR (????)Hi everyone,
#
# I'm <nameRedac_anon_screen_name_redacted>! I previously worked for Canadian Wildlife Service and am now starting a Graduate degree out of Trent University in Ontario. I will be studying population dynamics and reproductive success of bank swallows so this course will have a great application for analyzing my findings.Hello,
#
# My name's <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted> and I'm a PhD student in Social Informatics at Polish-Japanese Institute of Information Technology. I live in Warsaw, Poland and I'm happy to participate in this course!
#
# Best wishes,
# DDHello Everyone,
#
# My name is Dave <nameRedac_anon_screen_name_redacted> and I'm Director of Quality and Reliability for a high tech start up company working in Rochester, NY.  I have a degree in statistics but these topics weren't widely available back then so I'm trying to stay current.  Good luck to all.
#
# http://www.linkedin.com/in/davidlee5Hello everyone!
# My name is <nameRedac_anon_screen_name_redacted> guan. I come from Beijing China. We are going to celebrate the Spring festival in 9 days later. Good luck to all.Hello Everyone,
#
# My name is <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted>.  I have an degree in Engineering form the University of Toronto.  I have just completed Prof Ng's course in ML on coursera.  The latter was excellent and this course looks like a fantasitc way to add to my knowledge.  Thanks profs Hastie and Tibshirani for making it available.
#
# Cheers!Dear All,
#
# Please feel free to stay connected with me on LinkedIn http://www.linkedin.com/in/<nameRedac_anon_screen_name_redacted>siuc.
#
# <nameRedac_anon_screen_name_redacted>Hello Everyone,
#
# This is <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted> from Plano, TX. I just finished PhD in Mathematics. I'm now a Statistician at Capital One.
#
# I've been self-studying the textbook for a while and have replicated some examples in R. I'm so thrilled Dr. Hastie and Dr. Tibshirani are offering this online course. Feel free to connect with me on Linkedin: http://www.linkedin.com/in/daoyinglin
#
# Warmest Regards,
#
# DLinMy name is <nameRedac_anon_screen_name_redacted> and I recently finished a MSc in Applied Sociology. I'm looking forward to learning more stats methods and this will be my first foray into learning a programming language.
#
# Grateful for this fantastic opportunity,
# <nameRedac_anon_screen_name_redacted>Hello everybody,
#
# My name is Murali. I am studying statistics in India. I am also grateful for the opportunity that is being provided here.Hi all,
#
# I'm <nameRedac_anon_screen_name_redacted>, currently living and working in Perth, Western Australia. My main interests and research are in Time Series Analysis and I think this should prove a fantastic course.Hello!
#
# I'm <nameRedac_anon_screen_name_redacted> from Malaysia but currently working in Singapore as a Research Assistant in a university research centre. My main interests are in user and usability research. This course definitely will help in my exploration of R and using stat learning to inform user requirements for product development.wowGreat. Capital One came to my campus for recruitment last week only. But they came to Delhi, i don't know whether it's the same company or not. Anyways, since lots of Phds here, i am gonna ask tons of questions here. Pretty excited so much that didn't sleep last night :)Howdy Folks
#
# <nameRedac_anon_screen_name_redacted> here from New Delhi. Doing my masters in economics and have studied two semesters course work on regression and i hate the obsession of economists to trying put regression on every problem. So, that explains my interest in statistical learning and an opportunity to get answered from the authors themselves.Hey Jason, <nameRedac_anon_screen_name_redacted> here from Bucks county just north of Philadelphia. I'm taking this course to learn if these techniques can be used in my work where we need to classify a large corpus of strings into various categories.Hi, I'm <nameRedac_anon_screen_name_redacted> from Moscow too!) Good luck to everyoneHi Murali
# I am also from India and am from engg background. what college are you from ??Me too, doing modelling at UWA, PerthHi, this is <nameRedac_anon_screen_name_redacted> from Bangalore, India. I'm an engineer and I run a small learning lab at http://www.gloschol.com. Thank you, Stanford. Great to be here! Looking forward to learning from all classmates, as well.
#
# Feel free to connect at http://www.linkedin.com/in/linkedin2<nameRedac_anon_screen_name_redacted>Hi my name is <nameRedac_anon_screen_name_redacted>, I have just started a PhD in modelling, and want to throw some stats at it as well. Ditto, thanks to the lecturers and Uni, it is good to see some familiar material, and lots of new stuff.Hi Jonathan,
#
# I am in Perth too. I am currently trying to finish my thesis for Biostatistics degree. Where do you work if you don't mind me asking?Hi, my name is <nameRedac_anon_screen_name_redacted>, I am postdoc at the department of biology at Stanford University, my main interest is focused on the ecology of terrestrial mammals, especially looking at the interaction between predators and their prey.Hi everyone! My name is <nameRedac_anon_screen_name_redacted> and I am from Ukraine (Donetsk). I study for PhD in mothematical modeling. I intetrested in model optimization, features selection methods, time series analyses and forecastingHi, I am <nameRedac_anon_screen_name_redacted> from Lisbon, Portugal, working at open university at social science department.Hi everyone! I'm <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted>, from Malaysia. Currently I'm doing my PhD at Monash University Malaysia. My research is on the relationship between religion,spirituality and diet. I'm at my second year of study and currently collecting data. I'm taking this course because it'll help me to learn R! :)***Assalamu Alaikum*** (Peace be Upon All of You)
#
#
# I am <nameRedac_anon_screen_name_redacted> from Bombay, India. My job as a Statistician involves doing risk modelling, predictive analytics, primarily in the area of Credit Risk.
#
# This course should be immensely helpful to me to refresh (and learn from a new angle) the things that we were taught in University in M.Sc. (Statistics) as well as learn some modern (and not so modern) techniques straight from the horse's mouth. I mean Prof Efron: Bootstrap; Prof Chambers: S (and R) and of course, the Course Instructors- Prof Hastie-Tibshirani: GAM, LASSO.
#
# Thank you, Stanford !Ciao! I'm <nameRedac_anon_screen_name_redacted> from Italy. I've got a PhD in Aerospace Enginering and I'd like to learn about data analysis and R. This looks like the perfect choice for my goals! Actually, I was suggested to attend the course as part of a Analytics Engineer program I'm following at my company. Looking forward to studying this topic together with all of you!Hi all -- I'm <nameRedac_anon_screen_name_redacted> <nameRedac_anon_screen_name_redacted>, from Providence RI, US. My background is in public health and demography (both heavy on statistics), and my work involves modeling data from clinical trials, insured populations, some population-based surveys, and so on. I am taking this class for two reasons:
# 1. As someone else mentioned, these methods weren't widespread when I was doing my masters and PhD, so I want to see what all the fuss is about.
# 2. I am locked in a longstanding debate with my brother -- an engineer and machine-learning advocate -- about whether statistical learning (hypothesis-driven) or machine learning (atheoretic) are better for science, humanity, and the future of the world. Need to learn some things so I can score some points against him! He has taken some other courses with Hastie and Tibshirani, and highly recommended them to me.
# Nice to see such a wide swath of people and nationalities represented here! Should be fun.I hope pastafarianism is prominent in your research.Hi, I'm <nameRedac_anon_screen_name_redacted> from Toronto, Canada. I have a background in software engineering and am currently working on a cancer genomics project.Hi :)
# That is great that  You are taking this course Dominka. I am PhD student in Psychology at University of Gdansk, maybe we could take an example from others and create  a little polish study group? What do You think?
# Best wishes z pozdrowieniami znad morza,
# Jana <nameRedac_anon_screen_name_redacted>Dear Alesya,
# I just saw news about Majdan :/, hope it will end soon in the best way for Your Nation!
# Jana <nameRedac_anon_screen_name_redacted>
# PhD student, PolandHi!
#
# ...
#
# Formally, I think we can write:
#
# p(default|student)=sum_{available_balances}(p(default|balance)*p(balance|student))
#
# compared to a non-student, the terms with larger default probabilities (ie those for larger balances) are more heavily weighted for students, which is why: p(default|student)>p(default|nonstudent).
#
# But:
# p(default|student, balance)lt p(default|non-student|balance)
#
# Hope this makes sense.If I understand this right - you are citing an example - where we initially find more instances of lung cancer in the non-smoking group. If we do not have any other information - then the only conclusion we can draw would be - what you have said- that, "a smoker has lower risk of lung cancer" !!
#
# It is only when we add age to the mix, that we find that the high incidence of cancer was due to the non-smokers' higher age and for the same age a smoker is more likely to have lung cancer.
#
# We could argue that we should distrust the simple linear regression because of this, but, in my mind, this has got to do with how we pick samples for our study. We could have picked our samples of both smokers and non-smokers such that both included the same fraction of elderly people ("everything else being common between the two groups except that one group smokes and the other does not").
#
# I am not sure if this is the correct answer. Hope someone with more knowledge throws some light on this. Thanks for the interesting question though.Yes sirahman, totally agree.I can't see how groups could be compared if they differ on several dimensions, but I suppose one could pool the data for the two groups and try to do a two-variate logistic regression or try to classify in 'cancer' and 'non-cancer' and find how smoking and aging affect the probability of getting cancer - but, with this data, it probably wouldn't be reasonable to expect to capture interaction effects.
#
# I don't have knowledge or experience in this either, I am just trying to use logic.Thank your for your answer. I agree that doubts should be casted on the coefficients in the presence of confounding but what I am still confused about is the fact that we may still trust the whole model. What do you mean by that? Does it mean the fitted Y?
# ------------------------
# medoid  99 : What do you mean? We have access to the pdf of the course text book. If you want the Elements book just Google for it. The pdf is available on the author website.You can almost guess it:
#
# [http://www.stanford.edu/~hastie/local.ftp/Springer/OLD/ESLII_print4.pdf][1]
#
#  - Week 1: Chapters 1 & 2
#  - Week 2: Chapter 3
#  - Week 3: Chapter 4
#  - Week 4: Chapter 7
#  - Week 5: Chapter 5
#  - Week 6: Chapter 5 & 9
#  - Week 7: Chapter 9
#  - Week 8: Chapter 12
#  - Week 9: Chapter 14
#
#   [1]: http://www.stanford.edu/~hastie/local.ftp/Springer/OLD/ESLII_print4.pdfLink to the newest corrected version:
#
# http://statweb.stanford.edu/~tibs/ElemStatLearn/printings/ESLII_print10.pdfKeep in mind there are 2 books -- "Elements of Statistical Learning" vs "An Introduction to Statistical Learning, with Applications in R". They said this course follows Intro to Stat.
# ESL - more of the math, no R sections
# ISL - focus more on the methods, less on the math behind them
#     - R sectionsI believe he/she means that the professors specify which part of the chapters of the book should be read, since the ESL book is quite rigor and detailed.
# ------------------------
# medoid  869 : :-)
# ------------------------
# medoid  1000 : I changed my first comment.In your counter examples, have you tried adding irrelevant variables? The *training set* R-square will continue to increase or stay the same. In other words, over fitting your model (by adding irrelevant variables) will inflate your *training set* R-square.
#
# Residual standard error measures the variance of your residuals. Not the same as MSE or SSE or RSS.
#
#     # generate some data
#
#     set.seed(1)
#     x1 <- (1:100)+rnorm(100, 10, 5)
#     x2 <- log(x1)+rnorm(100, 0, 2)
#     x3 <- rnorm(100,20,5)
#
#     # true model
#
#     y <- 50 + 10*x1 +0.2*x2+ rnorm(100,0, 200)
#
#     # under-fit model
#     reg.one <- lm(y~x1)
#     summary(reg.one)
#
#     # true model
#     reg.true <- lm(y~x1 + x2 )
#     summary(reg.true)
#
#     # over-fit model
#     reg.overfit <- lm(y~poly(x1, 3) + poly(x2, 3) + poly(x3, 10))
#     summary(reg.overfit)First, I was under the impression that cross-validation and lasso shrinkage (regularization) would address this.  Second and more to the point, I did not find more TEST set error; but, more TRAINING set error.CV error is not training set error.It could be that the 14th variable contains information that were already contained in the other 13 variables. In which case, adding the 14th variable would increase your test set error (due to overfitting, aka higher variance).For ordinary least squares (and logistic regression), adding irrelevant variables to your model never **increases** training set error. This is why training set error is so unreliable. If you keep adding variables, the training set error always decrease or stay the same. Here's some code that demonstrates the need for a test set or cross-validation.
#
#     # generate random data
#
#     set.seed(1)
#
#     x1 <- rnorm(100, 10, 5)
#     x2 <- rnorm(100, 20, 10)
#     x3 <- rnorm(100, 30, 20)
#     x4 <- rnorm(100, 40, 10)
#     x5 <- rnorm(100,50,20)
#
#     y <- 50 + 50*x1 + rnorm(100,0, 200)
#
#     plot(x1,y)
#
#     # fit the true model
#
#     reg.true <- lm(y~x1)
#     summary(reg.true)
#
#     # overfit the model
#
#     reg.overfit <- lm(y~x1 + x2 + x3 + x4 + x5)
#     summary(reg.overfit)when you added $x_{14}$ and ran cv.glmnet(), did lasso choose $x_{14}$ to be in the model?This can happen. Here is an example with just two variables:
#
# ...............
#
# set.seed(1)
#
# x1 <- (1:100)
#
# x2 <- x1+rnorm(100,0,1)
#
# y <- 50 +3*x1 + rnorm(100,0,5)
#
# reg.one <- lm(y~x1)
#
# summary(reg.one)
#
# reg.true <- lm(y~x1 + x2 )
#
# summary(reg.true)
#
# ..........................
#
# The true model is the line y=50+3x1. We add a new variable which is highly correlated with x1, (but has nothing to do with the true model). The residual standard error rises slightly (0.025) in the new model with two variables. May be your case is similar.In my original post, I noted that I'm using CV (cross-validation with lasso shrinkage), specifically the cv.glmnet function.  I understand and appreciate the points about standard regression approaches with the examples you provide.  If you run your examples with the cv.glmnet function in the glmnet package you will note that your extra random variables do not appear.  My question remains why would an extra variable cause worse results on a training set?
#
# In the examples you provide, there is overfitting and that makes sense, but the SSE (on the training set) will go down.  I'm confused why my error is not going down as I add variables.
# ------------------------
# medoid  878 : Those warnings can occur any time R is VERY confident about some of the observations.  It is a good thing to note, but does not mean that anything went wrong.Hello,
#
# Thank you for the response. The test set error is about 32%, which I think is pretty high. Without the model, i.e. if I were to guess the same outcome repeatedly every single time, I would be incorrect 37% of the time. So, the model only improves prediction by 5 ppt - which sounds really low to me.
#
# I don't know what's realistic in real life problem. So, it's very hard for me to gauge if my model is "good" or "bad".Hello,
#
# Thank you for the response. That's very insightful. I'm going to try and replicate the plot for my data set (might need a little bit of work since it contains quite a number of independent variables).
#
# What I find confusing is - as mentioned in one of my responses above - if there is a perfect separation, shouldn't I expect to see really small test set error? Or are they mutually exclusive?Hello,
#
# Thank you for the response. If R is VERY confident about some of the observations, does that imply that the test set error should be really small?
#
# As I mentioned in my response above, the test set error is about 32%, which I think is pretty high. Without the model, i.e. if I were to guess the same outcome repeatedly every single time, I would be incorrect 37% of the time. So, the model only improves prediction by 5 ppt.
#
# Distribution is as follows:
#
# True positive = 3,087
#
# True negative = 20,339
#
# False positive = 1,378
#
# False negative = 9,544@aradianto:
#
# You might also find the first response in
# [[this thread]](https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2<zipRedac>14/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2<zipRedac>14-course-material-feedback/threads/52f99ed5ec<zipRedac>f93d<zipRedac>2c<zipRedac><zipRedac><zipRedac><zipRedac>63)
# interesting.
#
# It's got some pictures of a simple case which gives the message:
#
#     Warning message: glm.fit: fitted probabilities numerically <zipRedac> or 1 occurredthese are warnings, not errors. I believe the model is still usable. What's the test set error?
# ------------------------
# medoid  79 : Hi Bhabani,
# I guess that genes that interact with each other is quite different than simply a cluster of genes. It is not so easy to identify the interaction between genes.
# Cheers
#
# <nameRedac_anon_screen_name_redacted>Hi GuyDargent,
#
# I think I agree with you. The difference is that the outcome of case #1 is easily observed if you wait till the user clicks or leaves the site and that way you can label your observations
# user 1, behavior data, label: click
# user 2, behavior data, lable: no click
# ....
#
# and at the end you have a set of labeled data, so the training set is all label and thus learning is supervised.
#
# In case 2, unless you have proof for the interaction, you cannot label it. If you did label each data point, then you would have supervised learning. Would be great if somebody could confirm that my understanding is correct.
#
# R,
# <nameRedac_anon_screen_name_redacted>Hi Bhabani
#
# I guess your confusion lies in the nature of clustering experiments :)
#
# The goal of gene clusters might be the following:
#
# Let's say we analyse the expression of 1000 genes in cancer cells after drug treatment at four time points: 0, 1h, 5h, 1d.
# What we now get out of a cluster analysis can be results like this:
#
#  - genes 10, 102, 569, ... are not expressed at the beginning, then increase
#  - genes 1, 17, 32, ... are expressed at the beginning, but then decrease upon drug treatment
#  - genes 2, 20, 40, ... reach a peak after 1 hour and then drop
#  - and so on
#
# There is actually no way to predict that before, but those clusters may give very interesting insights, the experiment is actually aiming for (for example about how the drug interacts with different intracellular processes). The only way to have a training set, would be that someone has already performed the experiment before - and then it is not interesting any more to do it (publish of parish :) )I likened the web-click scenario to the Netflix example. The web site operators ought to have some data collected from existing users, which can form the same sort of sparse matrix described in the Netflix challenge. The goal must be to predict what sort of behavior is exhibited by users most likely to click some button.That is a good point. My though would be something like the following:
#
# Built some data of genes cluster interaction pattern, which will be used as supervised learning reference. Then when a new cluster is available compare it with the reference and predict.
#
# It may sound crazy :)Thanks GuyDargent and hooper1christopher.
#
# I am also find it difficult to differentiate between these two examples. May be in case of #1, we can quantify the predictor and response and predict the trend based on already available sample data.
#
# In case of #2, we can not predict the interaction among genes cluster as only supervised reference is cluster.
#
# Thanks,
# <nameRedac_anon_screen_name_redacted>Hi Bhabani,
#
# Supervised learning has a special set of values for each observation known as a response.  The goal of supervised learning is to use a training set to "learn" a function that maps from input to response.
#
# If you wanted to cast the gene clustering problem as a supervised problem, what would your response be (how about your input?)?I believe it has to do with the predictive nature of the circumstances. #2 is searching for something that already exists, while #1 serves to take given knowledge and produce a prediction or trend. I got hung up a bit on this question as well, especially as the slides don't give very clear definitions for the terms.
# ------------------------
# medoid  1014 : I think the discussion forums in Coursera, EdX and Udacity are surprisingly poor - hard to navigate, and few searching and sorting options. If they haven't got the resources to write a good one from scratch, maybe they could use something like the Stack Exchange platform, or even just phpBB.I found Stanford EdX experience inferior to Coursera. I understand Stanford reasons for pushing with its own offering. However the student experience at Coursera from my point of view is better.
#
# Specifically, the discussion forums on Coursera are much easier to use and navigate. Coursera also offers better testing options. Just as the poster above I have reservations about peer assessment option, but it's an option and having an option cannot be worse than not having it. Other options that I've seen on Coursera, are easier to use and do not get in a way of testing as much as EdX's JavaScript heavy parsing. I also found that I use 1.25 video speed on Coursera a lot. Unfortunately it's not available on EdX.+1 for CourseraAnd I too agree with the general sentiment here. Navigating the forum is almost terrible. Very difficult to see the list of forum topics. For example, if I need to look into discussions from week 1, it may take me forever to keep going down (loading more ) and at some point, I am going to give up. Not very user friendly at all. And I personally feel that for MOOCs, discussion forum is its best benefit.
#
# And there are Stanford professors offering the course on Coursera. Offering there would be good too (And it would be awesome if edX is able to create a user-friendly forum.)I personally prefer the EdX platform to coursera. The videos here are HD which make it much easier to read (especially important for programming classes). The discussion areas on coursera, while easier to read, fill up with discussions that have no connection with class material.I also prefer Coursera, but of course, it is up to the professors and Stanford to decide. Thanks you very much for the excellent course and the free books!
#
# I found the section navigation especially bothersome. Had to click on each subsection, then quiz, to download my answers to a file.  This is in one section, essentially one html page on Coursera.  Also saving video in usable resolution on Coursera is much easier with DownloadThemAll on Firefox, just one operation. I don't use discussions much for this type of course, but for programming courses, Coursera's forum was excellent with many pinned threads.  Professors do a good job of organizing project and homework discussions on a weekly basis.
#
# The auto-grading in conjunction with peer grading works well for programming classes.  Also many optional exercises are available to drill on the concept. Generally, I find the level of learning at Coursera to be is higher than from a regular college class.  I did not find this class to be of the same rigor as a regular college class, even for an intro class.  I think that is due to the limitations of the platform of EdX, which is not as easy for professors to list optional exercises or collect discussions into threads by weekly topic.I am not too sure about this peer-assessment thing.Maybe EdX could fix improve the Discussion experience to get it up to Coursera standards
# ------------------------
# medoid  759 : Yes.

# %% [markdown]
# ##Non-Negative Matrix Factorization

# %%
#NMF for grouped comments
n_topics = 40
n_top_words = 15

print("size of corpus: {}".format(len(grouped_comments)))

t0 = time()

# Fit the NMF model
print("Fitting the NMF model on with n_samples=%d and n_features=%d..."
      % (n_samples, X.shape[1]))
nmf = decomposition.NMF(n_components=n_topics).fit(X)
print("done in %0.3fs." % (time() - t0))

# Inverse the vectorizer vocabulary to be able
feature_names = tfidf.get_feature_names()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join( [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]] ))
    print
# Out:
# size of corpus: 1071
# Fitting the NMF model on with n_samples=1071 and n_features=1627...
# done in 28.821s.
# Topic #0:
# tree trees number split adding random forest unfortunately long classification kernel population red approach reply
#
# Topic #1:
# humanitiesscience winter2 winter2 14 courses humanitiesscience edu courses forum discussion forum humanitiesscience statlearning class stanford threads https class statlearning 14 i4x i4x humanitiesscience
#
# Topic #2:
# install install packages packages islr packages islr library package library islr version islr library islr package command rstudio cran session
#
# Topic #3:
# youtube com www youtube com watch https www watch youtube www com https dl discriminant analysis discriminant introduction list download videos
#
# Topic #4:
# image image description enter image amazonaws s3 amazonaws amazonaws com edx west https edx uploads s3 west west uploads uploads s3 edx enter
#
# Topic #5:
# tsboot boot index xy function coef sim fixed sim lm x1 function data blocks x1 1000 statistic x1 x2
#
# Topic #6:
# volume cube dimension dimensions boundary hypercube square region length unit area distance dimensional line points
#
# Topic #7:
# bcf usc usc www bcf usc edu bcf gareth edu gareth gareth isl isl http www isl data www csv edu islr
#
# Topic #8:
# logistic logistic regression regression linear regression linear classification models discriminant logit svm probability regression model glm multivariate probabilities
#
# Topic #9:
# automatic appears ols logit lda past grading posting ch resampling allow getting answers select things
#
# Topic #10:
# videos youtube download firefox download youtube video url mp4 hd download video downloading download videos copy downloaded play
#
# Topic #11:
# lecture slides slides pdf lecture page 30 link hd chapter downloaded numbers slide class stanford https class humanitiesscience statlearning
#
# Topic #12:
# great great course thank tibshirani prof hastie course prof hastie prof tibshirani enjoyed trevor thank course rob books thanks great
#
# Topic #13:
# wikipedia en org wiki wikipedia org en wikipedia wiki http en org http variance article bias measure http www average
#
# Topic #14:
# https github github solutions github com manual stat learning nameredac_anon_screen_name_redacted official stat com community cheers aware exercises https
#
# Topic #15:
# project org http cran cran project cran org web project web packages org web package http caret packages index html
#
# Topic #16:
# elemstatlearn tibs edu tibs tibs elemstatlearn statweb stanford http statweb statweb stanford edu stanford edu 2nd http pdf esl equation
#
# Topic #17:
# certificate accomplishment progress april march 2014 21 quizzes course info email 50 00 page statement
#
# Topic #18:
# interval confidence interval confidence 95 intervals confidence intervals parameter null hypothesis null hypothesis true contain value probability distribution
#
# Topic #19:
# sample samples size data points bootstrap sample size bootstrap sample data point points replacement bootstrap samples answer probability point sampling
#
# Topic #20:
# base log natural formula correct consistent answer used 10 stats correct answer instructors intercept notes written
#
# Topic #21:
# thanks great tool changed advance profs hi thanks nameredac_anon_screen_name_redacted cheers small ll instead provided nameredac_anon_screen_name_redacted r2
#
# Topic #22:
# poly df reg splines spline polynomial freedom degrees freedom polynomials degrees fitted values degree fitted raw summary
#
# Topic #23:
# glmnet lambda alpha lasso ridge ridge regression plot family regularization increases coefficients cv solved installed ols
#
# Topic #24:
# button submit video click quiz icon clicking quizzes screen right bar progress save attempts chapter
#
# Topic #25:
# rdata load load rdata xy ls file workspace loaded x1 command x2 list r1 loading x1 x2
#
# Topic #26:
# data frame frame pred lm predict lm data dat fit fit lm glm newdata data train data data auto
#
# Topic #27:
# chrome browser fine mac screen tried firefox works clicking worked using video volume formulas version
#
# Topic #28:
# sales tv advertising units typo 39 interaction 37 impact 1000 increase figure calculation wrong round
#
# Topic #29:
# file directory rstudio open csv auto editor working directory files installed script desktop read csv save windows
#
# Topic #30:
# staff talk number hi glad simulation set feedback decimal suggestion marked edx thank enjoyed ways
#
# Topic #31:
# eta_1 eta_0 epsilon eta_0 eta_1 x_1 hat x_2 eta_2 log mathrm odds eta egin respect frac
#
# Topic #32:
# pca principal components principal components 200 component variance pc var proportion pr sum explained matrix test
#
# Topic #33:
# elements statistical elements statistical learning statistical learning esl pages official lecture notes 21 17 available remember online book
#
# Topic #34:
# time series series block block bootstrap bootstrap time standard standard errors bootstrapping errors uncorrelated non search independent standard error
#
# Topic #35:
# variable x1 x2 variables interaction dummy predictors x1 x2 effect x3 relationship correlated levels predictor interactions
#
# Topic #36:
# 50 rnorm rep matrix rnorm matrix 100 svm generate 10 500 1000 normal labels half factor
#
# Topic #37:
# selection stepwise forward models backward model selection best model model predictors best subset step method number predictors select
#
# Topic #38:
# machine coursera machine learning learning learn free data analysis people good week analysis programming exercises feel course
#
# Topic #39:
# cv validation fold cross validation test cross estimate test cv error training folds fold cv test error test set error estimate

# %%
for topic_idx, topic in enumerate(nmf.components_):

    words = [feature_names[i] for i in topic.argsort()[:-(n_top_words):-1]]
    scores = [topic[i] for i in topic.argsort()[:-(n_top_words):-1]]

    dicta = {word: score for score, word in zip(scores, words)}

    s=pd.Series(dicta)
    plt.figure()
    plt.title("Topic #%d:" % topic_idx)
    s.plot(kind='bar');
# Out:
# /Users/wubr2000/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %%
#Word clouds
import vincent
vincent.core.initialize_notebook()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    tmpDic = {}
    for i in topic.argsort()[:-50 - 1:-1]:
        tmpDic[feature_names[i]] = topic[i]*100
    vincent.Word(tmpDic).display();
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# Topic #0:
# <div id="vis0f9a8865b7e9492abb76f25933cf3cfc"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "000", "val": 20.617355579835269}, {"col": "data", "idx": "10", "val": 24.522595727550602}, {"col": "data", "idx": "algorithm", "val": 14.10665463646642}, {"col": "data", "idx": "approach", "val": 22.478151101862785}, {"col": "data", "idx": "associated", "val": 21.686226622041431}, {"col": "data", "idx": "average", "val": 17.337834566684766}, {"col": "data", "idx": "best", "val": 44.582845264760053}, {"col": "data", "idx": "bootstrapping", "val": 18.215719720670645}, {"col": "data", "idx": "choose", "val": 42.23004530246893}, {"col": "data", "idx": "choosing", "val": 14.324107293267257}, {"col": "data", "idx": "compute", "val": 15.921176481458629}, {"col": "data", "idx": "cv", "val": 388.69475827952175}, {"col": "data", "idx": "discussed", "val": 23.615038362443457}, {"col": "data", "idx": "doing", "val": 17.452559792663575}, {"col": "data", "idx": "entire", "val": 28.120475520646632}, {"col": "data", "idx": "entirely", "val": 16.735167044507897}, {"col": "data", "idx": "errors", "val": 26.567986763052172}, {"col": "data", "idx": "estimate", "val": 57.038628912231772}, {"col": "data", "idx": "feature", "val": 14.641290303578042}, {"col": "data", "idx": "final", "val": 19.995150527429136}, {"col": "data", "idx": "fold", "val": 62.604337616079185}, {"col": "data", "idx": "folds", "val": 25.296869266934063}, {"col": "data", "idx": "glmnet", "val": 17.56630249384051}, {"col": "data", "idx": "groups", "val": 14.215532266289422}, {"col": "data", "idx": "loop", "val": 16.632174572315218}, {"col": "data", "idx": "mentioned", "val": 12.424712099732085}, {"col": "data", "idx": "method", "val": 15.002742053927667}, {"col": "data", "idx": "minimum", "val": 18.89545371733951}, {"col": "data", "idx": "models", "val": 22.922920386610333}, {"col": "data", "idx": "mse", "val": 35.078487836764353}, {"col": "data", "idx": "optimal", "val": 42.636575381959318}, {"col": "data", "idx": "options", "val": 18.524750404765964}, {"col": "data", "idx": "overall", "val": 14.36859992772419}, {"col": "data", "idx": "parameters", "val": 18.83558586155408}, {"col": "data", "idx": "perform", "val": 16.06800775605733}, {"col": "data", "idx": "pre", "val": 15.572224504148322}, {"col": "data", "idx": "prefer", "val": 14.751960289745956}, {"col": "data", "idx": "repeated", "val": 14.568259237810771}, {"col": "data", "idx": "rule", "val": 17.440906726478975}, {"col": "data", "idx": "run", "val": 18.257896467051857}, {"col": "data", "idx": "saying", "val": 13.244865052744851}, {"col": "data", "idx": "selected", "val": 16.804135903704381}, {"col": "data", "idx": "sets", "val": 14.55918051215701}, {"col": "data", "idx": "situations", "val": 13.429551003342574}, {"col": "data", "idx": "smaller", "val": 22.975425641820848}, {"col": "data", "idx": "standard", "val": 13.539940430905792}, {"col": "data", "idx": "test", "val": 29.547883819460669}, {"col": "data", "idx": "training", "val": 18.792732775963792}, {"col": "data", "idx": "usual", "val": 17.054388214046952}, {"col": "data", "idx": "ways", "val": 14.629409313292957}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis0f9a8865b7e9492abb76f25933cf3cfc"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #1:
# <div id="vise404682cb4304fe49b85a3681932bea5"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "10", "val": 6.5242538595240234}, {"col": "data", "idx": "assign", "val": 4.1446037775178821}, {"col": "data", "idx": "assignment", "val": 7.7986495344747029}, {"col": "data", "idx": "called", "val": 3.9584870294407484}, {"col": "data", "idx": "click", "val": 5.7578052435893108}, {"col": "data", "idx": "command", "val": 8.7695307757330028}, {"col": "data", "idx": "couldn", "val": 6.7071432965742943}, {"col": "data", "idx": "dataframe", "val": 7.9440593815385903}, {"col": "data", "idx": "datasets", "val": 8.762066748328099}, {"col": "data", "idx": "didn", "val": 5.149233014585243}, {"col": "data", "idx": "directly", "val": 6.0127048807769343}, {"col": "data", "idx": "directory", "val": 7.9727694213988105}, {"col": "data", "idx": "download", "val": 6.3019009119059843}, {"col": "data", "idx": "downloading", "val": 5.5969504425282324}, {"col": "data", "idx": "edu", "val": 5.5326670084322753}, {"col": "data", "idx": "esl", "val": 5.3105116191285706}, {"col": "data", "idx": "figure", "val": 4.6916865787976523}, {"col": "data", "idx": "file", "val": 22.408036244850987}, {"col": "data", "idx": "frame", "val": 5.8553398046952543}, {"col": "data", "idx": "head", "val": 6.6580043033960381}, {"col": "data", "idx": "html", "val": 5.1969587304229172}, {"col": "data", "idx": "humanitiesscience", "val": 6.380355086770563}, {"col": "data", "idx": "link", "val": 11.888390803214952}, {"col": "data", "idx": "list", "val": 10.015515829237973}, {"col": "data", "idx": "load", "val": 62.220886592641797}, {"col": "data", "idx": "loaded", "val": 14.412137113110472}, {"col": "data", "idx": "loading", "val": 9.3924419785827542}, {"col": "data", "idx": "ls", "val": 22.583752476518075}, {"col": "data", "idx": "message", "val": 5.2537197526590971}, {"col": "data", "idx": "names", "val": 6.2873246641342977}, {"col": "data", "idx": "numeric", "val": 3.9173559181766495}, {"col": "data", "idx": "objects", "val": 4.3241151669772249}, {"col": "data", "idx": "output", "val": 6.1980343109794918}, {"col": "data", "idx": "r1", "val": 7.9801069715343997}, {"col": "data", "idx": "rdata", "val": 126.30495164210495}, {"col": "data", "idx": "shouldn", "val": 3.5394413002178973}, {"col": "data", "idx": "shown", "val": 6.3216214830032298}, {"col": "data", "idx": "stanford", "val": 10.24532703216487}, {"col": "data", "idx": "statistical", "val": 4.2450183725875599}, {"col": "data", "idx": "statlearning", "val": 7.8417477873307107}, {"col": "data", "idx": "stuck", "val": 7.0458067496319092}, {"col": "data", "idx": "studio", "val": 5.4098592004291284}, {"col": "data", "idx": "summary", "val": 4.0637704743294352}, {"col": "data", "idx": "talking", "val": 3.5354228540937562}, {"col": "data", "idx": "type", "val": 9.5938145983191401}, {"col": "data", "idx": "url", "val": 4.8952614179699259}, {"col": "data", "idx": "users", "val": 4.2973709417827308}, {"col": "data", "idx": "view", "val": 4.3151107802380384}, {"col": "data", "idx": "workspace", "val": 23.550288006637533}, {"col": "data", "idx": "xy", "val": 36.400247400439532}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vise404682cb4304fe49b85a3681932bea5"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #2:
# <div id="visdeb294d6d7db4613a0fc0a970328871f"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "14", "val": 48.698212163378237}, {"col": "data", "idx": "16", "val": 5.5460249528291099}, {"col": "data", "idx": "17", "val": 3.6110702829636057}, {"col": "data", "idx": "18", "val": 2.777861986827932}, {"col": "data", "idx": "27", "val": 3.836786252682161}, {"col": "data", "idx": "39", "val": 2.7764035244392415}, {"col": "data", "idx": "agreed", "val": 3.8487014165178848}, {"col": "data", "idx": "blue", "val": 2.9399971845781976}, {"col": "data", "idx": "closely", "val": 2.827718962602658}, {"col": "data", "idx": "code", "val": 2.6548975077866013}, {"col": "data", "idx": "courses", "val": 41.936199658192173}, {"col": "data", "idx": "didn", "val": 3.644034641086181}, {"col": "data", "idx": "discussed", "val": 8.4236408174758353}, {"col": "data", "idx": "discussion", "val": 39.513648066760702}, {"col": "data", "idx": "edu", "val": 32.044371517227269}, {"col": "data", "idx": "especially", "val": 4.7819369327238244}, {"col": "data", "idx": "feedback", "val": 30.636253978126938}, {"col": "data", "idx": "following", "val": 4.1012303466664717}, {"col": "data", "idx": "forum", "val": 50.836823199094418}, {"col": "data", "idx": "future", "val": 3.2651130559443189}, {"col": "data", "idx": "general", "val": 4.1437116283525617}, {"col": "data", "idx": "humanitiesscience", "val": 81.092121026108529}, {"col": "data", "idx": "i4x", "val": 41.344080575576427}, {"col": "data", "idx": "includes", "val": 3.8223312876899409}, {"col": "data", "idx": "info", "val": 5.2150208508568427}, {"col": "data", "idx": "link", "val": 3.0547602517907815}, {"col": "data", "idx": "look", "val": 3.1006497231315078}, {"col": "data", "idx": "material", "val": 26.121891733273493}, {"col": "data", "idx": "meaning", "val": 2.8069687330343021}, {"col": "data", "idx": "mistake", "val": 4.4173465756512122}, {"col": "data", "idx": "quiz", "val": 4.6285293694059311}, {"col": "data", "idx": "r2", "val": 3.1518261798247953}, {"col": "data", "idx": "reference", "val": 3.2685528412380851}, {"col": "data", "idx": "response", "val": 2.9334397020381004}, {"col": "data", "idx": "responses", "val": 2.8151340091180614}, {"col": "data", "idx": "review", "val": 7.9928379724886351}, {"col": "data", "idx": "search", "val": 3.216204000556846}, {"col": "data", "idx": "stanford", "val": 37.902320969820728}, {"col": "data", "idx": "statlearning", "val": 44.760242561989372}, {"col": "data", "idx": "stats", "val": 3.6281568644590312}, {"col": "data", "idx": "stats216", "val": 36.904416668933507}, {"col": "data", "idx": "stuck", "val": 2.8159247996069263}, {"col": "data", "idx": "supposed", "val": 3.0867351520766095}, {"col": "data", "idx": "thread", "val": 24.155952311363247}, {"col": "data", "idx": "threads", "val": 46.238687767408202}, {"col": "data", "idx": "tricky", "val": 2.8200981565728673}, {"col": "data", "idx": "variables", "val": 2.7523005029156131}, {"col": "data", "idx": "website", "val": 3.7156805989489845}, {"col": "data", "idx": "winter2", "val": 66.920744708448126}, {"col": "data", "idx": "winter2014", "val": 45.723817178366289}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visdeb294d6d7db4613a0fc0a970328871f"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #3:
# <div id="vis1641c6acf00440c78f2f3c8abf294d2f"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "15", "val": 6.5808168832301588}, {"col": "data", "idx": "argument", "val": 3.2540232649430614}, {"col": "data", "idx": "attach", "val": 3.8083359802510088}, {"col": "data", "idx": "available", "val": 7.610991242439848}, {"col": "data", "idx": "built", "val": 4.5232242796956772}, {"col": "data", "idx": "command", "val": 10.670543802066588}, {"col": "data", "idx": "commands", "val": 6.2406477092206405}, {"col": "data", "idx": "cran", "val": 33.729525579843347}, {"col": "data", "idx": "datasets", "val": 7.8612910690410596}, {"col": "data", "idx": "dependent", "val": 3.9615293738441628}, {"col": "data", "idx": "did", "val": 3.9592698537249502}, {"col": "data", "idx": "download", "val": 5.5087339890227707}, {"col": "data", "idx": "following", "val": 3.3123892703518476}, {"col": "data", "idx": "functions", "val": 3.3486964397168681}, {"col": "data", "idx": "glmnet", "val": 8.9078014035913569}, {"col": "data", "idx": "google", "val": 6.635255876286636}, {"col": "data", "idx": "html", "val": 7.1998885181790708}, {"col": "data", "idx": "index", "val": 4.4844339667522179}, {"col": "data", "idx": "install", "val": 106.53359564149065}, {"col": "data", "idx": "installed", "val": 13.686580654900151}, {"col": "data", "idx": "islr", "val": 62.493775130944009}, {"col": "data", "idx": "library", "val": 40.096718512530735}, {"col": "data", "idx": "location", "val": 6.2393377527137899}, {"col": "data", "idx": "mass", "val": 6.2622840783486398}, {"col": "data", "idx": "meant", "val": 4.1750247176961084}, {"col": "data", "idx": "mentioned", "val": 3.9089741157997633}, {"col": "data", "idx": "options", "val": 3.8117618251252363}, {"col": "data", "idx": "org", "val": 13.645341035308098}, {"col": "data", "idx": "package", "val": 72.992822893055646}, {"col": "data", "idx": "packages", "val": 92.245656333793434}, {"col": "data", "idx": "pick", "val": 4.1348390697964525}, {"col": "data", "idx": "project", "val": 19.66459846802007}, {"col": "data", "idx": "rstudio", "val": 19.159515512170348}, {"col": "data", "idx": "run", "val": 6.6380870800209841}, {"col": "data", "idx": "search", "val": 4.5399289585943565}, {"col": "data", "idx": "session", "val": 11.959927140472178}, {"col": "data", "idx": "sets", "val": 3.1813109507959432}, {"col": "data", "idx": "solved", "val": 3.2267366165970932}, {"col": "data", "idx": "source", "val": 3.9139229405199183}, {"col": "data", "idx": "space", "val": 3.1763685551621865}, {"col": "data", "idx": "studio", "val": 3.6110809400582866}, {"col": "data", "idx": "summary", "val": 3.1566595170140461}, {"col": "data", "idx": "true", "val": 3.5636027530476038}, {"col": "data", "idx": "type", "val": 3.6840499073691064}, {"col": "data", "idx": "version", "val": 24.201275805683224}, {"col": "data", "idx": "versions", "val": 3.8795345905689262}, {"col": "data", "idx": "view", "val": 3.2444485991570704}, {"col": "data", "idx": "web", "val": 17.808867503082702}, {"col": "data", "idx": "windows", "val": 3.842450231846454}, {"col": "data", "idx": "world", "val": 4.0098479646475127}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis1641c6acf00440c78f2f3c8abf294d2f"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #4:
# <div id="visa693550e7b9b4e5c814b4418137de176"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "100", "val": 13.004679203140867}, {"col": "data", "idx": "1000", "val": 21.880847073297321}, {"col": "data", "idx": "alpha", "val": 8.9773746575767746}, {"col": "data", "idx": "argument", "val": 7.3935758958095166}, {"col": "data", "idx": "arguments", "val": 9.8895452618462496}, {"col": "data", "idx": "asked", "val": 5.3491430397591975}, {"col": "data", "idx": "available", "val": 6.3869606085220436}, {"col": "data", "idx": "beta1", "val": 10.648613283659019}, {"col": "data", "idx": "block", "val": 5.7070722541175085}, {"col": "data", "idx": "blocks", "val": 20.355705159229174}, {"col": "data", "idx": "boot", "val": 92.716674991988384}, {"col": "data", "idx": "bootstrap", "val": 9.3947767467707006}, {"col": "data", "idx": "code", "val": 5.7103857770372786}, {"col": "data", "idx": "coef", "val": 29.578555231183156}, {"col": "data", "idx": "coefficients", "val": 5.0512657573051465}, {"col": "data", "idx": "dataframe", "val": 4.8753597638046315}, {"col": "data", "idx": "dataset", "val": 7.3875730090892224}, {"col": "data", "idx": "fixed", "val": 16.919843492303269}, {"col": "data", "idx": "formula", "val": 4.5901379779305005}, {"col": "data", "idx": "functions", "val": 4.6128660559657613}, {"col": "data", "idx": "getting", "val": 4.5195254654244978}, {"col": "data", "idx": "got", "val": 7.6084162909511628}, {"col": "data", "idx": "help", "val": 7.6164583561674828}, {"col": "data", "idx": "index", "val": 57.398747782516168}, {"col": "data", "idx": "indices", "val": 15.179337668231744}, {"col": "data", "idx": "intervals", "val": 5.1627910657723559}, {"col": "data", "idx": "lm", "val": 22.182354308972478}, {"col": "data", "idx": "look", "val": 7.8416252874629926}, {"col": "data", "idx": "original", "val": 8.1987072798491454}, {"col": "data", "idx": "package", "val": 16.695900137176032}, {"col": "data", "idx": "pass", "val": 11.040291416900111}, {"col": "data", "idx": "performs", "val": 4.6185128090789194}, {"col": "data", "idx": "practical", "val": 5.2749085939151179}, {"col": "data", "idx": "r3", "val": 15.824165077949214}, {"col": "data", "idx": "random", "val": 4.5257805807347804}, {"col": "data", "idx": "return", "val": 16.430519536890142}, {"col": "data", "idx": "returns", "val": 5.0615994036009342}, {"col": "data", "idx": "se", "val": 7.4618817290188346}, {"col": "data", "idx": "seed", "val": 11.76108360693541}, {"col": "data", "idx": "sim", "val": 23.673506535605569}, {"col": "data", "idx": "simpler", "val": 4.7857288600973993}, {"col": "data", "idx": "statistic", "val": 14.909209431349362}, {"col": "data", "idx": "statistics", "val": 5.5383868473150955}, {"col": "data", "idx": "std", "val": 7.7565430625007119}, {"col": "data", "idx": "subset", "val": 15.288027557986092}, {"col": "data", "idx": "thread", "val": 4.7309000482722734}, {"col": "data", "idx": "tsboot", "val": 113.84324844921159}, {"col": "data", "idx": "works", "val": 4.3935898909988991}, {"col": "data", "idx": "wrong", "val": 6.0859783416267108}, {"col": "data", "idx": "xy", "val": 40.813403183254259}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visa693550e7b9b4e5c814b4418137de176"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #5:
# <div id="vise8bf3583959c45389044321eb833c367"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "00", "val": 5.0444466720566199}, {"col": "data", "idx": "0000", "val": 6.7539493801724397}, {"col": "data", "idx": "11", "val": 5.3889341247909472}, {"col": "data", "idx": "21", "val": 5.1164935062846251}, {"col": "data", "idx": "25", "val": 6.5756118375494115}, {"col": "data", "idx": "30", "val": 39.646122059350773}, {"col": "data", "idx": "36", "val": 4.2298225015941524}, {"col": "data", "idx": "40", "val": 4.2611290870287863}, {"col": "data", "idx": "address", "val": 4.4738630123893914}, {"col": "data", "idx": "available", "val": 3.9008339729674741}, {"col": "data", "idx": "b0", "val": 4.2559054971172605}, {"col": "data", "idx": "book", "val": 4.3398671782744689}, {"col": "data", "idx": "chapter", "val": 14.927992330696419}, {"col": "data", "idx": "classification", "val": 4.9018603230276376}, {"col": "data", "idx": "click", "val": 5.0018345743224399}, {"col": "data", "idx": "confusion", "val": 3.7588366950346517}, {"col": "data", "idx": "consistent", "val": 4.180934549300388}, {"col": "data", "idx": "cs", "val": 9.3071154011721369}, {"col": "data", "idx": "curious", "val": 4.1873050439938639}, {"col": "data", "idx": "downloaded", "val": 17.213938481061923}, {"col": "data", "idx": "edu", "val": 12.894043936152261}, {"col": "data", "idx": "equation", "val": 6.4517624555710569}, {"col": "data", "idx": "follow", "val": 8.3101286250513908}, {"col": "data", "idx": "format", "val": 5.4246362687090395}, {"col": "data", "idx": "formula", "val": 8.3316505195773516}, {"col": "data", "idx": "hd", "val": 16.004459954658319}, {"col": "data", "idx": "humanitiesscience", "val": 8.792232917859355}, {"col": "data", "idx": "learning", "val": 4.67116640891693}, {"col": "data", "idx": "lecture", "val": 70.282594611856837}, {"col": "data", "idx": "link", "val": 20.51064685897358}, {"col": "data", "idx": "lots", "val": 4.0929249329175486}, {"col": "data", "idx": "notes", "val": 12.67783511598822}, {"col": "data", "idx": "numbers", "val": 14.138795625761436}, {"col": "data", "idx": "open", "val": 5.4558647010604417}, {"col": "data", "idx": "page", "val": 40.026731380795141}, {"col": "data", "idx": "pages", "val": 15.789436363719489}, {"col": "data", "idx": "paper", "val": 7.9166790942268417}, {"col": "data", "idx": "pdf", "val": 93.735171368870908}, {"col": "data", "idx": "presented", "val": 5.7476787046326541}, {"col": "data", "idx": "produce", "val": 4.5451565254653259}, {"col": "data", "idx": "refers", "val": 6.189120405617933}, {"col": "data", "idx": "slide", "val": 13.8912437610821}, {"col": "data", "idx": "slides", "val": 108.85857559160345}, {"col": "data", "idx": "smgross", "val": 6.3445096034711508}, {"col": "data", "idx": "stanford", "val": 10.047785183301112}, {"col": "data", "idx": "statistical", "val": 8.0806796324818926}, {"col": "data", "idx": "statlearning", "val": 11.2226937363762}, {"col": "data", "idx": "talking", "val": 3.937821457230505}, {"col": "data", "idx": "winter2014", "val": 6.8597929181177744}, {"col": "data", "idx": "wondering", "val": 6.2835026065446984}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vise8bf3583959c45389044321eb833c367"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #6:
# <div id="vise16889791e7f4b7bacadf49a670e8786"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "05", "val": 4.684545874505023}, {"col": "data", "idx": "alternative", "val": 6.7419762096547053}, {"col": "data", "idx": "analysis", "val": 5.4148099829162035}, {"col": "data", "idx": "available", "val": 3.8713525750839439}, {"col": "data", "idx": "check", "val": 5.325213388295821}, {"col": "data", "idx": "com", "val": 59.808885808075317}, {"col": "data", "idx": "content", "val": 4.4059970514424149}, {"col": "data", "idx": "cost", "val": 3.0533680516217299}, {"col": "data", "idx": "coursera", "val": 10.984281191057466}, {"col": "data", "idx": "details", "val": 3.4307145537281669}, {"col": "data", "idx": "discriminant", "val": 5.9210256083744879}, {"col": "data", "idx": "docs", "val": 6.5452415633655985}, {"col": "data", "idx": "explained", "val": 3.3368682787579416}, {"col": "data", "idx": "extension", "val": 3.8141987331725637}, {"col": "data", "idx": "files", "val": 3.6460690915272376}, {"col": "data", "idx": "free", "val": 4.6886062007402511}, {"col": "data", "idx": "github", "val": 6.5668033660375853}, {"col": "data", "idx": "google", "val": 4.0741904750222453}, {"col": "data", "idx": "having", "val": 3.1771291808955722}, {"col": "data", "idx": "highly", "val": 3.302768485260736}, {"col": "data", "idx": "introduction", "val": 6.266796061538682}, {"col": "data", "idx": "issues", "val": 4.7086311415658919}, {"col": "data", "idx": "lectures", "val": 14.269672663629956}, {"col": "data", "idx": "link", "val": 8.7483487875872772}, {"col": "data", "idx": "links", "val": 5.9827103952404084}, {"col": "data", "idx": "list", "val": 9.4504919095314044}, {"col": "data", "idx": "march", "val": 3.2246295531747737}, {"col": "data", "idx": "net", "val": 3.7701850129510883}, {"col": "data", "idx": "org", "val": 3.0392272961363025}, {"col": "data", "idx": "output", "val": 5.4867830862004103}, {"col": "data", "idx": "package", "val": 3.3235029049091209}, {"col": "data", "idx": "predictions", "val": 3.2148032771330679}, {"col": "data", "idx": "programming", "val": 3.2852384872439924}, {"col": "data", "idx": "proportion", "val": 4.2389178884241439}, {"col": "data", "idx": "recommend", "val": 3.0263888866439168}, {"col": "data", "idx": "risk", "val": 3.0555777624760214}, {"col": "data", "idx": "rstudio", "val": 5.0481600274128473}, {"col": "data", "idx": "source", "val": 5.3346671833885795}, {"col": "data", "idx": "squared", "val": 3.3424089628854023}, {"col": "data", "idx": "sure", "val": 3.0800599263457209}, {"col": "data", "idx": "topics", "val": 4.5177520915621123}, {"col": "data", "idx": "unable", "val": 6.8689466500499092}, {"col": "data", "idx": "var", "val": 4.7651309672602897}, {"col": "data", "idx": "video", "val": 3.09608025770939}, {"col": "data", "idx": "videos", "val": 6.9174903663401732}, {"col": "data", "idx": "vs", "val": 3.988157165772952}, {"col": "data", "idx": "watch", "val": 131.06983575633058}, {"col": "data", "idx": "week", "val": 3.0136594674144233}, {"col": "data", "idx": "www", "val": 61.763547049173042}, {"col": "data", "idx": "youtube", "val": 121.1462103196278}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vise16889791e7f4b7bacadf49a670e8786"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #7:
# <div id="visc0650f8fe5ac4ce38af2681adc85ba87"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "advanced", "val": 11.997371716162197}, {"col": "data", "idx": "book", "val": 20.563864538140006}, {"col": "data", "idx": "books", "val": 27.749856454992312}, {"col": "data", "idx": "courses", "val": 10.88511429586134}, {"col": "data", "idx": "dr", "val": 22.901554659168934}, {"col": "data", "idx": "effort", "val": 13.419840797868076}, {"col": "data", "idx": "elements", "val": 16.84322967838429}, {"col": "data", "idx": "elemstatlearn", "val": 12.194208493944386}, {"col": "data", "idx": "enjoyed", "val": 22.892492318276066}, {"col": "data", "idx": "esl", "val": 27.224838698515342}, {"col": "data", "idx": "experience", "val": 17.174039027993139}, {"col": "data", "idx": "feel", "val": 11.483151397222841}, {"col": "data", "idx": "field", "val": 10.908595566067456}, {"col": "data", "idx": "follow", "val": 12.357073398601424}, {"col": "data", "idx": "forward", "val": 15.389918134194595}, {"col": "data", "idx": "free", "val": 23.210252010079564}, {"col": "data", "idx": "great", "val": 92.265478054909622}, {"col": "data", "idx": "hastie", "val": 30.784887334530321}, {"col": "data", "idx": "hours", "val": 10.69348372154889}, {"col": "data", "idx": "knowledge", "val": 11.27363499925165}, {"col": "data", "idx": "learn", "val": 15.776747325981081}, {"col": "data", "idx": "learned", "val": 20.373629559493402}, {"col": "data", "idx": "learning", "val": 44.695504652813852}, {"col": "data", "idx": "looking", "val": 14.124850322089507}, {"col": "data", "idx": "lot", "val": 25.736421015663026}, {"col": "data", "idx": "love", "val": 11.120597020057298}, {"col": "data", "idx": "machine", "val": 15.659177258190734}, {"col": "data", "idx": "material", "val": 11.979213872282957}, {"col": "data", "idx": "miss", "val": 13.416951180436584}, {"col": "data", "idx": "offer", "val": 15.879489386932333}, {"col": "data", "idx": "online", "val": 15.457582475212387}, {"col": "data", "idx": "people", "val": 12.522743206464302}, {"col": "data", "idx": "prof", "val": 21.269314985475912}, {"col": "data", "idx": "professors", "val": 24.939410372119081}, {"col": "data", "idx": "rob", "val": 20.164721548686622}, {"col": "data", "idx": "statistical", "val": 35.999760589702156}, {"col": "data", "idx": "statistics", "val": 17.468713510527937}, {"col": "data", "idx": "statweb", "val": 11.657269792932535}, {"col": "data", "idx": "taught", "val": 11.527198411605161}, {"col": "data", "idx": "team", "val": 19.360963896297172}, {"col": "data", "idx": "techniques", "val": 12.012081095115159}, {"col": "data", "idx": "theory", "val": 10.915394915462882}, {"col": "data", "idx": "tibs", "val": 10.930539007475053}, {"col": "data", "idx": "tibshirani", "val": 33.672217165358177}, {"col": "data", "idx": "time", "val": 16.767472948966201}, {"col": "data", "idx": "trevor", "val": 18.669312190349547}, {"col": "data", "idx": "useful", "val": 11.217804030867047}, {"col": "data", "idx": "ve", "val": 11.719076221480188}, {"col": "data", "idx": "week", "val": 17.443948414770531}, {"col": "data", "idx": "weeks", "val": 14.403623990850129}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visc0650f8fe5ac4ce38af2681adc85ba87"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #8:
# <div id="vis47a01b5fa77f418abf4f2c2c95ef1680"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "advice", "val": 1.2114566126789812}, {"col": "data", "idx": "allow", "val": 6.1256881652457826}, {"col": "data", "idx": "answers", "val": 4.3532934033025539}, {"col": "data", "idx": "appears", "val": 129.8470890681528}, {"col": "data", "idx": "apply", "val": 2.7717645211004083}, {"col": "data", "idx": "automatic", "val": 184.72588753690465}, {"col": "data", "idx": "better", "val": 3.0105101101207494}, {"col": "data", "idx": "certificate", "val": 1.0702834196835096}, {"col": "data", "idx": "ch", "val": 7.3090422326887738}, {"col": "data", "idx": "correct", "val": 1.5138075465729033}, {"col": "data", "idx": "correlation", "val": 1.0417745809549672}, {"col": "data", "idx": "exists", "val": 0.95567700169904324}, {"col": "data", "idx": "finish", "val": 1.0902025813150853}, {"col": "data", "idx": "generated", "val": 0.82200437946240779}, {"col": "data", "idx": "getting", "val": 5.4202489531006774}, {"col": "data", "idx": "great", "val": 2.3963937816700787}, {"col": "data", "idx": "lda", "val": 3.2615877146380625}, {"col": "data", "idx": "likely", "val": 2.6201408802836501}, {"col": "data", "idx": "logit", "val": 9.5349895347898084}, {"col": "data", "idx": "low", "val": 3.6896035432727832}, {"col": "data", "idx": "measured", "val": 0.95032905658271583}, {"col": "data", "idx": "multiple", "val": 2.4095342278893255}, {"col": "data", "idx": "past", "val": 9.2621197502346604}, {"col": "data", "idx": "posting", "val": 8.4884388463832252}, {"col": "data", "idx": "prediction", "val": 1.2385227174090874}, {"col": "data", "idx": "probably", "val": 3.4933816897243939}, {"col": "data", "idx": "problems", "val": 3.660328859062203}, {"col": "data", "idx": "prof", "val": 0.81934491910098162}, {"col": "data", "idx": "random", "val": 2.599951011398224}, {"col": "data", "idx": "recommend", "val": 0.84208391592323406}, {"col": "data", "idx": "regards", "val": 0.90139055400397372}, {"col": "data", "idx": "related", "val": 0.88654918279543504}, {"col": "data", "idx": "required", "val": 0.83112446139132068}, {"col": "data", "idx": "resampling", "val": 7.5132426878163168}, {"col": "data", "idx": "results", "val": 3.37192361133437}, {"col": "data", "idx": "screen", "val": 0.99232617991688377}, {"col": "data", "idx": "select", "val": 3.3973747700681103}, {"col": "data", "idx": "series", "val": 0.91765746320109975}, {"col": "data", "idx": "similar", "val": 1.1068154328878843}, {"col": "data", "idx": "software", "val": 2.8465372133712115}, {"col": "data", "idx": "started", "val": 3.1729629886784934}, {"col": "data", "idx": "teaching", "val": 3.8905991606910688}, {"col": "data", "idx": "things", "val": 3.8683118793168854}, {"col": "data", "idx": "throw", "val": 0.96969042178535436}, {"col": "data", "idx": "time", "val": 1.4838120405426223}, {"col": "data", "idx": "tsboot", "val": 3.5438164842085609}, {"col": "data", "idx": "turn", "val": 0.84380565564781662}, {"col": "data", "idx": "ve", "val": 2.2978742236725416}, {"col": "data", "idx": "work", "val": 1.9712951606833347}, {"col": "data", "idx": "year", "val": 1.0466205780385287}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis47a01b5fa77f418abf4f2c2c95ef1680"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #9:
# <div id="vis65babd99c4dc464a9c9545611715af6a"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "100", "val": 5.3176101299256651}, {"col": "data", "idx": "20", "val": 5.3155606188582141}, {"col": "data", "idx": "95", "val": 107.90587090897938}, {"col": "data", "idx": "account", "val": 9.2058792591446252}, {"col": "data", "idx": "assume", "val": 7.5678352535959279}, {"col": "data", "idx": "average", "val": 6.3333866886137056}, {"col": "data", "idx": "bayesian", "val": 13.000120382264424}, {"col": "data", "idx": "calculate", "val": 5.0870517914700342}, {"col": "data", "idx": "chance", "val": 5.284429178700659}, {"col": "data", "idx": "clarification", "val": 5.5080612023277933}, {"col": "data", "idx": "confidence", "val": 94.453634464455618}, {"col": "data", "idx": "constant", "val": 6.3668945630931688}, {"col": "data", "idx": "contain", "val": 22.14423038460043}, {"col": "data", "idx": "contains", "val": 16.499001692255934}, {"col": "data", "idx": "distribution", "val": 9.682681613857973}, {"col": "data", "idx": "doesn", "val": 5.1652704793982283}, {"col": "data", "idx": "errors", "val": 8.3846902145322346}, {"col": "data", "idx": "estimate", "val": 14.084462752351484}, {"col": "data", "idx": "eta_1", "val": 6.4255905583336954}, {"col": "data", "idx": "expect", "val": 7.3165599277220634}, {"col": "data", "idx": "freedom", "val": 5.0898265195082466}, {"col": "data", "idx": "include", "val": 9.8766031592156409}, {"col": "data", "idx": "interval", "val": 104.72422471311218}, {"col": "data", "idx": "intervals", "val": 56.2246710761396}, {"col": "data", "idx": "irreducible", "val": 11.69757377645017}, {"col": "data", "idx": "lies", "val": 6.7439495111609569}, {"col": "data", "idx": "meant", "val": 5.4749141142895352}, {"col": "data", "idx": "multiple", "val": 8.7812377973853959}, {"col": "data", "idx": "normally", "val": 5.2776897897174377}, {"col": "data", "idx": "option", "val": 8.152878577804735}, {"col": "data", "idx": "parameter", "val": 40.692033776908218}, {"col": "data", "idx": "perspective", "val": 5.8799829842213507}, {"col": "data", "idx": "prediction", "val": 17.966028929101867}, {"col": "data", "idx": "probability", "val": 36.13743421893453}, {"col": "data", "idx": "random", "val": 14.270512208234754}, {"col": "data", "idx": "range", "val": 16.511920805279068}, {"col": "data", "idx": "real", "val": 5.6163468465141992}, {"col": "data", "idx": "repeated", "val": 6.986120185521874}, {"col": "data", "idx": "sample", "val": 8.9863026363241776}, {"col": "data", "idx": "say", "val": 8.6411535420474284}, {"col": "data", "idx": "second", "val": 6.0788756534181605}, {"col": "data", "idx": "single", "val": 5.0614324090128635}, {"col": "data", "idx": "standard", "val": 8.8413227569792152}, {"col": "data", "idx": "sure", "val": 5.8481101869585865}, {"col": "data", "idx": "times", "val": 6.7637623132457314}, {"col": "data", "idx": "true", "val": 39.157410852116001}, {"col": "data", "idx": "unknown", "val": 13.521679238152448}, {"col": "data", "idx": "value", "val": 25.112343241027467}, {"col": "data", "idx": "winter2014", "val": 6.0718873484278939}, {"col": "data", "idx": "wrote", "val": 10.848544771836071}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis65babd99c4dc464a9c9545611715af6a"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #10:
# <div id="vis91dbe5a206bb43099b5d53ccf78788da"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
# ...
#          chart({el: "#visb550a816eb594fceb43051933eb8d469"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #47:
# <div id="vis18aa61c56d964cef86e3b5ca23f98e86"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "05", "val": 10.142678792521966}, {"col": "data", "idx": "16", "val": 7.9862214013671009}, {"col": "data", "idx": "alternative", "val": 13.091778325390512}, {"col": "data", "idx": "article", "val": 7.7253315575281256}, {"col": "data", "idx": "bayesian", "val": 19.190746621909458}, {"col": "data", "idx": "beta", "val": 16.542131099567424}, {"col": "data", "idx": "chance", "val": 13.500155341781239}, {"col": "data", "idx": "confidence", "val": 10.226306183569884}, {"col": "data", "idx": "confused", "val": 10.183179785203182}, {"col": "data", "idx": "definition", "val": 8.0736024664362649}, {"col": "data", "idx": "degrees", "val": 7.5494698583390791}, {"col": "data", "idx": "distribution", "val": 15.017263204315379}, {"col": "data", "idx": "effect", "val": 8.7164798536336274}, {"col": "data", "idx": "equal", "val": 8.3066344338787648}, {"col": "data", "idx": "errors", "val": 8.4474743401718175}, {"col": "data", "idx": "event", "val": 9.5574034754179298}, {"col": "data", "idx": "false", "val": 8.3055540018599388}, {"col": "data", "idx": "freedom", "val": 8.6135476068830474}, {"col": "data", "idx": "given", "val": 8.7808762860169658}, {"col": "data", "idx": "greater", "val": 7.8752009477719156}, {"col": "data", "idx": "guess", "val": 21.526000027269436}, {"col": "data", "idx": "happen", "val": 8.2096697764392399}, {"col": "data", "idx": "hypothesis", "val": 101.14064292885094}, {"col": "data", "idx": "interval", "val": 12.973406304366724}, {"col": "data", "idx": "kind", "val": 7.3905238613547333}, {"col": "data", "idx": "large", "val": 9.8720281649366228}, {"col": "data", "idx": "likely", "val": 10.749971640541354}, {"col": "data", "idx": "low", "val": 10.78194842120983}, {"col": "data", "idx": "measures", "val": 9.0049880402648714}, {"col": "data", "idx": "models", "val": 10.670898044149144}, {"col": "data", "idx": "null", "val": 158.27218645614906}, {"col": "data", "idx": "people", "val": 9.596617328812}, {"col": "data", "idx": "positive", "val": 13.824908000668955}, {"col": "data", "idx": "prior", "val": 8.2457775517012273}, {"col": "data", "idx": "probability", "val": 9.1205033644753097}, {"col": "data", "idx": "questions", "val": 9.1538344896601487}, {"col": "data", "idx": "relationship", "val": 12.710254109497274}, {"col": "data", "idx": "residual", "val": 11.493970302422685}, {"col": "data", "idx": "significance", "val": 16.217976363410809}, {"col": "data", "idx": "slope", "val": 23.293428175593977}, {"col": "data", "idx": "standard", "val": 9.7895353656379154}, {"col": "data", "idx": "statistic", "val": 28.521895914890035}, {"col": "data", "idx": "statistics", "val": 19.512662100849475}, {"col": "data", "idx": "testing", "val": 15.886178327320316}, {"col": "data", "idx": "tricky", "val": 8.684117977681499}, {"col": "data", "idx": "true", "val": 8.1705856611441039}, {"col": "data", "idx": "unlikely", "val": 16.01865745757171}, {"col": "data", "idx": "value", "val": 31.171657560154454}, {"col": "data", "idx": "wording", "val": 11.00293400925443}, {"col": "data", "idx": "zero", "val": 18.221506563145773}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis18aa61c56d964cef86e3b5ca23f98e86"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #48:
# <div id="vis68a027538889482a873d265e28808e43"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "10", "val": 23.903876122925691}, {"col": "data", "idx": "12", "val": 10.775885891444394}, {"col": "data", "idx": "20", "val": 7.8527529584743769}, {"col": "data", "idx": "500", "val": 9.627274822421013}, {"col": "data", "idx": "behavior", "val": 9.6769850289670938}, {"col": "data", "idx": "book", "val": 11.28571771096197}, {"col": "data", "idx": "build", "val": 13.433159297467528}, {"col": "data", "idx": "col", "val": 9.3989029073927668}, {"col": "data", "idx": "column", "val": 58.546664299698357}, {"col": "data", "idx": "columns", "val": 34.106647457125469}, {"col": "data", "idx": "compute", "val": 15.902596727932817}, {"col": "data", "idx": "computed", "val": 9.1395374587898282}, {"col": "data", "idx": "correlation", "val": 22.057007537251121}, {"col": "data", "idx": "correlations", "val": 12.386997356117528}, {"col": "data", "idx": "covariance", "val": 70.045965767269607}, {"col": "data", "idx": "creating", "val": 11.740256607807471}, {"col": "data", "idx": "difference", "val": 9.483715809421227}, {"col": "data", "idx": "egin", "val": 12.673363437274451}, {"col": "data", "idx": "essentially", "val": 9.970501532773973}, {"col": "data", "idx": "factor", "val": 22.198945665300908}, {"col": "data", "idx": "fitted", "val": 8.5604129460439964}, {"col": "data", "idx": "fix", "val": 8.7255061805260734}, {"col": "data", "idx": "formula", "val": 14.342004492957827}, {"col": "data", "idx": "frame", "val": 14.964653008687712}, {"col": "data", "idx": "glmnet", "val": 11.951247867184035}, {"col": "data", "idx": "graph", "val": 9.3696171404773807}, {"col": "data", "idx": "independent", "val": 7.8392332281138923}, {"col": "data", "idx": "inside", "val": 14.343733038668807}, {"col": "data", "idx": "intercept", "val": 77.546734101260256}, {"col": "data", "idx": "levels", "val": 35.225864175544423}, {"col": "data", "idx": "matrix", "val": 142.77486276510066}, {"col": "data", "idx": "mu", "val": 13.438915252962655}, {"col": "data", "idx": "object", "val": 12.257912987570437}, {"col": "data", "idx": "remove", "val": 21.994976412271608}, {"col": "data", "idx": "response", "val": 7.771915574599392}, {"col": "data", "idx": "rnorm", "val": 8.8803624377338579}, {"col": "data", "idx": "row", "val": 16.8085148789973}, {"col": "data", "idx": "runs", "val": 17.961234042271496}, {"col": "data", "idx": "sd", "val": 10.204368373289475}, {"col": "data", "idx": "single", "val": 8.1901522328219034}, {"col": "data", "idx": "slope", "val": 12.747899621437947}, {"col": "data", "idx": "space", "val": 7.8646034280274044}, {"col": "data", "idx": "specified", "val": 7.9756549310115981}, {"col": "data", "idx": "team", "val": 8.8241103225913253}, {"col": "data", "idx": "variable", "val": 16.489002788650374}, {"col": "data", "idx": "variables", "val": 7.6126247677323065}, {"col": "data", "idx": "variance", "val": 14.930826188726176}, {"col": "data", "idx": "vectors", "val": 9.5427059388721389}, {"col": "data", "idx": "xi", "val": 14.635839629450933}, {"col": "data", "idx": "years", "val": 12.216442938691328}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis68a027538889482a873d265e28808e43"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #49:
# <div id="vise4a1cc649bec4920a4de203d05dcf8ad"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "address", "val": 6.9702897395074777}, {"col": "data", "idx": "apply", "val": 9.7123983175197832}, {"col": "data", "idx": "assumptions", "val": 15.871882725324852}, {"col": "data", "idx": "bigger", "val": 13.80323204107164}, {"col": "data", "idx": "block", "val": 153.79849832878327}, {"col": "data", "idx": "blocks", "val": 22.692534016428993}, {"col": "data", "idx": "bootstrap", "val": 97.193311793796354}, {"col": "data", "idx": "bootstrapping", "val": 35.560383924973657}, {"col": "data", "idx": "code", "val": 9.3083859410943735}, {"col": "data", "idx": "day", "val": 15.63561836643888}, {"col": "data", "idx": "days", "val": 12.806655604244421}, {"col": "data", "idx": "depend", "val": 7.4915950674458003}, {"col": "data", "idx": "distributed", "val": 16.694301070696987}, {"col": "data", "idx": "distribution", "val": 10.572251055642655}, {"col": "data", "idx": "errors", "val": 40.133892226492307}, {"col": "data", "idx": "estimate", "val": 14.131524065900026}, {"col": "data", "idx": "estimates", "val": 7.7586137748567108}, {"col": "data", "idx": "factors", "val": 9.8860787733841846}, {"col": "data", "idx": "forum", "val": 16.306270648811211}, {"col": "data", "idx": "having", "val": 7.7258019215426854}, {"col": "data", "idx": "independent", "val": 19.417607161830986}, {"col": "data", "idx": "length", "val": 12.372600169610742}, {"col": "data", "idx": "location", "val": 7.2974349100200913}, {"col": "data", "idx": "lot", "val": 10.896860223253142}, {"col": "data", "idx": "march", "val": 18.588250962271612}, {"col": "data", "idx": "near", "val": 8.6485497015783857}, {"col": "data", "idx": "non", "val": 14.665851125441229}, {"col": "data", "idx": "observations", "val": 12.603340583189226}, {"col": "data", "idx": "options", "val": 7.9943573524951947}, {"col": "data", "idx": "order", "val": 7.6282954643082945}, {"col": "data", "idx": "ordinary", "val": 12.95745578069287}, {"col": "data", "idx": "people", "val": 10.298724452965249}, {"col": "data", "idx": "points", "val": 16.917741374820704}, {"col": "data", "idx": "regarding", "val": 8.1152070242106369}, {"col": "data", "idx": "regular", "val": 10.259615466034866}, {"col": "data", "idx": "sampling", "val": 9.044864602871943}, {"col": "data", "idx": "se", "val": 7.5325620674073193}, {"col": "data", "idx": "search", "val": 21.169529464435023}, {"col": "data", "idx": "seen", "val": 6.978933805378662}, {"col": "data", "idx": "series", "val": 70.321112229068376}, {"col": "data", "idx": "sim", "val": 8.4046828090580359}, {"col": "data", "idx": "solve", "val": 11.391042935192294}, {"col": "data", "idx": "standard", "val": 47.203489063944822}, {"col": "data", "idx": "std", "val": 13.241815077887301}, {"col": "data", "idx": "time", "val": 43.898117125546278}, {"col": "data", "idx": "tsboot", "val": 19.502633482834458}, {"col": "data", "idx": "uncorrelated", "val": 16.119048005505697}, {"col": "data", "idx": "user", "val": 8.3354037725784185}, {"col": "data", "idx": "welcome", "val": 8.3299423774773125}, {"col": "data", "idx": "williamchiu", "val": 11.006812304489458}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vise4a1cc649bec4920a4de203d05dcf8ad"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
#Write file to EXCEL for labeling each comment by hand
# import csv
# reload(sys)
# sys.setdefaultencoding("utf-8")

# myfile = csv.writer(open("grouped_comments.csv", 'wb'))
# for g in grouped_comments:
#     myfile.writerow([g])

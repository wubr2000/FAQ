# %%
import pandas as pd
import numpy as np
import sys
import logging
import seaborn 
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.metrics.pairwise import linear_kernel,pairwise_distances
from sklearn.feature_extraction import text as txt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer, HashingVectorizer
from IPython.display import display, Math, Latex

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation

from optparse import OptionParser

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Discussion forums specific stopwords
additional_stop_words = [
                         "zipredac","phoneredac","nameRedac_anon_screen_name_redacted",
                         "explanation", "helpful", "yes",
                         "agree","excellent","dear",
                         "ok", "cool", "idea", "guys",
                         "hello", "student", "sorry", "makes",
                         "sense", "nice", "meet", "yeah", "wow",
                         "hint", "post", "understand", "helped",
                         ]

# %%
forum = pd.read_csv("statsLearningForum.csv", quoting = 2, header = None, 
                    escapechar = "\\", encoding = "ISO-8859-1")

# %%
forum.columns = ["anon_screen_name", "type", "anonymous", "anonymous_to_peers", 
                 "at_position_list", "user_int_id", "body", "course_display_name", 
                 "created_at", "votes", "count", "down_count", "up_count", "up", "down",
                 "comment_thread_id", "parent_id",  "parent_ids", "sk","extra"]

# %%
pd.options.display.max_colwidth=110
#forum.head()

# %%
del forum["anon_screen_name"]
del forum["at_position_list"]
del forum["extra"]
del forum["course_display_name"]

# %%
forum.body.head()
# Out:
# 0    Welcome to the discussion forum! We are hoping this will be a useful place for us to discuss anything rela...
# 1                                           Thank you , Sir!\nIts great to have this Stat learning class from you.
# 2                                                Great to have online free textbook - here's to some "R" learning.
# 3                                                  Will we be able to download the videos as in other edX courses?
# 4                                                     FYI this is not an edX course but a Stanford OpenEdX course.
# Name: body, dtype: object

# %%
#Create "final_corpus", "all_questions", and "all_comments"

#"all_questions" are not only rows labeled "CommentThread" but also rows where there is a question mark - i.e.
#clearly a question and not just someone making a statement to initiate a chain.

corpus = []
for body in forum.body:
    corpus.append(''.join(body))    

#Clean junk in strings
final_corpus = []
for c in corpus:
    unicode(c)
    final_corpus.append(c.replace("\n"," ").replace("\n\n"," "))

print len(final_corpus)

questions = [ f for f in forum.body[forum.type=="CommentThread"] if "?" in f ]
#Clean junk in strings
all_questions = []
for q in questions:
    unicode(q)
    all_questions.append(q.replace("\n"," ").replace("\n\n"," "))

print len(all_questions)

all_comments = [ comment for comment in final_corpus if comment not in all_questions ]

print len(all_comments)
# Out:
# 5803
# 851
# 4952

# %%
#TF-IDF calculation on "all_questions"
#Prior to any topic modeling or clustering
#This doesn't work very well - take a look at the questions that are grouped together

tfidf = TfidfVectorizer(encoding='utf-8', lowercase = True, 
                        stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words))
tfid = tfidf.fit_transform(all_questions)

print tfid.shape
# Out:
# (851, 5046)

# %%
#Get the top 10 most similar questions using cosine similarity for each question

cosine_similarities = linear_kernel(tfid, tfid)

most_similar_index = []
for similar in cosine_similarities:
    most_similar_index.append(similar.argsort()[-10:][::-1])

print len(most_similar_index)
# Out:
# 851

# %%
for questions in most_similar_index[:10]:
    print "------------------------"
    for q in questions:
        print q, ":", all_questions[q]
# Out:
# ------------------------
# 0 : Does this course have an option to download video material? It will help for offline viewing and for locations with slow Internet access
# 89 : It would be nice if this course were offered thru Coursera.  Has anybody found the way to save video lectures for offline viewing onto their iPad ?
# 817 : Hello! I have a question:  The last notice about the course was: "The new course termination date is April 4, an extension by two weeks. This applies to all the quizzes, and access to course materials".  That last part **"access to course materials"**  is worrying me, **what does it mean as access?** Because what I used to do was download the videos from youtube and watch them in my ipad (for convinience because sometimes I didn't have access to internet), I did this for most of them so I'm worried that my record will not count in that matter. I've already watched every video, some online, some in my ipad.     Thank you.
# 246 : Anyone using an iPad mini for viewing the course material? Any limitations there?
# 140 : I'm a student at a high school that allows access to the internet. However, YouTube is blocked. In the Stanford online course, Environment Physiology, the individual video lectures could be downloaded. Can you offer to download the different lectures as well as embedded code to YouTube? I'm sure there are also other people who are taking this course that have limited access to YouTube as well.
# 640 : The video quality of .mov file available for download through download link is quite poor (slide text shown in the video are often blur).  Additionally since youtube in our country is blocked so it is not possible to view the course video directly.  It would be great help if someone can list down all the youtube video url for each lecture. For example the video url for lecture (Ch5-Resampling in R) is      https://www.youtube.com/watch?feature=player_embedded&v=YVSmsWoBKnA   Once this url is available, i can then download the video using www.clipconverter.cc
# 748 : I could not find the answer to this on the site.  I understand that the deadline for the course certificate is April 4, but what happens to the course material (slides, videos, R code) after April 4?  Will we retain access at that point?  Thank you.
# 5 : Dear colleagues,  Thank you for this course and its materials. my internet speed is low in Iran and i have exhausting problem to online learning. may I ask you to provide a possibility to download course materials include videos, please? Bests, H.M.V
# 821 : Hello everyone, I am a student learning statistic but English is not my native language. Therefore, I find it difficult to watch the lecture video without caption. Does anyone know how to download the subtitle file for the video(.swf)? In addition, the video which I downloaded is blur and hard to read words, I want to find the source for better quality of video. Thanks for reading!
# 139 : Does anyone know how to gain access to the R Sessions that are not HTML files? Thank you
# ------------------------
# 1 : Hi all,  Is it possible to download the subtitles as srt format?  Thanks!
# 763 : Is it possible to download all of the discussion threads (with responses)?
# 149 : I'd like to download it. Don't see it under "R Sessions".  Where might I find it? Thanks.
# 254 : Hi all. I'm very glad to participate this course. I saw that we can download de full video of each class. Is it possible to release also the captions? If is, how?  Thanks a lot!
# 287 : For categorical variables, do we always need to create dummy variables (0-1 format) for each class? why can't we simply use something like 1-yellow, 2-blue, 3-red...
# 39 : Hi,  Is it possible that we use Matlab instead of R in writing codes?
# 36 : Hi, Everyone,     I am in China where Youtube is blocked by the Great-Fire-Wall. So are there any other approaches or servers for me to visit or download the videos?        Thanks
# 262 : "If we have n data points, what is the probability that a given data point does not appear in a bootstrap sample?"  What is the format of the answer accepted? just a real number? I used fractionals and reals but it doesn't seems to get accepted... anyone got this question right? thanks
# 257 : Hello, I normally use Minitab for statistical analysis and I wanted to get the Lab files (such as Carseats in chapter 3) in CSV or text format so that I can do the exercises with Minitab.  I haven't been able to find them on the ISRL site. Could you help please ? Thanks, <nameRedac_anon_screen_name_redacted>
# 423 : Hi everyone,  I just would like to know, why do we get 2 coefficients in LDA for the R example in the lecture?  Thanks!
# ------------------------
# 2 : Seriously, have you looked at those questions in light of the material in the lecture? You either need to do a helluva lot better job of explaining the difference between supervised or unsupervised learning, or you need to write questions that are decidable based on the information available in the lecture.  The first question presents four learning problems.  1. Predict whether a website user will click on an ad     no training data mentioned.   2. Find clusters of genes that interact with each other     no training data mentioned,     clustering is mentioned explicitly in the lecture as an unsupervised training    problem.   3. Classify a handwritten digit as 0-9 from labeled examples     measurable outcome, and training data is available - supervised!   4. Find stocks that are likely to rise      No training data mentioned, so not supervised   And seriously, question 2?   What's up with that question?  The answer has one out of three goals for supervised learning, but because the other two are not mentioned it is incorrect?  This is like a game of simon says?   simon didn't say  "Understand which inputs affect the outcome, and how" so the answer is incorrect? No, the answer is correct, perhaps incomplete, but predicting IS a goal of supervised learning.  You guys are just playing games here.
# 48 : Why the #1 is a supervised learning and not #2, even though we can have sample of genes cluster?  1) Predict whether a website user will click on an ad  2) Find clusters of genes that interact with each other
# 60 : Hello there, I copy here the text of the question.   > Which of the following are supervised learning problems? More than one > box can be checked.    >-  Predict whether a website user will click on an ad  > - Find clusters of genes that interact with each other > - Classify  a handwritten digit as 0-9 from labeled examples >- Find stocks that  are likely to rise   As far as I have understood, only in the third answer the Y (response variable) is labelled, also known. Unlikely, in the first answer, it is clear the response variable would be clicking or not in the ad; in the fourth answer, rising or not would be the dependent variable Y, but in the way it is written, it is not clear to me that those response variables are given in the problem.  Thanks in advance for your answers
# 59 : Can Discriminant Analysis be considered an example of supervised learning ?
# 43 : Is is correct to say that ANY supervised learning problem involves prior labeling? As opposed to SOME?
# 152 : True or False: The goal of any supervised learning study is to be able to predict the response very accurately.  Why we don't want to predict the response very accurately? Or the main case of the question, that we can't always do it? Thank you.
# 575 : In the lecture, the professors comment on the selection of 500 genes, based on largest variance, from the thousands available (slide 38).  Professor Hastie explains that this does not bias the outcome because the genes were unsupervised by class.  Can somebody explain what *unsupervised by class* means and how one does it?  Thanks!
# 672 : Good day everyone,  I understand that sequential supervised learning is different from times series ["Machine Learning for Sequential Data: A Review" by Dietterich]. How can I apply bootstrap for these 2 different cases?  Thanks!
# 170 : Confidence interval derived in lecture 3 refers to statistical inference drawn out from the training data. That is, in the context of a given training data, the coefficients are estimated and a given confidence interval is calculated.  Which are the practical uses, in the context of learning, of confidence intervals drawn over training data sets?  Or in a different way: what does that confidence interval (calculated over the training set) tell us about how well the model will perform over other data set (real data, other test data)?.   I have similar question about p-values. For example, if the model is overfitted, the p-value will probably be very small but performance (prediction accuracy) over real data can be poor.
# 408 : I have seen these Bias and Variance graphs multiple times throughout the book. I never figured out how training or test data is used (or in other cases if the true model that generated the training data is even involved). How are the data for these graphs computed really?  Take Figure 6.5 as an example.  ![Figure 6.5 from ISL][1]    [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>77.png  For example, Wikipedia says Bias is E[f_i - E(f_hat_i)]^2  But if I am not mistaken, all these terms need to be estimated? But how?  I just need an equation that explicitly explains how test data or training data is used. I can handle x_ij or Sigma notation. I just don't know if it's right to obtain E(f_hat_i) by averaging over predicted values y_hat_i from all training data x_i (vector).
# ------------------------
# 3 : Hi,  I'm not sure whether it's an issue with Chrome but the slides are quite fuzzy and I'm unable to make out the text and graphics in some of the slides. Does anyone else have the same issues?  <nameRedac_anon_screen_name_redacted>
# 665 : Hi, I have found slides about "Pre-validation" and "Permutation tests" at the very end of Chapter #5 slides, however there are no such materials in video lectures. Am I missing something?
# 443 : Is it possible to remove the duplicate/transition slides from the lecture slides posted for download?  It's pretty unhelpful to have multiple copies (all but the last one incomplete) of many of the slides -- painful for reviewing.
# 24 : If the slides are being typeset with the Beamer package in LaTeX, may I suggest using the handout option, as in documentclass[handout]{beamer}, to reduce the number of pages for those of us who want to print them out? For example, the statistical learning slides are 37 pages, but fit on 30 slides. At 4-to-1, that's an extra two pages. Given the number of enrollees who might want to print them, that adds up quickly. I noticed the linear regression slides are 64 pages on 48 slides.   See section 20 of the Beamer manual for more details if necessary.
# 22 : Hi everyone,  I am unable to hear the audio properly. The voices sound like "chocky". I've tried mozilla and chrome and had the same problem.   Did anyone out there notice it as well?  Regards
# 220 : I understand that you downsize the video to make it fast to download. However, I cannot see the slides clearly, and it is troublesome to switch between video and slides. Can you upload a version of video that is high resolution? You can keep the one with low resolution too in case others need low resolution one.   Thanks.
# 25 : I tried to download and view the lecture slides (shortened url deleted) however, Adobe Reader claims the pdf's are corrupt. This occurs on 2 different machines.  Anyone else seeing this issue?  Staff edit: Download and view the lecture slides here: https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/ba1951b8f66c4cdca2fcaabcdc91b792/  Please don't use url shorteners.  Thanks!
# 594 : Hi - maybe it's just me, but I think there might be additional lecture notes/material that I'm not seeing on the website? I'm now up to Chapter 4 and I'm still having this issue that the lectures seem to leap to the quiz questions and there's nothing in between?   In some cases the quiz refers to a dataset I don't have, and in others it refers to "lecture notes".   I have the pdf of the lecture slides, but they don't seem to contain quite enough information to fill in the gaps.   Is anyone else having this problem?
# 167 : I think this is a important issue, but somewhat there are no details in the textbook, can someone explain it?  Thanks. <nameRedac_anon_screen_name_redacted>
# 45 : Hi there,  Is the solutions to the exercises in the text book available somewhere?
# ------------------------
# 4 : I'm really confused about this hypercube stuff, can anyone explain what this question is asking? Thanks..
# 116 : can anybody help me on this question? i did not understand what are they asking....
# 276 : I'm trying to understand how the hypercube question relates to the curse of dimensionality but can't find a clear connection. I know that most of the data at 50D will be at the 10% extreme of the hypercube, but what does that say about the distance between points?
# 153 : Can someone help me understand the question?  (A hypercube with side length 1 in d dimensions is defined to be the set of points (x1, x2, ..., xd) such that 0?xj?1 for all j = 1, 2, ..., d. Define the boundary region of the hypercube to be the set of all points such that there exists a j for which 0?xj?.05 or .95?xj?1 (i.e., it is the set of all points that have at least one dimension in the most extreme 10% of possible values). What proportion of the volume of a hypercube of dimension 50 is in the boundary region?  Please give your answer as a value between 0 and 1 with 3 significant digits. If you think the answer is 50.52%, you should say 0.505:)
# 406 : Could someone please explain to me how I get the model for question 3.5.R1 I have tried to answer the question but I can't wrap my head around it?  Thank you,
# 44 : I have no clue how to begin this question. I assumed that when p = 50, we would have captured the majority of the hypercube, but how would one begin to calculate something like this?
# 263 : The question states "Consider the linear regression model of y on X1 and X2. To within 10%, what is the standard error for ?1?"  Can someone explain explicitly what "within 10%" means here?  Thanks.
# 167 : I think this is a important issue, but somewhat there are no details in the textbook, can someone explain it?  Thanks. <nameRedac_anon_screen_name_redacted>
# 338 : I don´t understand the wording of this question: *Download the file 5.R.RData and load it into R using load("5.R.RData"). Consider the linear regression model of y on X1 and X2.  To within 10%, what is the standard error for ?1?*  What are they exactly asking by "To within 10%".  Any help welcome.
# 565 : Can anyone explain to me the "-1"?      x=model.matrix(Salary~.-1,data=Hitters)
# ------------------------
# 5 : Dear colleagues,  Thank you for this course and its materials. my internet speed is low in Iran and i have exhausting problem to online learning. may I ask you to provide a possibility to download course materials include videos, please? Bests, H.M.V
# 817 : Hello! I have a question:  The last notice about the course was: "The new course termination date is April 4, an extension by two weeks. This applies to all the quizzes, and access to course materials".  That last part **"access to course materials"**  is worrying me, **what does it mean as access?** Because what I used to do was download the videos from youtube and watch them in my ipad (for convinience because sometimes I didn't have access to internet), I did this for most of them so I'm worried that my record will not count in that matter. I've already watched every video, some online, some in my ipad.     Thank you.
# 793 : Is it possible to look through again materials after course finished?
# 678 : Will the course materials remain accessible to course participants flowing March 21st?  Or, should we download all pdfs and videos we might like to keep for future reference?  Thank you!
# 541 : Will the lecture materials, videos, notes etc. be available after the course is over?  Would be useful for those that want to review at a later point.
# 834 : First of all, Thank you so much to Trevor, Rob and the staffs to making this excellent online course. Well prepared materials and excellent video lectures. It was a wonderful learning experience.   I am interested to have further research and study on Statistical Learning area. Can you suggest any good postgraduate courses or research programs that fit well for students finish this course?  Regards
# 667 : Hello,  I find the videos far more viewable at 1.5x speed, but I am no longer able to get the videos to display at that speed.  Was that a deliberate change?  Thank you, Greg
# 209 : Hi-  I can't seem to get the video to play at any faster speed than 1.0x. When I download and play in VLC Player, it does not render well.  Any ideas on how to watch videos at higher playback speed?  thanks!
# 0 : Does this course have an option to download video material? It will help for offline viewing and for locations with slow Internet access
# 140 : I'm a student at a high school that allows access to the internet. However, YouTube is blocked. In the Stanford online course, Environment Physiology, the individual video lectures could be downloaded. Can you offer to download the different lectures as well as embedded code to YouTube? I'm sure there are also other people who are taking this course that have limited access to YouTube as well.
# ------------------------
# 6 : Hi, is there a possibility to see the videos with a 1.25x speedup? I'd like a quicker pace than 1x, but I can't follow 1.5x, and (at least in Firefox) there is no option in between.
# 667 : Hello,  I find the videos far more viewable at 1.5x speed, but I am no longer able to get the videos to display at that speed.  Was that a deliberate change?  Thank you, Greg
# 515 : I found that quiz formulas don't show appropriately. I didn't notice this problem until a recent firefox update (now I use firefox v20)   I tried IE, but it says it doesn't support the frame or something at all.  Can anyone help? Thanks  Attached: ![formulas don't work][1]     [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>12.png
# 19 : I am using Linux (Kubuntu 13.10).  Because of the course's "Progress" page, I assume there are embedded review questions in the videos.  I have tried watching the videos using both Firefox and Chrome but do not see the questions.  [My expectation is a yellow bar on the playback progress bar as appears with Coursera videos.]  Is my assumption correct about the review questions?  If so, how do I view them using Linux.  Thanks.
# 272 : Hello,  As some of you have noted before, I have found out that while the streaming videos have an optimal image quality, the downloads from the course site (which in my case I reproduce with either VCL on a Fedora <zipRedac>9 OS or with Quicktime on a Mac OS <zipRedac>0.5.8) are blurred.  In fact, one can't distinguish what is written on the screen at all.  Instead, the downloads from Youtube are all right (which I download with the aid of the Firefox add-on that you can find at http://www.downloadhelper.net/install.php).  However, by subscribing to the channel "Statistical learning" in Youtube, I only find the video "<zipRedac>0<zipRedac><zipRedac><zipRedac>3 Lab Meeting".  There are more videos at  https://www.youtube.com/channel/UC4OWDcPB<zipRedac>peiBXDfCSZ3h-w/videos?flow=grid&view=<zipRedac> but the order is not obvious and some lectures are missing.  Does anyone know where can I find all the videos in Youtube and whether the "blurredness" in the videos posted on the course site (once you download them) is going to be fixed at some point?  Thank you very much for this superb course.  Best wishes,  <nameRedac_anon_screen_name_redacted>
# 239 : ![slide 18 in Ch4 classification][1]     [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><zipRedac>38466.jpg  On slide 18 in Ch4 (as above), I don't quite follow why multiclass regression is formulated like this.  - what's k? is it the total number of classes in Y? - what's the expected result from multiclass regression? possibility for each class of Y?  - Do we need to determine which class the Y belongs to and how? what if possibilities are quite close?
# 5 : Dear colleagues,  Thank you for this course and its materials. my internet speed is low in Iran and i have exhausting problem to online learning. may I ask you to provide a possibility to download course materials include videos, please? Bests, H.M.V
# 582 : Is there a way to download high definition versions of the videos?  I don't have access to a particularly fast connection.  Mostly it is not a problem but I can't read the text of the videos of the Section 6 video.  I downloaded the videos and they are even less clear than the streamed versions.
# 775 : Since it comes to the end of the course, is there any possibility that we could have all the discussion section as a document and downloading in case we want to come back and revisit in future? Thanks.
# 423 : Hi everyone,  I just would like to know, why do we get 2 coefficients in LDA for the R example in the lecture?  Thanks!
# ------------------------
# 7 : Topic 2.2 is about Dimensionality and Structured models, while quiz 2.2 r1 asks about bias and variance, which are discussed in topic 2.3. What's the point of asking questions on topics which are not discussed yet?
# 92 : Hi Can somebody provide clues on solving this question ?  I am not sure if the topic is discussed in lect 2.2 ?  TIA
# 116 : can anybody help me on this question? i did not understand what are they asking....
# 194 : I viewed video 4.1 on Categories and then went to take the quiz associated with the video. The question was on Case/Control Samples. I don't recall that being discussed in the video. Am I missing something?
# 29 : The textbook and the lectures have a very specific definition of bias:  ![bias][1]  Does this definition capture the other forms of statistical bias (sample bias, omitted-variable bias, reporting bias, exclusion bias, analytical bias)?   http://en.wikipedia.org/wiki/Bias_(statistics)     [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>97.png
# 144 : Why we dont use different models for apples and oranges? I mean if we have interest in differences.   I dont understand questions 3.4.R1 and 3.4.R2.
# 28 : Test Set MSE can be decomposed into Bias, Variance, and Irreducible Error. "Bias" sounds worse than "Variance". Are they equally bad or is one more bad than the other?
# 8 : Is there any quiz from chapter 1?
# 112 : I think the question means two-sided alternative as one sided alternative were not discussed yet?
# 774 : Really like Introduction to Statistical Learning...plan on getting Elements of Statistical Learning next.   Does anyone else have any recommended books on the topic?
# ------------------------
# 8 : Is there any quiz from chapter 1?
# 37 : Very confused!  In the Courseware section I only see one link to a quiz.  It is for Chapter 2 (four binary-choice questions).  I've noticed some discussion posts about quizzes 1 and 2 ... where's quiz 1?  Or is the quiz for Chapter two 'quiz 1'?  Is there another open quiz?  Also, I've noticed some discussions about Quiz:2.2 R2  ... but I don't know what they're referring to.  Are there R quizzes as well?  Where?  I take it that the R quizzes are separate from the labs.  (The 'R Sessions' link doesn't indicate quizzes)  Can anyone point me in the right direction?  Thanks
# 380 : Is the quiz from section 6.9 missing?
# 459 : Dear all, So under Courseware, for every week there is a tab that says Chapter X quiz and when I click on that I can only see one MCQ question. There are the left and right buttons on top of the quiz but it doesn't seem to work on my laptop. So does that mean there is only one quiz question per week? Or there is something wrong with my web browser.... Thanks heaps for your help guys!!!
# 30 : Hi, what is the due date of quiz 1 and 2?
# 214 : Is there a help file of some sort explaining how the quiz software works?  Sorry to be dense, but I can't figure out what it's doing.  Can I go to the end of a chapter and do all the quiz questions?  If I get an answer wrong, what should I do?  What does the given number of "submits" mean?  Do I have to "Save"?  What if I don't?
# 839 : Can anyone help with this quiz? Are they looking for an numerical answer or in terms of n and k.
# 698 : As indicated by the slides will we get a Chapter 10 courseware package of videos, exercises and quiz ??, If so when, we have 7 days more till March 21st deadline.  regards
# 594 : Hi - maybe it's just me, but I think there might be additional lecture notes/material that I'm not seeing on the website? I'm now up to Chapter 4 and I'm still having this issue that the lectures seem to leap to the quiz questions and there's nothing in between?   In some cases the quiz refers to a dataset I don't have, and in others it refers to "lecture notes".   I have the pdf of the lecture slides, but they don't seem to contain quite enough information to fill in the gaps.   Is anyone else having this problem?
# 421 : Are there problems in each section, other than quiz? For example, I saw this in my progress: 2.4 Classification 0 of 1 possible points (0/1) Review & Quiz due Mar 21, 2014 at 16:30 PDT Problem Scores:    0/1  Where are problems? How could I see them? Thanks
# ------------------------
# 9 : Is there any spanish speaking people interested in creating a group for discussing, just in case, different topics of the course in our mother tongue?
# 813 : I know at least two other people who would be interested in seeing the videos and the book.  Can I direct them somewhere, or is this only available during the course?
# 805 : I understand having a deadline to finish the course helps motivation. However, the possibility of keeping the course open seems like a viable alternative given the format. It'd be nice for people to come back after applying the information to work and share some experiences. And, what will happen to all of this great discussion? Will it just disappear? Given the effort it took to create this course, I'm sure it will be offered again. However, why not just keep the course open?
# 568 : For the model y ~ 1+x+x^2, what is the coefficient of x ...  I got quite different result creating the following two models:  Fit1=lm(y~poly(x,2))  and  Fit2==lm(y~x+I(x^2))  Could someone explain what's the difference for this two models? I thought they should do the same thing, but apparently not.
# 13 : I realise that every student is different, but other MOOC platforms publish the expected volume of work for each course, say 10 hours per week, so that some degree of capacity planning is possible. This is particularly useful for people like me who have taken time off work to 're-purpose' their skills, in my case in data science.  Did the teaching team write anywhere what their expectation is for this course? I would be really grateful to know.  <nameRedac_anon_screen_name_redacted>
# 66 : Hi all,  I am developing a start-up which relies on statistical modelling. I would be interested to know what motivated others to join this course?  What kind of projects is everyone working on? I am quite curious...  M
# 787 : I took this course as an independent study for my degree. I just wonder after we finish this course, are we going to get the certificate? Thanks.
# 7 : Topic 2.2 is about Dimensionality and Structured models, while quiz 2.2 r1 asks about bias and variance, which are discussed in topic 2.3. What's the point of asking questions on topics which are not discussed yet?
# 140 : I'm a student at a high school that allows access to the internet. However, YouTube is blocked. In the Stanford online course, Environment Physiology, the individual video lectures could be downloaded. Can you offer to download the different lectures as well as embedded code to YouTube? I'm sure there are also other people who are taking this course that have limited access to YouTube as well.
# 42 : Hi all -- My statistical training was all in social sciences (sociology, demography) and biomed (public health, clinical trials). To me, this course is kind of like a language class so far. The concepts are familiar but they are called different things. Anyone else having this experience? Here are two examples:  1. "Bias." In this course, bias is a feature of a model. In my training, bias is a feature of the sample (called "training data" in this class), and can never be overcome by anything you do in the model. This class operates on an assumption of "big data," where the costs of drawing another sample are essentially zero, and you don't have to worry about how that sample was drawn. Very different from my "small data" background, where samples are expensive and time-consuming, and the way they are drawn is all important (was it random selection? were there inclusion/exclusion criteria?). In my world, there is no such thing as just "getting some more training datasets"!  2. "Qualitative." Here, the word qualitative is used to mean what I would call a categorical variable. So a "qualitative" model for Hastie is one where the dependent variable has classes rather than continuous numeric values. In my training, "qualitative" research is the kind anthropologists might do: conducting open or guided interviews with a small group of people, and then analyzing the text of those interviews for concepts. Nothing statistical about it. Thoughts, anyone? Other examples?

# %% [markdown]
# >Using pure cosine similarity between questions doesn't work too well.

# %% [markdown]
# > Adjusting `min_df` and `max_df` affects the results ALOT!!! They will essentially get rid of "OUTLIERS". Tell function to ignore these words because they occurred in either too many (`max_df`) or in too few (`min_df`) documents.
#
# > Setting `min_df`= X means that calculation will include only words that appear in at least X documents. This will throw out many really weird, idiosyncratic, or made-up words that appear rarely and that are not germane to the comment.
#
# > Setting `max_df` = Y means that calculation will exclude words that appear over and over again in every documents. For example, in these forum discussions, there are alot of "thanks", "good", "agree","helpful","helps", "thanks alot" type of words that will throw off calculation. Again, they are not germane to the discussion but will throw off the calcuation.
#
# > My approach here was to include as many "features" or words as possible but use these to "adjust" for outliers.
#
# > Bigrams and higher tend to make the results worse.
#
# > Need to include additional stopwords like "dear", "hint", "makes", "sense", "helpful", "explanation", etc. that dominates a topic.

# %% [markdown]
# ##Group all comments together first by `comment_thread_id`

# %%
#Need to figure out how comments and questions are grouped together
#forum[forum.type == "CommentThread"].head()

#Concatenate all comments together that has the same "comment_thread_id" - i.e. jam all the comments on one 
#question together - this should be better for analysis
concat_comments = forum[forum.type=="Comment"].sort("comment_thread_id").groupby("comment_thread_id").body.sum()

grouped_comments=[]
for c in concat_comments:
    unicode(c)
    grouped_comments.append(c.replace("\n"," ").replace("\n\n"," "))

# %% [markdown]
# ##K Means Clustering

# %%
#K-means clustering analysis

tfidf = TfidfVectorizer(encoding='utf-8', lowercase = True, 
                        stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words))
X = tfidf.fit_transform(grouped_comments)
print X.shape
print len(grouped_comments)
# Out:
# (1071, 10742)
# 1071

# %%
km = KMeans(n_clusters=30, init='k-means++', max_iter=100, n_init=1,
                verbose=True)
km_fit = km.fit_transform(X)
km_fit.shape
# Out:
# Initialization complete
# Iteration  0, inertia 1026.722
# Iteration  1, inertia 990.525
# Iteration  2, inertia 983.866
# Iteration  3, inertia 979.927
# Iteration  4, inertia 978.004
# Iteration  5, inertia 977.427
# Iteration  6, inertia 977.205
# Iteration  7, inertia 977.047
# Iteration  8, inertia 976.938
# Iteration  9, inertia 976.849
# Iteration 10, inertia 976.717
# Iteration 11, inertia 976.642
# Iteration 12, inertia 976.560
# Iteration 13, inertia 976.530
# Iteration 14, inertia 976.518
# Converged at iteration 14
# (1071, 30)

# %% [markdown]
# Below is from a [Stackoverflow article](http://stackoverflow.com/questions/12497252/how-can-i-cluster-document-using-kmean-flann-with-python):
#
# There is one big problem here: K-means is designed for Euclidean distance.
#
# The key problem is the mean function. The mean will reduce variance for Euclidean distance, but it might not do so for a different distance function. So in the worst case, k-means will no longer converge, but run in an infinite loop (although most implementations support stopping at a maximum number of iterations).
#
# Furthermore, the mean is not very sensible for sparse data, and text vectors tend to be very sparse. Roughly speaking the problem is that the mean of a large number of documents will no longer look like a real document, and this way become dissimilar to any real document, and more similar to other mean vectors. So the results to some extend degenerate.
#
# For text vectors, you probably will want to use a different distance function such as cosine similarity.
#
# And of course you first need to compute number vectors. For example by using relative term frequencies, normalizing them via TF-IDF.
#
# There is a variation of the k-means idea known as k-medoids. It can work with arbitrary distance functions, and it avoids the whole "mean" thing by using the real document that is most central to the cluster (the "medoid"). But the known algorithms for this are much slower than k-means.

# %% [markdown]
# ##K-Medoids Clustering
# > Good for very sparse matrix and also can use other distance measures
#
# > Rather than using the mean (which is usually not a real datapoint), K-medoids uses a particular datapoint as the centroid. This makes K-medoids less sensitive to outliers. And in case of text, can give an actual "representative" document of a topic.
#
# Valid values for metric are:
# from scikit-learn: [‘euclidean’, ‘l2’, ‘l1’, ‘manhattan’, ‘cityblock’]
# from scipy.spatial.distance: [‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘correlation’, ‘cosine’, ‘dice’, ‘hamming’, ‘jaccard’, ‘kulsinski’, ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’] See the documentation for scipy.spatial.distance for details on these metrics.

# %%
#K-Medoid
#Can pass in other distances for K-Medoids
import Pycluster
from Pycluster import kmedoids

distances = pairwise_distances(X, metric='euclidean', n_jobs=1)
nb_clusters = 50
clusterid, error, nfound = Pycluster.kmedoids(distances, nclusters= nb_clusters, npass=100)

# %%
#Look at the actual comments that are central to each cluster:
medoids = list(set(clusterid))

for m in medoids:
    print "------------------------"
    print "medoid ", m, ":", grouped_comments[m]
# Out:
# ------------------------
# medoid  0 : Hope to get full benefit of the course. Thanks.Sure! Count me in ???? ????It should be a great opportunity to pick up useful ideas on a hot subject from those who have made significant contributions to the field. I wish everyone has the most enjoyable learning experience the next eight weeks.vedio lecture is not opening in pakistanThanks so much for the comment DWaterson.  Glad you enjoyed the course!  I'd recommend taking a look at Elements of Statistical Learning if you want to get further into any of the material (available free online from the authors).  It is a little mathier than ISLR, but that allows one to get further into the models.Hi Enook,  Thanks so much for the comment.  I forwarded your post to the stanford edx people.  One of the main goals of online education is to provide more accessibility, so it is nice to hear it is working!Master's student Medical Informatics at the University of Amsterdam / Academic Medical Center (The Netherlands) present! I look forward to finishing this course.  -<nameRedac_anon_screen_name_redacted>This is an awesome class! I have 10yrs of job experience and now I wish to learn statistics as I see how it influences my regular life.yes this should be a real relaxed class that I will love to learn aboutOlá,  I'm very happy with the course and contents and feeling guilty because I gave not the appropriate attention to this discipline before.   Thanks for the opportunity!Thanks, lots of interesting code and method to learn from the course.yes it is because nowadays textbooks are expensiveThank you , Sir! Its great to have this Stat learning class from you.Thank you for this course, I hope to learn so much about this. I like the statitics.Thank you for the course. I'm taking it because it's interesting, and maybe I'll find ways to use it later. Last year, I downloaded and started reading ESL, but while I could conceptually understand the presentation, I could not do the exercises. Most of the math was too advanced for me as I've tried to learn math on my own as a hobby. With lectures and a forum and the new ISL, I hope it will be enough for me keep up with this class, and I look forward to the challenge.Hello!  I really appreciate your taking the time and effort to arrange this MOOC and allow a wide variety of folks to take it.  For many of us, making the pilgrimage to Stanford is physically impractical - time constraints and all - so this medium makes it a possibility.  This is my 3rd exposure to R so curious to see how you handle the tricks of the language from a practical basis.  I do appreciate you making the book pdf available for free - very generous on your part.Hello Professors and TA's, Thanks for all the hard work you've put into this class.  I'm probably a fairly typical attendee. I'm a middle age guy looking to grow some knowledge in an area that I am interested in but fairly unfamiliar with. The MOOC scene absolutely fascinates me and I find myself wanting to sign up for everything. I have lots of other things pulling at my time like my family and the need to put food on the table and wouldn't be able to risk my limited capital for a traditional bricks and mortars class with the rigidity of the benchmarking process. I just want to learn and I love the fact that this knowledge is available.  I'm grateful. Thank you.Hi, Mr. Hastie and Mr. Tibshirani:  Thank You very much for this wonderful course. I was counting the days left for the beginning, finally here It is!.flattered to follow this online course. Am eager to know the R software as am using SPSS.It's  amazing lectures. I will enjoy it with my friends and classmates.Thanks for offering this course and all the free resources. And many thanks for your efforts.Yep, India in particulargreeting !! Very interested in learning the application part of these course. Especially i would excited to learn R in the level i can use for my graduate study.  Please where can i find the schedule ??Hi, Mate! Came back here after a ...
# ------------------------
# medoid  409 : One way to visualize `n!` is that there are `n` choices available in the first position, `n-1` choices in the second position (because one choice has already been taken out to fill the first position, and has not replaced), `n-2` in the third position, and so on.  However, bootstrap samples aren't just permutations of the `n` data points---they are `n`-sized samples of the data points *with replacement*. The whole set of data points is available at each "choice", and even a sample that's just one data point repeated over and over would be a perfectly valid bootstrap sample.Thanks, Daniel and Kevin. After re-reading the question and knowing from Kevin's reply that the answer was simple, I figured it out. I just wonder why the question simply have been stated as "How many bootstrap samples are there, if sample order matters?"  It also helped to think about submitting an answer in R syntax, rather than TeX/LaTeX. (Still, there are limits: neither `cumprod(1:n)` nor `gamma(n+1)` worked for $n!$, back when I thought the question asked for how many ordered bootstrap samples there are without replacement...)  <nameRedac_anon_screen_name_redacted>Munoz, the answer is simpler than yours. Just consider permutation with repetition.Yeah, that does seem like a simpler way of putting the question.Check out the other threads on this question, which helped me out. There should be no ellipsis (...), since only samples of size n are considered (NOT samples of size 1 plus samples of size 2 ... plus samples of size n). Also, the counting scheme is "permutations" and not "combinations", as order of selection matters in the counting. Based on these assumptions, it accepted my answer as right (after getting some frustrating "can't parse the formula" errors.)Both for 5.4.R1 and 5.5.R1, the answers only require basic symbols, like parentheses, plus/minus/etc, exponential.  If you're coming up with something really complicated, it's incorrect.  Just type it like you would type it into R.  Hope that helps!I cannot enter anything I give up tried x^y and still will not let me answer.I got the answer right to this question, and it is indeed a simple thing to type in. But the question has to be worded better, because I found myself performing all sorts of "reading between the lines" to get it right. Got it on first try, too.I was also put off entering the correct answer several times because it would try to evaluate my incomplete formula, for example after I had typed '^' without anything after it, and return the parsing error comment.  grrrr
# ------------------------
# medoid  770 : Anyone?
# ------------------------
# eta_0))} $$  This model is nonlinear in the beta coefficients (they are "buried" deep inside the nonlinear function).  But it could be fitted using *nonlinear* least squares (See: `?nls`)  Here's some code      ## simulate some data     ## the "underlying" response is bounded between 0 and 100     ## but because of noise, individual measurements might not be     set.seed(1)     x <- seq(0, 10, by=0.1)     y.mean <- 100/(1+exp(-2*(x-5)))     y <- y.mean + 10*rnorm(x)     plot(y~x, col="gray")     lines(y.mean~x, type="l", col="blue", lty=3)          ## fit a nonlinear model     nonlin.mod <- nls(y ~ 100/(1+exp(-b1*(x-b0))), start=c(b0=1,b1=1))     lines(predict(nonlin.mod)~x, type="l", col="red")     summary(nonlin.mod)  ![fit of bounded nonlinear function][1]  That worked particularly nicely here, because the functional form being fitted was the same as that used to simulate the data.  And the noise was independently and identically normally distributed about the underlying function.      [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>01.pngpred <- predict(myfit, newdata=mynewdata)     pred[pred < 0] <- 0     pred[pred > 1] <- 1@scigeek:  > Great answer ahlf. Thanks a lot. I will try out your > suggestion on my data. >  > I also did a search and found the reference to Beta > Regression, where the response variable is restricted within > (0,1). >  > I am wondering what is your thoughts, in brief will do, on > using Beta Regression in similar cases. >  > Thanks a lot.  The idea is to get a model which has the same form as whatever generated the data.  Theoretical knowledge about the situation can be used to to help come up with a model which is reasonable.  To perhaps clarify a little  the example in the earlier post has two important features:  - an "underlying" mean value of $y$ which depends on $x$   according to a particular non-linear function.  - an additive error term which is independently identically   normally distributed.  Note that the form of the errors is one of the features of the model.  In some situations that form of errors might make sense. In others it might not.    Note that, in the example example, the *measured* values are not constrained to be within the range 0-100 (even though the underlying function is).  Whether this makes sense depends on the particular situation.    It might be that either:  - Even having individual measurements outside the range   0-100 is not possible.  - Measurements above 100 are possible but measurements less   than zero are not.  In either of those cases the error specification in the example would seem a little odd.  It still might work OK anyway despite that.  If the data is not getting close to the upper or lower bounds, a simple linear model might work OK.  In the example above, if the actual data for $y$ is between about 20 and 80, a linear model would probably be fine.  Or maybe, we could fit using splines.  Of course there would be no guarantee that the fitted value would lie in the range 0-100, but maybe it wouldn't go to far outside and we could truncate it.  I'm not familiar with beta regression.  But I guess we could model the errors as a beta function whose "position" depends on a predictor variable.  This would mean that the measured values of $y$, *including the error*, would be constrained to lie in the interval 0-1 (which could be scaled to any other interval).  I guess that would work best if the errors in the data really did have a (conditional) distribution which was a bit like a beta function.Great answer ahlf. Thanks a lot. I will try out your suggestion on my data.  I also did a search and found the reference to Beta Regression, where the response variable is restricted within (0,1).    I am wondering what is your thoughts, in brief will do, on using Beta Regression in similar cases.   Thanks a lot.Thanks a lot ahlf for this explanation. It's really helpful.  I will have to try out these suggestions.
# ------------------------
# medoid  901 : Yes, that's what I got as well.+1 had the same issueMe too.  Did you get d.d<zipRedac>2277<zipRedac> ?   (I replaced two digits by "d" as not to give the answer away).  In 10.R.3 I got d.d<zipRedac>71<zipRedac>7 , again close to but not quite the official answer.   Perhaps they used another random seed for their computation than the one used for the 10.R.Rdata file...I've go slightly different answer for 10.R.2 (and I missed the target in 10.R.3), but indeed I was confused by question statement:  "We can try forgetting about the raw features and using the first five principal components (computed on rbind(x,x.test)) instead as low-dimensional derived features. What is the mean-squared test error if we regress y on the first five principal components, and use the resulting model to predict y.test?"  So, why do we need to compute 5 PCs on the **full** data set, and why not on `x` matrix only?  Because, if I have joined all data by `rbind`, then I have no test data. And how do we compute `test error` in this case?  Probably, I've got very close answer by occasion.  And I join to others with statement above - it should be briefly sketched in the answers section "what is intended to do?"The principal components are found using the full data. You can still fit using only the training data and check the performance on the test data (using the first 5 principal components); It's not cheating as the y's of the test set have not been used in the creation of the fit.Good point, thanks! Indeed, I missed that **the model was not trained on the actual response values**.  Although, in neighbouring thread the similar question raised. And the response by staff is that "it is not obvious answer".   https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2014-quiz-review/threads/5329ca0def<phoneRedac>0014An I
# ------------------------
# medoid  905 : Thank you professors and TAs!  I'm so happy I found an R course before I finished my Masters (R is still not covered in our more traditional stats classes, so I felt left behind compared to what some people in my field are using right now.)   And a special thank you for extending the course a bit longer; because of that I was able to concentrate on a 2nd draft revision of the thesis and get it in on-time!  And now while it's being reviewed, I can focus on lessons I glossed over (sorry, its true!) and bum that progress % up.This has been a most rewarding course. I have learned enormously about Statistical Learning/Modern statistical techniques used in Data Mining and look forward to using them. Thank you for a wonderful course!!This course has been a great experience. Eventhough I will never be able to study a Master s degree at Stanford, this course allows me to feel what it may be like to take a class with two leading scientists as instructors. This course has also given a general view of the intriccacies of statistical learning. I hope to apply these concepts and solve specific problems in my job.  Thanks Dr. Tibshirani and Dr. Hasty.   Best regardsThis is the first time I signed-up for a course like statistical learning. Was a bit difficult initially since I had to balance both work and study. But enjoyed it. Looking forward to other statistical courses.  Thanks a ton.I would like to express my gratitude for this interesting course both teachers and supporting team.  It have been a little hard, because my native language is not English and because my algebra, combinatory and error theory knowledge was forgotten and I have had to study again. I have not too much free time, and working a little bit every night I know enough, to know there are a lot of things i do not know about statistics.  Thank youI would also like to express my appreciation for this course.  Thank you to everyone involved. <nameRedac_anon_screen_name_redacted>I would like to also extend my gratitude to all those involved in preparing, delivering and supporting this course.  I've found it very interesting and well structured and hope to start putting some of the techniques to use in my own work.  <nameRedac_anon_screen_name_redacted>Thank you, Dr. Hastie, Dr. Tibshirani and Dr. Witten for a top course in Statistical Learning. I've learned a lot.  Great explanations and a fantastic book. I got it! Now it's time to deep in "The Elements of Statistical Learning"... Maybe it will be another course. If so, count on me!  Thank you to students that helped me with some tricky questions. At last there's light!  :)Thank you both professors and TAs for the great course!  I've enjoyed a lot, even though the R sections were a bit difficult to follow for me.  Anyways, Thank you again.
# ------------------------
# medoid  907 : Is it maybe related to use "normalized" x?Be wary of tasks text:  Now, try an OLS linear regression of y on the matrix x. What is the mean squared prediction error if we use the fitted model to predict y.test from x.test?«  Calculate the error in the same way as in the previous two tasks. The formulas are exactly the same.   Be wary, however, in calculating  `y_hat` and  `fit`. In the function `lm` you have to calculate `fit` with the original matrix `x` and an original vector `y`. In calculating the `y_hat <- predict()`, you have to use the original matrix `x.test`. Then in the calculation of error use the calculated `y_hat` and original vector `y.test`.   I hope it will help.I am also struggling with this question. At present, I have the following script:  train <- cbind(y,x)  train= as.data.frame(train)  fit<- lm(y~,data=train)  yhat=predict(fit,x.test)  mean(yhat-y.test)^2  and I am unable to obtain the correct answer. Your feedback is appreciated.  Best wishes,First leave out first two rows. Use just `fit<-lm(y~.,x)`.  Be careful in this line:   compare result of your code `mean(yhat-y.test)^2` (which is not correct)  with this code      mean((yhat-y.test)^2)  Hope it will helpWhy did you use `cbind()`? It is not correct since in this case you have 201 independent variables instead 200, which is correct number. You should use only x.   Try      `fit<-lm(y~.,x)`But it's not exactly the answer... I'm puzzled. Something apparently so simple.ups  squared... sorry  Now yes!I suppose you mean:   sqrt(mean((yhat-y.test)^2))  But I get the same thing which lead to error!Dear FrancB,  Thank you. I have implemented your suggestions and obtained the correct answer.  Best wishes,I have done exactly this and I don't get the right answer.  I mean:  train <- cbind(y,x)  fit<- lm(y~.,data=train)  predict(fit,x.test)  and compare with y.test.  ...
# ------------------------
# medoid  269 : Hi Erza,  Please do continue to let us know if/when you find questions that can be improved!  Hope you are enjoying the class so far.I admit that I got a few questions wrong. But I get 5 attempts, which are plenty.If the course is given again, I REALLY hope that developers will go through the discussion, find those questions that generated the most comments, and revise them.I like questions that are teaching tools. That's part of the point, encouraging people to use the material and problem solve to find the answer. My issue is with questions that are ambiguous, so there are multiple possible valid answers depending on how its interpreted. These questions become frustrating guessing games, trying to figure out which meaning was meant. Students have to hope they guess right within the submission limit so they don't fail the quiz, and the class.I agree that the questions touch a wide range of purposes and perspectives: 2.2R2 (the hupercube) may throw you off both with its purely mathematical formulation and by the fact that it calls for a purely quantitative approach. 2.3R1 on the contrary calls for a quasi-philosophical approach for the extreme conditions of a system (or that's the way i like to view it). In either case what is clear from the questions is that one needs to handle problem solving from all these perspectives/ be a purist working on numbers and at the same time be an "extrapolator" working without any.  amm, yes that's not always comfortableI've noticed that most of the unclear questions have to deal with multiple choice. Effectively, each option only needs to be evaluated to true or false, so people can still "get it right" even with a vague question (sometimes by wild guess). The questions involving calculation require more precise information to find the right answer, and tend to be clearer.Another from the Chapter 3 quiz: Option 4 states "In a linear regression with several variables, a variable has a positive regression coefficient if and only if its correlation with the response is positive". This is very vague about whether cross-interaction terms are included or not, which changes the answer.The worst question I've seen yet: 7.2.2. The question as written gives no idea what it is asking for. It states something about valid basis functions, requiring students to make the obscure conclusion that this means "functions which have matching intercepts at the knot point". This is VERY different to what is in the lecture, which states basis functions should have specific forms to be used in regression.   This particular question generated an ENORMOUS discussion topic in the wiki, where someone posted a great explanation of what the question is actually after. The post goes on for quite some length, far more (and far clearer) than the "official" answer.Thanks for the feedback: Here's a good example from Section 2:  "While doing a homework assignment, you fit a Linear Model to your data set. You are thinking about changing the Linear Model to a Quadratic one. Which of the following is most likely true: Using the Quadratic Model will decrease your Irreducible Error.  Using the Quadratic Model will decrease the Bias of your model."  Bias was not covered in the videos until section 3.  Here's another from section 3: "Which of the following indicates a fairly strong relationship between X and Y?     R2 = 0.9     The p-value for the null hypothesis     is 0.0001      The t-statistic for the null hypothesis     is 30"  The question is after a strong effect between the two variable (implying correlation and a high R^2 value) but could also be interpreted as as strong likelihood of a relationship (implying a high T statistic). Since the meaning is unclear, finding the answer becomes a painful guessing game.FWIW, quiz questions--particularly in MOOCs like this--don't always have to be mere tests of whether you've learning something or not. They can be teaching tools in and of themselves.  I did a MOOC not too l ...
# ------------------------
# medoid  399 : I think this has been discussed quite a few times in this forum. For example:   https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2<zipRedac>14/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2<zipRedac>14-course-material-feedback/threads/52e548ce9b16c754bc<zipRedac><zipRedac><zipRedac><zipRedac>43  In general when dealing with dummy variables coding you should think in advance what you would like the estimated coefficients to represent (interpretation). For a rather extensive discussion on this topic (involving R), please follow:  http://www.ats.ucla.edu/stat/r/library/contrast_coding.htmwhen you code color as 1:yellow, 2:blue, 3:red, you're saying that blue has **twice** as much color as yellow.Thank you very much for your answer.   Still have one more question:  Do use 0-1 dummy variables to deal with qualitative variables in regression models. Do we have to do the same in other methods e.g. discriminant analysis? or just in regression models?
# ------------------------
# medoid  145 : The lecture slides.   https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2014/ba1951b8f66c4cdca2fcaabcdc91b792/
# ------------------------
# medoid  985 : Thank you very much for offering this course.Thank you again for a great course (Trevor, Rob and team)...and even given in 'my language' (Prof. Hastie!).  I would be very interested in any future course. RJS (UCT 1989)I agree with veroneti. And for me it was a privilege having the possibility to take a course taught by people who I cite in my Ph.D. thesis! :)It's my first MOOC, and although n=1, I suspect the quality of this course is significantly above the mean!  Thank you very much for the enjoyable and useful course material.  You guys deserve a raise!  Cheers.Thanks for your time and big effort. Thanks for the great course and the amazing book.Thank you so much for the excellent course! I really enjoyed every minute of it! This was one of the best courses I have taken so far! Thank you so much professors for the several hours you've put in to produce this course, for writing and making the text books freely available (I will definitely be buying both the books now that I can decipher most of the material presented in the book), and the course staff for making this possible!   My sincere thanks once again to each and everyone who made this possible.Agree with the above comments. Great course indeed. Enjoyed every bit of the course material as well as the sense of humor of Prof.Tibshirani and Prof.Hastie. I am looking forward to future courses.Indeed, it was a great class.  Thank you very much!The most unifying statistical learning course I have ever taken. It has given me a very consistent view of the field. Thanks a lot.Thank you for this wonderful course. It was very well taught (of course)! You guys are great. Hopefully you'll consider more MOOCs.I have just finished. Thanks a lot for this great course. I enjoyed very much and learned a lot of new things. Best regards.Agreed! This has been an extraordinary experience in learning.   Thank you, Thank you, Thank you, Profs. Hastie, Tibshirani, Witten and all the other folks who made this happen: Will Fithian, Sam Gross, Wes Choy, Greg Maximov, Greg Bruhns, Marc Sanders, and the guest speakers.  The course provided new challenging information and some background explanation of topics I learned from other data mining and predictive analytic courses I have taken.This is the best online course I took so far.  thank you very much!
# ------------------------
# medoid  512 : What's the difference between these two functions?  lm.fn2  > function(data,index){return(coef(lm(y ~ X1 + X2, data = data[index,])))}  and  boot.fn > function(data,index) > {return(coef(lm(y ~ X1 + X2, data = data,subset=index)))}  Notice in one function, data = data[index,] while the other function uses subset.  How come these two functions are different?  The subset version, boot.fn, cannot be used in tsboot, while lm.fn2 can ...Thanks dkdog, that helps tremendously!My reading of tsboot() is that the statistic function does not take the same arguments as the boot() statistic function;  it only takes the data (time series).I removed the "dollar" ref to Xy, Xy"dollar"X1 e.g. uses the complete vector X1 and bootstrap cannot reassign the row indices. You´ll find more information by typing ?'$' in the R console.  boot.fn = function (data, index) {    return(coef(lm(y ~ X1 + X2, data = data, subset=index)))  }I think your error comes from the funtion boot.fn you created.... it seems that you're fixing the index in the same order always (1:1000), not allowing bootstrap to actually do what is intended. Try  lm.fn=function(data,index){   with(data[index,],{     return(coef(lm(y~X1+X2)))   }   ) }  and then  boot.block=tsboot(Xy, lm.fn, R=1000,l = 100,sim="fixed")   allowing the index to be random. Hope this helps..
# ------------------------
# medoid  407 : The statement on slide 36 is: "About two-thirds of the original data points appear in each bootstrap sample."  But I only understand that the inclusion-probability of a data point for one sample is $1-frac{1}{e}approx2/3$.  And then I would expect, that the probability that a data point appears in each sample is $(1-frac{1}{e})^B$.  Could please anyone tell me, where my error in reasoning is.One way to define the exponential function ($e^x$) is as the limit as $n$ goes to infinity of $(1 + frac{x}{n})^n$. Compare this with your answer to question 5.5 and you'll see why any given row in a data set (where the number of sampled values is equal to the number of rows in the data set, sampled with replacement) has just under a 2/3 chance of being included in the bootstrap sample.   Here's a nice intuitive explanation of how the exponential function arises in many different circumstances: http://betterexplained.com/articles/an-intuitive-guide-to-exponential-functions-e/.Hi Kikaka,  Not sure if this explanation helps but I thought I'd give it a go:  If the inclusion probability is indeed 1 - 1/e it must be so that the exclusion probability is its opposite, i.e. 1/e. So you have a 1/e likelihood that a data point will not be drawn from the original training set. The likelihood never changes because we have replacement (every data point that gets picked out once can be picked out again). Remember that the result of 1 - 1/e is contingent on the fact that the bootstrap sample and the training data are of the same size (k), which makes the result independent of sample size. I'm not sure what 'B' represents in your equation but if B >> 1 the probability converges to 0 and for 0 < B < 1 the probability would converge to 1. Neither alternative is likely with replacement of data points.I think that you're correct, take the answer for the question 5.5, n->infinity equals 1/e (~ 0,3 or 1/3).This isn't meant to be an analytic answer and could be just a coincidence. However in answering the question about the probability of a particular datapoint not being included in a boostrap sample, I calculated values for large samples (say size 100,000 or larger) and found that it converges to a value. This value is convenienly related to the one you're asking about since probabilities sum to one; all you have to do is take the formula you found to answer question 5.5, evaluate it with a large n and take its complement to 1 in order to find the probability of a data point being included in a boostrap sample. As I said, it might just be a coincidence but if it were it would be quite a remarkable one!Thank you for the link, I really enjoyed the explanations, I never had a  great math teacher that explained things like this.Thanks! Good one.
# ------------------------
# medoid  25 : Hi pklaltjha,  All of the R code for the sessions are available under the heading "R Sessions."  Feel free to go peruse.Also there's an R package designed for the book.  See the book website ...Once I downloaded ISLR_1.0.zip, I loaded as a package.  But, now how I see the files, for example, Auto.data or Auto.csv?  Thank you  <nameRedac_anon_screen_name_redacted>I think glmnet, written by the professors, will be used for lasso and regularization of linear models.   A handy packet is caret, which comprises a lot of useful functions for statistical learning.Hi all ,I am wondering why r discussion page's first ,four chapters are not downloadable and whenever I click on it,it displays /demands Statistica macro which on my lap is expired. Please guide ?
# ------------------------
# medoid  922 : I get the same error. How is one supposed to enter n choose k?page 388!This problem really aggregated me. The answer is fairly simple. It is also spelled out in the book. I ended up getting it wrong because I must have typed something wrong the first time, and I spent over an hour researching online to figure out what I did wrong and trying alternatives. Ugh.Thanks..it was was simpler.  Much appreciate your help!It's much simpler than that. What if n=3 and k=2? How many ways can you assign three things into two groups?nice! :DThanks for the 388 page hint.It is referenced in in Chapter 10 of Introduction to Statistical Learning First Printing where it discusses K-Means Clustering regarding why it is a very difficult problem to solve ...   (hope this helps).Very clever.Where was this in the book?  Thanks.I like to think about it as a 'digit' analogy. In our problem, each of the points (observations) can be assigned to one of k clusters. We can represent each possible assignment of points to clusters as an n-digit number in base k.  We all know base 10 where each digit can have a value from 0...9 inclusive.  If there were 3 points in 10 clusters (remember they say naive implementation) the set of all assignments is represented by the set of numbers 000 ... 999 and the count of combinations is 10^3 = k^n.How do I enter the formula ? The error is "Couldn't parse the formula".  How do I enter the factorial ?
# ------------------------
# eta_1 x)}} } $  ![not perfectly separated - logit works OK][1]  ----  Now here's a case where there *is* perfect separation.  The glm fit wasn't happy about this, and gave the following warning message:      Warning message:     glm.fit: fitted probabilities numerically 0 or 1 occurred  Anyway, here's where it ended up with:  ![perfectly separated - logit struggles][2]  ----  In fitting, the *steepness* of the predicted probability can be adjusted:  ![logit model curves][3]  So in the second case, anything with an *infinite* steepness and a transition somewhere between $x=3$ and $x=4$ would fit the data *perfectly*.  This means the the fit isn't well defined.  The infinite slope would mean that the left 3 points $mathrm{Prob}(y=1)=0$ while the right 3 points have $mathrm{Prob}(y=1)=1$  With these probabilities, the observed sample data would be *certain*, so that would be the maximum likelihood.  But the infinite slope parameter and lack of unique solution create problems in the actual fitting.  ----   **Note about LDA**  In the second case, with perfect separation, LDA should be fine.  It will see two groups with equal prior probabilities for each group. (3 points in each)  It will see the groups centred about different means:  - $y=0$ group with mean 2 - $y=1$ group with mean 5  and assume they both have the same standard deviation (of 1).  So that if $x>3.5$ the probability will be higher for the $y=1$ group and if $x<3.5$ the probability will be higher for the $y=0$ group.     [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>84.png   [2]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>83.png   [3]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>17.pngFor those interested in trying this out for themselves,  here's some R code for the plots above.  (Hopefully it's self contained, so you can just cut-and-paste to get started)  First plot (not perfect separation)      data1 <- data.frame(x=c(1,2,3,4,5,6), y=c(0,0,1,0,1,1))     plot(y ~ x, data=data1)     glm.fit <- glm(y ~ x , family="binomial", data=data1)     glm.fit     b0 <- glm.fit$coefficients[1]     b1 <- glm.fit$coefficients[2]     prob.curve.data <- data.frame(x=seq(1,6,by=0.01))     prob.curve.data <- transform(prob.curve.data, prob=exp(b0+b1*x)/(1+exp(b0+b1*x)))     plot(y ~ x, data=data1)     lines(prob ~ x, data=prob.curve.data, col="blue")      Second plot (perfect separation)          data2 <- data.frame(x=c(1,2,3,4,5,6), y=c(0,0,0,1,1,1))     plot(y ~ x, data=data2)     glm.fit <- glm(y ~ x , family="binomial", data=data2)     glm.fit     b0 <- glm.fit$coefficients[1]     b1 <- glm.fit$coefficients[2]     prob.curve.data <- data.frame(x=seq(1,6,by=0.01))     prob.curve.data <- transform(prob.curve.data, prob=exp(b0+b1*x)/(1+exp(b0+b1*x)))     plot(y ~ x, data=data2)     lines(prob ~ x, data=prob.curve.data, col="red")Nice one @alhf... I was really pleased they mentioned the separation problem in the course because it's something that was skipped in my original statistics course, and those glm.fit error messages aren't the easiest to work out if you don't know about the separation problem.  Worth noting that with grouped data (ie where you're attempting to predict proportions ie proportion of insurance claims by postcode and demographic data) this doesn't usually happen ... because the data generally doesn't have zeroes and ones.
# ------------------------
# medoid  653 : When you use all the data to fit a model, you cannot trust the training error. Your CV error is an estimate of the test error.*You would then use all the data to find the best model with 3 variables using forward stepwise regression.*   If I understand correctly, then this process will find the best model with three variable using **training error**. Won't that lead to overfitting?Cross-validation chooses the model size associated with the algorithm (forward, backward, hybrid stepwise), not the actual model.   For example, let's say you're choosing between model size 2 and 3 (each of which were built using forward stepwise regression). And say cross validation chose model size 3 based on the lowest CV MSE. You would then use all the data to find the best model with 3 variables using forward stepwise regression. Your final model may or may not contain all the variables in your K models.Look at the last paragraphs on page 249 (validation set approach) and 250 (CV approach). Essentially, after your figured out the optimal model size, you throw away your K-models and choose the best model using all the data.*When you use all the data to fit a model, you cannot trust the training error. Your CV error is an estimate of the test error.*  But when we use all the data to fit a model, we do not have CV error anymore.  We cannot trust the training error. Then how do we know if the new model is any good?
# ------------------------
# medoid  35 : Hey Rakhlin , It's good to see here buddy :)I was mistaking reducible error for bias. Now it seems the reducible error for a certain data set is the overall effects of how the model performs on average and how its performance varies from one data set to another.Nice to meet you too, Lovekesh!Thanks for sharing. This is indeed an excellent article.A very good explanation of the Bias-Variance Tradeoff:  http://scott.fortmann-roe.com/docs/BiasVariance.htmlMore flexible model better fits in-sample data. At the same time it would result in greater out-of-sample error (than simpler model would) if training set isn't large enough. The reason is greater variance in models built on small random subset of all possible data.  Bias-variance trade-off is central topic in machine learning. In Caltech ML course taught by Professor Abu-Mostafa this topic covered in two 1-hour lectures in the middle of the course (bias-variance itself and subsequent topic of error and noise).I think reducible error consists of bias and variance as presented in the following section. More complicated model may have high variance and low bias, any maybe the total error is higher than simple model.   PS. one way to deal with high variance error of complicated models is to use ensemble methods.ditto, taWith a more complicated model, there is a problem of over-fitting. Your algorithm just memorize the data points and it becomes more serious if you have less no. of data points.   So, a complicated model will have high bias but low variance as it practically learned it's way around but it will give large amount of error when you try to use the estimated complicated model to predict new the response for new data points.   For example, assume that the original distribution is y = x^2 + e  But, you tried a fourth order polynomial or higher to fit the data. This will result in a much wigglier curve, which has obviously high bias as it's way off from simple quadratic nature but has low variance.   Hope this help , although i would seriously recommend you go through the lecture videos mentioned above and then try to read a slightly technical article over it. And complement it with some random simulations.lecture on bias-variance tradeoff http://www.youtube.com/watch?v=zrEyxfl2-a8
# ------------------------
# medoid  36 : Yes. The inductive approach it´s very helpful. Thanks!This helped immensely. Finally got the right answer. Thanks!A hypercube is just a cube in more than 3 dimensions.Thank you. It really helped a lot.This drawing is really helpful and I suggest to start just with this one and then focus on 3rd dimension. All you have to do then is to compare volume of your cube with the smaller one without that boundry ;)The question builds on the curse of dimensionality. This has been highlighted in the other thread.Never seen a hypercube, no idea.Thanks! It really heled?Ha Me neither!  think I will go for a 0/1 on this question.Thanks, this really helped to visualize the problem and got the right answergreat hint. it took me for a while to figure out what the question want. Like Asier said, getting the answer is easy but to understand what it want is hell.  Thanks all- draw a line and mark the part of the boundary -> 10% of the volume lives there - draw a square and mark the part of the boundary -> 1-xxx of the volume lives there - extrapolateBoth are defined in the book, pages 32 and 33Yes, got it... I was really wrong ... it is quite easy... I was just substracting another area...many thanks .just missunderstood.As far as I can see this question is unrelated to anything we've covered so far.  Similarly 2.2 R1 ... I don't think bias or variance were mentioned. (Yes, underfit and overfit, but not bias or variance).Absolutely! Thanks everyone in this thread for helping clear up what the question is asking.Thanks :)Very good suggestion thank you!Thanks to the above, I understand the math, but I am not clear how this helps us with conducting supervised learning. I see that from a probabilistic perspective, this exercise tells us that an in an experiment with a relatively low, 10%, probability of success, you have a very high probability of observing a success at least once if the experiment is repeated 50 times.  How does this relate to the material presented?Guys, Thanks a lot !!! Never thought these boards were any useful. How wrong I was. Much appreciated.This helped tremendously. It's just very hard to understand the question if you're not used to the math.I would like to suggest a hint, considering the volume of the inner space, i.e. the space other than the bound region.ooooh felt so good getting it right. The real difficulty is in trying to understand what it's asking for!If you have problems with eating this problem at once, I suggest that you start with lower number of dimensions to see how the area changes. Then, it might be easier to find a general solution.Hi, Is [REDACTED BY COURSE STAFF] the answer?  Please help with solution if my anyone has cracked the above Math puzzle.I have done drawing in the same way as shown above and generalized for d dimensions but my solutions is not correct... any clue?You first need to calculate the **area** of the white **square** and then the complement of that will be the area of the blue region (the required answer). Then do it for a cube (d=3) and take the complement. You get the point.I completely agree. Getting the answer is easy; understanding the question is hell... Thanks to all.Fabulous hint, really helped me to grasp the problem. Thanks!You can start with a simple line. Then, continue with a square. Then, with a cube. The "pattern" emerge. It took me all afternoon to figure it out.First time I saw the word "hypercube".That's a good hint. It may be just because I have done it, but it seems straightforward if you simply think of the problem geometrically.Ah! When I first read this question, I thought "how am I ever going to figure this out"... but as soon as I read your hint, it clicked. Thank you!I actually found section 2.5 - Local Methods in High Dimensions of "The Elements of Statistical Learning" to be really helpful for this question.  I think the pdf for that book (the big brother to the class textbook) is also freely available.It demonstrates the curse of dimensionality ...
# ------------------------
# medoid  934 : 9.R.*
# ------------------------
# medoid  940 : yes
# ------------------------
# medoid  432 : I'm confused about where you're getting $2^p$ folds from. The CV error tells us which method to chose, not which model. Does that clarify things?But then again, to test all possible models with cross-validation, assuming one subset of variables per model, you need (2^p) folds.Yes, it does. I'm confused about the number $2^p$.Thanks for the nice explanation.   So you keep only the best model in each fold?  How do you decide at the end of K folds which model-parameter (ie. which k variables) to choose?  And how do you interpred the standard deviation `SE(CV)` at the end?> ... does that mean we have $2^p$ folds?   We fix it as say $5$- or $10$- fold CV. That doesn't change. But the question is asking whether the number of variables that has say the lowest $RSS$ on the validation set on each fold is necessarily the same.    > And how does the cross-validation error tell us which set of k variables to choose?  $K$-fold CV (where $K$ is unrelated to the $k$ variables under discussion) ends up in an average CV error for your model. Because for each training/validation split, you get a error on the validation set. And you repeat that for $K$ validation sets. Taking the average error over all validation sets yields average CV error.   But you don't just have to train a single model each time (i.e., on each fold). You can train different models on the same training/validation split (or the same model with different "hyperparameters" depending on the model). And the best model on one training/validation split may have $k$ variables, while the best model on another training/validation split could have $k+1$ variables, for example.I believe you are confusing $K$-fold with the $k$ predictor variables asked by the OP.Oh, I thought from the lecture that CV will tell us which set of p variables to choose. No?thinking about the purpose of cross validation -- find the trade off between bias and variation and decide the right balance.   - Different k-fold cross validation will provide different weight on variation and bias. e.g. LOOCV will result in a more biased model (give the training data almost same), and a small K validation will result in a more variation model (given the training data will be more different).  - Different feature in a model will represent different bias of the model.  So different K choice will result a different feature set in the model.  my 0.02.
# ------------------------
# medoid  433 : Ch1 Introduction  1.1 Opening Remarks (https://www.youtube.com/watch?v=2wLfFB_6SKI) 1.2 Examples and Framework (https://www.youtube.com/watch?v=LvaTokhYnDw)  Ch 02 Overview of Statistical Learning  Introduction to Regression Model (https://www.youtube.com/watch?v=WjyuiK5taS8) 2.2 Dimensionality and Structured Models (https://www.youtube.com/watch?v=UvxHOkYQl8g) 2.3 Model Selection and Bias-Variance Tradeoff (https://www.youtube.com/watch?v=VusKAosxxyk) 2.4 Classification (https://www.youtube.com/watch?v=vVj2itVNku4) 2.R Introduction to R (https://www.youtube.com/watch?v=jwBgGS_4RQA) Interview with John Chambers (https://www.youtube.com/watch?v=jk9S3RTAl38)  Ch 03 Linear Regression  3.1 Simple Linear Regression (https://www.youtube.com/watch?v=PsE9UqoWtS4) 3.2 Hypothesis Testing and Interval Confidence (https://www.youtube.com/watch?v=J6AdoiNUyWI) 3.3 Multiple Linear Regression (https://www.youtube.com/watch?v=1hbCJyM9ccs) 3.4 Some Important Questions (https://www.youtube.com/watch?v=3T6RXmIHbJ4) 3.5 Extensions of the linear models (https://www.youtube.com/watch?v=IFzVxLv0TKQ) 3.R Linear Regression in R (https://www.youtube.com/watch?v=5ONFqIk3RFg)  Ch4 Classification  4.1 Introduction to Classification Problems (https://www.youtube.com/watch?v=sqq21-VIa1c) 4.2 Logistic Regression (https://www.youtube.com/watch?v=31Q5FGRnxt4) 4.3 Multivariate Logistic Regression (https://www.youtube.com/watch?v=MpX8rVv_u4E) 4.4 Logistic Regression - Case Control Sampling and Multiclass (https://www.youtube.com/watch?v=GavRXXEHGqU) 4.5 Discriminant Analysis (https://www.youtube.com/watch?v=RfrGiG1Hm3M) 4.6 Gaussian Discriminant Analysis - One Variable (https://www.youtube.com/watch?v=QG0pVJXT6EU) 4.7 Gaussian Discriminant Analysis - Many Variable (https://www.youtube.com/watch?v=X4VDZDp2vqw) 4.8 Quadratic Discriminant Analysis and Naive Bayes (https://www.youtube.com/watch?v=6FiNGTYAOAA) 4.R Classification in R (https://www.youtube.com/watch?v=TxvEVc8YNlU)  Ch05 Resampling Methods  Interview with Bradley Efron (https://www.youtube.com/watch?v=6l9V1sINzhE) 5.1 Cross-Validation (https://www.youtube.com/watch?v=_2ij6eaaSl0) 5.2 K-fold Cross-Validation (https://www.youtube.com/watch?v=nZAM5OXrktY) 5.3 Cross-Validation: the wong and right way (https://www.youtube.com/watch?v=S06JpVoNaA0) 5.4 The Bootstrap (https://www.youtube.com/watch?v=p4BYWX7PTBM) 5.5 More on the Bootstrap (https://www.youtube.com/watch?v=BzHz0J9a6k0) 5.R Resampling in R (https://www.youtube.com/watch?v=6dSXlqYou can download the videos now and watch them whenever you want later.Thanks for the answer and does it include the videos ?I'm afraid I do not think so.Yes, I believe so.
# ------------------------
# ...
# ------------------------
# medoid  93 : Hmmm. True. I misread the post. When I saw "overfit" I automatically interpreted that flexibility was worse... So, you are right. It isn´t answered...I don't think the variance and the irreducible error are the same. The variance relates to the difference between sets (so if you take a sample size of 10 random numbers between 1 and 10 in one exercise the average of the data might be 5, but when you take the next sample of ten numbers, the average might be 7. There is a high variance between sets even though the true average (if you did this say 10,000 times) would be 5 with a variance of maybe 0.1. so if you have a high variance and low number of samples, then I think you go with a rigid model to avoid over-weighting the outliersHere is my understanding: If the irreducible error is higher, the probability to use the training data to proxy the real data is lower. More flexible model means we are trying to use the model (high variant one) to simulate the result from training data which is not reliable, so the more flexible, the worse.If the irreducible error is high, then even with the ideal f, there will be significant variations about y=f(x).  A highly flexible model will be able to over fit and capture some of the particular random variations in y that were in the training data.Ok. I think I got it. Thanks!But the listed, correct solution to "The variance of the error terms, i.e. ?2=Var(?), is extremely high," is the flexible model is worse than the inflexible model.  And, an *over fit* by a highly flexible model is not good.  If we know we have an extremely high, irreducible error, why would we want to go with a model that will be difficult to interpret? I'd do with the less flexible model that I could understand and interpret.  This question is not answered yet. Further help and comments appreciated.But I think the question is asking not about the variance of f(hat). It is asking about the variance of the error term -Var(e)-. In ISLR page 23 it says:  > Hence, we see that the expected test MSE can never lie below Var(e), the irreducible error from (2.3).
# ------------------------
# medoid  95 : If you want columns 2 and 7:  zcol=z[,c(2,7)]  Rows 1 and 3:  zrows=z[c(1,3),]  And combine the command as above (Jgray post) if you only wanted specific elements of the new matrix.  ![enter image description here][1]           [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>15.jpgThe set.seed function is used so that so that random numbers generated following set.seed will be the same. It is often used in examples in a text book to ensure that the example in the text is reproducible.   For example:   x= rnorm (50) ,  y=x+ rnorm (50 , mean =50 , sd =.1) ,  cor (x,y)   will return different values for cor(x,y) depending on the random numbers generated. However   set.seed(1303) ,  x= rnorm (50) ,  y=x+ rnorm (50 , mean =50 , sd =.1) ,  cor (x,y) will generate the same result for cor(x,y)  Any integer can be used as the argument for set.seed.dear all,  on the page 45 of the ISLR the "function set.seed" takes an argument 1303. What does this number (**1303**) exactly mean?  It seems that help of R explains RNG (which is also unclear to me) rather than set.seed, at least I did not understood the explanation from ?set.seed  thanks in advancethank youthank youIs this what you have in mind?![enter image description here][1]     [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><phoneRedac>67.jpg
# ------------------------
# medoid  866 : I didn't have a scooby, but after following those two discussions, I managed to produce correct answers.  It's the stuff that has nothing to do with SVM that really stumped me.  Whilst I wouldn't claim to have a deep understanding of how the answers were produced, I learned quite a lot from those two discussions and doing the question.Follow these two discussion  https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2<zipRedac>14/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2<zipRedac>14-course-material-feedback/threads/531dd393d1bf779c7a<zipRedac><zipRedac><zipRedac><zipRedac>1d  https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2<zipRedac>14/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2<zipRedac>14-quiz-review/threads/531ccc3b5<zipRedac>d<phoneRedac><zipRedac>2bWhat are the default values for Gamma and cost?You can run the summary() function after the svm fit and R will print those for you."#Courseware Question 9.R.1 "#Reference ISLR pages 359-362 with radial kernel substituted  "#Load SVM and Set up for loop to capture errors from 1000 train/test runs  library(e1071)  error = rep(0,1000) for (i in 1:1000) {    #Generate training data set with 50 observations from one class and 50 observations from the other   x1=matrix(rnorm(50*10), ncol=10)   y1=c(rep(0, 50))   x2=matrix(rnorm(50*10), ncol=10)   x2[,1:5]=x2[,1:5] + 1   y2=c(rep(1,50))   xdat1=rbind(x1,x2)   ydat1=c(y1,y2)   traindat=data.frame(x=xdat1, y=as.factor(ydat1))      #Fit default support vector classifier   svmfit=svm(y~., data=traindat)        #Generate test data set   x1test=matrix(rnorm(50*10), ncol=10)   y1test=c(rep(0, 50))   x2test=matrix(rnorm(50*10), ncol=10)   x2test[,1:5]=x2test[,1:5] + 1   y2test=c(rep(1,50))   xdat1test=rbind(x1,x2)   ydat1test=c(y1,y2)   testdat=data.frame(x=xdat1test, y=as.factor(ydat1test))      #Predict the class labels of these test observations using default svmfit and calculate the error   ypred=predict(svmfit, testdat)   error[i]=(sum(ypred != testdat$y))/100 } hist(error) mean(error) sd(error)Thanks. This makes both the data structure and logic understandable.Thanks very much for all the responses; I'm not sure I learned a whole lot about SVM in answering this question, but by going through the lines of code everyone posted, I sure learned a lot about generating variables, putting them into vectors and matrices, and running simulations multiple times.  If the professors ever ran a course called "tricks for dummies in R", whereby they just had a dozen or so R projects which each exemplified a different trick (even if it was all in something simple, like OLS), or a series of projects where you start with a bunch of data and go through the process of looking at it, screening it and so on as a statistician would, I'd sign up in a second.  Two asides.  Firstly, when I tried DWaterson's code above, I got very low error rates, but when I used the other code for mvrnorm, I got error rates comparable with the right answers.  I'm not really sure why that should have been the case.  Secondly, I ran into problems with the logistic regression question because all I did was swap the svm line above for a glm one (glm.fit=glm(y~.,data=dat,family="binomial")).  It turns out that you need to change the error command as well, because predict in glm gives you the probabilities, not the actual classes the prediction falls into.  If others had the same problem, I found the solution here: https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter2<zipRedac>14/discussion/forum/i4x-HumanitiesScience-Stats216-course-Winter2<zipRedac>14-course-material-feedback/threads/531dfcf<phoneRedac><zipRedac>f<zipRedac>6<zipRedac><zipRedac><zipRedac><zipRedac><zipRedac>a  Note, however, that the suggested replacement error function gives you the total number of errors; you need to divide by the size of your tests set to get the rate.
# ------------------------
# medoid  611 : Thanks for the comments!thanks. didn't see it.In a more general sense, I hear people make this kind of mistake all the time, usually sounds like "there's only a 5% (10%, 20% ...) chance, so ..." and they draw some fixed, logical if-then conclusion, like the low-prob event will never happen. Or, they make the correct bet on whatever has the larger probability. But, any probability over 0 means it will happen sometime (well, probably!!). Also, a probability estimate tells you what will happen over many trials, but sure does not help much for the next trial or observation.       I think it's like the cross validation chapter. Some set of data may yield estimates of statistics, but a different set of similar data will yield different estimates. This happens a lot in financial data: something will have an average of xx%, but shift the data by a year or so then the average is yy%, some totally different value. It's quite a challenge to get stats or estimates that hold up over time.Maybe the only reference you'll need.   http://warnercnr.colostate.edu/~anderson/thompson1.html  However, I enjoyed this paper recently.  http://www.ejwagenmakers.com/2007/pValueProblems.pdf  Two striking things it shows is that a ridiculously lax Bayesian prior still does not end up claiming the null hypothesis is as likely as a p-value (p. 792-3). And second, that the null hypothesis significance testing paradigm does not compare the null hypothesis to the alternative. As a consequence, it rules out the very real possibility that, even if the data are unlikely given the null hypothesis, they are even more unlikely given the alternative hypothesis (p. 793).@WhittK:  > I was wondering if anyone had comments on the thesis of this > article? > http://www.nature.com/news/scientific-method-statistical-errors-<zipRedac>.<zipRedac><zipRedac>700  There's also an earlier forum thread discussing that article ([click here](https://class.stanford.edu/courses/HumanitiesScience/StatLearning/Winter20<zipRedac><zipRedac>/discussion/forum/i<zipRedac>x-HumanitiesScience-Stats2<zipRedac>6-course-Winter20<zipRedac><zipRedac>-general/threads/52fc85b<zipRedac>25<zipRedac><zipRedac>f62c<phoneRedac>5)).p-values can be very misleading. First, the p-values are calculated in the lm() function with very strict assumptions about the data:  1. residuals are uncorrelated 2. variance of residuals is constant  Second, stepwise regression or best subsets regression can search through the X variables space and find the ones with the lowest p-values. This could lead to overfitting (high variance, low bias). That is why I always ask for the cross-validation or test set MSE.  Third, p-values can change substantially if ONE variable were added or removed from the model.Wow -- "402 Citations Questioning the Indiscriminate Use of Null Hypothesis Significance Tests in Observational Studies" Thanks for the link. A list maintained since 1997!Thanks for the comment. I had not made the mental connection with overfitting.
# ------------------------
# medoid  869 : :-)
# ------------------------
# eta_1$ is squared.  (This example is a bit silly because it could easily be rewritten to be linear in the coefficients.)
# ------------------------
# medoid  759 : Yes.
# ------------------------
# medoid  378 : you have to install it first:  install.packages("ISLR")
# ------------------------
# medoid  725 : Thanks, smgross. I wondered about trying dummy variables but didn't know if the result would be meaningful. Your response is helpful.Hi Charles_S,  One answer is that if you have 2 class categorical variables you can just use a dummy variable (0-1) and then calculate the correlation with that dummy variable.  Obviously this won't work for more than 2 classes, but then you can use other measures of similarity as you suggest.Hi DWaterson,  There are several issues with your post.  1) Supervised selection of predictors is fine as long as you do the selection in an honest fashion.  This means, for example, that if you are using CV to estimate the error you need to do the selection inside of the CV (as opposed to selecting and then doing CV).  The claim "this will bias your outcome" I think refers to the fact that if you estimate the CV error in the incorrect way (select and then do CV) your estimate of error will be biased downwards.  The idea of using unsupervised selection is that you can do this before the CV (although there are a lot of caveats here relating to assumptions of the model).  2)  Random Forests do NOT do feature selection.  Each tree may have 31-ish variables, but you need ALL of the variables in order to calculate each trees prediction.  You are correct that they have some manner of feature importance.Thanks, I'll look into those. By the end of this week's lectures, I hope to know more about trees.Staff note: This response contains misconceptions.  I am leaving it as is to facilitate discussion.  Please see the staff response for a more correct response to the original question.  It sounds like you are using supervised selection to select the predictors with the strongest relationship with the response in your filtering technique. This will bias your outcome. You could use the method our Professors used of simply including those predictors with the largest variance as a filter. Or, if you are trying to create a best predictive model, you may wish to try Random Forests. Your tree may be on the bushy side, thus difficult to interpret, but the number of predictors are reduced to the square-root of 1,000 or 31ish and each of the 1,000 in your dataset have a chance to be "heard". This will bring n and p a lot closer in size. Also, with so many predictors, chances are good many of them will be correlated. You could plot a correlation matrix to see. We could use cross-validation to find the best model. However, with only 27 observations, you may wish to try OOB error estimation. Random Forests will provide a low error predictive model. It will also output the predictor importance pareto. If you need to use your model for interpreting the relationship between the predictors and the response, Boosting may be the way to go. I would use OOB to estimate test error. Boosting should result in a small, more interpretable tree. It will also provide good predictive performance. If you are simply trying to find the most important predictors, you can simply fit a classification tree. You can prune it to give it more predictive power, but as a predictive model, it will not match the power of Random Forest or Boosting, but will be much more interpretable.

# %% [markdown]
# ##Non-Negative Matrix Factorization

# %%
#NMF for grouped comments

from sklearn import decomposition
from time import time

print("size of corpus: {}".format(len(grouped_comments)))

n_samples = 1000
n_features = 10000
n_topics = 50
n_top_words = 20

t0 = time()

vectorizer = TfidfVectorizer(min_df=10, max_df=150,
                             max_features=n_features, 
                             stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words))

counts = vectorizer.fit_transform(grouped_comments[:n_samples])
tfidf = TfidfTransformer().fit_transform(counts)
print("done in %0.3fs." % (time() - t0))

# Fit the NMF model
print("Fitting the NMF model on with n_samples=%d and n_features=%d..."
      % (n_samples, n_features))
nmf = decomposition.NMF(n_components=n_topics).fit(tfidf)
print("done in %0.3fs." % (time() - t0))

# Inverse the vectorizer vocabulary to be able
feature_names = vectorizer.get_feature_names()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join( [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]] ))
    print
# Out:
# size of corpus: 1071
# done in 0.406s.
# Fitting the NMF model on with n_samples=1000 and n_features=10000...
# done in 31.086s.
# Topic #0:
# cv fold estimate best optimal choose mse test entire errors folds 10 discussed smaller models approach associated 000 final minimum
#
# Topic #1:
# rdata load xy workspace ls file loaded link stanford list type loading command datasets r1 directory dataframe statlearning assignment stuck
#
# Topic #2:
# humanitiesscience winter2 forum 14 threads winter2014 statlearning courses i4x discussion stanford stats216 edu feedback material thread discussed review 16 info
#
# Topic #3:
# install packages package islr library cran version project rstudio web installed org session command glmnet datasets available html run google
#
# Topic #4:
# tsboot boot index xy coef sim lm 1000 blocks fixed package return r3 subset indices statistic 100 seed pass beta1
#
# Topic #5:
# slides pdf lecture page 30 link downloaded hd pages chapter numbers slide edu notes statlearning stanford cs humanitiesscience formula follow
#
# Topic #6:
# watch youtube www com lectures coursera list link videos unable alternative github docs introduction links discriminant output analysis source check
#
# Topic #7:
# great learning statistical tibshirani hastie books esl lot professors free dr enjoyed prof book learned rob team trevor statistics week
#
# Topic #8:
# automatic appears logit past posting resampling ch allow getting answers teaching things low problems tsboot probably select results lda started
#
# Topic #9:
# 95 interval confidence intervals parameter true probability value contain prediction range contains random estimate unknown bayesian irreducible wrote include distribution
#
# Topic #10:
# log base natural formula 10 consistent correct wrong stats odds instructors written accepted assume calculation mathematical confusion notation specify balance
#
# Topic #11:
# volume cube boundary dimension hypercube dimensions square region area length 05 dimensional line point unit dimensionality points greater discussions proportion
#
# Topic #12:
# bcf usc gareth isl www edu islr pdf html credit elemstatlearn csv textbook tibs website book labs datasets download statweb
#
# Topic #13:
# tv sales advertising interaction units 1000 39 37 impact increase effect slide wrong terms prediction main calculation formula effects count
#
# Topic #14:
# distance x_i vector normal unit dimensions 10 length sum distribution points xi feature y_i correlation noticed element paragraph 25 maximum
#
# Topic #15:
# trees tree number split random kernel adding caret red unfortunately residuals population long single reply approach classification probability html constant
#
# Topic #16:
# edx image uploads amazonaws west s3 enter description png com icon platform click reg label bar section multiple seed shows
#
# Topic #17:
# auto csv islr library read attach caret numeric package file column obs load length lm 200 row create desktop str
#
# Topic #18:
# variance bias flexible high low irreducible var average tradeoff complicated random loocv reduce worse higher fits underlying noise estimates factors
#
# Topic #19:
# hi nameredac_anon_screen_name_redacted advance cheers include currently code able work ll science ve luck b0 fact follow com learn google group
#
# Topic #20:
# eta_0 epsilon eta_1 x_1 x_2 linear eta_2 dummy log odds variables respect interactions categorical terms slope interaction non effects parameters
#
# Topic #21:
# hat mathrm eta deviation frac standard sigma y_i eta_1 x_i fitted egin epsilon estimate residual left proportion sqrt se effective
#
# Topic #22:
# selection stepwise models forward backward best subset linear method step fitting choose number overfitting interaction select sub feature rss techniques
#
# Topic #23:
# chrome browser fine mac tried firefox volume screen works worked formulas reading clicking downloading version work specific speaking checked provided
#
# Topic #24:
# download videos youtube firefox video url hd downloaded copy play downloading add format access available versions link computer website quality
#
# Topic #25:
# file rstudio directory open csv editor files script installed save text running desktop studio windows mac run working workspace current
#
# Topic #26:
# staff talk number feedback simulation suggestion ways pass march general marked internet attempt particular 21 subject correct 05 possible unfortunately
#
# Topic #27:
# solutions manual github official stat nameredac_anon_screen_name_redacted community com aware learning cheers based html working solution blog quality elements statistical guide
#
# Topic #28:
# decimal places coefficient standard credit r1 provide questions long missing significant round r2 throw loop doesn assignment computer sum change
#
# Topic #29:
# lasso glmnet lambda ridge coefficients alpha zero net non important shrinkage features ordinary squares curious variables deal regularization std slope
#
# Topic #30:
# wikipedia en wiki org article www firefox project ratio uncorrelated html came measure se caret listed cran did talk cs
#
# Topic #31:
# poly raw polynomials orthogonal lm polynomial uses coefficients formula incorrect fit basis true reason quadratic 16 reg eta frame splines
#
# Topic #32:
# glm alpha fit pred cost numeric binomial sum predict object family argument vector names lm type default specify output multivariate
#
# Topic #33:
# bootstrap sample samples size replacement probability points number randomly estimator sampling resampling boethian point sets estimate asking formula deviation population
#
# Topic #34:
# supervised learning unsupervised goal response clustering algorithm input variable machine positive output examples negative false label predicting click statistical clicked
#
# Topic #35:
# plot figure col typo plots package box factor lm plotting max residuals 36 min look default command line red depending
#
# Topic #36:
# test train training predict pred svm fit lm 200 mse frame obs 1000 got correct curve nrow newdata cbind rep
#
# Topic #37:
# logistic logit probability odds svm probabilities response likelihood log predict classification discriminant particular predicted expected linear transformation binomial lower dependent
#
# Topic #38:
# 50 progress rnorm rep certificate half page 10 100 number pass generate seed believe line normal random observations svm datasets
#
# Topic #39:
# pca principal components 200 component frame proportion pr explained features feature var rows names sum original categorical variance analysis variables
#
# Topic #40:
# predictors correlated variables predictor variable correlation response dummy missing leave significant point high large relationship random predicted fit handle step
#
# Topic #41:
# video quiz button icon screen clicking click bar progress quizzes browser section windows double view turn currently issue chapter generally
#
# Topic #42:
# lda discriminant classification groups nearest prove linear classes figured direction normal bayes mass guess labels mu math dimensions analysis sigma
#
# Topic #43:
# x1 x2 interaction xy x3 equation linear statistic typo interactions relationship variable correlated residuals lm coefficient summary variables effect correctly
#
# Topic #44:
# exercises questions answers chapter conceptual book quizzes textbook week section posted homework accomplishment info coursera march site students applied labs
#
# Topic #45:
# validation cross fold folds loocv observations average variables split best performance training tuning spline iteration test parts estimates estimate parameter
#
# Topic #46:
# age reg df spline fit summary lines effects interaction main included splines steps fitted col year balance natural rnorm unless
#
# Topic #47:
# null hypothesis value statistic slope guess statistics bayesian zero beta significance unlikely testing distribution positive chance alternative interval relationship residual
#
# Topic #48:
# matrix intercept covariance column levels columns 10 factor correlation remove runs row variable compute frame variance xi inside formula mu
#
# Topic #49:
# block bootstrap series standard time errors bootstrapping blocks search tsboot independent march points distributed forum uncorrelated assumptions day non estimate

# %%
for topic_idx, topic in enumerate(nmf.components_):

    words = [feature_names[i] for i in topic.argsort()[:-(n_top_words-12):-1]]
    scores = [topic[i] for i in topic.argsort()[:-(n_top_words-12):-1]]

    dicta = {word: score for score, word in zip(scores, words)}

    s=pd.Series(dicta)
    plt.figure()
    plt.title("Topic #%d:" % topic_idx)
    s.plot(kind='bar');
# Out:
# /Users/wubr2000/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %%
#Word clouds
import vincent
vincent.core.initialize_notebook()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    tmpDic = {}
    for i in topic.argsort()[:-50 - 1:-1]:
        tmpDic[feature_names[i]] = topic[i]*100
    vincent.Word(tmpDic).display();
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# Topic #0:
# <div id="vis0f9a8865b7e9492abb76f25933cf3cfc"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "000", "val": 20.617355579835269}, {"col": "data", "idx": "10", "val": 24.522595727550602}, {"col": "data", "idx": "algorithm", "val": 14.10665463646642}, {"col": "data", "idx": "approach", "val": 22.478151101862785}, {"col": "data", "idx": "associated", "val": 21.686226622041431}, {"col": "data", "idx": "average", "val": 17.337834566684766}, {"col": "data", "idx": "best", "val": 44.582845264760053}, {"col": "data", "idx": "bootstrapping", "val": 18.215719720670645}, {"col": "data", "idx": "choose", "val": 42.23004530246893}, {"col": "data", "idx": "choosing", "val": 14.324107293267257}, {"col": "data", "idx": "compute", "val": 15.921176481458629}, {"col": "data", "idx": "cv", "val": 388.69475827952175}, {"col": "data", "idx": "discussed", "val": 23.615038362443457}, {"col": "data", "idx": "doing", "val": 17.452559792663575}, {"col": "data", "idx": "entire", "val": 28.120475520646632}, {"col": "data", "idx": "entirely", "val": 16.735167044507897}, {"col": "data", "idx": "errors", "val": 26.567986763052172}, {"col": "data", "idx": "estimate", "val": 57.038628912231772}, {"col": "data", "idx": "feature", "val": 14.641290303578042}, {"col": "data", "idx": "final", "val": 19.995150527429136}, {"col": "data", "idx": "fold", "val": 62.604337616079185}, {"col": "data", "idx": "folds", "val": 25.296869266934063}, {"col": "data", "idx": "glmnet", "val": 17.56630249384051}, {"col": "data", "idx": "groups", "val": 14.215532266289422}, {"col": "data", "idx": "loop", "val": 16.632174572315218}, {"col": "data", "idx": "mentioned", "val": 12.424712099732085}, {"col": "data", "idx": "method", "val": 15.002742053927667}, {"col": "data", "idx": "minimum", "val": 18.89545371733951}, {"col": "data", "idx": "models", "val": 22.922920386610333}, {"col": "data", "idx": "mse", "val": 35.078487836764353}, {"col": "data", "idx": "optimal", "val": 42.636575381959318}, {"col": "data", "idx": "options", "val": 18.524750404765964}, {"col": "data", "idx": "overall", "val": 14.36859992772419}, {"col": "data", "idx": "parameters", "val": 18.83558586155408}, {"col": "data", "idx": "perform", "val": 16.06800775605733}, {"col": "data", "idx": "pre", "val": 15.572224504148322}, {"col": "data", "idx": "prefer", "val": 14.751960289745956}, {"col": "data", "idx": "repeated", "val": 14.568259237810771}, {"col": "data", "idx": "rule", "val": 17.440906726478975}, {"col": "data", "idx": "run", "val": 18.257896467051857}, {"col": "data", "idx": "saying", "val": 13.244865052744851}, {"col": "data", "idx": "selected", "val": 16.804135903704381}, {"col": "data", "idx": "sets", "val": 14.55918051215701}, {"col": "data", "idx": "situations", "val": 13.429551003342574}, {"col": "data", "idx": "smaller", "val": 22.975425641820848}, {"col": "data", "idx": "standard", "val": 13.539940430905792}, {"col": "data", "idx": "test", "val": 29.547883819460669}, {"col": "data", "idx": "training", "val": 18.792732775963792}, {"col": "data", "idx": "usual", "val": 17.054388214046952}, {"col": "data", "idx": "ways", "val": 14.629409313292957}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis0f9a8865b7e9492abb76f25933cf3cfc"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #1:
# <div id="vise404682cb4304fe49b85a3681932bea5"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "10", "val": 6.5242538595240234}, {"col": "data", "idx": "assign", "val": 4.1446037775178821}, {"col": "data", "idx": "assignment", "val": 7.7986495344747029}, {"col": "data", "idx": "called", "val": 3.9584870294407484}, {"col": "data", "idx": "click", "val": 5.7578052435893108}, {"col": "data", "idx": "command", "val": 8.7695307757330028}, {"col": "data", "idx": "couldn", "val": 6.7071432965742943}, {"col": "data", "idx": "dataframe", "val": 7.9440593815385903}, {"col": "data", "idx": "datasets", "val": 8.762066748328099}, {"col": "data", "idx": "didn", "val": 5.149233014585243}, {"col": "data", "idx": "directly", "val": 6.0127048807769343}, {"col": "data", "idx": "directory", "val": 7.9727694213988105}, {"col": "data", "idx": "download", "val": 6.3019009119059843}, {"col": "data", "idx": "downloading", "val": 5.5969504425282324}, {"col": "data", "idx": "edu", "val": 5.5326670084322753}, {"col": "data", "idx": "esl", "val": 5.3105116191285706}, {"col": "data", "idx": "figure", "val": 4.6916865787976523}, {"col": "data", "idx": "file", "val": 22.408036244850987}, {"col": "data", "idx": "frame", "val": 5.8553398046952543}, {"col": "data", "idx": "head", "val": 6.6580043033960381}, {"col": "data", "idx": "html", "val": 5.1969587304229172}, {"col": "data", "idx": "humanitiesscience", "val": 6.380355086770563}, {"col": "data", "idx": "link", "val": 11.888390803214952}, {"col": "data", "idx": "list", "val": 10.015515829237973}, {"col": "data", "idx": "load", "val": 62.220886592641797}, {"col": "data", "idx": "loaded", "val": 14.412137113110472}, {"col": "data", "idx": "loading", "val": 9.3924419785827542}, {"col": "data", "idx": "ls", "val": 22.583752476518075}, {"col": "data", "idx": "message", "val": 5.2537197526590971}, {"col": "data", "idx": "names", "val": 6.2873246641342977}, {"col": "data", "idx": "numeric", "val": 3.9173559181766495}, {"col": "data", "idx": "objects", "val": 4.3241151669772249}, {"col": "data", "idx": "output", "val": 6.1980343109794918}, {"col": "data", "idx": "r1", "val": 7.9801069715343997}, {"col": "data", "idx": "rdata", "val": 126.30495164210495}, {"col": "data", "idx": "shouldn", "val": 3.5394413002178973}, {"col": "data", "idx": "shown", "val": 6.3216214830032298}, {"col": "data", "idx": "stanford", "val": 10.24532703216487}, {"col": "data", "idx": "statistical", "val": 4.2450183725875599}, {"col": "data", "idx": "statlearning", "val": 7.8417477873307107}, {"col": "data", "idx": "stuck", "val": 7.0458067496319092}, {"col": "data", "idx": "studio", "val": 5.4098592004291284}, {"col": "data", "idx": "summary", "val": 4.0637704743294352}, {"col": "data", "idx": "talking", "val": 3.5354228540937562}, {"col": "data", "idx": "type", "val": 9.5938145983191401}, {"col": "data", "idx": "url", "val": 4.8952614179699259}, {"col": "data", "idx": "users", "val": 4.2973709417827308}, {"col": "data", "idx": "view", "val": 4.3151107802380384}, {"col": "data", "idx": "workspace", "val": 23.550288006637533}, {"col": "data", "idx": "xy", "val": 36.400247400439532}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vise404682cb4304fe49b85a3681932bea5"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #2:
# <div id="visdeb294d6d7db4613a0fc0a970328871f"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "14", "val": 48.698212163378237}, {"col": "data", "idx": "16", "val": 5.5460249528291099}, {"col": "data", "idx": "17", "val": 3.6110702829636057}, {"col": "data", "idx": "18", "val": 2.777861986827932}, {"col": "data", "idx": "27", "val": 3.836786252682161}, {"col": "data", "idx": "39", "val": 2.7764035244392415}, {"col": "data", "idx": "agreed", "val": 3.8487014165178848}, {"col": "data", "idx": "blue", "val": 2.9399971845781976}, {"col": "data", "idx": "closely", "val": 2.827718962602658}, {"col": "data", "idx": "code", "val": 2.6548975077866013}, {"col": "data", "idx": "courses", "val": 41.936199658192173}, {"col": "data", "idx": "didn", "val": 3.644034641086181}, {"col": "data", "idx": "discussed", "val": 8.4236408174758353}, {"col": "data", "idx": "discussion", "val": 39.513648066760702}, {"col": "data", "idx": "edu", "val": 32.044371517227269}, {"col": "data", "idx": "especially", "val": 4.7819369327238244}, {"col": "data", "idx": "feedback", "val": 30.636253978126938}, {"col": "data", "idx": "following", "val": 4.1012303466664717}, {"col": "data", "idx": "forum", "val": 50.836823199094418}, {"col": "data", "idx": "future", "val": 3.2651130559443189}, {"col": "data", "idx": "general", "val": 4.1437116283525617}, {"col": "data", "idx": "humanitiesscience", "val": 81.092121026108529}, {"col": "data", "idx": "i4x", "val": 41.344080575576427}, {"col": "data", "idx": "includes", "val": 3.8223312876899409}, {"col": "data", "idx": "info", "val": 5.2150208508568427}, {"col": "data", "idx": "link", "val": 3.0547602517907815}, {"col": "data", "idx": "look", "val": 3.1006497231315078}, {"col": "data", "idx": "material", "val": 26.121891733273493}, {"col": "data", "idx": "meaning", "val": 2.8069687330343021}, {"col": "data", "idx": "mistake", "val": 4.4173465756512122}, {"col": "data", "idx": "quiz", "val": 4.6285293694059311}, {"col": "data", "idx": "r2", "val": 3.1518261798247953}, {"col": "data", "idx": "reference", "val": 3.2685528412380851}, {"col": "data", "idx": "response", "val": 2.9334397020381004}, {"col": "data", "idx": "responses", "val": 2.8151340091180614}, {"col": "data", "idx": "review", "val": 7.9928379724886351}, {"col": "data", "idx": "search", "val": 3.216204000556846}, {"col": "data", "idx": "stanford", "val": 37.902320969820728}, {"col": "data", "idx": "statlearning", "val": 44.760242561989372}, {"col": "data", "idx": "stats", "val": 3.6281568644590312}, {"col": "data", "idx": "stats216", "val": 36.904416668933507}, {"col": "data", "idx": "stuck", "val": 2.8159247996069263}, {"col": "data", "idx": "supposed", "val": 3.0867351520766095}, {"col": "data", "idx": "thread", "val": 24.155952311363247}, {"col": "data", "idx": "threads", "val": 46.238687767408202}, {"col": "data", "idx": "tricky", "val": 2.8200981565728673}, {"col": "data", "idx": "variables", "val": 2.7523005029156131}, {"col": "data", "idx": "website", "val": 3.7156805989489845}, {"col": "data", "idx": "winter2", "val": 66.920744708448126}, {"col": "data", "idx": "winter2014", "val": 45.723817178366289}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visdeb294d6d7db4613a0fc0a970328871f"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #3:
# <div id="vis1641c6acf00440c78f2f3c8abf294d2f"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "15", "val": 6.5808168832301588}, {"col": "data", "idx": "argument", "val": 3.2540232649430614}, {"col": "data", "idx": "attach", "val": 3.8083359802510088}, {"col": "data", "idx": "available", "val": 7.610991242439848}, {"col": "data", "idx": "built", "val": 4.5232242796956772}, {"col": "data", "idx": "command", "val": 10.670543802066588}, {"col": "data", "idx": "commands", "val": 6.2406477092206405}, {"col": "data", "idx": "cran", "val": 33.729525579843347}, {"col": "data", "idx": "datasets", "val": 7.8612910690410596}, {"col": "data", "idx": "dependent", "val": 3.9615293738441628}, {"col": "data", "idx": "did", "val": 3.9592698537249502}, {"col": "data", "idx": "download", "val": 5.5087339890227707}, {"col": "data", "idx": "following", "val": 3.3123892703518476}, {"col": "data", "idx": "functions", "val": 3.3486964397168681}, {"col": "data", "idx": "glmnet", "val": 8.9078014035913569}, {"col": "data", "idx": "google", "val": 6.635255876286636}, {"col": "data", "idx": "html", "val": 7.1998885181790708}, {"col": "data", "idx": "index", "val": 4.4844339667522179}, {"col": "data", "idx": "install", "val": 106.53359564149065}, {"col": "data", "idx": "installed", "val": 13.686580654900151}, {"col": "data", "idx": "islr", "val": 62.493775130944009}, {"col": "data", "idx": "library", "val": 40.096718512530735}, {"col": "data", "idx": "location", "val": 6.2393377527137899}, {"col": "data", "idx": "mass", "val": 6.2622840783486398}, {"col": "data", "idx": "meant", "val": 4.1750247176961084}, {"col": "data", "idx": "mentioned", "val": 3.9089741157997633}, {"col": "data", "idx": "options", "val": 3.8117618251252363}, {"col": "data", "idx": "org", "val": 13.645341035308098}, {"col": "data", "idx": "package", "val": 72.992822893055646}, {"col": "data", "idx": "packages", "val": 92.245656333793434}, {"col": "data", "idx": "pick", "val": 4.1348390697964525}, {"col": "data", "idx": "project", "val": 19.66459846802007}, {"col": "data", "idx": "rstudio", "val": 19.159515512170348}, {"col": "data", "idx": "run", "val": 6.6380870800209841}, {"col": "data", "idx": "search", "val": 4.5399289585943565}, {"col": "data", "idx": "session", "val": 11.959927140472178}, {"col": "data", "idx": "sets", "val": 3.1813109507959432}, {"col": "data", "idx": "solved", "val": 3.2267366165970932}, {"col": "data", "idx": "source", "val": 3.9139229405199183}, {"col": "data", "idx": "space", "val": 3.1763685551621865}, {"col": "data", "idx": "studio", "val": 3.6110809400582866}, {"col": "data", "idx": "summary", "val": 3.1566595170140461}, {"col": "data", "idx": "true", "val": 3.5636027530476038}, {"col": "data", "idx": "type", "val": 3.6840499073691064}, {"col": "data", "idx": "version", "val": 24.201275805683224}, {"col": "data", "idx": "versions", "val": 3.8795345905689262}, {"col": "data", "idx": "view", "val": 3.2444485991570704}, {"col": "data", "idx": "web", "val": 17.808867503082702}, {"col": "data", "idx": "windows", "val": 3.842450231846454}, {"col": "data", "idx": "world", "val": 4.0098479646475127}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis1641c6acf00440c78f2f3c8abf294d2f"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #4:
# <div id="visa693550e7b9b4e5c814b4418137de176"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "100", "val": 13.004679203140867}, {"col": "data", "idx": "1000", "val": 21.880847073297321}, {"col": "data", "idx": "alpha", "val": 8.9773746575767746}, {"col": "data", "idx": "argument", "val": 7.3935758958095166}, {"col": "data", "idx": "arguments", "val": 9.8895452618462496}, {"col": "data", "idx": "asked", "val": 5.3491430397591975}, {"col": "data", "idx": "available", "val": 6.3869606085220436}, {"col": "data", "idx": "beta1", "val": 10.648613283659019}, {"col": "data", "idx": "block", "val": 5.7070722541175085}, {"col": "data", "idx": "blocks", "val": 20.355705159229174}, {"col": "data", "idx": "boot", "val": 92.716674991988384}, {"col": "data", "idx": "bootstrap", "val": 9.3947767467707006}, {"col": "data", "idx": "code", "val": 5.7103857770372786}, {"col": "data", "idx": "coef", "val": 29.578555231183156}, {"col": "data", "idx": "coefficients", "val": 5.0512657573051465}, {"col": "data", "idx": "dataframe", "val": 4.8753597638046315}, {"col": "data", "idx": "dataset", "val": 7.3875730090892224}, {"col": "data", "idx": "fixed", "val": 16.919843492303269}, {"col": "data", "idx": "formula", "val": 4.5901379779305005}, {"col": "data", "idx": "functions", "val": 4.6128660559657613}, {"col": "data", "idx": "getting", "val": 4.5195254654244978}, {"col": "data", "idx": "got", "val": 7.6084162909511628}, {"col": "data", "idx": "help", "val": 7.6164583561674828}, {"col": "data", "idx": "index", "val": 57.398747782516168}, {"col": "data", "idx": "indices", "val": 15.179337668231744}, {"col": "data", "idx": "intervals", "val": 5.1627910657723559}, {"col": "data", "idx": "lm", "val": 22.182354308972478}, {"col": "data", "idx": "look", "val": 7.8416252874629926}, {"col": "data", "idx": "original", "val": 8.1987072798491454}, {"col": "data", "idx": "package", "val": 16.695900137176032}, {"col": "data", "idx": "pass", "val": 11.040291416900111}, {"col": "data", "idx": "performs", "val": 4.6185128090789194}, {"col": "data", "idx": "practical", "val": 5.2749085939151179}, {"col": "data", "idx": "r3", "val": 15.824165077949214}, {"col": "data", "idx": "random", "val": 4.5257805807347804}, {"col": "data", "idx": "return", "val": 16.430519536890142}, {"col": "data", "idx": "returns", "val": 5.0615994036009342}, {"col": "data", "idx": "se", "val": 7.4618817290188346}, {"col": "data", "idx": "seed", "val": 11.76108360693541}, {"col": "data", "idx": "sim", "val": 23.673506535605569}, {"col": "data", "idx": "simpler", "val": 4.7857288600973993}, {"col": "data", "idx": "statistic", "val": 14.909209431349362}, {"col": "data", "idx": "statistics", "val": 5.5383868473150955}, {"col": "data", "idx": "std", "val": 7.7565430625007119}, {"col": "data", "idx": "subset", "val": 15.288027557986092}, {"col": "data", "idx": "thread", "val": 4.7309000482722734}, {"col": "data", "idx": "tsboot", "val": 113.84324844921159}, {"col": "data", "idx": "works", "val": 4.3935898909988991}, {"col": "data", "idx": "wrong", "val": 6.0859783416267108}, {"col": "data", "idx": "xy", "val": 40.813403183254259}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visa693550e7b9b4e5c814b4418137de176"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #5:
# <div id="vise8bf3583959c45389044321eb833c367"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "00", "val": 5.0444466720566199}, {"col": "data", "idx": "0000", "val": 6.7539493801724397}, {"col": "data", "idx": "11", "val": 5.3889341247909472}, {"col": "data", "idx": "21", "val": 5.1164935062846251}, {"col": "data", "idx": "25", "val": 6.5756118375494115}, {"col": "data", "idx": "30", "val": 39.646122059350773}, {"col": "data", "idx": "36", "val": 4.2298225015941524}, {"col": "data", "idx": "40", "val": 4.2611290870287863}, {"col": "data", "idx": "address", "val": 4.4738630123893914}, {"col": "data", "idx": "available", "val": 3.9008339729674741}, {"col": "data", "idx": "b0", "val": 4.2559054971172605}, {"col": "data", "idx": "book", "val": 4.3398671782744689}, {"col": "data", "idx": "chapter", "val": 14.927992330696419}, {"col": "data", "idx": "classification", "val": 4.9018603230276376}, {"col": "data", "idx": "click", "val": 5.0018345743224399}, {"col": "data", "idx": "confusion", "val": 3.7588366950346517}, {"col": "data", "idx": "consistent", "val": 4.180934549300388}, {"col": "data", "idx": "cs", "val": 9.3071154011721369}, {"col": "data", "idx": "curious", "val": 4.1873050439938639}, {"col": "data", "idx": "downloaded", "val": 17.213938481061923}, {"col": "data", "idx": "edu", "val": 12.894043936152261}, {"col": "data", "idx": "equation", "val": 6.4517624555710569}, {"col": "data", "idx": "follow", "val": 8.3101286250513908}, {"col": "data", "idx": "format", "val": 5.4246362687090395}, {"col": "data", "idx": "formula", "val": 8.3316505195773516}, {"col": "data", "idx": "hd", "val": 16.004459954658319}, {"col": "data", "idx": "humanitiesscience", "val": 8.792232917859355}, {"col": "data", "idx": "learning", "val": 4.67116640891693}, {"col": "data", "idx": "lecture", "val": 70.282594611856837}, {"col": "data", "idx": "link", "val": 20.51064685897358}, {"col": "data", "idx": "lots", "val": 4.0929249329175486}, {"col": "data", "idx": "notes", "val": 12.67783511598822}, {"col": "data", "idx": "numbers", "val": 14.138795625761436}, {"col": "data", "idx": "open", "val": 5.4558647010604417}, {"col": "data", "idx": "page", "val": 40.026731380795141}, {"col": "data", "idx": "pages", "val": 15.789436363719489}, {"col": "data", "idx": "paper", "val": 7.9166790942268417}, {"col": "data", "idx": "pdf", "val": 93.735171368870908}, {"col": "data", "idx": "presented", "val": 5.7476787046326541}, {"col": "data", "idx": "produce", "val": 4.5451565254653259}, {"col": "data", "idx": "refers", "val": 6.189120405617933}, {"col": "data", "idx": "slide", "val": 13.8912437610821}, {"col": "data", "idx": "slides", "val": 108.85857559160345}, {"col": "data", "idx": "smgross", "val": 6.3445096034711508}, {"col": "data", "idx": "stanford", "val": 10.047785183301112}, {"col": "data", "idx": "statistical", "val": 8.0806796324818926}, {"col": "data", "idx": "statlearning", "val": 11.2226937363762}, {"col": "data", "idx": "talking", "val": 3.937821457230505}, {"col": "data", "idx": "winter2014", "val": 6.8597929181177744}, {"col": "data", "idx": "wondering", "val": 6.2835026065446984}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vise8bf3583959c45389044321eb833c367"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #6:
# <div id="vise16889791e7f4b7bacadf49a670e8786"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "05", "val": 4.684545874505023}, {"col": "data", "idx": "alternative", "val": 6.7419762096547053}, {"col": "data", "idx": "analysis", "val": 5.4148099829162035}, {"col": "data", "idx": "available", "val": 3.8713525750839439}, {"col": "data", "idx": "check", "val": 5.325213388295821}, {"col": "data", "idx": "com", "val": 59.808885808075317}, {"col": "data", "idx": "content", "val": 4.4059970514424149}, {"col": "data", "idx": "cost", "val": 3.0533680516217299}, {"col": "data", "idx": "coursera", "val": 10.984281191057466}, {"col": "data", "idx": "details", "val": 3.4307145537281669}, {"col": "data", "idx": "discriminant", "val": 5.9210256083744879}, {"col": "data", "idx": "docs", "val": 6.5452415633655985}, {"col": "data", "idx": "explained", "val": 3.3368682787579416}, {"col": "data", "idx": "extension", "val": 3.8141987331725637}, {"col": "data", "idx": "files", "val": 3.6460690915272376}, {"col": "data", "idx": "free", "val": 4.6886062007402511}, {"col": "data", "idx": "github", "val": 6.5668033660375853}, {"col": "data", "idx": "google", "val": 4.0741904750222453}, {"col": "data", "idx": "having", "val": 3.1771291808955722}, {"col": "data", "idx": "highly", "val": 3.302768485260736}, {"col": "data", "idx": "introduction", "val": 6.266796061538682}, {"col": "data", "idx": "issues", "val": 4.7086311415658919}, {"col": "data", "idx": "lectures", "val": 14.269672663629956}, {"col": "data", "idx": "link", "val": 8.7483487875872772}, {"col": "data", "idx": "links", "val": 5.9827103952404084}, {"col": "data", "idx": "list", "val": 9.4504919095314044}, {"col": "data", "idx": "march", "val": 3.2246295531747737}, {"col": "data", "idx": "net", "val": 3.7701850129510883}, {"col": "data", "idx": "org", "val": 3.0392272961363025}, {"col": "data", "idx": "output", "val": 5.4867830862004103}, {"col": "data", "idx": "package", "val": 3.3235029049091209}, {"col": "data", "idx": "predictions", "val": 3.2148032771330679}, {"col": "data", "idx": "programming", "val": 3.2852384872439924}, {"col": "data", "idx": "proportion", "val": 4.2389178884241439}, {"col": "data", "idx": "recommend", "val": 3.0263888866439168}, {"col": "data", "idx": "risk", "val": 3.0555777624760214}, {"col": "data", "idx": "rstudio", "val": 5.0481600274128473}, {"col": "data", "idx": "source", "val": 5.3346671833885795}, {"col": "data", "idx": "squared", "val": 3.3424089628854023}, {"col": "data", "idx": "sure", "val": 3.0800599263457209}, {"col": "data", "idx": "topics", "val": 4.5177520915621123}, {"col": "data", "idx": "unable", "val": 6.8689466500499092}, {"col": "data", "idx": "var", "val": 4.7651309672602897}, {"col": "data", "idx": "video", "val": 3.09608025770939}, {"col": "data", "idx": "videos", "val": 6.9174903663401732}, {"col": "data", "idx": "vs", "val": 3.988157165772952}, {"col": "data", "idx": "watch", "val": 131.06983575633058}, {"col": "data", "idx": "week", "val": 3.0136594674144233}, {"col": "data", "idx": "www", "val": 61.763547049173042}, {"col": "data", "idx": "youtube", "val": 121.1462103196278}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vise16889791e7f4b7bacadf49a670e8786"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #7:
# <div id="visc0650f8fe5ac4ce38af2681adc85ba87"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "advanced", "val": 11.997371716162197}, {"col": "data", "idx": "book", "val": 20.563864538140006}, {"col": "data", "idx": "books", "val": 27.749856454992312}, {"col": "data", "idx": "courses", "val": 10.88511429586134}, {"col": "data", "idx": "dr", "val": 22.901554659168934}, {"col": "data", "idx": "effort", "val": 13.419840797868076}, {"col": "data", "idx": "elements", "val": 16.84322967838429}, {"col": "data", "idx": "elemstatlearn", "val": 12.194208493944386}, {"col": "data", "idx": "enjoyed", "val": 22.892492318276066}, {"col": "data", "idx": "esl", "val": 27.224838698515342}, {"col": "data", "idx": "experience", "val": 17.174039027993139}, {"col": "data", "idx": "feel", "val": 11.483151397222841}, {"col": "data", "idx": "field", "val": 10.908595566067456}, {"col": "data", "idx": "follow", "val": 12.357073398601424}, {"col": "data", "idx": "forward", "val": 15.389918134194595}, {"col": "data", "idx": "free", "val": 23.210252010079564}, {"col": "data", "idx": "great", "val": 92.265478054909622}, {"col": "data", "idx": "hastie", "val": 30.784887334530321}, {"col": "data", "idx": "hours", "val": 10.69348372154889}, {"col": "data", "idx": "knowledge", "val": 11.27363499925165}, {"col": "data", "idx": "learn", "val": 15.776747325981081}, {"col": "data", "idx": "learned", "val": 20.373629559493402}, {"col": "data", "idx": "learning", "val": 44.695504652813852}, {"col": "data", "idx": "looking", "val": 14.124850322089507}, {"col": "data", "idx": "lot", "val": 25.736421015663026}, {"col": "data", "idx": "love", "val": 11.120597020057298}, {"col": "data", "idx": "machine", "val": 15.659177258190734}, {"col": "data", "idx": "material", "val": 11.979213872282957}, {"col": "data", "idx": "miss", "val": 13.416951180436584}, {"col": "data", "idx": "offer", "val": 15.879489386932333}, {"col": "data", "idx": "online", "val": 15.457582475212387}, {"col": "data", "idx": "people", "val": 12.522743206464302}, {"col": "data", "idx": "prof", "val": 21.269314985475912}, {"col": "data", "idx": "professors", "val": 24.939410372119081}, {"col": "data", "idx": "rob", "val": 20.164721548686622}, {"col": "data", "idx": "statistical", "val": 35.999760589702156}, {"col": "data", "idx": "statistics", "val": 17.468713510527937}, {"col": "data", "idx": "statweb", "val": 11.657269792932535}, {"col": "data", "idx": "taught", "val": 11.527198411605161}, {"col": "data", "idx": "team", "val": 19.360963896297172}, {"col": "data", "idx": "techniques", "val": 12.012081095115159}, {"col": "data", "idx": "theory", "val": 10.915394915462882}, {"col": "data", "idx": "tibs", "val": 10.930539007475053}, {"col": "data", "idx": "tibshirani", "val": 33.672217165358177}, {"col": "data", "idx": "time", "val": 16.767472948966201}, {"col": "data", "idx": "trevor", "val": 18.669312190349547}, {"col": "data", "idx": "useful", "val": 11.217804030867047}, {"col": "data", "idx": "ve", "val": 11.719076221480188}, {"col": "data", "idx": "week", "val": 17.443948414770531}, {"col": "data", "idx": "weeks", "val": 14.403623990850129}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#visc0650f8fe5ac4ce38af2681adc85ba87"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #8:
# <div id="vis47a01b5fa77f418abf4f2c2c95ef1680"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "advice", "val": 1.2114566126789812}, {"col": "data", "idx": "allow", "val": 6.1256881652457826}, {"col": "data", "idx": "answers", "val": 4.3532934033025539}, {"col": "data", "idx": "appears", "val": 129.8470890681528}, {"col": "data", "idx": "apply", "val": 2.7717645211004083}, {"col": "data", "idx": "automatic", "val": 184.72588753690465}, {"col": "data", "idx": "better", "val": 3.0105101101207494}, {"col": "data", "idx": "certificate", "val": 1.0702834196835096}, {"col": "data", "idx": "ch", "val": 7.3090422326887738}, {"col": "data", "idx": "correct", "val": 1.5138075465729033}, {"col": "data", "idx": "correlation", "val": 1.0417745809549672}, {"col": "data", "idx": "exists", "val": 0.95567700169904324}, {"col": "data", "idx": "finish", "val": 1.0902025813150853}, {"col": "data", "idx": "generated", "val": 0.82200437946240779}, {"col": "data", "idx": "getting", "val": 5.4202489531006774}, {"col": "data", "idx": "great", "val": 2.3963937816700787}, {"col": "data", "idx": "lda", "val": 3.2615877146380625}, {"col": "data", "idx": "likely", "val": 2.6201408802836501}, {"col": "data", "idx": "logit", "val": 9.5349895347898084}, {"col": "data", "idx": "low", "val": 3.6896035432727832}, {"col": "data", "idx": "measured", "val": 0.95032905658271583}, {"col": "data", "idx": "multiple", "val": 2.4095342278893255}, {"col": "data", "idx": "past", "val": 9.2621197502346604}, {"col": "data", "idx": "posting", "val": 8.4884388463832252}, {"col": "data", "idx": "prediction", "val": 1.2385227174090874}, {"col": "data", "idx": "probably", "val": 3.4933816897243939}, {"col": "data", "idx": "problems", "val": 3.660328859062203}, {"col": "data", "idx": "prof", "val": 0.81934491910098162}, {"col": "data", "idx": "random", "val": 2.599951011398224}, {"col": "data", "idx": "recommend", "val": 0.84208391592323406}, {"col": "data", "idx": "regards", "val": 0.90139055400397372}, {"col": "data", "idx": "related", "val": 0.88654918279543504}, {"col": "data", "idx": "required", "val": 0.83112446139132068}, {"col": "data", "idx": "resampling", "val": 7.5132426878163168}, {"col": "data", "idx": "results", "val": 3.37192361133437}, {"col": "data", "idx": "screen", "val": 0.99232617991688377}, {"col": "data", "idx": "select", "val": 3.3973747700681103}, {"col": "data", "idx": "series", "val": 0.91765746320109975}, {"col": "data", "idx": "similar", "val": 1.1068154328878843}, {"col": "data", "idx": "software", "val": 2.8465372133712115}, {"col": "data", "idx": "started", "val": 3.1729629886784934}, {"col": "data", "idx": "teaching", "val": 3.8905991606910688}, {"col": "data", "idx": "things", "val": 3.8683118793168854}, {"col": "data", "idx": "throw", "val": 0.96969042178535436}, {"col": "data", "idx": "time", "val": 1.4838120405426223}, {"col": "data", "idx": "tsboot", "val": 3.5438164842085609}, {"col": "data", "idx": "turn", "val": 0.84380565564781662}, {"col": "data", "idx": "ve", "val": 2.2978742236725416}, {"col": "data", "idx": "work", "val": 1.9712951606833347}, {"col": "data", "idx": "year", "val": 1.0466205780385287}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis47a01b5fa77f418abf4f2c2c95ef1680"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #9:
# <div id="vis65babd99c4dc464a9c9545611715af6a"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "100", "val": 5.3176101299256651}, {"col": "data", "idx": "20", "val": 5.3155606188582141}, {"col": "data", "idx": "95", "val": 107.90587090897938}, {"col": "data", "idx": "account", "val": 9.2058792591446252}, {"col": "data", "idx": "assume", "val": 7.5678352535959279}, {"col": "data", "idx": "average", "val": 6.3333866886137056}, {"col": "data", "idx": "bayesian", "val": 13.000120382264424}, {"col": "data", "idx": "calculate", "val": 5.0870517914700342}, {"col": "data", "idx": "chance", "val": 5.284429178700659}, {"col": "data", "idx": "clarification", "val": 5.5080612023277933}, {"col": "data", "idx": "confidence", "val": 94.453634464455618}, {"col": "data", "idx": "constant", "val": 6.3668945630931688}, {"col": "data", "idx": "contain", "val": 22.14423038460043}, {"col": "data", "idx": "contains", "val": 16.499001692255934}, {"col": "data", "idx": "distribution", "val": 9.682681613857973}, {"col": "data", "idx": "doesn", "val": 5.1652704793982283}, {"col": "data", "idx": "errors", "val": 8.3846902145322346}, {"col": "data", "idx": "estimate", "val": 14.084462752351484}, {"col": "data", "idx": "eta_1", "val": 6.4255905583336954}, {"col": "data", "idx": "expect", "val": 7.3165599277220634}, {"col": "data", "idx": "freedom", "val": 5.0898265195082466}, {"col": "data", "idx": "include", "val": 9.8766031592156409}, {"col": "data", "idx": "interval", "val": 104.72422471311218}, {"col": "data", "idx": "intervals", "val": 56.2246710761396}, {"col": "data", "idx": "irreducible", "val": 11.69757377645017}, {"col": "data", "idx": "lies", "val": 6.7439495111609569}, {"col": "data", "idx": "meant", "val": 5.4749141142895352}, {"col": "data", "idx": "multiple", "val": 8.7812377973853959}, {"col": "data", "idx": "normally", "val": 5.2776897897174377}, {"col": "data", "idx": "option", "val": 8.152878577804735}, {"col": "data", "idx": "parameter", "val": 40.692033776908218}, {"col": "data", "idx": "perspective", "val": 5.8799829842213507}, {"col": "data", "idx": "prediction", "val": 17.966028929101867}, {"col": "data", "idx": "probability", "val": 36.13743421893453}, {"col": "data", "idx": "random", "val": 14.270512208234754}, {"col": "data", "idx": "range", "val": 16.511920805279068}, {"col": "data", "idx": "real", "val": 5.6163468465141992}, {"col": "data", "idx": "repeated", "val": 6.986120185521874}, {"col": "data", "idx": "sample", "val": 8.9863026363241776}, {"col": "data", "idx": "say", "val": 8.6411535420474284}, {"col": "data", "idx": "second", "val": 6.0788756534181605}, {"col": "data", "idx": "single", "val": 5.0614324090128635}, {"col": "data", "idx": "standard", "val": 8.8413227569792152}, {"col": "data", "idx": "sure", "val": 5.8481101869585865}, {"col": "data", "idx": "times", "val": 6.7637623132457314}, {"col": "data", "idx": "true", "val": 39.157410852116001}, {"col": "data", "idx": "unknown", "val": 13.521679238152448}, {"col": "data", "idx": "value", "val": 25.112343241027467}, {"col": "data", "idx": "winter2014", "val": 6.0718873484278939}, {"col": "data", "idx": "wrote", "val": 10.848544771836071}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis65babd99c4dc464a9c9545611715af6a"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #10:
# <div id="vis91dbe5a206bb43099b5d53ccf78788da"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
# ...
#          chart({el: "#visb550a816eb594fceb43051933eb8d469"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #47:
# <div id="vis18aa61c56d964cef86e3b5ca23f98e86"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "05", "val": 10.142678792521966}, {"col": "data", "idx": "16", "val": 7.9862214013671009}, {"col": "data", "idx": "alternative", "val": 13.091778325390512}, {"col": "data", "idx": "article", "val": 7.7253315575281256}, {"col": "data", "idx": "bayesian", "val": 19.190746621909458}, {"col": "data", "idx": "beta", "val": 16.542131099567424}, {"col": "data", "idx": "chance", "val": 13.500155341781239}, {"col": "data", "idx": "confidence", "val": 10.226306183569884}, {"col": "data", "idx": "confused", "val": 10.183179785203182}, {"col": "data", "idx": "definition", "val": 8.0736024664362649}, {"col": "data", "idx": "degrees", "val": 7.5494698583390791}, {"col": "data", "idx": "distribution", "val": 15.017263204315379}, {"col": "data", "idx": "effect", "val": 8.7164798536336274}, {"col": "data", "idx": "equal", "val": 8.3066344338787648}, {"col": "data", "idx": "errors", "val": 8.4474743401718175}, {"col": "data", "idx": "event", "val": 9.5574034754179298}, {"col": "data", "idx": "false", "val": 8.3055540018599388}, {"col": "data", "idx": "freedom", "val": 8.6135476068830474}, {"col": "data", "idx": "given", "val": 8.7808762860169658}, {"col": "data", "idx": "greater", "val": 7.8752009477719156}, {"col": "data", "idx": "guess", "val": 21.526000027269436}, {"col": "data", "idx": "happen", "val": 8.2096697764392399}, {"col": "data", "idx": "hypothesis", "val": 101.14064292885094}, {"col": "data", "idx": "interval", "val": 12.973406304366724}, {"col": "data", "idx": "kind", "val": 7.3905238613547333}, {"col": "data", "idx": "large", "val": 9.8720281649366228}, {"col": "data", "idx": "likely", "val": 10.749971640541354}, {"col": "data", "idx": "low", "val": 10.78194842120983}, {"col": "data", "idx": "measures", "val": 9.0049880402648714}, {"col": "data", "idx": "models", "val": 10.670898044149144}, {"col": "data", "idx": "null", "val": 158.27218645614906}, {"col": "data", "idx": "people", "val": 9.596617328812}, {"col": "data", "idx": "positive", "val": 13.824908000668955}, {"col": "data", "idx": "prior", "val": 8.2457775517012273}, {"col": "data", "idx": "probability", "val": 9.1205033644753097}, {"col": "data", "idx": "questions", "val": 9.1538344896601487}, {"col": "data", "idx": "relationship", "val": 12.710254109497274}, {"col": "data", "idx": "residual", "val": 11.493970302422685}, {"col": "data", "idx": "significance", "val": 16.217976363410809}, {"col": "data", "idx": "slope", "val": 23.293428175593977}, {"col": "data", "idx": "standard", "val": 9.7895353656379154}, {"col": "data", "idx": "statistic", "val": 28.521895914890035}, {"col": "data", "idx": "statistics", "val": 19.512662100849475}, {"col": "data", "idx": "testing", "val": 15.886178327320316}, {"col": "data", "idx": "tricky", "val": 8.684117977681499}, {"col": "data", "idx": "true", "val": 8.1705856611441039}, {"col": "data", "idx": "unlikely", "val": 16.01865745757171}, {"col": "data", "idx": "value", "val": 31.171657560154454}, {"col": "data", "idx": "wording", "val": 11.00293400925443}, {"col": "data", "idx": "zero", "val": 18.221506563145773}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis18aa61c56d964cef86e3b5ca23f98e86"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #48:
# <div id="vis68a027538889482a873d265e28808e43"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "10", "val": 23.903876122925691}, {"col": "data", "idx": "12", "val": 10.775885891444394}, {"col": "data", "idx": "20", "val": 7.8527529584743769}, {"col": "data", "idx": "500", "val": 9.627274822421013}, {"col": "data", "idx": "behavior", "val": 9.6769850289670938}, {"col": "data", "idx": "book", "val": 11.28571771096197}, {"col": "data", "idx": "build", "val": 13.433159297467528}, {"col": "data", "idx": "col", "val": 9.3989029073927668}, {"col": "data", "idx": "column", "val": 58.546664299698357}, {"col": "data", "idx": "columns", "val": 34.106647457125469}, {"col": "data", "idx": "compute", "val": 15.902596727932817}, {"col": "data", "idx": "computed", "val": 9.1395374587898282}, {"col": "data", "idx": "correlation", "val": 22.057007537251121}, {"col": "data", "idx": "correlations", "val": 12.386997356117528}, {"col": "data", "idx": "covariance", "val": 70.045965767269607}, {"col": "data", "idx": "creating", "val": 11.740256607807471}, {"col": "data", "idx": "difference", "val": 9.483715809421227}, {"col": "data", "idx": "egin", "val": 12.673363437274451}, {"col": "data", "idx": "essentially", "val": 9.970501532773973}, {"col": "data", "idx": "factor", "val": 22.198945665300908}, {"col": "data", "idx": "fitted", "val": 8.5604129460439964}, {"col": "data", "idx": "fix", "val": 8.7255061805260734}, {"col": "data", "idx": "formula", "val": 14.342004492957827}, {"col": "data", "idx": "frame", "val": 14.964653008687712}, {"col": "data", "idx": "glmnet", "val": 11.951247867184035}, {"col": "data", "idx": "graph", "val": 9.3696171404773807}, {"col": "data", "idx": "independent", "val": 7.8392332281138923}, {"col": "data", "idx": "inside", "val": 14.343733038668807}, {"col": "data", "idx": "intercept", "val": 77.546734101260256}, {"col": "data", "idx": "levels", "val": 35.225864175544423}, {"col": "data", "idx": "matrix", "val": 142.77486276510066}, {"col": "data", "idx": "mu", "val": 13.438915252962655}, {"col": "data", "idx": "object", "val": 12.257912987570437}, {"col": "data", "idx": "remove", "val": 21.994976412271608}, {"col": "data", "idx": "response", "val": 7.771915574599392}, {"col": "data", "idx": "rnorm", "val": 8.8803624377338579}, {"col": "data", "idx": "row", "val": 16.8085148789973}, {"col": "data", "idx": "runs", "val": 17.961234042271496}, {"col": "data", "idx": "sd", "val": 10.204368373289475}, {"col": "data", "idx": "single", "val": 8.1901522328219034}, {"col": "data", "idx": "slope", "val": 12.747899621437947}, {"col": "data", "idx": "space", "val": 7.8646034280274044}, {"col": "data", "idx": "specified", "val": 7.9756549310115981}, {"col": "data", "idx": "team", "val": 8.8241103225913253}, {"col": "data", "idx": "variable", "val": 16.489002788650374}, {"col": "data", "idx": "variables", "val": 7.6126247677323065}, {"col": "data", "idx": "variance", "val": 14.930826188726176}, {"col": "data", "idx": "vectors", "val": 9.5427059388721389}, {"col": "data", "idx": "xi", "val": 14.635839629450933}, {"col": "data", "idx": "years", "val": 12.216442938691328}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vis68a027538889482a873d265e28808e43"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# Topic #49:
# <div id="vise4a1cc649bec4920a4de203d05dcf8ad"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "address", "val": 6.9702897395074777}, {"col": "data", "idx": "apply", "val": 9.7123983175197832}, {"col": "data", "idx": "assumptions", "val": 15.871882725324852}, {"col": "data", "idx": "bigger", "val": 13.80323204107164}, {"col": "data", "idx": "block", "val": 153.79849832878327}, {"col": "data", "idx": "blocks", "val": 22.692534016428993}, {"col": "data", "idx": "bootstrap", "val": 97.193311793796354}, {"col": "data", "idx": "bootstrapping", "val": 35.560383924973657}, {"col": "data", "idx": "code", "val": 9.3083859410943735}, {"col": "data", "idx": "day", "val": 15.63561836643888}, {"col": "data", "idx": "days", "val": 12.806655604244421}, {"col": "data", "idx": "depend", "val": 7.4915950674458003}, {"col": "data", "idx": "distributed", "val": 16.694301070696987}, {"col": "data", "idx": "distribution", "val": 10.572251055642655}, {"col": "data", "idx": "errors", "val": 40.133892226492307}, {"col": "data", "idx": "estimate", "val": 14.131524065900026}, {"col": "data", "idx": "estimates", "val": 7.7586137748567108}, {"col": "data", "idx": "factors", "val": 9.8860787733841846}, {"col": "data", "idx": "forum", "val": 16.306270648811211}, {"col": "data", "idx": "having", "val": 7.7258019215426854}, {"col": "data", "idx": "independent", "val": 19.417607161830986}, {"col": "data", "idx": "length", "val": 12.372600169610742}, {"col": "data", "idx": "location", "val": 7.2974349100200913}, {"col": "data", "idx": "lot", "val": 10.896860223253142}, {"col": "data", "idx": "march", "val": 18.588250962271612}, {"col": "data", "idx": "near", "val": 8.6485497015783857}, {"col": "data", "idx": "non", "val": 14.665851125441229}, {"col": "data", "idx": "observations", "val": 12.603340583189226}, {"col": "data", "idx": "options", "val": 7.9943573524951947}, {"col": "data", "idx": "order", "val": 7.6282954643082945}, {"col": "data", "idx": "ordinary", "val": 12.95745578069287}, {"col": "data", "idx": "people", "val": 10.298724452965249}, {"col": "data", "idx": "points", "val": 16.917741374820704}, {"col": "data", "idx": "regarding", "val": 8.1152070242106369}, {"col": "data", "idx": "regular", "val": 10.259615466034866}, {"col": "data", "idx": "sampling", "val": 9.044864602871943}, {"col": "data", "idx": "se", "val": 7.5325620674073193}, {"col": "data", "idx": "search", "val": 21.169529464435023}, {"col": "data", "idx": "seen", "val": 6.978933805378662}, {"col": "data", "idx": "series", "val": 70.321112229068376}, {"col": "data", "idx": "sim", "val": 8.4046828090580359}, {"col": "data", "idx": "solve", "val": 11.391042935192294}, {"col": "data", "idx": "standard", "val": 47.203489063944822}, {"col": "data", "idx": "std", "val": 13.241815077887301}, {"col": "data", "idx": "time", "val": 43.898117125546278}, {"col": "data", "idx": "tsboot", "val": 19.502633482834458}, {"col": "data", "idx": "uncorrelated", "val": 16.119048005505697}, {"col": "data", "idx": "user", "val": 8.3354037725784185}, {"col": "data", "idx": "welcome", "val": 8.3299423774773125}, {"col": "data", "idx": "williamchiu", "val": 11.006812304489458}]}], "height": 500, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": "auto", "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 960}, function(chart) {
#          chart({el: "#vise4a1cc649bec4920a4de203d05dcf8ad"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %%
#Write file to EXCEL for labeling each comment by hand
# import csv
# reload(sys)
# sys.setdefaultencoding("utf-8")

# myfile = csv.writer(open("grouped_comments.csv", 'wb'))
# for g in grouped_comments:
#     myfile.writerow([g])

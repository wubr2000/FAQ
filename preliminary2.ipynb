# %%
import pandas as pd
import numpy as np
from scipy import io
from scipy import sparse
import sys
import logging
import seaborn 
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex
from time import time

from sklearn import metrics
from sklearn.metrics.pairwise import linear_kernel,pairwise_distances
from sklearn.feature_extraction import text as txt
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer, HashingVectorizer
from sklearn import decomposition

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer
from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation

from optparse import OptionParser

import bs4 as bs4
import re, sys

from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from nltk.tokenize.regexp import WordPunctTokenizer
import nltk

import gensim
from gensim import corpora, similarities, models
from gensim import matutils

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
forum = pd.read_csv("/Users/wubr2000/Dropbox/Data Science Courses/Zipfian project Ideas/FAQ/FAQ/data/statsLearningForum4.csv", quoting = 2, header = 0, 
                    escapechar = "\\", encoding = "ISO-8859-1")

# %%
forum.columns = [c.replace("'","") for c in forum.columns]

# %%
pd.options.display.max_colwidth=110
forum.shape
# Out:
# (5816, 22)

# %%
# del forum["anon_screen_name"]
# del forum["at_position_list"]
# del forum["course_display_name"]

# %%
forum.head()
# Out:
#               forum_post_id             anon_screen_name           type  \
# 0  52d9c25f2ef29131c4000006  <anon_screen_name_redacted>  CommentThread
# 1  52ddd0df53cc4488d700000a  <anon_screen_name_redacted>        Comment
# 2  52dddba253cc4488d700000e  <anon_screen_name_redacted>        Comment
# 3  52dddfb1e37bb2b024000026  <anon_screen_name_redacted>        Comment
# 4  52dde3d5e37bb2b02400002a  <anon_screen_name_redacted>        Comment
#
#   anonymous anonymous_to_peers at_position_list  forum_int_id  \
# 0     False              False               []        236783
# 1     False              False               []        250919
# 2     False              False               []        185455
# 3     False              False               []         26725
# 4     False              False               []        185455
#
#                                                                                                             body  \
# 0  Welcome to the discussion forum! We are hoping this will be a useful place for us to discuss anything rela...
# 1                                         Thank you , Sir!\nIts great to have this Stat learning class from you.
# 2                                              Great to have online free textbook - here's to some "R" learning.
# 3                                                Will we be able to download the videos as in other edX courses?
# 4                                                   FYI this is not an edX course but a Stanford OpenEdX course.
#
#                          course_display_name           created_at  \
# 0  HumanitiesScience/StatLearning/Winter2014  2014-01-17 23:53:03
# 1  HumanitiesScience/StatLearning/Winter2014  2014-01-21 01:43:59
# 2  HumanitiesScience/StatLearning/Winter2014  2014-01-21 02:29:54
# 3  HumanitiesScience/StatLearning/Winter2014  2014-01-21 02:47:13
# 4  HumanitiesScience/StatLearning/Winter2014  2014-01-21 03:04:53
#
#                                                                                                            votes  \
# 0  {u'count': 75, u'point': 75, u'down_count': 0, u'up': [u'163860', u'14271', u'228806', u'206818', u'235912...
# 1  {u'count': 14, u'point': 14, u'down_count': 0, u'up': [u'206818', u'125457', u'217287', u'220410', u'23416...
# 2  {u'count': 10, u'point': 10, u'down_count': 0, u'up': [u'201036', u'164697', u'220410', u'215307', u'21187...
# 3  {u'count': 10, u'point': 10, u'down_count': 0, u'up': [u'99424', u'207466', u'220410', u'18216', u'248452'...
# 4                           {u'count': 0, u'point': 0, u'down_count': 0, u'up': [], u'down': [], u'up_count': 0}
#
#    count  down_count  up_count  \
# 0     75           0        75
# 1     14           0        14
# 2     10           0        10
# 3     10           0        10
# 4      0           0         0
#
#                                                                                                               up  \
# 0  ['163860', '14271', '228806', '206818', '235912', '244031', '164365', '20920', '123798', '182423', '231089...
# 1  ['206818', '125457', '217287', '220410', '234163', '207082', '206981', '195735', '212544', '215307', '2411...
# 2           ['201036', '164697', '220410', '215307', '211875', '265776', '264664', '271942', '173133', '184242']
# 3             ['99424', '207466', '220410', '18216', '248452', '125017', '192813', '195753', '194337', '231415']
# 4                                                                                                             []
#
#   down         comment_thread_id                 parent_id  \
# 0   []                      None                      None
# 1   []  52d9c25f2ef29131c4000006                      None
# 2   []  52d9c25f2ef29131c4000006                      None
# 3   []  52d9c25f2ef29131c4000006                      None
# 4   []  52d9c25f2ef29131c4000006  52dddfb1e37bb2b024000026
#
#                                parent_ids  \
# 0                                    None
# 1                                      []
# 2                                      []
# 3                                      []
# 4  [ObjectId('52dddfb1e37bb2b024000026')]
#
#                                                   sk
# 0                                               None ...
# 1                           52ddd0df53cc4488d700000a ...
# 2                           52dddba253cc4488d700000e ...
# 3                           52dddfb1e37bb2b024000026 ...
# 4  52dddfb1e37bb2b024000026-52dde3d5e37bb2b02400002a ...
#
# [5 rows x 22 columns]

# %% [markdown]
# ##Text Cleaning Functions

# %%
#Text Cleaning Functions
def mrclean(text):
    '''
    NAME
            mrclean
    SYNOPSIS
            Cleans incoming text
    DESCRIPTION
            Removes all untranslatable unicode
    '''
    c = ['\xe2','\x80','\x93','\xc2','\xa0','\n', '\r', '\u2019', '\n\n', '\x96', 
         'zipredac', 'phoneredac', 'nameRedac_anon_screen_name_redacted']  
    return re.sub('[%s]' % ''.join(c), '', text)

def soupText(eText):
    '''
    NAME
            soupText

    SYNOPSIS
            Removes all the HTML tags using BeautifulSoup

    DESCRIPTION
            Explicitly calls utf-8, replaces all double quotes with single and calls on helper function mrclean
    '''
    eText = str(eText.encode("utf-8").replace("'",'"') )
    soup = bs4.BeautifulSoup(eText)
    cleanText = soup.findAll(text=True)  #.get_text()
    return mrclean(''.join(cleanText))

# %% [markdown]
# ##Group all comments and associated questions together

# %%
#Concatenate all comments together that has the same "comment_thread_id" 
#- i.e. jam all the comments on one question together - this should be better for analysis
concat_comments = forum[forum.type=="Comment"].sort("comment_thread_id").groupby("comment_thread_id").body.sum()

grouped_comments=[]
for c in concat_comments:
    unicode(c)
    soupText(c)
    grouped_comments.append(c)

grouped_questions = []
for i in concat_comments.index:
    q = forum.body[forum.forum_post_id == i]
    grouped_questions.append(q.iloc[0])

#grouped_questions[:5]

# %%
grouped_comments[:5]
# Out:
# [u'Thank you for the course. I\'m taking it because it\'s interesting, and maybe I\'ll find ways to use it later. Last year, I downloaded and started reading ESL, but while I could conceptually understand the presentation, I could not do the exercises. Most of the math was too advanced for me as I\'ve tried to learn math on my own as a hobby. With lectures and a forum and the new ISL, I hope it will be enough for me keep up with this class, and I look forward to the challenge.Si... sobretodo en espa\xf1ol...It\'s  amazing lectures. I will enjoy it with my friends and classmates.Hola, vivo en Per\xfa, y el curso es muy interesante, espero que se publicite m\xe1s a pa\xedses latinoamericanos !Thank you sir for opening the course. looking forward to the next lectures.Great to have online free textbook - here\'s to some "R" learning.Excited to learn from the bright professors and their invaluable knowledge of statistical techniques, modeling, and analysis.Thanks I\'m so happy to be part of this course.Yep, India in particularHello there, my name is <nameRedac_<anon_screen_name_redacted>> <nameRedac_<anon_screen_name_redacted>>, <nameRedac_<anon_screen_name_redacted>>, from Caracas, Venezuela. I want to thank  all people behind this mooc too. Thanks you very much for your time and for all those resources you have made available for all us of  for free.Thanks for offering this course.  I\'m looking forward to this learning experience!I am also looking forward to this class. I am a Econ major at Cal state Fullerton so this class will come in handy later in my studies. I was especially attracted to the part about predicting market behaviors.Hi, Mr. Hastie and Mr. Tibshirani:\n\nThank You very much for this wonderful course. I was counting the days left for the beginning, finally here It is!.are you from asiaLooking forward to this course. I am excited and intend to follow the entire course schedule.Master\'s student Medical Informatics at the University of Amsterdam / Academic Medical Center (The Netherlands) present! I look forward to finishing this course.\n\n-<nameRedac_<anon_screen_name_redacted>>Hope to get full benefit of the course. Thanks.Thanks for offering this course and all the free resources. And many thanks for your efforts.Thank you , Sir! Its great to be here in Stat learning class. but the video lectures are not opening here in Pakistan. Can you please help?Very interesting course and quite good for understanding! Also it is a nice way to learn new things and to improve English skills as well!vedio lecture is not opening in pakistanIs there anyone interested in a greek study group?Will we be able to download the videos as in other edX courses?Its a great course indeed. Please suggest something relating to the video problem mentioned in above comments, as we are unable to open any of your videos here in Pakistan.Many Thanks for Professors and TA, which spend they valuable time on this course.\nLooking forward for this exciting course.Sure! Count me in\n???? ????I am so excited about this course!!!Both the sir i am very very very excited to learn this course from both of you. And i am a regular student of this course. I am very thankful to you for offering this course. I know i am going to learn a lot of things in the course. ThanksFYI this is not an edX course but a Stanford OpenEdX course.Is the email sent to remind me of this course every week?\nI did not receive any email about the information of this course.Thanks for putting together such a nice course for free. I am liking what i am seeing so far. All your efforts are greats appreciated!!!I am really excited about the course.\nI am a great fan of ESL so taking a course based on its contents taught by its authors is just, uah!!!\nThanks for the initiativeThanks a lot... this was a great experience of learning statisticsA big warm greeting. I\'m <nameRedac_<anon_screen_name_redacted>>, 32 yo programmer from Rome, Italy. I have completed several online courses offer ...
#  u'Videos are stored in YouTube. For instance Lecture 2.1 is:\n\nhttps://www.youtube.com/watch?v=WjyuiK5taS8\n\nAny videos downloader will let you download from YOuTube. Try for instance:\n\nhttps://addons.mozilla.org/en-US/firefox/addon/video-downloadhelper/\n\n6 million users.\n\nHope this helps,\n\nEWhy we cannot download them directly from page?That\'s my case too. Youtube is selective in our country and I fail to download the courses. I prefer URL to be put in the"Vedio download link"\n\nPeace!!!True..even we are not able to copy you-tube url for explicitly download sameMaybe you are in China. I think the browser named \'xskywalker\' may be help.  The Chrome with GoAgent is also available.  \nAnd of course I wish the videos were downloadable.Sorry, I meet the same problem as above classmates. We\'re not able to access Youtube resources. Could the administrators help us out? Thanks!JerryBut YouTube is not available for every country.Thanks it is really helpfulThanks, playlist is convenient. I assume these videos will stay on YouTube after course end?Youtube is blocked in some countries of the world. Please  put course videos on course web site so as to be accessible to more people.Duh... didn\'t see it under "Playlists"... was just looking at "Uploads".Thanks!I have a similar question. It appears that such an option is not available.I could download the videos at work but I cannot watch them there. I can watch them at home but I cannot download at home.YouTube is blocked from my country, if I cann\'t not get access to the lectures, I am afraid I have to stop now. If you are the instructor or TA, can you give me some clarification of the video download issue, thank you.I can\'t find these lectures on YouTube...\n\nThe link above from ErnestoArmijo does point to one lecture, but I surely can\'t find any of the others.\n\nCan anyone post a youtube link that points to any sort of list, etc. of the class lectures as a whole?  \n\nIt\'s a shame that the lectures aren\'t easily downloadable from OpenEDX.  I\'ve never known any other MOOC to not offer downloads of its lectures.I guess the complete list of videos are here https://www.youtube.com/channel/UC4OWDcPB1peiBXDfCSZ3h-w/videos?flow=grid&view=1Thank you',
#  u"pretty sure 50% overallWhat if I failed to pass one or two of the quizzes but got all others right?i.e in every section one needs 50% or overall at the end of the course cummulative scores should be atleast 50%..??As soon as you have answered the first quiz, you can go to the page Progress. According to this, you need to get 50% correct in order to pass, meaning (I suppose) to get a certificate.Are the quizes the only 'work' we turn in to get a certificate? Are the book exercises something we have the option of doing?",
#  u"Switched from R to Python. Problem with R is its too slow, good for quick analysis and prototyping on small training setsI am a big fan of Python. In my work, I am always using the Python with numpy, sklearn and other packages. This course I think, is more about application which we could choose different tools to realize our algorithm. Whichever tools you use may be Ok as long as you could solve your problem. Althoug it's not compulsory in my mind, it's quite worth to learning R. What's more, R is very easy to learn especially you have learn Python.I think that R is better for quick data analysis, but if you want implement some stat's algos for your system than Python would be better choice. :)",
#  u'I simply select, copy and pasteTry this - http://savefrom.netThis is only my 2nd online course ever, and I just got on board. I would like to do the same thing.Me too! Very useful for slow internet connections!Amazing! Thank you a lot Artib!']

# %% [markdown]
# ##Stopwords, Lemmatizer, and TfidfVectorizer

# %%
#Discussion forums specific stopwords
additional_stop_words = [
                         "zipredac","phoneredac","nameRedac_anon_screen_name_redacted", 
                         "anon_screen_name_redacted", "nameRedac_", "nameredac_"
                         "explanation", "helpful", "yes",
                         "agree","excellent","dear", "thanks", "congratulations", "great",
                         "ok", "cool", "idea", "guys",
                         "hello", "student", "sorry", "makes",
                         "sense", "nice", "meet", "yeah", "wow",
                         "hint", "post", "understand", "helped",
                         "www","http","https","org","web","en","wiki","wikipedia","youtube","edu","com","://",
                         "got"
                         ]

# %% [markdown]
# >Token-level analysis such as stemming, lemmatizing, compound splitting, filtering based on part-of-speech, etc. are not included in the scikit-learn codebase, but can be added by customizing either the tokenizer or the analyzer. Here’s a TfidfVectorizer with a tokenizer and lemmatizer using NLTK:

# %%
class LemmaTokenizer(object):
    '''Scikit learn requires the tokenizer to be a callable class if custom made'''
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]

# %% [markdown]
# > Adjusting for "outliers"
# - Adjusting `min_df` and `max_df` affects the results ALOT!!! They will essentially get rid of "OUTLIERS". Tell function to ignore these words because they occurred in either too many (`max_df`) or in too few (`min_df`) documents.
#
# - Setting `min_df`= X means that calculation will include only words that appear in at least X documents. This will throw out many really weird, idiosyncratic, or made-up words that appear rarely and that are not germane to the comment.
#
# - Setting `max_df` = Y means that calculation will exclude words that appear over and over again in every documents. For example, in these forum discussions, there are alot of "thanks", "good", "agree","helpful","helps", "thanks alot" type of words that will throw off calculation. Again, they are not germane to the discussion but will throw off the calcuation. `max_df` is not that relevant if `sublinear_tf` is also turned on since they both do similar things.
#
# - The `sublinear_tf` parameter, when True, transforms the term frequency calculation to: tf = 1 + log(tf).
#
# - This transformation, as the name implies, is sublinear, which in practice lessens the effect of frequently occurring words. Since this calculation is only for the term frequency—and thus only affects the numerator of the tf-idf calculation—having a sublinear transform is a good way to reduce the effect of very common words.
#
# - Bigrams and higher tend to make the results worse.
#
# - NLTK WordNetLemmatizer really screwed things up...

# %% [markdown]
# >Need to throw away URLs in bag of words

# %%
n_samples = len(grouped_comments)
n_features = 10000

tfidf = TfidfVectorizer(min_df = 10, 
                         #max_df =.99,
                         max_features = n_features, 
                         stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words),
                         #tokenizer = LemmaTokenizer(),
                         sublinear_tf=True,
                         ngram_range=(1,2),
                         )

counts = tfidf.fit_transform(grouped_comments[:n_samples])
X = TfidfTransformer().fit_transform(counts)

print X.shape
print len(grouped_comments)
print type(X)
X_transformed = X.T
print X_transformed.shape
# Out:
# (1074, 1587)
# 1074
# <class 'scipy.sparse.csr.csr_matrix'>
# (1587, 1074)

# %%
#Saving the sparse matrix in a file
io.savemat('X.mat', {'M' : X}, oned_as='column')
io.savemat('X_transformed.mat', {'M' : X_transformed}, oned_as='column')

# %%
#Saving the bag of words in a file
bag_of_words = tfidf.get_feature_names()
outfile = open('vocab.txt', 'w')
outfile.write("\n".join(bag_of_words))

# %% [markdown]
# ##K Means Clustering

# %%
#K-means clustering analysis

# km = KMeans(n_clusters=30, init='k-means++', max_iter=100, n_init=1,
#                 verbose=True)
# km_fit = km.fit_transform(X)
# km_fit.shape

#K-means with Sillouhette Coefficient
starting_clusters = 3
silhouette = []
for n in range(starting_clusters,31):
    kmeans_model = KMeans(n_clusters=n, init='k-means++', max_iter=100, random_state=1).fit(X)
    labels = kmeans_model.labels_
    silhouette.append(metrics.silhouette_score(X, labels, metric='euclidean'))
# Out:
# /Users/wubr2000/anaconda/lib/python2.7/site-packages/numpy/core/_methods.py:55: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
top_clusters = np.argsort(silhouette)[:-3:-1]+3
print "top two optimal number of clusters to use based on k-means (using silhouette coefficient): " 
print top_clusters
# Out:
# top two optimal number of clusters to use based on k-means (using silhouette coefficient):
# [20 28]

# %% [markdown]
# From Scikit-learn: If the ground truth labels are not known, evaluation must be performed using the model itself. The Silhouette Coefficient (sklearn.metrics.silhouette_score) is an example of such an evaluation, where a higher Silhouette Coefficient score relates to a model with better defined clusters. The Silhouette Coefficient is defined for each sample and is composed of two scores:
#
# a: The mean distance between a sample and all other points in the same class.
#
# b: The mean distance between a sample and all other points in the next nearest cluster.
#
# The Silhoeutte Coefficients for a single sample is then given as:
# s = (b - a)/max(a, b)
#
# The score is bounded between -1 for incorrect clustering and +1 for highly dense clustering. Scores around zero indicate overlapping clusters.
#
# The score is higher when clusters are dense and well separated, which relates to a standard concept of a cluster.

# %%
opt_k = 20

y_true = KMeans(n_clusters=n, init='k-means++', max_iter=100, random_state=1).fit_predict(X)

y_true[:200]
# Out:
# array([ 2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2, 15,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  3,  2,  2, 15, 15, 15,  2,  2,  2,  2, 15, 28,  2,
#         2,  2,  2,  2,  2,  2,  2,  3,  2,  1, 13,  2,  2,  2,  2,  2,  3,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         3,  2,  2,  2,  2,  2,  3, 15,  2,  2, 20,  2, 15,  2, 22,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2, 13, 28,  2,  2,
#         2,  4,  2,  2,  1,  2, 11,  2,  2,  2, 20,  2,  2,  2, 20,  2,  2,
#         2, 13,  2, 28,  2,  2,  2,  2,  2, 28,  2, 28,  2,  3,  3,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,
#         2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2,  2, 20,  2,  2,  3,  2,
#         2,  2,  2,  2,  2,  2, 15,  2,  2,  2,  2,  2,  2], dtype=int32)

# %% [markdown]
# > K-mean doesn't work. It's showing that most of the comments belong to 1 group (prob like 90%). This cannot be used for benchmark for topic modeling. This is even if I use only 4 or 5 clusters to begin with.

# %% [markdown]
# Below is from a [Stackoverflow article](http://stackoverflow.com/questions/12497252/how-can-i-cluster-document-using-kmean-flann-with-python):
#
# There is one big problem here: K-means is designed for Euclidean distance.
#
# The key problem is the mean function. The mean will reduce variance for Euclidean distance, but it might not do so for a different distance function. So in the worst case, k-means will no longer converge, but run in an infinite loop (although most implementations support stopping at a maximum number of iterations).
#
# Furthermore, the mean is not very sensible for sparse data, and text vectors tend to be very sparse. Roughly speaking the problem is that the mean of a large number of documents will no longer look like a real document, and this way become dissimilar to any real document, and more similar to other mean vectors. So the results to some extend degenerate.
#
# For text vectors, you probably will want to use a different distance function such as cosine similarity.
#
# And of course you first need to compute number vectors. For example by using relative term frequencies, normalizing them via TF-IDF.
#
# There is a variation of the k-means idea known as k-medoids. It can work with arbitrary distance functions, and it avoids the whole "mean" thing by using the real document that is most central to the cluster (the "medoid"). But the known algorithms for this are much slower than k-means.

# %% [markdown]
# ##K-Medoids Clustering
# > Good for very sparse matrix and also can use other distance measures
#
# > Rather than using the mean (which is usually not a real datapoint), K-medoids uses a particular datapoint as the centroid. This makes K-medoids less sensitive to outliers. And in case of text, can give an actual "representative" document of a topic.
#
# Valid values for metric are:
# from scikit-learn: [‘euclidean’, ‘l2’, ‘l1’, ‘manhattan’, ‘cityblock’]
# from scipy.spatial.distance: [‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘correlation’, ‘cosine’, ‘dice’, ‘hamming’, ‘jaccard’, ‘kulsinski’, ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’] See the documentation for scipy.spatial.distance for details on these metrics.

# %%
#K-Medoid
#Can pass in other distances for K-Medoids
import Pycluster
from Pycluster import kmedoids

distances = pairwise_distances(X, metric='euclidean', n_jobs=1)
nb_clusters = 20
clusterid, error, nfound = Pycluster.kmedoids(distances, nclusters= nb_clusters, npass=100)

# %%
#Look at the actual comments that are central to each cluster:
medoids = list(set(clusterid))

for m in medoids:
    print "------------------------"
    print "medoid ", m, ":", grouped_questions[m]
# Out:
# ------------------------
# medoid  129 : Hi! I posted that I have issues loading the R sessions even though I have R downloaded on my computer and have no idea how to fix them. Can someone please help? I really do not want to fall behind and really want to learn all the material in the course on a timely basis. I do not understand why I can not open up the R sessions even though I have R???
# ------------------------
# medoid  34 : Thanks a lot for the interview! I hope there are going to be a lot more interviews of other people who shaped our nowadays view of statistical learning!
# ------------------------
# medoid  483 : * SAS has recently introduced the experimental "modelaverage" statement to the GLMSELECT procedure.  setting the options 'selection=none' and 'sampling=urs(percent=100)' appears to allow for bootstrap estimates of the parameters.  i've recreated the R code from the LAB using SAS below;
#
#
# * > set.seed(1)
#   > boot.fn(Auto,sample(392,392,replace=T));
# * regression using single bootstrap;
# proc glmselect data=Auto seed=1;
#    title2 'Auto Data: Regression Using Single Bootstrap (1)';
#    model mpg = horsepower / selection=none;  * keep all variables in the model;
#    modelaverage nsamples=1 sampling=urs(percent=100);  * experimental, 'urs' indicates w/ replacement;
# run;
#
# *  > boot.fn(Auto,sample(392,392,replace=T));
# proc glmselect data=Auto seed=2;
#    title2 'Auto Data: Regression Using Single Bootstrap (2)';
#    model mpg = horsepower / selection=none;  * keep all variables in the model;
#    modelaverage nsamples=1 sampling=urs(percent=100);  * experimental, 'urs' indicates w/ replacement;
# run;
#
# * regression using 1000 bootstraps;
# proc glmselect data=Auto seed=3;
#    title2 'Auto Data: Regression Using 1000 Bootstraps';
#    model mpg = horsepower / selection=none;  * keep all variables in the model;
#    modelaverage nsamples=1000 sampling=urs(percent=100);  * experimental, 'urs' indicates w/ replacement;
# run;
#
# * regression using 1000 bootstraps (quadratic model);
# proc glmselect data=Auto seed=3;
#    title2 'Auto Data: Regression Using 1000 Bootstraps (Quadratic Model)';
#    model mpg = horsepower horsepowersq / selection=none;  * keep all variables in the model;
#    modelaverage nsamples=1000 sampling=urs(percent=100);  * experimental, 'urs' indicates w/ replacement;
# run;
#
# quit;
# ------------------------
# medoid  198 : How do you unenroll from this course?
# ------------------------
# medoid  38 : ch2.R references Auto.csv, is this file available for download?
# ------------------------
# medoid  785 : Hello everyone,
# I am pretty new to online lectures.  There's a lot material:
# 1) videos (passive learning)
# 2) lecture pdf (pretty straight forward)
# 4) reading the text (I tend to forget that, do you do it?)
# 3) quiz (can be tricky)
# 4) R code (waiting till the end)
# 5) book exercise (if you have time)
#
# Those are all I can think of.  What is the most effective way to do them?  What order do you recommend doing them in?  i.e. quiz right after lecture?  Save them like a text at the end?
#
# I usually do the quiz after watching the video; saving the R codes at the very end; referring to the book only if I have to.  How are you studying this?
# ------------------------
# medoid  9 : Welcome to join us!
# ------------------------
# medoid  139 : Hello everybody,
# I believe the third question in 3.1.2 is wrong.
#
# It only says that I construct a confidence interval, without specifing the confidence level.
# It implicitly assumes that interval is 95% but it is possible to use differente levels.
#
# Thank you for your attention.
# <nameRedac_<anon_screen_name_redacted>>
# ------------------------
# medoid  269 : I've had problems with a number of quiz questions due to poor and ambiguous wording. Some involve things that are not covered in the videos, and at least one involves something not even covered in the book! Scanning the forums shows that other people are having similar issues. Were these questions tested before the course started, or are we effectively the testers?
# ------------------------
# medoid  88 : Merci!
# Viele Grüße!
# <nameRedac_<anon_screen_name_redacted>>
# ------------------------
# medoid  51 : Test Set MSE can be decomposed into Bias, Variance, and Irreducible Error. "Bias" sounds worse than "Variance". Are they equally bad or is one more bad than the other?
# ------------------------
# medoid  372 : I am using Firefox (not going to go into what all add-ons I have.  The coefficient for model element beta_0 was displayed as "  6" instead of "-6".  After getting it wrong with different numbers of significant digits specified, I reloaded.  One can see the codes briefly before they are converted to math symbology and it clearly says "-6" in gray before changing to the math font.
#
# Just in case any others are having the same issue....
# ------------------------
# medoid  723 : I am completely lost with this one. I have read the notes and the book and can´t figure it out. Can anyone help?
# ------------------------
# medoid  759 : I notice a lot of emphasis on this method (validation set) in chapter 8, used I assume to test we have the correct analysis. But, I assume after we did this we would in practice rerun it using the whole data-set to ensure our model was the best it could be?
# ------------------------
# medoid  568 : Why SE(a) is roughly the same as SD(a)?
#
# pls help out. Thanks!
# ------------------------
# medoid  354 : From the text book:
#
# "This is an important distinction for a credit card company
# that is trying to determine to whom they should offer credit. A student is
# riskier than a non-student if no information about the students credit card
# balance is available. However, that student is less risky than a non-student
# with the same credit card balance!"
#
# I agree with the explanation leading to this suggestion for credit card companies. I also partially agree with the latter part of the suggestion "... that student is less risky than a non-student with the same credit card balance", but I think the first part is problematic. If we think that there is confounding in the simple regression model (sorry I could not find a better wording but I hope this gets the main message), then should we not trust it at all?
#
# Take another example, let Y = lung cancer status (yes,no), X1 = smoking status and X2 = age. Let assume that elderly people are more likely to have lung cancer.
#
# Now in the model Y ~ X1 we find that smoking has a protective effect but later discover that the non-smoking group has on average older people than the smoking one. Then should we suggest that if there is no information on age (I know this is silly, but just for this argument) should we conclude that a smoker has lower risk of lung cancer?
#
# I would like to thank in advance any reply and discussion; and my apologies for the poor English.
# ------------------------
# medoid  283 : I noticed that in the video, around the 4:19 mark - as well as page 8 in the slides - the formula for Maximum Likelihood contains an error on the formulation of the ML function. It says
#
# eta)$
#
# which should of course be
#
# eta_1)$
#
# It is correct in the book (fortunately).
# ------------------------
# medoid  817 : I had troubles understanding which assumptions are made for and what is calculated as std error in predict. I am posting my investigation so far, I would appreciate some ideas, in particular how to apply the bootstrap to calculate the std error (Would it be as straightforward as sampling from the $X_i$ and calculating the std errors between the predicted $hat{Y_i}$ and the exact $Y_i$?)
#
# **My reasoning**
#
# - predict output corresponds to a new $X_i$ value, for which there is no corresponding Y, so predict$se.fit can not be the std error of the prediction itself. In other words, as there is no actual $Y_i$, it can not be the standard error calculated from the actual $Y_i$ and the predicted $hat{Y_i}$
#
# - digging up into the R code for predict(), se is calculated according to the formula (8.04) in Elements of Statistical Learning (page 2<zipRedac>4). However, the formula is not justified
#
# - The first answer to a question [1] in stackexchange clarifies the reasoning behind the formula:
#
#     >The prediction is just a linear combination of the estimated coefficients. The coefficients are asymptotically normal so a linear combination of those coefficients will be asymptotically normal as well. So if we can obtain the covariance matrix for the parameter estimates we can obtain the standard error for a linear combination of those estimates easily. If I denote the covariance matrix as $Sigma$ and write the coefficients for my linear combination in a vector as $C$ then the standard error is just $sqrt{C' Sigma C}$
#
# And it is indeed calculated that way by predict():
#
#     > library(MASS)
#     >
#     > library(ISLR)
#     >
#     > fit1=lm(medv~lstat,data=Boston)
#     > predict(fit1,data.frame(lstat=c(4.98)),se.fit=TRUE)$se.fit
#     [1] 0.<phoneRedac>
#     > sqrt(t(c(1, 4.98)) %*% vcov(fit1) %*% c(1, 4.98) )
#               [,1]
#     [1,] 0.<phoneRedac>
#     >
#
# - Finally, a page from UCLA [2] offers a very clear explanation of what's behind this procedure: the delta method approximation
#
# **Conclusions**
#
# - predict$se.fit calculates the (generalized?) std error, understood as the square root of the estimated error variance. This is very different from the std errors calculated for the coefficients, that are result of comparing actual and predicted values.
#
# - predict$se.fit assumes that the distribution is well-behaved (or even normal) for which the delta method is a valid approximation. A fat tailed distribution would probably give quite wrong se values.
#
# - Bootstrap or similar co
# ------------------------
# medoid  587 : We thought Dr. Whitten did an incredible job of explaining the material -- it was so clear, emphasizing the concepts and utility of different techniques without getting lost in explanations of the math. We would love to have her back more!
# ------------------------
# medoid  805 : The video quality of .mov file available for download through download link is quite poor (slide text shown in the video are often blur).
#
# Additionally since youtube in our country is blocked so it is not possible to view the course video directly.
#
# It would be great help if someone can list down all the youtube video url for each lecture. For example the video url for lecture (Ch5-Resampling in R) is
#
#    https://www.youtube.com/watch?feature=player_embedded&v=YVSmsWoBKnA
#
# Once this url is available, i can then download the video using www.clipconverter.cc

# %% [markdown]
# ##Non-Negative Matrix Factorization

# %%
#NMF for grouped comments
n_topics = opt_k
n_top_words = 15

print("size of corpus: {}".format(len(grouped_comments)))

t0 = time()

# Fit the NMF model
print("Fitting the NMF model on with n_samples=%d and n_features=%d..."
      % (n_samples, X.shape[1]))
nmf = decomposition.NMF(n_components=n_topics).fit(X)
print("done in %0.3fs." % (time() - t0))

# Inverse the vectorizer vocabulary to be able
feature_names = tfidf.get_feature_names()

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d:" % topic_idx)
    print(" ".join( [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]] ))
    print
# Out:
# size of corpus: 1074
# Fitting the NMF model on with n_samples=1074 and n_features=1587...
# done in 22.109s.
# Topic #0:
# interval confidence confidence interval 95 intervals parameter confidence intervals null hypothesis null hypothesis true contain value probability distribution
#
# Topic #1:
# humanitiesscience winter2 winter2 14 courses humanitiesscience stanford courses discussion forum forum humanitiesscience statlearning threads class stanford statlearning i4x i4x humanitiesscience forum i4x 14
#
# Topic #2:
# install install packages packages islr packages islr library package library islr rstudio version islr package islr library command session installed
#
# Topic #3:
# course learning hastie tibshirani prof enjoyed statistical learning statistical books thank machine learning machine thank course book professors
#
# Topic #4:
# videos download watch video download videos firefox download video mp4 url right click hd copy downloading format available
#
# Topic #5:
# image enter image image description edx amazonaws s3 amazonaws uploads s3 edx west west west uploads uploads s3 enter description description edx
#
# Topic #6:
# tsboot boot xy index function coef sim fixed sim x1 x2 x1 x2 lm x1 block function data blocks
#
# Topic #7:
# cran project package cran project packages project caret packages index html pdf papers covariance paper installed try
#
# Topic #8:
# volume cube dimensions dimension boundary hypercube square region length 50 unit distance area dimensional points
#
# Topic #9:
# bcf usc bcf usc gareth usc gareth gareth isl isl isl data csv islr textbook credit website read csv html
#
# Topic #10:
# automatic appears ols logit lda past posting grading ch resampling allow getting answers finish things
#
# Topic #11:
# cv validation cross validation cross fold test cv error estimate test fold cv best best model training estimate test set test error
#
# Topic #12:
# data frame frame predict pred lm matrix dat rnorm pca train fit lm data data rep 50
#
# Topic #13:
# chrome browser fine mac screen firefox clicking video tried works button windows using version worked
#
# Topic #14:
# glmnet lambda alpha lasso ridge plot ridge regression family regularization cv coefficients increases solved net installed
#
# Topic #15:
# lecture slides slides pdf lecture 30 page link hd chapter downloaded numbers slide class stanford humanitiesscience statlearning statlearning
#
# Topic #16:
# elemstatlearn tibs stanford tibs tibs elemstatlearn statweb statweb stanford stanford esl elements statistical elements statistical learning 2nd statistical pdf learning
#
# Topic #17:
# eta_1 eta_0 epsilon eta_0 eta_1 x_1 hat x_2 eta_2 mathrm log eta odds hat eta frac egin
#
# Topic #18:
# logistic logistic regression regression linear regression linear discriminant classification models discriminant analysis regression model glm logit multivariate gaussian watch
#
# Topic #19:
# bootstrap samples time series sample series size block data points bootstrap sample bootstrap samples data point block bootstrap points standard sample size
#
# Topic #20:
# base log natural formula r2 answer correct consistent correct answer used r1 10 stats wrong accepted
#
# Topic #21:
# trees tree number split adding long unfortunately forest random kernel red classification approach reply staff
#
# Topic #22:
# submit quiz progress button quizzes video click icon certificate accomplishment 50 clicking questions bar march
#
# Topic #23:
# sales tv advertising units typo interaction 39 37 impact 1000 figure increase slide round main
#
# Topic #24:
# bias variance high bias variance var low flexible high variance sum irreducible irreducible error error tradeoff variance tradeoff rate
#
# Topic #25:
# solutions github manual nameredac_ official stat learning cheers stat hi community aware learning exercises working based
#
# Topic #26:
# predictors variable variables interaction x1 x2 correlated predictor dummy model effect relationship levels interactions x3
#
# Topic #27:
# file rdata directory load open csv load rdata workspace working directory rstudio loaded files auto editor save

# %%
#Getting the W and H for NMF model where X = dot(W , H)
W = nmf.fit_transform(X)
H = nmf.components_

# %%
#Test how accurate model is compared to truth from K-mean:

from sklearn.metrics import accuracy_score

y_pred_nmf = argmax(W, axis=1)

#accuracy_score(y_true, y_pred_nmf)

# %%
for topic_idx, topic in enumerate(nmf.components_):

    words = [feature_names[i] for i in topic.argsort()[:-(n_top_words):-1]]
    scores = [topic[i] for i in topic.argsort()[:-(n_top_words):-1]]

    dicta = {word: score for score, word in zip(scores, words)}

    s=pd.Series(dicta)
    plt.figure()
    plt.title("Topic #%d:" % topic_idx)
    s.plot(kind='bar');
# Out:
# /Users/wubr2000/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:412: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_num_figures`).
#   max_open_warning, RuntimeWarning)

# %%
topics_dicts = []

for i in xrange(n_topics):
    # n_top_words of keys and values
    keys, values = zip(*sorted(zip(feature_names, H[i]), key = lambda x: x[1])[:-n_top_words:-1])
    val_arr = np.array(values)
    norms = val_arr / np.sum(val_arr)
    #normalize = lambda x: int(x / (max(counter.values()) - min(counter.values())) * 90 + 10)
    topics_dicts.append(dict(zip(keys, np.rint(norms* 300))))

topics_dicts
# Out:
# [{u'best': 16.0,
#   u'best model': 16.0,
#   u'cross': 26.0,
#   u'cross validation': 27.0,
#   u'cv': 40.0,
#   u'cv error': 18.0,
#   u'estimate': 15.0,
#   u'estimate test': 17.0,
#   u'fold': 25.0,
#   u'fold cv': 17.0,
#   u'test': 21.0,
#   u'test set': 15.0,
#   u'training': 16.0,
#   u'validation': 31.0},
#  {u'class stanford': 20.0,
#   u'courses humanitiesscience': 21.0,
#   u'discussion forum': 20.0,
#   u'forum': 20.0,
#   u'forum i4x': 19.0,
#   u'humanitiesscience': 31.0,
#   u'humanitiesscience statlearning': 20.0,
#   u'i4x': 19.0,
#   u'i4x humanitiesscience': 19.0,
#   u'stanford courses': 21.0,
#   u'statlearning': 20.0,
#   u'threads': 20.0,
#   u'winter2': 26.0,
#   u'winter2 14': 24.0},
#  {u'available': 10.0,
#   u'copy': 12.0,
#   u'download': 43.0,
#   u'download video': 19.0,
#   u'download videos': 25.0,
#   u'downloading': 11.0,
#   u'firefox': 22.0,
#   u'hd': 12.0,
#   u'mp4': 16.0,
#   u'right click': 12.0,
#   u'url': 15.0,
#   u'video': 26.0,
#   u'videos': 49.0,
#   u'watch': 28.0},
#  {u'auto': 14.0,
#   u'csv': 19.0,
#   u'directory': 30.0,
#   u'editor': 13.0,
#   u'file': 42.0,
#   u'files': 14.0,
#   u'load': 28.0,
#   u'load rdata': 17.0,
#   u'loaded': 15.0,
#   u'open': 22.0,
#   u'rdata': 32.0,
#   u'rstudio': 18.0,
#   u'working directory': 17.0,
#   u'workspace': 18.0},
#  {u'2nd': 11.0,
#   u'elements': 12.0,
#   u'elements statistical': 13.0,
#   u'elemstatlearn': 38.0,
#   u'esl': 13.0,
#   u'pdf': 7.0,
#   u'stanford': 14.0,
#   u'stanford tibs': 36.0,
#   u'statistical': 9.0,
#   u'statistical learning': 11.0,
#   u'statweb': 33.0,
#   u'statweb stanford': 33.0,
#   u'tibs': 36.0,
#   u'tibs elemstatlearn': 35.0},
#  {u'book': 17.0,
#   u'books': 20.0,
#   u'course': 33.0,
#   u'enjoyed': 20.0,
#   u'hastie': 23.0,
#   u'learning': 28.0,
#   u'machine': 18.0,
#   u'machine learning': 19.0,
#   u'prof': 21.0,
#   u'statistical': 20.0,
#   u'statistical learning': 21.0,
#   u'thank': 19.0,
#   u'thank course': 17.0,
#   u'tibshirani': 23.0},
#  {u'block': 20.0,
#   u'block bootstrap': 17.0,
#   u'bootstrap': 36.0,
#   u'bootstrap sample': 19.0,
#   u'bootstrap samples': 18.0,
#   u'data point': 17.0,
#   u'data points': 21.0,
#   u'points': 17.0,
#   u'sample': 24.0,
#   u'samples': 29.0,
#   u'series': 20.0,
#   u'size': 21.0,
#   u'standard': 17.0,
#   u'time series': 23.0},
#  {u'bcf': 33.0,
#   u'bcf usc': 33.0,
#   u'credit': 9.0,
#   u'csv': 15.0,
#   u'gareth': 32.0,
#   u'gareth isl': 32.0,
#   u'isl': 28.0,
#   u'isl data': 18.0,
#   u'islr': 11.0,
#   u'read csv': 7.0,
#   u'textbook': 10.0,
#   u'usc': 33.0,
#   u'usc gareth': 32.0,
#   u'website': 8.0},
#  {u'1000': 11.0,
#   u'block': 15.0,
#   u'blocks': 14.0,
#   u'boot': 48.0,
#   u'bootstrap': 12.0,
#   u'coef': 17.0,
#   u'function': 20.0,
#   u'function data': 13.0,
#   u'index': 23.0,
#   u'lm': 11.0,
#   u'sim': 16.0,
#   u'sim fixed': 18.0,
#   u'tsboot': 64.0,
#   u'xy': 18.0},
#  {u'alpha': 38.0,
#   u'coefficients': 9.0,
#   u'cv': 10.0,
#   u'family': 11.0,
#   u'glm': 9.0,
#   u'glmnet': 67.0,
#   u'increases': 9.0,
#   u'lambda': 42.0,
#   u'lasso': 37.0,
#   u'net': 9.0,
#   u'plot': 12.0,
#   u'regularization': 10.0,
#   u'ridge': 26.0,
#   u'ridge regression': 11.0},
#  {u'command': 7.0,
#   u'install': 50.0,
#   u'install packages': 46.0,
#   u'islr': 29.0,
#   u'islr library': 8.0,
#   u'islr package': 8.0,
#   u'library': 22.0,
#   u'library islr': 17.0,
#   u'package': 18.0,
#   u'packages': 38.0,
#   u'packages islr': 28.0,
#   u'rstudio': 10.0,
#   u'session': 7.0,
#   u'version': 10.0},
#  {u'degree': 17.0,
#   u'degrees': 17.0,
#   u'degrees freedom': 18.0,
#   u'df': 27.0,
#   u'fitted values': 18.0,
#   u'freedom': 18.0,
#   u'lm': 20.0,
#   u'poly': 36.0,
#   u'polynomial': 20.0,
#   u'polynomials': 20.0,
#   u'raw': 17.0,
#   u'reg': 29.0,
#   u'spline': 22.0,
#   u'splines': 22.0},
#  {u'allow': 4.0,
#   u'answers': 3.0,
#   u'appears': 101.0,
#   u'automatic': 138.0,
#   u'ch': 5.0,
#   u'getting': 3.0,
#   u'grading': 6.0,
#   u'lda': 6.0,
#   u'logit': 7.0,
#   u'ols': 7.0,
#   u'past': 6.0,
#   u'posting': 6.0,
#   u'resampling': 4.0,
#   u'things': 3.0},
#  {u'answer': 9.0,
#   u'attempts': 9.0,
#   u'bar': 10.0,
#   u'button': 50.0,
#   u'click': 29.0,
#   u'clicking': 19.0,
#   u'icon': 24.0,
#   u'quiz': 27.0,
#   u'quizzes': 19.0,
#   u'right': 11.0,
#   u'save': 10.0,
#   u'screen': 13.0,
#   u'submit': 43.0,
#   u'video': 27.0},
#  {u'classification': 20.0,
#   u'discriminant': 20.0,
#   u'discriminant analysis': 13.0,
#   u'gaussian': 9.0,
#   u'glm': 10.0,
#   u'linear': 24.0,
#   u'linear regression': 28.0,
#   u'logistic': 45.0,
#   u'logistic regression': 42.0,
#   u'logit': 10.0,
#   u'models': 19.0,
#   u'multivariate': 11.0,
#   u'regression': 37.0,
#   u'regression model': 11.0},
#  {u'30': 18.0,
#   u'chapter': 10.0,
#   u'class stanford': 7.0,
#   u'downloaded': 9.0,
#   u'hd': 10.0,
#   u'humanitiesscience statlearning': 7.0,
#   u'lecture': 37.0,
#   u'lecture slides': 63.0,
#   u'link': 12.0,
#   u'numbers': 8.0,
#   u'page': 18.0,
#   u'pdf': 37.0,
#   u'slide': 8.0,
#   u'slides': 56.0},
#  {u'aware': 15.0,
#   u'cheers': 18.0,
#   u'community': 17.0,
#   u'exercises': 11.0,
#   u'github': 33.0,
#   u'hi': 16.0,
#   u'learning': 11.0,
#   u'manual': 31.0,
#   u'nameredac_': 30.0,
#   u'official': 26.0,
#   u'solutions': 42.0,
#   u'stat': 18.0,
#   u'stat learning': 22.0,
#   u'working': 9.0},
#  {u'browser': 43.0,
#   u'chrome': 75.0,
#   u'clicking': 12.0,
#   u'fine': 26.0,
#   u'firefox': 21.0,
#   u'mac': 25.0,
#   u'screen': 16.0,
#   u'tried': 15.0,
#   u'using': 12.0,
#   u'version': 11.0,
#   u'video': 10.0,
#   u'volume': 10.0,
#   u'worked': 11.0,
#   u'works': 13.0},
#  {u'amazonaws': 22.0,
#   u'description': 19.0,
#   u'edx': 22.0,
#   u'edx west': 22.0,
#   u'enter': 19.0,
#   u'enter image': 22.0,
#   u'image': 23.0,
#   u'image description': 22.0,
#   u's3': 21.0,
#   u's3 amazonaws': 22.0,
#   u'uploads': 22.0,
#   u'uploads s3': 22.0,
#   u'west': 22.0,
#   u'west uploads': 22.0},
#  {u'10': 11.0,
#   u'answer': 16.0,
#   u'base': 73.0,
#   u'consistent': 12.0,
#   u'correct': 15.0,
#   u'correct answer': 11.0,
#   u'formula': 20.0,
#   u'log': 58.0,
#   u'natural': 26.0,
#   u'r1': 10.0,
#   u'r2': 20.0,
#   u'stats': 9.0,
#   u'used': 10.0,
#   u'wrong': 9.0},
#  {u'average': 13.0,
#   u'bias': 41.0,
#   u'bias variance': 17.0,
#   u'error': 12.0,
#   u'flexible': 15.0,
#   u'high': 21.0,
#   u'high variance': 17.0,
#   u'low': 17.0,
#   u'random': 15.0,
#   u'rate': 13.0,
#   u'tree': 33.0,
#   u'trees': 35.0,
#   u'var': 15.0,
#   u'variance': 38.0},
#  {u'egin': 10.0,
#   u'epsilon': 34.0,
#   u'eta': 11.0,
#   u'eta_0': 36.0,
#   u'eta_0 eta_1': 31.0,
#   u'eta_1': 37.0,
#   u'eta_2': 20.0,
#   u'frac': 9.0,
#   u'hat': 23.0,
#   u'log': 14.0,
#   u'mathrm': 14.0,
#   u'odds': 11.0,
#   u'x_1': 27.0,
#   u'x_2': 23.0},
#  {u'50': 11.0,
#   u'area': 11.0,
#   u'boundary': 26.0,
#   u'cube': 39.0,
#   u'dimension': 31.0,
#   u'dimensional': 11.0,
#   u'dimensions': 31.0,
#   u'distance': 11.0,
#   u'hypercube': 25.0,
#   u'length': 14.0,
#   u'region': 16.0,
#   u'square': 22.0,
#   u'unit': 12.0,
#   u'volume': 41.0},
#  {u'caret': 26.0,
#   u'covariance': 7.0,
#   u'cran': 37.0,
#   u'cran project': 39.0,
#   u'html': 14.0,
#   u'index': 13.0,
#   u'installed': 7.0,
#   u'package': 37.0,
#   u'packages': 20.0,
#   u'paper': 7.0,
#   u'papers': 8.0,
#   u'pdf': 11.0,
#   u'project': 36.0,
#   u'project packages': 37.0},
#  {u'interaction': 13.0,
#   u'interactions': 9.0,
#   u'linear': 9.0,
#   u'lm x1': 18.0,
#   u'rdata': 9.0,
#   u'relationship': 9.0,
#   u'residuals': 10.0,
#   u'statistic': 8.0,
#   u'typo': 15.0,
#   u'x1': 62.0,
#   u'x1 x2': 43.0,
#   u'x2': 55.0,
#   u'x3': 20.0,
#   u'xy': 21.0},
#  {u'1000': 12.0,
#   u'37': 16.0,
#   u'39': 17.0,
#   u'advertising': 31.0,
#   u'effect': 10.0,
#   u'effects': 11.0,
#   u'impact': 14.0,
#   u'income': 10.0,
#   u'increase': 11.0,
#   u'interaction': 23.0,
#   u'main': 11.0,
#   u'sales': 61.0,
#   u'tv': 48.0,
#   u'units': 25.0},
#  {u'categorical': 18.0,
#   u'correlated': 16.0,
#   u'dependent': 16.0,
#   u'dependent variable': 15.0,
#   u'dummy': 27.0,
#   u'dummy variables': 18.0,
#   u'effect': 15.0,
#   u'levels': 22.0,
#   u'model': 16.0,
#   u'predictor': 22.0,
#   u'predictors': 33.0,
#   u'response': 18.0,
#   u'variable': 34.0,
#   u'variables': 30.0},
#  {u'00': 12.0,
#   u'2014': 17.0,
#   u'21': 16.0,
#   u'50': 24.0,
#   u'accomplishment': 32.0,
#   u'april': 26.0,
#   u'certificate': 36.0,
#   u'course': 19.0,
#   u'email': 13.0,
#   u'info': 15.0,
#   u'march': 27.0,
#   u'page': 15.0,
#   u'progress': 32.0,
#   u'quizzes': 15.0},
#  {u'dat': 22.0,
#   u'data': 16.0,
#   u'data frame': 32.0,
#   u'frame': 30.0,
#   u'lm data': 18.0,
#   u'matrix': 23.0,
#   u'pca': 26.0,
#   u'pred': 22.0,
#   u'predict': 24.0,
#   u'principal': 17.0,
#   u'principal components': 17.0,
#   u'rep': 17.0,
#   u'test': 18.0,
#   u'train': 20.0},
#  {u'95': 31.0,
#   u'confidence': 33.0,
#   u'confidence interval': 33.0,
#   u'confidence intervals': 19.0,
#   u'contain': 14.0,
#   u'hypothesis': 17.0,
#   u'interval': 34.0,
#   u'intervals': 23.0,
#   u'null': 17.0,
#   u'null hypothesis': 16.0,
#   u'parameter': 20.0,
#   u'probability': 13.0,
#   u'true': 15.0,
#   u'value': 13.0}]

# %%
import vincent

vincent.core.initialize_notebook()

for i in xrange(n_topics):
    word_cloud = vincent.Word(topics_dicts[i])
    word_cloud.width = 400
    word_cloud.height = 400
    word_cloud.padding = 0
    word_cloud.display()

#word_cloud.grammar();
# Out:
#            <script>
#
#                 function vct_load_lib(url, callback){
#                       if(typeof d3 !== 'undefined' &&
#                          url === 'http://d3js.org/d3.v3.min.js'){
#                         callback()
#                       }
#                       var s = document.createElement('script');
#                       s.src = url;
#                       s.async = true;
#                       s.onreadystatechange = s.onload = callback;
#                       s.onerror = function(){
#                         console.warn("failed to load library " + url);
#                         };
#                       document.getElementsByTagName("head")[0].appendChild(s);
#                 };
#                 var vincent_event = new CustomEvent(
#                   "vincent_libs_loaded",
#                   {bubbles: true, cancelable: true}
#                 );
#
#                function load_all_libs(){
#                   console.log('Loading Vincent libs...')
#                   vct_load_lib('http://d3js.org/d3.v3.min.js', function(){
#                   vct_load_lib('http://d3js.org/d3.geo.projection.v0.min.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/d3-cloud/d3.layout.cloud.js', function(){
#                   vct_load_lib('http://wrobstory.github.io/vega/vega.v1.3.3.js', function(){
#                   window.dispatchEvent(vincent_event);
#                   });
#                   });
#                   });
#                   });
#                };
#                if(typeof define === "function" && define.amd){
#                     if (window['d3'] === undefined ||
#                         window['topojson'] === undefined){
#                         require.config(
#                             {paths: {
#                               d3: 'http://d3js.org/d3.v3.min',
#                               topojson: 'http://d3js.org/topojson.v1.min'
#                               }
#                             }
#                           );
#                         require(["d3"], function(d3){
#                             console.log('Loading Vincent from require.js...')
#                             window.d3 = d3;
#                             require(["topojson"], function(topojson){
#                                 window.topojson = topojson;
#                                 load_all_libs();
#                             });
#                         });
#                     } else {
#                         load_all_libs();
#                     };
#                }else{
#                     console.log('Require.js not found, loading manually...')
#                     load_all_libs();
#                };
#
#            </script>
# <div id="viscd3ce6667ed84094a1521228cfcb9620"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "best", "val": 16.0}, {"col": "data", "idx": "best model", "val": 16.0}, {"col": "data", "idx": "cross", "val": 26.0}, {"col": "data", "idx": "cross validation", "val": 27.0}, {"col": "data", "idx": "cv", "val": 40.0}, {"col": "data", "idx": "cv error", "val": 18.0}, {"col": "data", "idx": "estimate", "val": 15.0}, {"col": "data", "idx": "estimate test", "val": 17.0}, {"col": "data", "idx": "fold", "val": 25.0}, {"col": "data", "idx": "fold cv", "val": 17.0}, {"col": "data", "idx": "test", "val": 21.0}, {"col": "data", "idx": "test set", "val": 15.0}, {"col": "data", "idx": "training", "val": 16.0}, {"col": "data", "idx": "validation", "val": 31.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#viscd3ce6667ed84094a1521228cfcb9620"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visa85572f0819d4c4fb50ca82f52dce495"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "class stanford", "val": 20.0}, {"col": "data", "idx": "courses humanitiesscience", "val": 21.0}, {"col": "data", "idx": "discussion forum", "val": 20.0}, {"col": "data", "idx": "forum", "val": 20.0}, {"col": "data", "idx": "forum i4x", "val": 19.0}, {"col": "data", "idx": "humanitiesscience", "val": 31.0}, {"col": "data", "idx": "humanitiesscience statlearning", "val": 20.0}, {"col": "data", "idx": "i4x", "val": 19.0}, {"col": "data", "idx": "i4x humanitiesscience", "val": 19.0}, {"col": "data", "idx": "stanford courses", "val": 21.0}, {"col": "data", "idx": "statlearning", "val": 20.0}, {"col": "data", "idx": "threads", "val": 20.0}, {"col": "data", "idx": "winter2", "val": 26.0}, {"col": "data", "idx": "winter2 14", "val": 24.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visa85572f0819d4c4fb50ca82f52dce495"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis67e16581d2ba4a68b4995735d83ad402"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "available", "val": 10.0}, {"col": "data", "idx": "copy", "val": 12.0}, {"col": "data", "idx": "download", "val": 43.0}, {"col": "data", "idx": "download video", "val": 19.0}, {"col": "data", "idx": "download videos", "val": 25.0}, {"col": "data", "idx": "downloading", "val": 11.0}, {"col": "data", "idx": "firefox", "val": 22.0}, {"col": "data", "idx": "hd", "val": 12.0}, {"col": "data", "idx": "mp4", "val": 16.0}, {"col": "data", "idx": "right click", "val": 12.0}, {"col": "data", "idx": "url", "val": 15.0}, {"col": "data", "idx": "video", "val": 26.0}, {"col": "data", "idx": "videos", "val": 49.0}, {"col": "data", "idx": "watch", "val": 28.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis67e16581d2ba4a68b4995735d83ad402"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visee4a656024684c87b58666eca26b7d75"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "auto", "val": 14.0}, {"col": "data", "idx": "csv", "val": 19.0}, {"col": "data", "idx": "directory", "val": 30.0}, {"col": "data", "idx": "editor", "val": 13.0}, {"col": "data", "idx": "file", "val": 42.0}, {"col": "data", "idx": "files", "val": 14.0}, {"col": "data", "idx": "load", "val": 28.0}, {"col": "data", "idx": "load rdata", "val": 17.0}, {"col": "data", "idx": "loaded", "val": 15.0}, {"col": "data", "idx": "open", "val": 22.0}, {"col": "data", "idx": "rdata", "val": 32.0}, {"col": "data", "idx": "rstudio", "val": 18.0}, {"col": "data", "idx": "working directory", "val": 17.0}, {"col": "data", "idx": "workspace", "val": 18.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visee4a656024684c87b58666eca26b7d75"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis7da9e3ee36df4a21820962d9e5a07e07"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "2nd", "val": 11.0}, {"col": "data", "idx": "elements", "val": 12.0}, {"col": "data", "idx": "elements statistical", "val": 13.0}, {"col": "data", "idx": "elemstatlearn", "val": 38.0}, {"col": "data", "idx": "esl", "val": 13.0}, {"col": "data", "idx": "pdf", "val": 7.0}, {"col": "data", "idx": "stanford", "val": 14.0}, {"col": "data", "idx": "stanford tibs", "val": 36.0}, {"col": "data", "idx": "statistical", "val": 9.0}, {"col": "data", "idx": "statistical learning", "val": 11.0}, {"col": "data", "idx": "statweb", "val": 33.0}, {"col": "data", "idx": "statweb stanford", "val": 33.0}, {"col": "data", "idx": "tibs", "val": 36.0}, {"col": "data", "idx": "tibs elemstatlearn", "val": 35.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis7da9e3ee36df4a21820962d9e5a07e07"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis490cdd525974402aa7c728a29cbeaed9"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "book", "val": 17.0}, {"col": "data", "idx": "books", "val": 20.0}, {"col": "data", "idx": "course", "val": 33.0}, {"col": "data", "idx": "enjoyed", "val": 20.0}, {"col": "data", "idx": "hastie", "val": 23.0}, {"col": "data", "idx": "learning", "val": 28.0}, {"col": "data", "idx": "machine", "val": 18.0}, {"col": "data", "idx": "machine learning", "val": 19.0}, {"col": "data", "idx": "prof", "val": 21.0}, {"col": "data", "idx": "statistical", "val": 20.0}, {"col": "data", "idx": "statistical learning", "val": 21.0}, {"col": "data", "idx": "thank", "val": 19.0}, {"col": "data", "idx": "thank course", "val": 17.0}, {"col": "data", "idx": "tibshirani", "val": 23.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis490cdd525974402aa7c728a29cbeaed9"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visae2c4aa950414b39a9d3c87e303abfd3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "block", "val": 20.0}, {"col": "data", "idx": "block bootstrap", "val": 17.0}, {"col": "data", "idx": "bootstrap", "val": 36.0}, {"col": "data", "idx": "bootstrap sample", "val": 19.0}, {"col": "data", "idx": "bootstrap samples", "val": 18.0}, {"col": "data", "idx": "data point", "val": 17.0}, {"col": "data", "idx": "data points", "val": 21.0}, {"col": "data", "idx": "points", "val": 17.0}, {"col": "data", "idx": "sample", "val": 24.0}, {"col": "data", "idx": "samples", "val": 29.0}, {"col": "data", "idx": "series", "val": 20.0}, {"col": "data", "idx": "size", "val": 21.0}, {"col": "data", "idx": "standard", "val": 17.0}, {"col": "data", "idx": "time series", "val": 23.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visae2c4aa950414b39a9d3c87e303abfd3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis9f9c86c8cef24c13af9a8cce82702b81"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "bcf", "val": 33.0}, {"col": "data", "idx": "bcf usc", "val": 33.0}, {"col": "data", "idx": "credit", "val": 9.0}, {"col": "data", "idx": "csv", "val": 15.0}, {"col": "data", "idx": "gareth", "val": 32.0}, {"col": "data", "idx": "gareth isl", "val": 32.0}, {"col": "data", "idx": "isl", "val": 28.0}, {"col": "data", "idx": "isl data", "val": 18.0}, {"col": "data", "idx": "islr", "val": 11.0}, {"col": "data", "idx": "read csv", "val": 7.0}, {"col": "data", "idx": "textbook", "val": 10.0}, {"col": "data", "idx": "usc", "val": 33.0}, {"col": "data", "idx": "usc gareth", "val": 32.0}, {"col": "data", "idx": "website", "val": 8.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis9f9c86c8cef24c13af9a8cce82702b81"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visf3de2677202e4640a152bdee66f59262"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "1000", "val": 11.0}, {"col": "data", "idx": "block", "val": 15.0}, {"col": "data", "idx": "blocks", "val": 14.0}, {"col": "data", "idx": "boot", "val": 48.0}, {"col": "data", "idx": "bootstrap", "val": 12.0}, {"col": "data", "idx": "coef", "val": 17.0}, {"col": "data", "idx": "function", "val": 20.0}, {"col": "data", "idx": "function data", "val": 13.0}, {"col": "data", "idx": "index", "val": 23.0}, {"col": "data", "idx": "lm", "val": 11.0}, {"col": "data", "idx": "sim", "val": 16.0}, {"col": "data", "idx": "sim fixed", "val": 18.0}, {"col": "data", "idx": "tsboot", "val": 64.0}, {"col": "data", "idx": "xy", "val": 18.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visf3de2677202e4640a152bdee66f59262"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visba2d99875ead46c69440d10d37aa61ab"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "alpha", "val": 38.0}, {"col": "data", "idx": "coefficients", "val": 9.0}, {"col": "data", "idx": "cv", "val": 10.0}, {"col": "data", "idx": "family", "val": 11.0}, {"col": "data", "idx": "glm", "val": 9.0}, {"col": "data", "idx": "glmnet", "val": 67.0}, {"col": "data", "idx": "increases", "val": 9.0}, {"col": "data", "idx": "lambda", "val": 42.0}, {"col": "data", "idx": "lasso", "val": 37.0}, {"col": "data", "idx": "net", "val": 9.0}, {"col": "data", "idx": "plot", "val": 12.0}, {"col": "data", "idx": "regularization", "val": 10.0}, {"col": "data", "idx": "ridge", "val": 26.0}, {"col": "data", "idx": "ridge regression", "val": 11.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visba2d99875ead46c69440d10d37aa61ab"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis548411e99f714a2aaa1a74c4c596f3c9"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "command", "val": 7.0}, {"col": "data", "idx": "install", "val": 50.0}, {"col": "data", "idx": "install packages", "val": 46.0}, {"col": "data", "idx": "islr", "val": 29.0}, {"col": "data", "idx": "islr library", "val": 8.0}, {"col": "data", "idx": "islr package", "val": 8.0}, {"col": "data", "idx": "library", "val": 22.0}, {"col": "data", "idx": "library islr", "val": 17.0}, {"col": "data", "idx": "package", "val": 18.0}, {"col": "data", "idx": "packages", "val": 38.0}, {"col": "data", "idx": "packages islr", "val": 28.0}, {"col": "data", "idx": "rstudio", "val": 10.0}, {"col": "data", "idx": "session", "val": 7.0}, {"col": "data", "idx": "version", "val": 10.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis548411e99f714a2aaa1a74c4c596f3c9"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="viseb88f2d440e84e7099587dcd1fea5bd3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "degree", "val": 17.0}, {"col": "data", "idx": "degrees", "val": 17.0}, {"col": "data", "idx": "degrees freedom", "val": 18.0}, {"col": "data", "idx": "df", "val": 27.0}, {"col": "data", "idx": "fitted values", "val": 18.0}, {"col": "data", "idx": "freedom", "val": 18.0}, {"col": "data", "idx": "lm", "val": 20.0}, {"col": "data", "idx": "poly", "val": 36.0}, {"col": "data", "idx": "polynomial", "val": 20.0}, {"col": "data", "idx": "polynomials", "val": 20.0}, {"col": "data", "idx": "raw", "val": 17.0}, {"col": "data", "idx": "reg", "val": 29.0}, {"col": "data", "idx": "spline", "val": 22.0}, {"col": "data", "idx": "splines", "val": 22.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#viseb88f2d440e84e7099587dcd1fea5bd3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis7df1c418c39744319d04bd1090feba09"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "allow", "val": 4.0}, {"col": "data", "idx": "answers", "val": 3.0}, {"col": "data", "idx": "appears", "val": 101.0}, {"col": "data", "idx": "automatic", "val": 138.0}, {"col": "data", "idx": "ch", "val": 5.0}, {"col": "data", "idx": "getting", "val": 3.0}, {"col": "data", "idx": "grading", "val": 6.0}, {"col": "data", "idx": "lda", "val": 6.0}, {"col": "data", "idx": "logit", "val": 7.0}, {"col": "data", "idx": "ols", "val": 7.0}, {"col": "data", "idx": "past", "val": 6.0}, {"col": "data", "idx": "posting", "val": 6.0}, {"col": "data", "idx": "resampling", "val": 4.0}, {"col": "data", "idx": "things", "val": 3.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis7df1c418c39744319d04bd1090feba09"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis12cd2105083c4eadae097bb2011d4e30"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "answer", "val": 9.0}, {"col": "data", "idx": "attempts", "val": 9.0}, {"col": "data", "idx": "bar", "val": 10.0}, {"col": "data", "idx": "button", "val": 50.0}, {"col": "data", "idx": "click", "val": 29.0}, {"col": "data", "idx": "clicking", "val": 19.0}, {"col": "data", "idx": "icon", "val": 24.0}, {"col": "data", "idx": "quiz", "val": 27.0}, {"col": "data", "idx": "quizzes", "val": 19.0}, {"col": "data", "idx": "right", "val": 11.0}, {"col": "data", "idx": "save", "val": 10.0}, {"col": "data", "idx": "screen", "val": 13.0}, {"col": "data", "idx": "submit", "val": 43.0}, {"col": "data", "idx": "video", "val": 27.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis12cd2105083c4eadae097bb2011d4e30"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis0dd490d3ff3e4ccfa387a8ab6a8e20e2"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "classification", "val": 20.0}, {"col": "data", "idx": "discriminant", "val": 20.0}, {"col": "data", "idx": "discriminant analysis", "val": 13.0}, {"col": "data", "idx": "gaussian", "val": 9.0}, {"col": "data", "idx": "glm", "val": 10.0}, {"col": "data", "idx": "linear", "val": 24.0}, {"col": "data", "idx": "linear regression", "val": 28.0}, {"col": "data", "idx": "logistic", "val": 45.0}, {"col": "data", "idx": "logistic regression", "val": 42.0}, {"col": "data", "idx": "logit", "val": 10.0}, {"col": "data", "idx": "models", "val": 19.0}, {"col": "data", "idx": "multivariate", "val": 11.0}, {"col": "data", "idx": "regression", "val": 37.0}, {"col": "data", "idx": "regression model", "val": 11.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis0dd490d3ff3e4ccfa387a8ab6a8e20e2"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis42fbbc2e81a54020a2ebac285752545e"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "30", "val": 18.0}, {"col": "data", "idx": "chapter", "val": 10.0}, {"col": "data", "idx": "class stanford", "val": 7.0}, {"col": "data", "idx": "downloaded", "val": 9.0}, {"col": "data", "idx": "hd", "val": 10.0}, {"col": "data", "idx": "humanitiesscience statlearning", "val": 7.0}, {"col": "data", "idx": "lecture", "val": 37.0}, {"col": "data", "idx": "lecture slides", "val": 63.0}, {"col": "data", "idx": "link", "val": 12.0}, {"col": "data", "idx": "numbers", "val": 8.0}, {"col": "data", "idx": "page", "val": 18.0}, {"col": "data", "idx": "pdf", "val": 37.0}, {"col": "data", "idx": "slide", "val": 8.0}, {"col": "data", "idx": "slides", "val": 56.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis42fbbc2e81a54020a2ebac285752545e"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visf6680dde75af46acb7abaf7fa9bdaae1"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "aware", "val": 15.0}, {"col": "data", "idx": "cheers", "val": 18.0}, {"col": "data", "idx": "community", "val": 17.0}, {"col": "data", "idx": "exercises", "val": 11.0}, {"col": "data", "idx": "github", "val": 33.0}, {"col": "data", "idx": "hi", "val": 16.0}, {"col": "data", "idx": "learning", "val": 11.0}, {"col": "data", "idx": "manual", "val": 31.0}, {"col": "data", "idx": "nameredac_", "val": 30.0}, {"col": "data", "idx": "official", "val": 26.0}, {"col": "data", "idx": "solutions", "val": 42.0}, {"col": "data", "idx": "stat", "val": 18.0}, {"col": "data", "idx": "stat learning", "val": 22.0}, {"col": "data", "idx": "working", "val": 9.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visf6680dde75af46acb7abaf7fa9bdaae1"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis7886ea7cd7cf4570a6f61b68f8c3c05a"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "browser", "val": 43.0}, {"col": "data", "idx": "chrome", "val": 75.0}, {"col": "data", "idx": "clicking", "val": 12.0}, {"col": "data", "idx": "fine", "val": 26.0}, {"col": "data", "idx": "firefox", "val": 21.0}, {"col": "data", "idx": "mac", "val": 25.0}, {"col": "data", "idx": "screen", "val": 16.0}, {"col": "data", "idx": "tried", "val": 15.0}, {"col": "data", "idx": "using", "val": 12.0}, {"col": "data", "idx": "version", "val": 11.0}, {"col": "data", "idx": "video", "val": 10.0}, {"col": "data", "idx": "volume", "val": 10.0}, {"col": "data", "idx": "worked", "val": 11.0}, {"col": "data", "idx": "works", "val": 13.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis7886ea7cd7cf4570a6f61b68f8c3c05a"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis89ce11504872489b9e597bcb158df1e7"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "amazonaws", "val": 22.0}, {"col": "data", "idx": "description", "val": 19.0}, {"col": "data", "idx": "edx", "val": 22.0}, {"col": "data", "idx": "edx west", "val": 22.0}, {"col": "data", "idx": "enter", "val": 19.0}, {"col": "data", "idx": "enter image", "val": 22.0}, {"col": "data", "idx": "image", "val": 23.0}, {"col": "data", "idx": "image description", "val": 22.0}, {"col": "data", "idx": "s3", "val": 21.0}, {"col": "data", "idx": "s3 amazonaws", "val": 22.0}, {"col": "data", "idx": "uploads", "val": 22.0}, {"col": "data", "idx": "uploads s3", "val": 22.0}, {"col": "data", "idx": "west", "val": 22.0}, {"col": "data", "idx": "west uploads", "val": 22.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis89ce11504872489b9e597bcb158df1e7"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visea6bda8f23b04301a3ea7938fcb72b42"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "10", "val": 11.0}, {"col": "data", "idx": "answer", "val": 16.0}, {"col": "data", "idx": "base", "val": 73.0}, {"col": "data", "idx": "consistent", "val": 12.0}, {"col": "data", "idx": "correct", "val": 15.0}, {"col": "data", "idx": "correct answer", "val": 11.0}, {"col": "data", "idx": "formula", "val": 20.0}, {"col": "data", "idx": "log", "val": 58.0}, {"col": "data", "idx": "natural", "val": 26.0}, {"col": "data", "idx": "r1", "val": 10.0}, {"col": "data", "idx": "r2", "val": 20.0}, {"col": "data", "idx": "stats", "val": 9.0}, {"col": "data", "idx": "used", "val": 10.0}, {"col": "data", "idx": "wrong", "val": 9.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visea6bda8f23b04301a3ea7938fcb72b42"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis506449e4b6134177885368c7721452b3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "average", "val": 13.0}, {"col": "data", "idx": "bias", "val": 41.0}, {"col": "data", "idx": "bias variance", "val": 17.0}, {"col": "data", "idx": "error", "val": 12.0}, {"col": "data", "idx": "flexible", "val": 15.0}, {"col": "data", "idx": "high", "val": 21.0}, {"col": "data", "idx": "high variance", "val": 17.0}, {"col": "data", "idx": "low", "val": 17.0}, {"col": "data", "idx": "random", "val": 15.0}, {"col": "data", "idx": "rate", "val": 13.0}, {"col": "data", "idx": "tree", "val": 33.0}, {"col": "data", "idx": "trees", "val": 35.0}, {"col": "data", "idx": "var", "val": 15.0}, {"col": "data", "idx": "variance", "val": 38.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis506449e4b6134177885368c7721452b3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visc52f24c8d3514484b615cea9ccbe6493"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "egin", "val": 10.0}, {"col": "data", "idx": "epsilon", "val": 34.0}, {"col": "data", "idx": "eta", "val": 11.0}, {"col": "data", "idx": "eta_0", "val": 36.0}, {"col": "data", "idx": "eta_0 eta_1", "val": 31.0}, {"col": "data", "idx": "eta_1", "val": 37.0}, {"col": "data", "idx": "eta_2", "val": 20.0}, {"col": "data", "idx": "frac", "val": 9.0}, {"col": "data", "idx": "hat", "val": 23.0}, {"col": "data", "idx": "log", "val": 14.0}, {"col": "data", "idx": "mathrm", "val": 14.0}, {"col": "data", "idx": "odds", "val": 11.0}, {"col": "data", "idx": "x_1", "val": 27.0}, {"col": "data", "idx": "x_2", "val": 23.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visc52f24c8d3514484b615cea9ccbe6493"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vise9687c8e4254482aba2300d0ff0fd8cb"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "50", "val": 11.0}, {"col": "data", "idx": "area", "val": 11.0}, {"col": "data", "idx": "boundary", "val": 26.0}, {"col": "data", "idx": "cube", "val": 39.0}, {"col": "data", "idx": "dimension", "val": 31.0}, {"col": "data", "idx": "dimensional", "val": 11.0}, {"col": "data", "idx": "dimensions", "val": 31.0}, {"col": "data", "idx": "distance", "val": 11.0}, {"col": "data", "idx": "hypercube", "val": 25.0}, {"col": "data", "idx": "length", "val": 14.0}, {"col": "data", "idx": "region", "val": 16.0}, {"col": "data", "idx": "square", "val": 22.0}, {"col": "data", "idx": "unit", "val": 12.0}, {"col": "data", "idx": "volume", "val": 41.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vise9687c8e4254482aba2300d0ff0fd8cb"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis4c668361a3a84d0b91a8d79dbd525518"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "caret", "val": 26.0}, {"col": "data", "idx": "covariance", "val": 7.0}, {"col": "data", "idx": "cran", "val": 37.0}, {"col": "data", "idx": "cran project", "val": 39.0}, {"col": "data", "idx": "html", "val": 14.0}, {"col": "data", "idx": "index", "val": 13.0}, {"col": "data", "idx": "installed", "val": 7.0}, {"col": "data", "idx": "package", "val": 37.0}, {"col": "data", "idx": "packages", "val": 20.0}, {"col": "data", "idx": "paper", "val": 7.0}, {"col": "data", "idx": "papers", "val": 8.0}, {"col": "data", "idx": "pdf", "val": 11.0}, {"col": "data", "idx": "project", "val": 36.0}, {"col": "data", "idx": "project packages", "val": 37.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis4c668361a3a84d0b91a8d79dbd525518"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visdd067346b3e7494db18c2ea7e6e5bf44"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "interaction", "val": 13.0}, {"col": "data", "idx": "interactions", "val": 9.0}, {"col": "data", "idx": "linear", "val": 9.0}, {"col": "data", "idx": "lm x1", "val": 18.0}, {"col": "data", "idx": "rdata", "val": 9.0}, {"col": "data", "idx": "relationship", "val": 9.0}, {"col": "data", "idx": "residuals", "val": 10.0}, {"col": "data", "idx": "statistic", "val": 8.0}, {"col": "data", "idx": "typo", "val": 15.0}, {"col": "data", "idx": "x1", "val": 62.0}, {"col": "data", "idx": "x1 x2", "val": 43.0}, {"col": "data", "idx": "x2", "val": 55.0}, {"col": "data", "idx": "x3", "val": 20.0}, {"col": "data", "idx": "xy", "val": 21.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visdd067346b3e7494db18c2ea7e6e5bf44"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="viscdf09f13b0c5476e83d4133a3d873bdb"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "1000", "val": 12.0}, {"col": "data", "idx": "37", "val": 16.0}, {"col": "data", "idx": "39", "val": 17.0}, {"col": "data", "idx": "advertising", "val": 31.0}, {"col": "data", "idx": "effect", "val": 10.0}, {"col": "data", "idx": "effects", "val": 11.0}, {"col": "data", "idx": "impact", "val": 14.0}, {"col": "data", "idx": "income", "val": 10.0}, {"col": "data", "idx": "increase", "val": 11.0}, {"col": "data", "idx": "interaction", "val": 23.0}, {"col": "data", "idx": "main", "val": 11.0}, {"col": "data", "idx": "sales", "val": 61.0}, {"col": "data", "idx": "tv", "val": 48.0}, {"col": "data", "idx": "units", "val": 25.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#viscdf09f13b0c5476e83d4133a3d873bdb"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis2fc1d54e9fc14a18974fcce96af46e03"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "categorical", "val": 18.0}, {"col": "data", "idx": "correlated", "val": 16.0}, {"col": "data", "idx": "dependent", "val": 16.0}, {"col": "data", "idx": "dependent variable", "val": 15.0}, {"col": "data", "idx": "dummy", "val": 27.0}, {"col": "data", "idx": "dummy variables", "val": 18.0}, {"col": "data", "idx": "effect", "val": 15.0}, {"col": "data", "idx": "levels", "val": 22.0}, {"col": "data", "idx": "model", "val": 16.0}, {"col": "data", "idx": "predictor", "val": 22.0}, {"col": "data", "idx": "predictors", "val": 33.0}, {"col": "data", "idx": "response", "val": 18.0}, {"col": "data", "idx": "variable", "val": 34.0}, {"col": "data", "idx": "variables", "val": 30.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis2fc1d54e9fc14a18974fcce96af46e03"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis6b08bb45afd6488697c81fe38ee4d9b6"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "00", "val": 12.0}, {"col": "data", "idx": "2014", "val": 17.0}, {"col": "data", "idx": "21", "val": 16.0}, {"col": "data", "idx": "50", "val": 24.0}, {"col": "data", "idx": "accomplishment", "val": 32.0}, {"col": "data", "idx": "april", "val": 26.0}, {"col": "data", "idx": "certificate", "val": 36.0}, {"col": "data", "idx": "course", "val": 19.0}, {"col": "data", "idx": "email", "val": 13.0}, {"col": "data", "idx": "info", "val": 15.0}, {"col": "data", "idx": "march", "val": 27.0}, {"col": "data", "idx": "page", "val": 15.0}, {"col": "data", "idx": "progress", "val": 32.0}, {"col": "data", "idx": "quizzes", "val": 15.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis6b08bb45afd6488697c81fe38ee4d9b6"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="vis88b4fdfcc8ec41ff925c8026285324e3"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "dat", "val": 22.0}, {"col": "data", "idx": "data", "val": 16.0}, {"col": "data", "idx": "data frame", "val": 32.0}, {"col": "data", "idx": "frame", "val": 30.0}, {"col": "data", "idx": "lm data", "val": 18.0}, {"col": "data", "idx": "matrix", "val": 23.0}, {"col": "data", "idx": "pca", "val": 26.0}, {"col": "data", "idx": "pred", "val": 22.0}, {"col": "data", "idx": "predict", "val": 24.0}, {"col": "data", "idx": "principal", "val": 17.0}, {"col": "data", "idx": "principal components", "val": 17.0}, {"col": "data", "idx": "rep", "val": 17.0}, {"col": "data", "idx": "test", "val": 18.0}, {"col": "data", "idx": "train", "val": 20.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#vis88b4fdfcc8ec41ff925c8026285324e3"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>
# <div id="visf6092b8e758d41eb8ebb4d132bfa861d"></div>
# <script>
#    ( function() {
#      var _do_plot = function() {
#        if (typeof vg === 'undefined') {
#          window.addEventListener('vincent_libs_loaded', _do_plot)
#          return;
#        }
#        vg.parse.spec({"axes": [], "data": [{"name": "table", "transform": [{"font": "Helvetica Neue", "fontSize": "data.val", "rotate": {"random": [-90, -60, -30, 0, 30, 60]}, "text": "data.idx", "type": "wordcloud"}], "values": [{"col": "data", "idx": "95", "val": 31.0}, {"col": "data", "idx": "confidence", "val": 33.0}, {"col": "data", "idx": "confidence interval", "val": 33.0}, {"col": "data", "idx": "confidence intervals", "val": 19.0}, {"col": "data", "idx": "contain", "val": 14.0}, {"col": "data", "idx": "hypothesis", "val": 17.0}, {"col": "data", "idx": "interval", "val": 34.0}, {"col": "data", "idx": "intervals", "val": 23.0}, {"col": "data", "idx": "null", "val": 17.0}, {"col": "data", "idx": "null hypothesis", "val": 16.0}, {"col": "data", "idx": "parameter", "val": 20.0}, {"col": "data", "idx": "probability", "val": 13.0}, {"col": "data", "idx": "true", "val": 15.0}, {"col": "data", "idx": "value", "val": 13.0}]}], "height": 400, "legends": [], "marks": [{"from": {"data": "table"}, "properties": {"enter": {"align": {"value": "center"}, "angle": {"field": "angle"}, "baseline": {"value": "middle"}, "fill": {"field": "data.idx", "scale": "color"}, "font": {"field": "font"}, "fontSize": {"field": "fontSize"}, "text": {"field": "data.idx"}, "x": {"field": "x"}, "y": {"field": "y"}}}, "type": "text"}], "padding": 0, "scales": [{"domain": {"data": "table", "field": "data.idx"}, "name": "color", "range": "category10", "type": "ordinal"}], "width": 400}, function(chart) {
#          chart({el: "#visf6092b8e758d41eb8ebb4d132bfa861d"}).update();
#        });
#      };
#      _do_plot();
#    })();
# </script>
# <style>.vega canvas {width: 100%;}</style>

# %% [markdown]
# ##Get the top 5 questions corresponding to each NMF topic

# %%
FAQ = []
for t in xrange(n_topics):
    FAQ.append([grouped_questions[i] for i in np.argsort(W.T[t])[:-6:-1]])

# %%
#Print out each topics and 5 questions that are most closely associated with that topic
for topic_idx, topic in enumerate(nmf.components_):
    print "******************************"
    print("Important words for Topic #%d:" % (topic_idx+1))
    print
    print(" ".join( [feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]] ))
    print
    print "******************************"
    print
    for k, v in enumerate(FAQ[topic_idx]):
        print "Question #", k+1
        print "============="
        print v
        print
# Out:
# ******************************
# Important words for Topic #1:
#
# cv validation cross validation cross fold test cv error estimate test fold cv best model best training test set estimate test error
#
# ******************************
#
# Question # 1
# =============
# **Is it wrong to use the same data set for doing both (1) data exploration and (2) cross-validation?**
#
# Before building a predictive model, I want to do some data exploration to gain insights into my data. Examples:
#
#  1. Which features are correlated with the response variable?
#  2. Is the relationship between a feature and the response variable linear or non-linear?
#
# It seems to me that I should set aside a fraction of data for data exploration, and I should not use *that* data in K-fold cross-validation in order to avoid the mistake discussed "5.3 Cross-Validation: the wrong and right way".
#
# However, this way, I have less training data, and, consequently, worse predictive performance.
#
# **Do people really set aside a fraction of data for data exploration and exclude that from K-fold cross-validation? Or am I being too paranoid?**
#
# Question # 2
# =============
# I understand that k-fold cross validation is used to get an estimate of test error, but I do not see how it helps in selecting the best model. In particular, if you're doing k-fold cross validation then overall you're estimating k models (potentially with different parameters) and running k validation tests. But how do you know which of the k models estimated with the training data is best, if ultimately you're just calculating a weighted average of all the test errors?
#
# Question # 3
# =============
# I don't really understand that:
#
# "True or false: a correct cross-validation procedure will possibly choose a different set of k variables for every fold."
#
# If we vary the set of k variables from 1 to p, does that mean we have $2^p$ folds? And how does the cross-validation error tell us which set of k variables to choose?
#
# Question # 4
# =============
# Hi everyone,
# I have developed a model to predict the probability of failure by counting the number of the properties failed in predefined classifications. Now, to validate my model, I have thought of K-fold cross validation. By dividing the data-set in 10 folds. Train with 9 folds every time and finish the process. Then take the average of all folds and compare it with each fold and calculate the error of the model. Do you think this is right?
#
# Question # 5
# =============
# I want to estimate the 95% Confidence Interval of test set error (RMSE, F1-score, etc.). Is the following approach valid?
#
# (1) Get model's predictions for the test data set.
#
# (2) Draw a large number (e.g. 10,000) of **bootstrap** samples from the test data set.
#
# (3) For each of the 10,000 bootstrap samples, compute the RMSE *[from step (1) we know the predicted values]*
#
# (4) Sort the 10,000 RMSE values, and pick the middle 95% range as the 95% CI of test set error (RMSE).
#
# ******************************
# Important words for Topic #2:
#
# humanitiesscience winter2 winter2 14 stanford courses courses humanitiesscience discussion forum forum humanitiesscience statlearning class stanford threads statlearning i4x i4x humanitiesscience forum i4x 14
#
# ******************************
#
# Question # 1
# =============
# I am looking at this problem and I am not sure where to even start. I mean I can guess that it should be somewhere in the order of 90-95% but I have no idea how to get an actual answer. How did other people start this off?
#
# Question # 2
# =============
# Why SE(a) is roughly the same as SD(a)?
#
# pls help out. Thanks!
#
# Question # 3
# =============
# I started the class late and i'm hoping someone will read this, but i was reading more on the jackknife for estimating a parameter's variance and bias. My question is that, from reading the wikipedia on it, it sounds like it is related to Leave One Out K fold cross validation. Is that understanding completely off base? I know the purpose of cross validation is to see how a model works on sub samples of the data, but the estimation of the mean and variance between the two methods sound similar to me.
#
# Question # 4
# =============
# Just a comment more than anything else.
#
# There are a few questions through out the course where I thought, "wtf?"  7.2.R2 was one of those questions.
#
# Question # 5
# =============
# Lasso produces biased estimations. I wonder what are the disadvantages of using a model like Lasso for performing feature selection (estimating the relevant predictors) followed by a less biased method (linear regression or ridge regression)./
#
# STAFF EDIT:  This post has a slightly false premise.  Ridge regression is biased just like the Lasso.
#
# ******************************
# Important words for Topic #3:
#
# videos download watch video download videos firefox download video mp4 url right click hd copy downloading format downloaded
#
# ******************************
#
# Question # 1
# =============
# I do not see any link to download the course videos to listen off line.
#
# Question # 2
# =============
# Convex optimization after a week included another tab "Video downloads", and now students can download videos to watch them off-line. It is pretty common practice among other MOOC to download the videos. Granted SU plaftorm is not that mature, but the other course proved it is possible.
#
# So please add video downloads feature (tab).
#
# Question # 3
# =============
# Dear colleagues,
# Thank you for this course and its materials.
# my internet speed is low in Iran and i have exhausting problem to online learning. may I ask you to provide a possibility to download course materials include videos, please?
# Bests,
# H.M.V
#
# Question # 4
# =============
# Dear staff
# please insert download links in the bottoms of videos
#
# Question # 5
# =============
# Hello,
#
# As some of you have noted before, I have found out that while the streaming videos have an optimal image quality, the downloads from the course site (which in my case I reproduce with either VCL on a Fedora <zipRedac>9 OS or with Quicktime on a Mac OS <zipRedac>0.5.8) are blurred.  In fact, one can't distinguish what is written on the screen at all.
#
# Instead, the downloads from Youtube are all right (which I download with the aid of the Firefox add-on that you can find at http://www.downloadhelper.net/install.php).
#
# However, by subscribing to the channel "Statistical learning" in Youtube, I only find the video "<zipRedac>0<zipRedac><zipRedac><zipRedac>3 Lab Meeting".  There are more videos at  https://www.youtube.com/channel/UC4OWDcPB<zipRedac>peiBXDfCSZ3h-w/videos?flow=grid&view=<zipRedac> but the order is not obvious and some lectures are missing.
#
# Does anyone know where can I find all the videos in Youtube and whether the "blurredness" in the videos posted on the course site (once you download them) is going to be fixed at some point?
#
# Thank you very much for this superb course.
#
# Best wishes,
#
# <nameRedac_<anon_screen_name_redacted>>
#
# ******************************
# Important words for Topic #4:
#
# file rdata directory load open csv rstudio workspace working directory load rdata loaded files auto editor script
#
# ******************************
#
# Question # 1
# =============
# Hello,
#
# I have the issue with loading data in R from the assignment 7.R. I am using the command data=load("~/Downloads/7.R.RData") to load the downloaded file. When I type the command to see the descriptive stats summary(data), the output is the following:
# " Length     Class      Mode
#         2 character character ",
#
# that is not actually true))
#
# Moreover, when I tried to open with TextEdit the downloaded file (I am using Mac OS X Mavericks), there are just a bunch of random characters ie may be there is problem with encoding.
#
# Could you please help me with this?
#
# Question # 2
# =============
# In the first problem of 5.R, "Download the file 5.R.RData and load it into R using load("5.R.RData"). Consider the linear regression model of y on X1 and X2. "
#
# I load the data using load("5.R.RData").
#
# >hw<-load("5.R.RData")
#
# > hw
#
#   [1] "Xy"
#
# > summary(hw)
#
#    Length     Class      Mode
#         1 character character
#
# Does "5.R.RData" contain any data?
#
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 3
# =============
# Hello,
# I'm trying to upload data from excel or from an Internet website. I don't follow the directions in the book or various online helps. I'm not sure what I'm doing wrong.
#
# I've tried following the video (under ch. 1) where Auto-read.csv("~/desktop/nameofmyfile.csv) is what I tried.
#
# I've also tried these steps from an R instruction manual:
# "The best way to read an Excel file is to export it to a comma delimited file and import it using the method above. On windows systems you can use the RODBC package to access Excel files. The first row should contain variable/column names."
#
# But I use MAC and the RODBC command didn't work.
#
# Any thoughts or help is appreciated!
#
# Question # 4
# =============
# Hello,
#
# I have some problems with this data file attached. Can somebody help me with switching it onto Excel file? I operate on Statistica not SPSS here in Poland. Thanks fot all help.
#
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 5
# =============
# I am trying to download 5.R.RData, but I cannot opent it, can please let me know how I can open this file.
#
# With kind regards,
#
# <nameRedac_<anon_screen_name_redacted>>
#
# ******************************
# Important words for Topic #5:
#
# eta_1 eta_0 epsilon eta_0 eta_1 hat x_1 x_2 eta_2 mathrm eta log hat eta egin x_i frac
#
# ******************************
#
# Question # 1
# =============
# Dear Trevor and Rob,
#
# In Ch 4 of your book, I have not find any information on how to deal with / interpret interaction effects in logit models.
#
# Due to non-linearity of logit model the interaction coefficients cannot be interpreted in a same way as in linear models. When I started to study this question, I came across Norton, Wang, Ai (2004) paper (http://www.unc.edu/~enorton/NortonWangAi.pdf) that stated that:
#
# 1. The interaction effect could be nonzero even if the interaction coefficient equal 0.
#
# 2. The statistical significance of the interaction effects cannot be tested with a simple t test on the coefficient of the interaction term. Instead, the statistical significance of the entire cross derivative must be calculated.
#
# 3. The interaction effect is conditional on the independent variables, unlike the interaction effect in linear models.
#
# 4. Because there are two or more additive terms, each of which can be positive or negative, the interaction effect may have different signs for different values of covariates. Therefore, the sign of interaction coefficient does not necessarily indicate the sign of the interaction effect.
#
# Given all these aforementioned issues how to properly calculate correct interaction effects and standard errors for logit models?
# Do you know whether there is command in R that can do this?
#
# Although Norton does introduce a STATA command that can do these calculations in his paper, this command works only if you interact 2 variables, and I need to interact 3 or more variables in my research. Further, Norton's command works only if there are less than 1 million observations in a data set.
#
# I would be very thankful if you could answer my questions.
#
# Question # 2
# =============
# When calculating the standard error on Slide 7 the equation is dependent on $sigma^2$ which is $Var(epsilon)$. How does one experimentally figure out $epsilon$?
#
# Question # 3
# =============
# I ran a multiple linear regression analysis in R with two predictor variables. One predictor variable's distribution had a high skew and kurtosis so I did a transformation and took the log of those values to make the distribution appear normal. Then I ran the regression model and the response variable has positive and negative values. However, in reality the response variable cannot be negative. (for instance, predicting how many apples someone will eat can only be <zipRedac> or ><zipRedac>) Did I run this model incorrectly or is it fine to have these negative prediction values?
#
# Here is the regression code: (residuals are normal with no corr to predicted values)
# model1<- lm(response ~ predictor1 + predictor2)
#
# Here is the result:
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)          24.3465     4.133<zipRedac>   5.891 3.94e-<zipRedac>7 ***
#
# predictor1      -5.1336     <zipRedac>.9434  -5.441 1.86e-<zipRedac>6 ***
#
# predictor2   <zipRedac>.9955     <zipRedac>.2769   3.596 <zipRedac>.<zipRedac><zipRedac><zipRedac>774 ***
#
# Residual standard error: 5.5<zipRedac>1 on 47 degrees of freedom
# Multiple R-squared:  <zipRedac>.5<zipRedac>79,	Adjusted R-squared:  <zipRedac>.487
# F-statistic: 24.26 on 2 and 47 DF,  p-value: 5.784e-<zipRedac>8
#
# Question # 4
# =============
# How to understand the sentence below?
# Does anyone give a specific example to explain this phenomenon ?
# Correlations amongst predictors cause problems:
# - The variance of all coefficients tends to increase, sometimes
# dramatically
#
# Question # 5
# =============
# Here's a quote from the video on 3.5: "We still call it a linear model, because it's actually linear in the coefficients. But as a function of the variables, it's become nonlinear."
#
# I'm confused by this statement. I'm used to my high school algebra class were we classified a function/model by its highest degree monomial. I'm not following how the coefficients are linear vs. the variables are non-linear.
#
# I'm also confused about the example given in video 3.5 using horsepower and horsepower^2. How exactly would be interpret horsepower squared? Would we say, "the correlation between mpg and horsepower squared is ___" OR, "Given the slope __, for every one unit increase in horsepower^2, we estimate an increase/decrease of mpg"?
# Thanks,
# <nameRedac_<anon_screen_name_redacted>>
#
# ******************************
# Important words for Topic #6:
#
# great great course course learning tibshirani hastie prof thank statistical learning enjoyed books statistical machine learning prof hastie machine
#
# ******************************
#
# Question # 1
# =============
# It was a great pleasure to listen and practice with both of you and the discussion community.
# Enjoyed too youre great sense of humour ;-)
# And actually, I hope see you soon perhaps on future courses :-)
#
# Question # 2
# =============
# Hi Rob, Trevor and team!
#
# Thanks a ton for conducting such a fantastic course and making it all so simple :) Looking forward to some more advanced courses covering unsupervised learning in more detail I hope!!
#
# Question # 3
# =============
# Welcome to the discussion forum! We are hoping this will be a useful place for us to discuss anything related to the course. Let's try to keep things productive by following a few guidelines:
#
#  - Search before you post - someone might have already posted an answer to your question, and it will be easier for everyone if there aren't a lot of duplicate postings.
#
#  - Use the sub-forums, e.g. discuss quiz questions (without posting solutions!) in the "Quiz and Review" forum.
#
#  - Lets follow the golden rule in all posts  write to others as you would like them to write to you. We try to interpret each other charitably, treat each other with respect, and be civil and professional in all our posts.
#
# We are looking forward to working with you all!
#
# Question # 4
# =============
# Thank you for all the effort you put into providing such a great course.  I have been a fan of The Elements of Statistical Learning for a while.  When I saw there was a MOOC based on Introduction to Statistical Learning, I knew I had to take it.
#
# Thanks again.
#
# Question # 5
# =============
# Many thanks to Trevor and Rob for a great course. A bit of humour makes a big difference and tag-teaming works well to aid understanding. Like many participants, I did not devote as much time to the course as I would have liked, given the pressures of work. For this reason especially, I am grateful that the materials could all be downloaded for later study. The free PDF version of the book was a very generous gesture. Our library already has a copy of ESL2, so although the maths looks a bit scary, I intend to dip into this too.
#
# ******************************
# Important words for Topic #7:
#
# button submit click video quiz icon clicking quizzes screen right save bar attempts answer chapter
#
# ******************************
#
# Question # 1
# =============
# Hi All,
#
# After saving the answers, it says "you need to click on check to grade yours answers"
#
# How can I do that ?
#
# Thanks
#
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 2
# =============
# Is there any quiz from chapter 1?
#
# Question # 3
# =============
# After saving my answers in the quiz I get the following message:
# "Your answers have been saved but not graded. Click 'Check' to grade them."
# However I cannot see where to do this, there is no button or anything visible called "check". Please help! Thanks
#
# Question # 4
# =============
# Hi!
#
# just a small question... every time that I am answering a question in a quiz, after saving my answer I have this message "Your answers have been saved but not graded. Click 'Check' to grade them.". But I fon't know how to "check" my answer. Can you please help me? is it really important for the evaluation of the work?
#
# Thank you!
#
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 5
# =============
# Very confused!
#
# In the Courseware section I only see one link to a quiz.  It is for Chapter 2 (four binary-choice questions).  I've noticed some discussion posts about quizzes 1 and 2 ... where's quiz 1?  Or is the quiz for Chapter two 'quiz 1'?  Is there another open quiz?
#
# Also, I've noticed some discussions about Quiz:2.2 R2  ... but I don't know what they're referring to.  Are there R quizzes as well?  Where?  I take it that the R quizzes are separate from the labs.  (The 'R Sessions' link doesn't indicate quizzes)
#
# Can anyone point me in the right direction?  Thanks
#
# ******************************
# Important words for Topic #8:
#
# usc bcf bcf usc gareth usc gareth gareth isl isl isl data csv islr textbook credit website read csv html
#
# ******************************
#
# Question # 1
# =============
# Hi my name is <nameRedac_<anon_screen_name_redacted>> from Nigeria. I just registered for this course, but i'm unable to download the book as the link provided results in a "Page not found" error. Please I need help on this. Without the book it's extremely difficult for me to follow this class.
#
# Thanks,
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 2
# =============
# Please, can somebody let me know where I can find the Credit data set mentioned on slide 44?
# Thank you
#
# Question # 3
# =============
# I can't find the advertising data. Does anyone know where it is or is it not provided?
#
# Jim
#
# Question # 4
# =============
# Hi Everyone:
#
# In the lecture the professor mentioned there are labs. But I did not find any place there are labs. Can anyone share the link of labs with me?
#
# Thank you!
#
# Question # 5
# =============
# I have seen this question asked a few times but I didn't see an answer. Will textbook answers would be posted? Also I am looking at Chapter 2 Question 8 in the textbook it references a College.csv data set is that data available? I did not see it on the course pages.
#
# ******************************
# Important words for Topic #9:
#
# tsboot boot index function xy sim fixed coef sim block blocks function data bootstrap 1000 fixed package
#
# ******************************
#
# Question # 1
# =============
# Has anybody installed Tsboot in R verion 3.x or lower ?
#
# Warning in install.packages :
#   package tsboot is not available (for R version 3.0.2)
#
# Question # 2
# =============
# Will solutions to the problems be posted at any point?  In particular, I have not been able to solve 5.R.R4, and would like to see how to do it (beyond just seeing the numerical answer).  Thanks!
#
# Question # 3
# =============
# I haven't succeeded in the block boot strap yet. I've got the boot.fn function, and I've seen that tsboot allows setting a block size. But when I run it, I get 0's for all of the bias and std. errors. (Note -- used dots instead of dollar sign in lm) (EDIT -- used dot instead of dollar sign because the wiki reformats it. In actual code, I use the dollar sign $.)
#
# > boot.fn = function (data, index) {
#  return(coef(lm(Xy.y ~ Xy.X<zipRedac> + Xy.X2, data = data, subset=index)))
#  }
# > tsboot(Xy, boot.fn, <zipRedac>000, l = <zipRedac>00, sim = "fixed", index=<zipRedac>:<zipRedac>000)
#
# This is the output:
#
# BLOCK BOOTSTRAP FOR TIME SERIES
#
# Fixed Block Length of <zipRedac>00
#
# Call:
# tsboot(tseries = Xy, statistic = boot.fn, R = <zipRedac>000, l = <zipRedac>00,
#     sim = "fixed", index = <zipRedac>:<zipRedac>000)
#
#
# Bootstrap Statistics :
#      original  bias    std. error
# t<zipRedac>* 0.<phoneRedac>       0           0
# t2* 0.<zipRedac>453263       0           0
# t3* 0.<phoneRedac>       0           0
#
# I'm sure I've missed something, can't figure it out ...
#
# Question # 4
# =============
# this is the code let me pass the R3 question:
#
#     boot.fn = function(data,index) return(coef(lm(y~X1 + X2, data = data, subset=index)))
#     boot(Xy, boot.fn, 1000)
#
# but when I pluged that in to the tsboot, I got the error:
#
#     tsboot(Xy, boot.fn, R=1000, sim="fixed", l=100)
#
#      Error in eval(expr, envir, enclos) :
#       argument "index" is missing, with no default
#
# So, like others, I searched the forum, looked some threads, finally, I changed the code into:
#
#     boot.fn = function(data,index) return(coef(lm(y~X1 + X2, data = data[index,])))
# I got the right answer for R4 and R3.
#
# The thing is I cann't figure out why the one(boot.fn) above works fine in boot, what's wrong
# when used in tsboot??? Please, anyone can direct me to the right document?thanks a lot!!!
#
# Question # 5
# =============
# I can't seem to get block bootstrapping to work as I keep getting the same estimate of std err of beta1 as without blocking. This was my R commands:
#
#     > b1.stderr=function(y,X1,X2){
#     +   Xy.fit<-glm(y~X1+X2)
#     +   summary(Xy.fit)$coefficients[2,2]
#     + }
#     >
#     > b1.stderr.fn=function(data, index){
#     +   with(data[index,],b1.stderr(y,X1,X2))
#     + }
#     >
#     > boot.out=tsboot(Xy,b1.stderr.fn,R=1<zipRedac><zipRedac><zipRedac>,sim="fixed",l=1<zipRedac><zipRedac>)
#     > boot.out
#
#     BLOCK BOOTSTRAP FOR TIME SERIES
#
#     Fixed Block Length of 1<zipRedac><zipRedac>
#
#     Call:
#     tsboot(tseries = Xy, statistic = b1.stderr.fn, R = 1<zipRedac><zipRedac><zipRedac>, l = 1<zipRedac><zipRedac>,
#         sim = "fixed")
#
#
#     Bootstrap Statistics :
#           original      bias    std. error
#     t1* <zipRedac>.<zipRedac><phoneRedac> -<zipRedac>.<zipRedac><zipRedac>132419 <zipRedac>.<zipRedac><zipRedac><phoneRedac>
#
# ******************************
# Important words for Topic #10:
#
# glmnet lambda alpha lasso ridge plot family ridge regression regularization cv coefficients increases net solved installed
#
# ******************************
#
# Question # 1
# =============
# Can we use lasso for logistic regression in the same way like for linear regression?
#
# Question # 2
# =============
# What is the best practice for choosing the $lambda$ parameters to search over with ridge regression and the lasso? The software that I've seen requires these as an input.
#
# Both the book and the lectures made it clear that cross validation works well to evaluate the choice of $lambda$- I'm just curious if there is a general best practice for which values of $lambda$ to start out with.
#
# The plots in the book are on log scale from 0.02 to 50, perhaps suggesting that $lambda = 2^i$ for $i = -6, -5, dots, 5, 6$ is one place to start.
#
# Thoughts?
#
# Question # 3
# =============
# Much thanks to this excellent course, We have learnt a lot of statistical methods, some of which involve well-disigned mathematical formulae, while others rely on tree structure.
#
# I am just wondering, which methods can better deal with the Curse of Dimensionality, Taking into consideration the time and space complexity required to run these methods on massive and high-dimensional data ?
#
# Thanks!
#
# Question # 4
# =============
# If the response variable is 3-class, can I use lasso or ridge to solve it by logistic regression model? Thanks!
#
# Question # 5
# =============
# I am wondering why we do not use normalization of variables using lasso for example to avoid situations when we have one predictor in millions and another one in units, the effect in this case will be the different sensitivity of coefficients.
#
# ******************************
# Important words for Topic #11:
#
# image enter image image description amazonaws s3 amazonaws edx edx west west west uploads uploads s3 uploads s3 enter description description edx
#
# ******************************
#
# Question # 1
# =============
# Hello everyone,
# I am struggling with the chapter on discriminant analysis.  I can't figure out how the discriminant score actually came about.
#
# I took the log of the Bayes probability density on Chap 4. P23.  I can't get the result on Chap 4. P24.
#
# Has anyone worked out the solution before?  I remember the prof said it's a nasty bit. lol.
#
# Thanks!
#
# Question # 2
# =============
# I have done all the quizs. when I see the performance it says 100% but over al score is 9%. Can somebody explain em what is going on? To get the credit do we have to some assignments or just quiz after each lecture.
#
# Question # 3
# =============
# * sorry about the formatting - it appears to be automatic;
#
# proc datasets memtype=data library=work kill; run;
# options nodate nonumber ps=68 ls=120 mprint mlogic sgen; title; footnote; ods graphics off;
#
# ***** 6.5.3 Choosing Among Models Using the Validation Set Approach and Cross-Validation *****;
# title '6.5.3 Choosing Among Models Using the Validation Set Approach and Cross-Validation';
#
# * csv file created from Portfolio dataset (> write.csv(Hitters,file="Hitters.csv");
# * note: need to add "Player" to 1st row in resulting csv file before importing into sas;
# proc import out=HittersAll(rename=(Salary=SalaryChar)) dbms=dlm replace
#      datafile='\Cu-ynk-fsdeptsStatisticsTraining Courses and MaterialsStatisticalLearningCourseTextbookHitters.csv';
#    getnames=yes;
#    delimiter=',';
#    guessingrows=1000;
# run;
#
# * delete row if any variable missing;
# * > Hitters=na.omit(Hitters);
# data Hitters;
#    set HittersAll;
#    Salary = SalaryChar + 0;
#    * delete row if any variable missing;
#    if nmiss(of _numeric_) + cmiss(of _character_) > 0 then delete;
#    * sas needs numeric variables only for best subset selection (which is available only in procs reg & phreg);
#    if League = 'A' then League01 = 0; else League01 = 1;
#    if Division = 'E' then Division01 = 0; else Division01 = 1;
#    if NewLeague = 'A' then NewLeague01 = 0; else NewLeague01 = 1;
# run;
#
# * use contents & sql to get list of (numeric only) predictors for model statement;
# proc contents data=Hitters(keep=_numeric_) noprint out=ContentsOut(keep=Name);
# run;
#
# proc sql noprint;
#    select Name into :Predictors separated by ' '
#    from ContentsOut
#    where Name ne 'Salary';
# quit;
#
# * > set.seed(1)
#   > train=sample(c(TRUE,FALSE),nrow(Hitters),rep=TRUE)
#   > test=(!train);
# * randomly split the data into training and test datasets;
# proc surveyselect data=Hitters method=srs samprate=0.5 rep=1 seed=1 out=HittersSelect1 outall noprint;
#    * 'method=srs' specifies without replacement;
#    * 'outall' option keeps all data in output dataset and adds 'selected' variable (0,1);
# run;
#
# data HittersTrain1 HittersTest1;
#    set HittersSelect1;
#    if selected = 1 then output HittersTrain1;
#    * create mutiple reps of test data to merge with models of each size in score procedure;
#      else do _in_ = 1 to 19;  * _in_ = # of variables included in the model;
#         output HittersTest1;
#      end;
# run;
#
# * > regfit.best=regsubsets(Salary~.,data=Hitters[train,],nvmax=19)
# * perform best subset selection, up to 19 predictors - note that glmsel
#
# Question # 4
# =============
# I am obviously missing something. My progress reports the scores from the quizes and has large gaps between them. I don't have any problem scores. Where are the Review and Quiz for the different sections (viedeos)? Where are the problems? Is there something which I should have read which I didn't read? Thank you very much.
#
# Question # 5
# =============
# I have finished watching two weeks video now and wanted to do quizzes. I can see in gray that many of the quizzes are due on 21 March. However, I cannot open any.
#
# ******************************
# Important words for Topic #12:
#
# bootstrap samples sample time series size series data points block bootstrap sample bootstrap samples data point points standard block bootstrap sample size
#
# ******************************
#
# Question # 1
# =============
# Lecture Slide 34 says ...
#
# "We can instead create blocks of consecutive observations, and sample those with replacements. Then we paste together sampled blocks to obtain a bootstrap dataset."
#
# What does this mean?  Might anyone be able to illustrate more specifically?
#
# Thanks
#
# Question # 2
# =============
# The problem is posed as, "If we have n data points, what is the probability that a given data point does not appear in *a* bootstrap sample?".  I took this to mean in a single bootstrap sample.
#
# However, I believe the correct answer as provided instead solves the question, "If we have n data points, what is the probability that a given data point does not appear in *any* bootstrap sample?"
#
# Could be that it's too early in the day for me, or that it's been too long since I have thought much about probability.  Can someone please point out where I've gone wrong?
# Much obliged
#
# Question # 3
# =============
# I ran simple bootstrapping and then block bootstrapping on the Portfolio data available with the ISLR package (R). Although the value of alpha came out same in both cases, I am getting a difference in standard errors (0.0<phoneRedac> for the simple case, 0.<zipRedac>068888 for the 2nd case). I thought they should be almost identical in this particular case.
#
# I have couple of questions:
# <zipRedac>. Is this difference can be considered significant or not ?
# 2. If we apply block bootstrapping to a data sets which doesn't look like a time series, how much difference should we expect from the simple bootstrapping ?
#
# I must warn you that my background is in Algebra (not applied sciences). So to me any difference is significant (hence the source of the question).:)
#
# Thanks.
#
# Question # 4
# =============
# The question is:  To carry out this implementation on a data set with n data points, how many bootstrap data sets would we need to average over?
#
# It seems to me that the answer must include a factorial (!).  But when I try to enter "!" into the answer box I get the error message "Sorry, couldn't parse formula."  Does anyone have any suggestions?
#
# Question # 5
# =============
# Hi there,
#
# The result of 5.5.R.1 consider different order in a bootstrap as different sample. What I mean is, according to the given result, say a sample with observation 1,2,3 and a bootstrap of 1,2,3 and 2,1,3 will be considered different.
#
# ******************************
# Important words for Topic #13:
#
# install install packages packages islr packages islr library package library islr rstudio version islr package islr library command session cran
#
# ******************************
#
# Question # 1
# =============
# Kindly describe how to load ISLR in R nterpreter. This is a not available in the standard library.
#
# > library(ISLR)
# Error in library(ISLR) : there is no package called ISLR
# > names(ISLR)
# Error: object 'ISLR' not found
# >
#
# Question # 2
# =============
# Why when I wrote library(leaps),it shows that Error in library(leaps) : there is no package called leaps
#
# Question # 3
# =============
# Hi,
# Can someone help me install the ISLR package on my PC. I have downloaded the package from the website but don't know what to do after this. There is nothing online either.
#
# Any help is much appreciated.
#
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 4
# =============
# Hello,
# I've watched the video guide 3.R about how to use R in linear regression. I tried to practice using commands but when the professor type the command which required the data file named "Carseats", I didn't know where the file is. Could anyone tell me how to find that file? I hope to practice commands related to the data "Carseats".
# Thank you!
#
# Question # 5
# =============
# I get the following message
# package ISLR is not available (for R version 2.15.0)
# i have downloaded the laterst RSutio version though (Version 0.98.501)
#
# any idea?
#
# tks
#
# ******************************
# Important words for Topic #14:
#
# automatic appears ols logit lda past posting grading ch resampling allow getting answers things select
#
# ******************************
#
# Question # 1
# =============
# proc datasets memtype=data library=work kill; run;
# options nodate nonumber ps=68 ls=120 mprint mlogic sgen; title; footnote; ods graphics off;
#
# * csv file created from Smarket dataset (> write.csv(Smarket,file="Smarket.csv");
# * note: need to delete 1st column in resulting csv file before importing into sas;
# proc import out=Smarket dbms=dlm replace
#      datafile='\Cu-ynk-fsdeptsStatisticsTraining Courses and MaterialsStatisticalLearningCourseTextbookSmarket.csv';
#    getnames=yes;
#    delimiter=',';
#    guessingrows=100;
# run;
#
# * create test & training datasets;
# data TrainingData Smarket2005;
#    set Smarket;
#    if Year < 2005 then output TrainingData;
#      else output Smarket2005;
# run;
#
# ***** 4.6.4 Quadratic Discriminant Analysis *****;
# title '4.6.4 Quadratic Discriminant Analysis';
#
# * > qda.fit=qda(Direction~Lag1+Lag2,data=Smarket,subset=train)
#   > qda.class=predict(qda.fit,Smarket.2005)$class;
# proc discrim data=TrainingData testdata=Smarket2005 method=normal pool=no simple testout=Preds5;
#    * 'pool=no' performs QDA: 'QDA assumes that each class has its own covariance matrix';
#    title2 'Reduced Model: From Training Data Applied to Test Data';
#    class Direction;
#    priors proportional;
#    var Lag1 Lag2;
# run;
#
# * confusion matrix (http://support.sas.com/kb/22/603.html);
# * > table(qda.class,Direction.2005);
# proc freq data=Preds5;
#    table _INTO_*Direction / out=CellCounts5 norow nocol nopercent;
# run;
#
# * calculate % correctly predicted;
# * > mean(qda.class==Direction.2005);
# data CellCounts5;
#    set CellCounts5;
#    Match = 0;
#    if _INTO_ = Direction then Match = 1;
# run;
#
# proc means data=CellCounts5 mean;
#    freq count;
#    var Match;
# run;
#
# quit;
#
# Question # 2
# =============
# *From the dept of "too much free time," I created SAS programs to duplicate the output from the R code in the Chapter 4 Lab.;
#
# proc datasets memtype=data library=work kill; run;
# options nodate nonumber ps=68 ls=120 mprint mlogic sgen; title; footnote; ods graphics off;
#
# ***** 4.6.1 The Stock Market Data *****;
# title '4.6.1 The Stock Market Data';
#
# * csv file created from Smarket dataset (> write.csv(Smarket,file="Smarket.csv");
# * note: need to delete 1st column in resulting csv file before importing into sas;
# proc import out=Smarket dbms=dlm replace
#      datafile='\Cu-ynk-fsdeptsStatisticsTraining Courses and MaterialsStatisticalLearningCourseTextbookSmarket.csv';
#    getnames=yes;
#    delimiter=',';
#    guessingrows=100;
# run;
#
# * > names(Smarket);
# proc contents data=Smarket;
# run;
#
# * > summary(Smarket);
# proc univariate data=Smarket;
# run;
#
# * > cor(Smarket[,9]);
# proc corr data=Smarket;
# run;
#
# * > plot(Volume);
# data Smarket;
#    set Smarket;
#    Index + 1;
# run;
#
# proc sgplot data=Smarket;  * note: by default, places a png file in current folder;
#    scatter x=Index y=Volume;
# run;
#
# quit;
#
# Question # 3
# =============
# *From the dept of "too much free time," I created SAS programs to duplicate the output from the R code in the Chapter 4 Lab.;
#
# proc datasets memtype=data library=work kill; run;
# options nodate nonumber ps=68 ls=120 mprint mlogic sgen; title; footnote; ods graphics off;
#
# * csv file created from Smarket dataset (> write.csv(Smarket,file="Smarket.csv");
# * note: need to delete 1st column in resulting csv file before importing into sas;
# proc import out=Smarket dbms=dlm replace
#      datafile='\Cu-ynk-fsdeptsStatisticsTraining Courses and MaterialsStatisticalLearningCourseTextbookSmarket.csv';
#    getnames=yes;
#    delimiter=',';
#    guessingrows=100;
# run;
#
# ***** 4.6.2 Logistic Regression *****;
# title '4.6.2 Logistic Regression';
#
# * > glm.fit=glm(Direction~Lag1+Lag2+Lag3+Lag4+Lag5+Volume,data=Smarket,family=binomial)
#   > summary(glm.fit)
#   > glm.probs=predict(glm.fit,type ="response");
# proc logistic data=Smarket;
#    title2 'Full Model: All Data';
#    model Direction(event='Up') = Lag1 Lag2 Lag3 Lag4 Lag5 Volume;
#    output out=Preds resdev=DevResid predprobs=i;
# run;
#
# proc means data=Preds min p25 median p75 max;
#    var DevResid;
# run;
#
# * > glm.probs [1:10];
# proc print data=Preds (obs=10);
#    var IP_Up;
# run;
#
# * confusion matrix (http://support.sas.com/kb/22/603.html);
# * > glm.pred=rep("Down",1250)
#   > glm.pred[glm.probs > .5]="Up"
#   > table(glm.pred,Direction);
# proc freq data=Preds;
#    table _INTO_*Direction / out=CellCounts norow nocol nopercent;
# run;
#
# * calculate % logistic regression correctly predicted;
# * > mean(glm.pred==Direction);
# data CellCounts;
#    set CellCounts;
#    Match = 0;
#    if Direction = _INTO_ then Match = 1;
# run;
#
# proc means data=CellCounts mean;
#    freq count;
#    var Match;
# run;
#
# * create model from training data (year < 2005);
# * > train=(Year < 2005)
#   > Smarket.2005=Smarket[!train,]
#   > Direction.2005=Direction[!train];
# data TrainingData Smarket2005;
#    set Smarket;
#    if Year < 2005 then output TrainingData;
#      else output Smarket2005;
# run;
#
# * fit reduced model on training data and apply to test data;
# * > glm.fit=glm(Direction~Lag1+Lag2+Lag3+Lag4+Lag5+Volume,data=Smarket,family=binomial,subset=train);
# proc logistic data=TrainingData;
#    title2 'Full Model';
#    model Direction(event='Up') = Lag1 Lag2 Lag3 Lag4 Lag5 Volume;
#    * > glm.probs=predict(glm.fit,Smarket.2005,type="response");
#    score data=Smarket2005 out=Preds2;
# run;
#
# * confusion matrix on test data (http://support.sas.com/kb/22/603.html);
# * > glm.pred=rep("Down",252)
#   > glm.pred[glm.
#
# Question # 4
# =============
# *From the dept of "too much free time," I created SAS programs to duplicate the output from the R code in the Chapter 4 Lab.;
#
# proc datasets memtype=data library=work kill; run;
# options nodate nonumber ps=68 ls=120 mprint mlogic sgen; title; footnote; ods graphics off;
#
# * csv file created from Smarket dataset (> write.csv(Smarket,file="Smarket.csv");
# * note: need to delete 1st column in resulting csv file before importing into sas;
# proc import out=Smarket dbms=dlm replace
#      datafile='\Cu-ynk-fsdeptsStatisticsTraining Courses and MaterialsStatisticalLearningCourseTextbookSmarket.csv';
#    getnames=yes;
#    delimiter=',';
#    guessingrows=100;
# run;
#
# * create test & training datasets;
# data TrainingData Smarket2005;
#    set Smarket;
#    if Year < 2005 then output TrainingData;
#      else output Smarket2005;
# run;
#
# ***** 4.6.5 K-Nearest Neighbors *****;
# title '4.6.5 K-Nearest Neighbors';
#
# * model using k=1 (results may differ slightly from R b/c of ties/use of seed - i think);
# * > library(class)
#   > train.X=cbind(Lag1,Lag2)[train,]
#   > test.X=cbind(Lag1,Lag2)[!train,]
#   > train.Direction=Direction[train]
#   > set.seed(1)
#   > knn.pred=knn(train.X,test.X,train.Direction,k=1);
# proc discrim data=TrainingData testdata=Smarket2005 method=npar k=1 testout=Preds6 noprint;
#    title2 'K=1 Reduced Model: From Training Data Applied to Test Data';
#    class Direction;
#    var Lag1 Lag2;
#    priors proportional;
# run;
#
# * confusion matrix (http://support.sas.com/kb/22/603.html);
# * > table(knn.pred,Direction.2005);
# proc freq data=Preds6;
#    table _INTO_*Direction / out=CellCounts6 norow nocol nopercent;
# run;
#
# * calculate % correctly predicted;
# data CellCounts6;
#    set CellCounts6;
#    Match = 0;
#    if _INTO_ = Direction then Match = 1;
# run;
#
# proc means data=CellCounts6 mean;
#    freq count;
#    var Match;
# run;
#
# * model using k=3 (results may differ slightly from R b/c of ties/use of seed - i think);
# * > knn.pred=knn(train.X,test.X,train.Direction,k=3);
# proc discrim data=TrainingData testdata=Smarket2005 method=npar k=3 testout=Preds7 noprint;
#    title2 'K=3 Reduced Model: From Training Data Applied to Test Data';
#    class Direction;
#    var Lag1 Lag2;
#    priors proportional;
# run;
#
# * confusion matrix (http://support.sas.com/kb/22/603.html);
# * > mean(knn.pred==Direction.2005);
# proc freq data=Preds7;
#    table _INTO_*Direction / out=CellCounts7 norow nocol nopercent;
# run;
#
# * calculate % correctly predicted;
# data CellCounts7;
#    set CellCounts7;
#    Match = 0;
#    if _INTO_ = Direction then Match
#
# Question # 5
# =============
# *From the dept of "too much free time," I created SAS programs to duplicate the output from the R code in the Chapter 4 Lab.;
#
# proc datasets memtype=data library=work kill; run;
# options nodate nonumber ps=68 ls=120 mprint mlogic sgen; title; footnote; ods graphics off;
#
# * csv file created from Smarket dataset (> write.csv(Smarket,file="Smarket.csv");
# * note: need to delete 1st column in resulting csv file before importing into sas;
# proc import out=Smarket dbms=dlm replace
#      datafile='\Cu-ynk-fsdeptsStatisticsTraining Courses and MaterialsStatisticalLearningCourseTextbookSmarket.csv';
#    getnames=yes;
#    delimiter=',';
#    guessingrows=100;
# run;
#
# ***** 4.6.3 Linear Discriminant Analysis *****;
# title '4.6.3 Linear Discriminant Analysis';
#
# * create test & training datasets;
# data TrainingData Smarket2005;
#    set Smarket;
#    if Year < 2005 then output TrainingData;
#      else output Smarket2005;
# run;
#
# * fit an LDA model to the training data and apply it to the test data;
# * > lda.fit=lda(Direction~Lag1+Lag2,data=Smarket,subset=train)
#   > lda.pred=predict(lda.fit, Smarket.2005);
# proc discrim data=TrainingData testdata=Smarket2005 method=normal pool=yes simple testout=Preds4;
#    * 'pool=yes' performs LDA: 'the LDA classifier results from assuming ... a common variance';
#    title2 'Reduced Model: From Training Data Applied to Test Data';
#    class Direction;
#    priors proportional;  * 'In the absence of any additional information, LDA estimates pk using the ';
#    var Lag1 Lag2;        * 'proportion of the training observations that belong to the kth class     ';
# run;
#
# * confusion matrix (http://support.sas.com/kb/22/603.html);
# * > lda.class=lda.pred$class
#   > table(lda.class,Direction.2005);
# proc freq data=Preds4;
#    table _INTO_*Direction / out=CellCounts4 norow nocol nopercent;
# run;
#
# * calculate % correctly predicted;
# * > mean(lda.class==Direction.2005);
# data CellCounts4;
#    set CellCounts4;
#    Match = 0;
#    if _INTO_ = Direction then Match = 1;
# run;
#
# proc means data=CellCounts4 mean;
#    freq count;
#    var Match;
# run;
#
# * recreate the predictions using the posterior probabilities;
# * > sum(lda.pred$posterior[,1]>=.5)
#   > sum(lda.pred$posterior[,1]<.5)
#   > sum(lda.pred$posterior[,1]>.9);
# data Thresholds;
#    set Preds4 end=eof;
#    if Down ge 0.5 then N_AbovePoint5 + 1;
#    if Down < 0.5 then N_BelowPoint5 + 1;
#    if Down > 0.9 then N_AbovePoint9 + 1;
#    keep N_AbovePoint5 N_BelowPoint5 N_AbovePoint9;
#    if eof then output;
# run;
#
# proc print data=Thresholds;
# run;
#
# quit
#
# ******************************
# Important words for Topic #15:
#
# logistic logistic regression regression linear regression linear classification discriminant models discriminant analysis regression model multivariate logit glm gaussian watch
#
# ******************************
#
# Question # 1
# =============
# In the simplified LOOCV formula for linear and polynomial regression using leverages hi topic(Lec 5.2), is there a simplified formula for classification problems?
#
# Question # 2
# =============
# ![slide 18 in Ch4 classification][1]
#
#
#   [1]: https://edx-west-uploads.s3.amazonaws.com/1<phoneRedac><zipRedac>38466.jpg
#
# On slide 18 in Ch4 (as above), I don't quite follow why multiclass regression is formulated like this.
#
# - what's k? is it the total number of classes in Y?
# - what's the expected result from multiclass regression? possibility for each class of Y?
# - Do we need to determine which class the Y belongs to and how? what if possibilities are quite close?
#
# Question # 3
# =============
# Dear All,
#
# I liked the course a lot and I enjoy watching videos and playing with R. Unfortunately, due to busy schedule I am not able to watch all lectures and do all homework. I would like to know if course materials will be available after the end of the course. I really want to study all the topics of this wonderful MOOC.
#
# Many Thanks for your answers!
#
# Question # 4
# =============
# The lecture and text clearly prefer Discriminant analysis to a logistic regression when there are more than 2 classes (groupings).  If there are two, particularly a True/False sort or condition, is logistic as good?  Did I misunderstand something?
#
# Question # 5
# =============
# Hi,
# I had no internet for a week, and tried to do R practices with downloaded videos. It is impossible to read the text. I have a Laptop with windows 7 and QuickTime Player 7.7.5 not professional. Downloaded videos are not useful. I don't know if classmates have also this problem.
#
# ******************************
# Important words for Topic #16:
#
# lecture slides slides pdf lecture 30 page link hd chapter downloaded numbers slide class stanford humanitiesscience statlearning notes
#
# ******************************
#
# Question # 1
# =============
# Some of the questions make reference to "page X of the 'Notes.'" What are the notes? The textbook? The slide PDFs?
#
# Yes, I know it's dumb....
#
# Thanks in advance for your assistance.
#
# Question # 2
# =============
# How do I access the Course Notes?  I'm trying to catch up after missing a few weeks and one of the questions references a graph on page 30 of those notes but I'm unable to find them anywhere.
#
# Question # 3
# =============
# Where is this? Not textbooks?  Course material notes would be instructive and useful.  I should have asked sooner.   Thanks In Advance,  Charlie <nameRedac_<anon_screen_name_redacted>>  (Really enjoying the class)
#
# Question # 4
# =============
# I was unable to find the plot on page 30 of the NOTES that was referred to in the Quiz to determine what would happen if I moved the point to K.  Any insight on where the notes are would be helpful for future quizzes if they refer to the notes for anything.
# Thank you.
#
# Question # 5
# =============
# In 2.4.R1 there is a reference to page 30 of the lecture notes. I can't seem to find them -- the book doesn't have a graph on page 30, and the graph on the slides for this lecture doesn't make sense. I presume the reference is to figure 2.17 on page 42 of the book but would still like to find the notes.
# Thanks!
#
# ******************************
# Important words for Topic #17:
#
# solutions github manual nameredac_ official stat learning stat cheers community hi aware learning exercises working based
#
# ******************************
#
# Question # 1
# =============
# There are pretty good exercises at the end of each chapter in the book. Has anyone found answers for those exercises?
#
# Please share if anyone finds answers to those exercises.
#
# Question # 2
# =============
# Is it possible to get answer sheets for the book exercises each week, for those of us who want to practice more(especially in R)?
#
# Thanks
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 3
# =============
# Hi there,
#
# Is the solutions to the exercises in the text book available somewhere?
#
# Question # 4
# =============
# How can we get some feedback on our efforts with the textbook's exercises?
#
# Are there any solutions available?
#
# Could we perhaps have dedicated discussion threads for end-of-chapter exercises?
#
# Question # 5
# =============
# Forgive me if someone already asked this question and I just couldn't find it...
#
# Does anyone know where I can find the solutions to the problems in the ISLR book? As far as I can tell the course has no actual assignments beyond the short quizzes, and I think it would be useful for me to practice with the problem sets and check my work.
#
# Thanks for any help you can offer..
#
# ******************************
# Important words for Topic #18:
#
# ...
#
# Can anyone help me figure out where is mistake in my calculation?
#
# Question # 2
# =============
# According to the notes and the slide the equation is D = - sigma(pmk * log(pmk).
#
# When I answered the question, grader did not accept. After getting them wrong for 5 submission, I learned that the grader uses ln instead of log. Not sure which is right, the grader or the course notes. Can the instructor please clarify? Thanks, <nameRedac_<anon_screen_name_redacted>>
#
# Question # 3
# =============
# I would be so grateful if Professor Trevor and Professor Bob would please make clear in all use of logs whether they refer to log or ln, so that we do not have to guess what is their intent.
#
# I have had quite a few graduate courses in math, engineering, and finance and have yet to run across the use of log to indicate either log or ln.
#
# Professor Trevor and Professor Bob, please eliminate this possible source of error!
#
# Thank you very much.  Great course.
#
# Question # 4
# =============
# The formula on the slide shows a linear combination of $K+3$ base functions. This should be $K+1$ for linear splines. In general for degree $d$ splines, there are $K+d$ base functions. $K+3$ is for cubic splines.
#
# Question # 5
# =============
# The logarithmic base used in calculating cross entropy is not clear. In information coding theory normally base 2 is used. It looks like here the base e is used. Does it matter which base is used in calculating this? In my opinion it does not matter. is this true?
#
# ******************************
# Important words for Topic #23:
#
# volume cube dimensions dimension boundary hypercube square region length unit 50 distance area dimensional points
#
# ******************************
#
# Question # 1
# =============
# I have no clue how to begin this question. I assumed that when p = 50, we would have captured the majority of the hypercube, but how would one begin to calculate something like this?
#
# Question # 2
# =============
# Other than the general topic of dimensionality, I don't see anything in the presentation or reading that addresses determining the proportion of volume on the boundary of a p-dimensional hypercube.  This research seems relevant:  http://simple.wikipedia.org/wiki/Hypercube
#
# Question # 3
# =============
# I'm really confused about this hypercube stuff, can anyone explain what this question is asking? Thanks..
#
# Question # 4
# =============
# Does anyone have a suggestion for a smart approach to visualizing this question? I know abstractly that high dimensionality complicates the model and increases the spread of data points thus including non local neighbors. From this fact what is the next step to answer the question?
#
# Question # 5
# =============
# In the question 2.2 R2 in Chapter 2 I gave the answer calculated by formula
# 0.05^50 + (1 - 0.95^50) and according to class system it was wrong. I strongly disagree. Please explain, why my answer is wrong.
#
# ******************************
# Important words for Topic #24:
#
# cran project cran project packages package project caret packages html index pdf papers covariance paper installed try
#
# ******************************
#
# Question # 1
# =============
# Can we find the predictor importance by doing ANOVA and rank them on the basis of R-square(assuming that the predictors are uncorrelated)? Or shall we fit a linear model and rank them on the basis of coefficient absolute value?
#
# Question # 2
# =============
# When we talked about simple linear regression a few lectures ago we talked about hypothesis testing and statistical significance of coefficients. But in case of ridge and lasso they were not mentioned. My questions: are significance tests even important and/or relevant in such cases?  more broadly, what's the deal with hypothesis testing in high-dimensional datasets?
#
# Question # 3
# =============
# In response to Lecture 8.1 introducing decision trees, where the splits are only on variables one at a time (there were two variables in that case, `year` and `hits`), it occurred to me it could be beneficial to split instead in a bivariate manner. For example, one would first find an optimal bivariate boundary, which could be a curve or line involving both variables. And then recurse.
#
# Is anyone aware of a decision tree procedure that splits like this?
#
# Question # 4
# =============
# The regsubsets() function (leaps library) performs best subset selection by identifying the best linear model that contains a given number of predictors in **linear regression**.
#
# My question is: is it possible to use this function in a logistic regression? and if the answer is negative, is there an alternative function in R similar to regsubsts() but for logistic models?
#
# Thanks.
#
# Question # 5
# =============
# ** preparing package for lazy loading
# Error : package class was built before R 3.0.0: please re-install it
# ERROR: lazy loading failed for package e1071
#
# It's not that easy to install R packages! I had to install a newer version of R and now it seems that it's too new?
# What should I do?
#
# ******************************
# Important words for Topic #25:
#
# sales tv advertising units interaction 39 37 impact age 1000 main income figure effects increase
#
# ******************************
#
# Question # 1
# =============
# Can somebody please explain the solution? Thnx
#
# Question # 2
# =============
# The course slides (40/48 in chapter 3) state:
#
# "If we include an interaction in a model, we should also
# include the main eects, even if the p-values associated
# with their coecients are not signicant.
#
# Specically, the interaction terms also contain main effects,
# if the model has no main effect terms."
#
# I don't understand this statement.  Can anyone help me understand it?
#
# Question # 3
# =============
# I am pretty sure I got the idea of how to solve 3.5 R1 (well, the answer is correct at least), but applying the same exact procedure to 3.5 R2 (changing 50 to 250, of course) does not give me the correct answer... so I am wondering if there is something really basic that I am missing
#
# What I am doing is:
#
# eta_3}$
#
# I can get the same exact result in R by subtracting the predicted values from two prediction differing in $$1$ of radio advertising.
#
# So these two methods give the same results, but the answer is not correct for the $$250$ TV case, why is that?
#
# Question # 4
# =============
# Could someone please explain to me how I get the model for question 3.5.R1 I have tried to answer the question but I can't wrap my head around it?
# Thank you,
#
# Question # 5
# =============
# the data set description (pg 73. Table 3.3 description) specifies sales, TV and Radio advertising numbers are in 1000. that means would would have to plug in 50/1000 and 250/1000 in the formula, not 50 and 250 shown as the "correct" answer.
#
# Additionally, the question uses following format and assumptions: final answer assumes that you use all digits on the slide pg 37 of the slides ch3. (no rounding according to standard error). the final answer also asks you to estimate impact on the sales in 1000 units on $1 increase in radio advertising (but please refer to the first paragraph of the post on how they actually do it)
#
# ******************************
# Important words for Topic #26:
#
# x1 x2 x1 x2 xy x3 lm x1 typo interaction residuals interactions linear statistic relationship coefficient rdata
#
# ******************************
#
# Question # 1
# =============
# I do not understand how a linear method can caputer nonlinear effects. It is rather counterintuitive. I am sorry, I may have missed  it, but, it does not make sense to me.
#
# Question # 2
# =============
# I followed the minimum risk investment example but I am struggling applying this code to the lm(y~X1+X2). I don't understand how to adjust the "function" section of the code below. Any advice or help on this?
#
# ## Bootstrap
# ## Minimum risk investment - Section 5.2
#
# alpha=function(x,y){
#   vx=var(x)
#   vy=var(y)
#   cxy=cov(x,y)
#   (vy-cxy)/(vx+vy-2*cxy)
# }
# alpha(Portfolio$X,Portfolio$Y)
#
# ## What is the standard error of alpha?
#
# alpha.fn=function(data, index){
#   with(data[index,],alpha(X,Y))
# }
#
# alpha.fn(Portfolio,1:100)
#
# set.seed(1)
# alpha.fn (Portfolio,sample(1:100,100,replace=TRUE))
#
# boot.out=boot(Portfolio,alpha.fn,R=1000)
# boot.out
# plot(boot.out)
#
# Question # 3
# =============
# In the lab, the professor seemed to do these 2 ways, and I just want to clarify that I understand correctly.
#
# lm(y ~. Xvar1 :Xvar 2) --This says test all variables but ALSO test the interaction between X1 and X2
#
# lm(y ~ Y ~ X1*X2)
#
# (I get there is more code to make this valid, but this is the part I want to understand better)
#
# With the exception of the number of variables being tested, are the interactions the same
#
# Ex. can I do X1 * X2 or X1:X2 to signify an interaction, or are they for different purposes(ex. in the : approach, he uses all variables AND the interaction, whereas in the * it's 1 variable + 1 interaction)
#
# Question # 4
# =============
# I have just recently joined this course but already found it very interesting and helpful. I just would like to have one small comment. It would be great if the lectures on linear regression have a small section on "interaction and collinearity" between predictors; specifically how one would check the model for and deal with that as I have seen quite a few people in general having questions related to this e.g. centering the main effects in model with interaction to avoid collinearity, etc.
#
# Question # 5
# =============
# Question 7.Q.1 choice 2 is worded as follows:
#
# "2) Then, fit a cubic spline model for **r** against X2 to obtain f^2(x)."
#
# Shouldn't it be:
#
# "2) Then, fit a cubic spline model for ***y*** against X2 to obtain f^2(x)."?
#
# ******************************
# Important words for Topic #27:
#
# predictors variable variables dummy predictor levels model response correlated categorical dummy variables correlation dependent effect intercept
#
# ******************************
#
# Question # 1
# =============
# As shown in slide 15/40 of the classification presentation:
#
# When a model is built with multiple correlated variables (say ldl and obesity) the model only assigns significance to one of the variables. Is this a random process? or does it go for the "best" one.
#
# If one of the variables is better than the others, then how is it better? ie. How is each variable judged?
#
# Question # 2
# =============
# In the lecture, professor used two dummy variables to represent ethnicity. I am curious about why he chose two dummy variables instead of one. Can we use only one dummy variable in this scenario?
#
# x_i =
#
#       2  if ith person is Asian
#       1  if ith person is Caucasian
#       0  if ith person is AA
#
# Question # 3
# =============
# Can anyone explain to me the "-1"?
#
#     x=model.matrix(Salary~.-1,data=Hitters)
#
# Question # 4
# =============
# In particular, it has been mentioned that for PCA and SVM, that the X variables should be scaled to have variance 1. This suggests to me that categorical variables present a problem.
#
# So, can these methods be used when you have categorical X variables and if so how is it done?
#
# Question # 5
# =============
# Hi all,
# I have a concern about the significance when using a categorial variable.
# First, for example if we have a categorical variable with three levels.. then I understood that pvalues (except the intercept)are the result of testing this level against the first level (i.e the base line)... so then, what does the pvalue in the intercept mean?
#
# Second, in the quizz is proposed the following:
# According to the balance vs ethnicity model, what is the predicted balance for an Asian in the data set?
#
# If the categorial variable is not significant, why do we have to sum beta0+betaAsian?
# I thought that due to its non significant effect all etnias have the same value, i.e., beta 0
#
# Thank you very much for your ideas and help
#
# ******************************
# Important words for Topic #28:
#
# certificate progress accomplishment march april 50 2014 quizzes 21 page info course 00 email quiz
#
# ******************************
#
# Question # 1
# =============
# Will we receive a personalized certificate in case of satisfactory work?
#
# Question # 2
# =============
# My progress says 99% done (I got some incorrect answers).
#
# Do I do nothing now?
#
# Also, how do you know my mailing address. I look at my profile and I don't see an address.
#
# Question # 3
# =============
# Dear Team,
#
# I am excited to learn the material in the class.
#
# However, I am interested to know the score required for the Statement of Accomplishment.
#
# Cheers,
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 4
# =============
# It was said "The deadline for completing all the requirements to get your Statement of Accomplishment is March 21." But what was the criteria for completing, I have failed in answer couple of the exercises, will I get the accomplishment statement or not. From the progress page I see my progress is 94% for the time being.
#
# Thanks!
#
# Question # 5
# =============
# Will I receive a certificate of accomplishment even though I finished the course today, April 2nd. I thought that since the course was extended that the certificate of accomplishment would be extended to the new class end time.
#
# ******************************
# Important words for Topic #29:
#
# data frame frame predict pred lm pca dat matrix train lm data rnorm fit data fit lm test
#
# ******************************
#
# Question # 1
# =============
# it seems like everybody got close, like for instance getting 1.06 for 10.R.2 and 3.66 for 10.R.3.
# it would be great to have a correction that gives exact answers !
#
# thks
#
# Question # 2
# =============
# How to extract the first five principal component? I know how to use regression on y with five variables and how to get mss, but I do not know how to connect them with R
#
# Question # 3
# =============
# Hi,
#
# I am struggling to build a regression model from the PCA results as is alluded to in 10.R.2:
#
# "What is the mean-squared test error if we regress y on the first five principal components, and use the resulting model to predict y.test?"
#
# I do a prcomp and extract the training values for the principal components
# pc1 <-prcomp(rbind(x, x.test));
# fit <- lm(y ~pc1$x[1:300,1]+pc1$x[1:300,2]+pc1$x[1:300,3]+pc1$x[1:300,4]+pc1$x[1:300,5])
#
# But I am unable to use a predict function using this model ?
#
# Question # 4
# =============
# Hi,
# I can see the first five principle components , when i do a summary, but I am not sure how to use them as the new predictors , do i extract and store the first five in a separate variable. Sorry I have never used R before, so confused a little.
#
#
# <nameRedac_<anon_screen_name_redacted>>
#
# Question # 5
# =============
# I suppose you evaluate the "latent variables" via the first 5 principal components of the "merged matrix" x, x.test. That way you get 5 variables  and 1300 observations. On the other hand, to "regress y on the first 5 p.c." you do the same thing to y, and get one variable with 300!!! observations. Isn't there something weird here?
#
# ******************************
# Important words for Topic #30:
#
# interval confidence confidence interval 95 intervals parameter confidence intervals null hypothesis null hypothesis true contain value probability distribution
#
# ******************************
#
# Question # 1
# =============
# Is the third choice missing an explicit mention of an assumption?
#
# Question # 2
# =============
# I don't understand the difference between the second and third answers of quiz 3.1.R2.  If the confidence interval contains the true value 95% of the time, than any one confidence interval has a 95% chance of containing the true value.
#
# Question # 3
# =============
# Does the last choice question relate to multivariate regression without interaction terms or is it supposed to apply to all classes of multivariate regressions? I'm quite confused about its wording and would love to get some clarifications.
#
# Question # 4
# =============
# I agree with this statement, but the professors do not. What is wrong with this statement?
#
# Question # 5
# =============
# How can we calculate the t statistics without degrees of freedom?

# %% [markdown]
# ##Find cosine similarity between comments and the various topics as determined by NMF
# > Output: questions are "closest" to these NMF topics (as measured by cosine distances?)

# %%
topics_bag = []
for topic_idx, topic in enumerate(nmf.components_):
    words = [feature_names[i] for i in topic.argsort()[::-1]]
    scores = [topic[i] for i in topic.argsort()[::-1]]
    topics_bag.append(zip(scores, words))

# topics_array = pd.DataFrame(topics_bag[1])
# topics_array.T
# sparse.csr_matrix(topics_array)
print len(topics_bag[1])
print "-----------------------------"
#print X[1]
# Out:
# 1591
# -----------------------------

# %%
# cosine_similarities = linear_kernel(tfid, tfid)

# most_similar_index = []
# for similar in cosine_similarities:
#     most_similar_index.append(similar.argsort()[-10:][::-1])

# print len(most_similar_index)

# %%
#Word clouds
# import vincent
# vincent.core.initialize_notebook()

# for topic_idx, topic in enumerate(nmf.components_):
#     print("Topic #%d:" % topic_idx)
#     tmpDic = {}
#     for i in topic.argsort()[:-50 - 1:-1]:
#         tmpDic[feature_names[i]] = topic[i]*100
#     vincent.Word(tmpDic).display();

# %%
#Write file to EXCEL for labeling each comment by hand
# import csv
# reload(sys)
# sys.setdefaultencoding("utf-8")

# myfile = csv.writer(open("grouped_comments.csv", 'wb'))
# for g in grouped_comments:
#     myfile.writerow([g])
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes to improve accuracy

# %% [markdown]
# ##Latent Dirichlet Allocation (LDA) by using `gensim` library
#
# > Gensim unfortunately isn't sklearn friendly.
#
# > Take corpus again and run it through the mmcorpus. Then use it for LDA model in gensim.

# %%
#NLTK-generated corpus vector
stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words)

def cleanDoc(doc):
    stopset = stop_words
    stemmer = nltk.PorterStemmer()
    lemmatizer = nltk.WordNetLemmatizer()
    tokens = WordPunctTokenizer().tokenize(doc)
    clean = [token.lower() for token in tokens if token.lower() not in stopset and len(token) > 2]
    stemmed = [stemmer.stem(word) for word in clean]
    final = [lemmatizer.lemmatize(word) for word in stemmed]
    return final


cleaned = []
for line in grouped_comments:
    cleaned.append(' '.join(cleanDoc(line)))

class MyCorpus(object):
    def __iter__(self):
        for line in cleaned:
            yield dictionary.doc2bow(line.lower().split())

corpus = MyCorpus()
len(cleaned)
# Out:
# 1074

# %%
#corpus = gensim.matutils.Sparse2Corpus(X.T) #corpus vector directly from scipy sparse matrix
stop_words = txt.ENGLISH_STOP_WORDS.union(additional_stop_words)

# collect statistics about all tokens
dictionary = corpora.Dictionary(line.lower().split() for line in cleaned)

# remove stop words and words that appear only once
stop_ids = [dictionary.token2id[stopword] for stopword in stop_words 
            if stopword in dictionary.token2id]
once_ids = [tokenid for tokenid, docfreq in dictionary.dfs.iteritems() 
            if docfreq == 1 or docfreq == 2 or docfreq == 3 or docfreq == 4]
dictionary.filter_tokens(stop_ids + once_ids) # remove stop words and words that appear only once
dictionary.compactify() # remove gaps in id sequence after words that were removed
dictionary.save('questions.dict')
print(dictionary)

corpora.MmCorpus.serialize('questions.mm', corpus)
corpora.SvmLightCorpus.serialize('questions.svmlight', corpus)
corpora.BleiCorpus.serialize('questions.lda-c', corpus)
#corpora.LowCorpus.serialize('questions.low', corpus)

# ##Then the dictionary and corpus can be used to train using LDA

mm = corpora.MmCorpus('questions.mm')
blei = corpora.BleiCorpus('questions.lda-c')
#low = corpora.LowCorpus('questions.low')
# Out:
# Dictionary(1742 unique tokens)

# %%
print(mm)
# Out:
# MmCorpus(1074 documents, 1742 features, 49135 non-zero entries)

# %%
#LDA model
import warnings
warnings.filterwarnings('ignore')

t0 = time()

lda = gensim.models.ldamodel.LdaModel(corpus = blei, 
                                      id2word = dictionary, 
                                      num_topics = n_topics, 
                                      #update_every = 1, 
                                      #chunksize = 10000, 
                                      passes = 4,
                                      )
print("LDA done in %0.3fs." % (time() - t0))
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes to improve accuracy
# LDA done in 48.835s.

# %%
for i in range(0, lda.num_topics-1):
    print lda.print_topic(i)
# Out:
# 0.029*miss + 0.026*data + 0.018*page + 0.015*use + 0.014*observ + 0.013*variabl + 0.012*pdf + 0.011*imput + 0.011*work + 0.011*fold
# 0.087*watch + 0.018*cours + 0.015*video + 0.012*download + 0.010*like + 0.009*model + 0.009*regress + 0.008*thank + 0.008*use + 0.007*question
# 0.023*use + 0.023*cours + 0.016*data + 0.013*time + 0.012*>.< + 0.011*book + 0.010*work + 0.010*like + 0.010*just + 0.009*exercis
# 0.068*data + 0.045*bootstrap + 0.037*block + 0.031*point + 0.020*sampl + 0.013*set + 0.012*function + 0.012*time + 0.010*age + 0.009*observ
# 0.019*use + 0.012*just + 0.011*linear + 0.011*math + 0.011*model + 0.009*adjust + 0.009*cours + 0.008*work + 0.008*regress + 0.008*question
# 0.022*variabl + 0.019*use + 0.017*error + 0.016*data + 0.016*observ + 0.015*model + 0.013*exampl + 0.013*respons + 0.012*think + 0.010*test
# 0.047*video + 0.030*quiz + 0.023*credit + 0.019*point + 0.016*click + 0.014*section + 0.014*edx + 0.014*imag + 0.013*icon + 0.012*amazonaw
# 0.035*use + 0.019*data + 0.015*function + 0.013*nameredac_ + 0.012*work + 0.010*tsboot + 0.009*statist + 0.009*just + 0.009*answer + 0.009*tri
# 0.034*plot + 0.023*use + 0.013*look + 0.011*valu + 0.011*balanc + 0.011*like + 0.010*... + 0.010*time + 0.010*number + 0.010*function
# 0.026*estim + 0.024*error + 0.023*valu + 0.023*interv + 0.019*sampl + 0.017*data + 0.015*confid + 0.014*mean + 0.014*standard + 0.014*distribut
# 0.038*variabl + 0.034*model + 0.021*correl + 0.017*data + 0.016*bia + 0.015*use + 0.013*varianc + 0.012*error + 0.011*mean + 0.010*regress
# 0.027*download + 0.027*file + 0.025*video + 0.022*data + 0.022*packag + 0.019*use + 0.018*islr + 0.018*work + 0.016*instal + 0.011*tri
# 0.044*data + 0.020*variabl + 0.017*fit + 0.017*eta_1 + 0.014*eta_0 + 0.013*column + 0.012*intercept + 0.012*probabl + 0.011*model + 0.010*matrix
# 0.030*question + 0.019*answer + 0.014*think + 0.014*probabl + 0.011*sampl + 0.011*point + 0.011*dimens + 0.009*correct + 0.009*number + 0.008*valu
# 0.061*cours + 0.052*class + 0.051*humanitiessci + 0.035*thread + 0.031*discus + 0.030*forum + 0.030*statlearn + 0.028*stanford + 0.026*nameredac_ + 0.024*winter2
# 0.030*answer + 0.020*sampl + 0.018*data + 0.014*differ + 0.014*... + 0.013*question + 0.012*mpg + 0.012*valu + 0.012*formula + 0.012*train
# 0.048*model + 0.029*linear + 0.022*use + 0.019*error + 0.014*variabl + 0.014*regress + 0.011*data + 0.010*varianc + 0.007*select + 0.007*respons
# 0.053*tree + 0.013*split + 0.012*use + 0.012*variabl + 0.011*book + 0.011*packag + 0.010*pdf + 0.010*springer + 0.009*discount + 0.009*data
# 0.082*regress + 0.056*logist + 0.054*watch + 0.029*linear + 0.023*classif + 0.019*model + 0.018*multivari + 0.017*use + 0.016*analysi + 0.014*introduct
# 0.078*matrix + 0.040*mean + 0.022*rnorm + 0.020*rep + 0.017*row + 0.014*learn + 0.013*500 + 0.012*ident + 0.012*data + 0.012*vector
# 0.057*null + 0.031*error + 0.030*hypothesi + 0.026*standard + 0.021*reject + 0.021*statist + 0.017*>.< + 0.014*interv + 0.013*valu + 0.012*sampl
# 0.019*function + 0.014*cube + 0.014*volum + 0.014*fit + 0.013*data + 0.012*linear + 0.012*boundari + 0.012*hat + 0.011*squar + 0.010*line
# 0.029*set + 0.026*test + 0.022*??? + 0.019*data + 0.018*train + 0.016*prime + 0.016*use + 0.015*variabl + 0.013*sampl + 0.012*reg
# 0.030*model + 0.023*set + 0.019*radio + 0.019*interact + 0.014*data + 0.013*select + 0.012*use + 0.010*just + 0.009*term + 0.009*fit
# 0.063*test + 0.051*model + 0.033*data + 0.021*fit + 0.020*train + 0.019*set + 0.018*use + 0.015*error + 0.014*lasso + 0.014*predict
# 0.035*fit + 0.034*data + 0.027*use + 0.022*set + 0.021*model + 0.020*error + 0.016*predict + 0.016*test + 0.015*train + 0.012*valid
# 0.072*cours + 0.038*learn + 0.019*statist + 0.019*thank + 0.012*class + 0.012*book + 0.011*use + 0.010*look + 0.010*like + 0.009*good
# 0.021*use + 0.015*log + 0.013*hat + 0.013*regress + 0.011*eta + 0.011*coeffici + 0.011*squar + 0.010*point + 0.010*equat + 0.010*variabl
# 0.030*packag + 0.027*function + 0.023*use + 0.018*variabl + 0.014*data + 0.011*plot + 0.010*exampl + 0.010*problem + 0.010*tri + 0.010*need

# %%
#Matching NMF topics with LDA topics

nmf_lda=[]
for topic_idx, topic in enumerate(nmf.components_):
    words = [feature_names[i] for i in topic.argsort()[:-(n_top_words):-1]]
    nmf_lda.append(lda[dictionary.doc2bow(words)])

for k, v in enumerate(nmf_lda): 
    print "NMF topic: #", k, "matching LDA topic: #", max(nmf_lda[k])[0]
# Out:
# NMF topic: # 0 matching LDA topic: # 25
# NMF topic: # 1 matching LDA topic: # 14
# NMF topic: # 2 matching LDA topic: # 11
# NMF topic: # 3 matching LDA topic: # 11
# NMF topic: # 4 matching LDA topic: # 18
# NMF topic: # 5 matching LDA topic: # 26
# NMF topic: # 6 matching LDA topic: # 3
# NMF topic: # 7 matching LDA topic: # 11
# NMF topic: # 8 matching LDA topic: # 28
# NMF topic: # 9 matching LDA topic: # 24
# NMF topic: # 10 matching LDA topic: # 11
# NMF topic: # 11 matching LDA topic: # 25
# NMF topic: # 12 matching LDA topic: # 8
# NMF topic: # 13 matching LDA topic: # 11
# NMF topic: # 14 matching LDA topic: # 18
# NMF topic: # 15 matching LDA topic: # 0
# NMF topic: # 16 matching LDA topic: # 7
# NMF topic: # 17 matching LDA topic: # 11
# NMF topic: # 18 matching LDA topic: # 6
# NMF topic: # 19 matching LDA topic: # 15
# NMF topic: # 20 matching LDA topic: # 19
# NMF topic: # 21 matching LDA topic: # 27
# NMF topic: # 22 matching LDA topic: # 21
# NMF topic: # 23 matching LDA topic: # 17
# NMF topic: # 24 matching LDA topic: # 19
# NMF topic: # 25 matching LDA topic: # 25
# NMF topic: # 26 matching LDA topic: # 29
# NMF topic: # 27 matching LDA topic: # 6
# NMF topic: # 28 matching LDA topic: # 25
# NMF topic: # 29 matching LDA topic: # 20

# %% [markdown]
# ## Topic Model using Anchor word algorithm
#
# - "Separability requires that each topic has some near-perfect indicator word – a word that we call the anchor word for this topic— that appears with reasonable probability in that topic but with negligible probability in all other topics (e.g., “soccer” could be an anchor word for the topic “sports”). We give a formal definition in Section 1.1. This property is particularly natural in the context of topic modeling, where the number of distinct words (dictionary size) is very large compared to the number of topics. In a typical application, it is common to have a dictionary size in the thousands or tens of thousands, but the number of topics is usually somewhere in the range from 50 to 100. Note that separability does not mean that the anchor word always occurs (in fact, a typical document may be very likely to contain no anchor words). Instead, it dictates that when an anchor word does occur, it is a strong indicator that the corresponding topic is in the mixture used to generate the document." -- [A Practical Algorithm for Topic Modeling with Provable Guarantees](http://arxiv.org/pdf/1212.4777.pdf) by Sanjeev Arora; Rong Ge; Yonatan Halpern; David Mimno; Ankur Moitra; David Sontag; Yichen Wu; Michael Zhu

# %%
import os

os.popen("/usr/local/Cellar/stanford-parser/3.3.1/libexec/lexparser.sh /usr/local/Cellar/stanford-parser/3.3.1/libexec/stupid.txt > ~/Desktop/parsed.txt")
# Out:
# <open file '/usr/local/Cellar/stanford-parser/3.3.1/libexec/lexparser.sh /usr/local/Cellar/stanford-parser/3.3.1/libexec/stupid.txt > ~/Desktop/parsed.txt', mode 'r' at 0x1140d3810>
